# %%
# ! /users/amr1/pho4/data/genome/bigWigMerge data/cbf1_nexus/sc_myc_cbf1_nexus_1_positive.bw data/cbf1_nexus/sc_myc_cbf1_nexus_2_positive.bw data/cbf1_nexus/positive_strand.bedGraph
# ! /users/amr1/pho4/data/genome/bedGraphToBigWig data/cbf1_nexus/positive_strand.bedGraph data/genome/saccer/sacCer3.chrom.sizes data/cbf1_nexus/pos.bw

# %%
# import pyBigWig
# from itertools import *

# def customSort(val):
#       chrom_number = "".join(takewhile(str.isalpha,val[0]))
#       start = val[0].replace(chrom_number,"")
#       return int(start)

# # Data loader that accepts multiple replicates and adds them together
    
# class DataLoader(object):
    
#     def __init__(self, replicates):
#         """
#         Args:
#             replicates (list of bigwig files)
#         """
#         self.replicates = replicates
    
#     def merge(self):
#       bigWigs = []
#       # bw_pos1.chroms() - remember to save the chromosomes dict into a variable
#       # num_chroms = 16 # don't need this anymore b/c length of chromosomes dict
      
#       # opening bw files.
#       for idx in range(len(self.replicates)):
#         bigWigs.append(pyBigWig.open(self.replicates[idx]))
        
#       chrms = ["chrI","chrII","chrIII","chrIV","chrV","chrVI","chrVII","chrVIII",
#                "chrIX","chrX","chrXI","chrXII","chrXIII","chrXIV","chrXV","chrXVI","chrM"]
        
#       # retrieve values. save to new array, then save that to new bw file.
#       combined_dict = {}
#       for c in chrms:
#         for j in range(len(bigWigs)):
#           intervals = bigWigs[j].intervals(c)
#           for i in intervals:
#             start = i[0]
#             end = i[1]
#             val = i[2]
#             for k in range(start,end):
#               if (c+str(start)) in combined_dict:
#                 combined_dict[c+str(start)]+=val
#               else:
#                 combined_dict[c+str(start)]=val
      
#       # sort combined_dict
#       # SORT EACH CHROMOSOME AT A TIME, THEN ADD TO DICTIONARY
#       sorted_dict = {}
#       flag = True
#       chrom_list = []
#       prev_chrom_num = ""

#       for key in combined_dict:
#         chrom_number = "".join(takewhile(str.isalpha,key))
#         if (flag or chrom_number==prev_chrom_num):
#           chrom_list.append((key,combined_dict[key]))
#         else:
#           chrom_list.sort(key=customSort)
#           # append to new dictionary
#           # code here:
#           for entry in chrom_list:
#             sorted_dict[entry[0]]=entry[1]
#           chrom_list = []
#           chrom_list.append((key,combined_dict[key]))
#         flag = False
#         prev_chrom_num=chrom_number
   
      
#       # sorted_dict format
#       """
#       Key: chrom number + start, ex: "chrI324"
#       Value: the sum of the values in the bigwig files
#       """
#       return sorted_dict 
    
#     def getChromNums(self):
#       # get an ordered list of the chromosome numbers
#       ch_num = []
#       for key in self.merge():
#           chrom_number = "".join(takewhile(str.isalpha,key))
#           ch_num.append(chrom_number)
#       return np.array(ch_num)
    
#     def getChromStart(self):
#       # get an ordered list of the chromosome start positions
#       ch_start = []
#       for key in self.merge():
#         chrom_number = "".join(takewhile(str.isalpha,key))
#         start = key.replace(chrom_number,"")
#         ch_start.append(int(start))
#       return np.array(ch_start)
    
#     def getChromEnd(self):
#       # get an ordered list of the chromosome end positions. 1 base pair long so end pos is 1 more than start.
#       ch_end = []
#       for entry in self.getChromStart():
#         ch_end.append(entry+1)
#       return np.array(ch_end)
    
#     def getChromVals(self):
#       # get an ordered list of the chromosome values.
#       ch_vals = []
#       vals_dict = self.merge() 
#       for key in vals_dict:
#         ch_vals.append(vals_dict[key])
#       return np.array(ch_vals)

# %%
# import pyBigWig
# import numpy as np

# data_loader = DataLoader(["data/cbf1_nexus/sc_myc_cbf1_nexus_1_negative.bw", "data/cbf1_nexus/sc_myc_cbf1_nexus_2_negative.bw"])
# data_loader.merge();
# neg_bw = pyBigWig.open("data/cbf1_nexus/neg.bw","w")
# neg_bw.addHeader([("chrI",230218),("chrII",813184),("chrIII",316620),("chrIV",1531933),("chrV",576874),("chrVI",270161),("chrVII",1090940),("chrVIII",562643),("chrIX",439888),("chrX",745751),("chrXI",666816),("chrXII",1078177),("chrXIII",924431),("chrXIV",784333),("chrXV",1091291),("chrXVI",948066),("chrM",85779)])
# neg_bw.addEntries(data_loader.getChromNums(),data_loader.getChromStart(),ends=data_loader.getChromEnd(),values=data_loader.getChromVals())
# neg_bw.close()

# %%
# # in the dir, execute
# cat sc_myc_cbf1_nexus_1_peaks.narrowPeak sc_myc_cbf1_nexus_2_peaks.narrowPeak | perl -lane 'print $F[0]."\t".$F[1]."\t".$F[2]."\t".(($F[1]+$F[9]))' | sortBed > pooled_peaks.bed

# %%
# ! bedtools merge -d 10 -c 4 -o collapse -i data/cbf1_nexus/pooled_peaks.bed > data/cbf1_nexus/merged_peaks.bed
# ! bedtools intersect -wa -a data/cbf1_nexus/merged_peaks.bed -b data/cbf1_nexus/sc_myc_cbf1_nexus_1_peaks.narrowPeak -F 0.5 > data/cbf1_nexus/intermediate
# ! bedtools intersect -wa -a data/cbf1_nexus/intermediate -b data/cbf1_nexus/sc_myc_cbf1_nexus_2_peaks.narrowPeak -F 0.5 > data/cbf1_nexus/intermediate2

# %%
# import os
# import numpy as np

# readfile = open('data/cbf1_nexus/intermediate2', 'r')
# writefile = open('data/cbf1_nexus/intermediate3', 'w')
# for idx, line in enumerate(readfile):
#     chrm, start, end, coords = line.strip().split('\t')
#     summits = coords.strip().split(',')
#     for summit in summits: writefile.write(chrm+"\t"+summit+"\t"+summit+"\t.\t"+summit+"\n")
# writefile.close()

# %%
# # in the dir, execute
# cat intermediate3 | bedtools slop -g ~/pho4/data/genome/saccer/sacCer3.chrom.sizes -b 200 | perl -lane 'if ($F[2]-$F[1]==400) {print $F[0]."\t".$F[1]."\t".$F[2]."\t.\t".$F[4]}' | sortBed  > overlap.peaks.bed
# cat overlap.peaks.bed | egrep -w 'chrI|chrVI' | gzip -c > test.bed.gz ; cat overlap.peaks.bed | egrep -w 'chrIX' | gzip -c > valid.bed.gz ; cat overlap.peaks.bed | egrep -w -v 'chrI|chrVI|chrIX' | gzip -c > train.bed.gz

# %% [markdown]
# Train Model

# %%
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers
# Out:
# Using TensorFlow backend.
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import numpy as np
import gzip
import keras
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import keras_genomics
from keras_genomics.layers.convolutional import RevCompConv1D
import keras
import keras.layers as kl
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers

def multinomial_nll(true_counts, logits):
    """Compute the multinomial negative log-likelihood
    Args:
      true_counts: observed count values
      logits: predicted logit values
    """
    counts_per_example = tf.reduce_sum(true_counts, axis=-1)
    dist = tfp.distributions.Multinomial(total_count=counts_per_example,
                                         logits=logits)
    return (-tf.reduce_sum(dist.log_prob(true_counts)) / 
            tf.to_float(tf.shape(true_counts)[0]))


#from https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/losses.py#L87
class MultichannelMultinomialNLL(object):
    def __init__(self, n):
        self.__name__ = "MultichannelMultinomialNLL"
        self.n = n

    def __call__(self, true_counts, logits):
        for i in range(self.n):
            loss = multinomial_nll(true_counts[..., i], logits[..., i])
            if i == 0:
                total = loss
            else:
                total += loss
        return total

    def get_config(self):
        return {"n": self.n}

#If we want to avoid zero-padding, then the input seq len will be determined
# by parameters of the convolutions
class AbstractProfileModel(object):

    def get_output_profile_len(self):
        raise NotImplementedError()

    def get_model(self):
        raise NotImplementedError()

def trim_flanks_of_conv_layer(conv_layer, output_len, width_to_trim, filters):
    layer = keras.layers.Lambda(
        lambda x: x[:,
          int(0.5*(width_to_trim)):-(width_to_trim-int(0.5*(width_to_trim)))],
        output_shape=(output_len, filters))(conv_layer)
    return layer

#model architecture is based on 
#https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/models.py#L534
#The non-cli parameters are specified in:
# https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/src/chipnexus/train/seqmodel/joint-model-valid.gin
#The cli parameters are in line 165 of:
# https://docs.google.com/spreadsheets/d/1n3l2HXKSNpmNUOifD41uRzDEAgmOqXMQDxquRaz6WLg/edit#gid=0
# which seems to match https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/src/chipnexus/train/seqmodel/ChIP-seq-default.gin
class RcBPnetArch(AbstractProfileModel):   

    def __init__(self, input_seq_len, c_task_weight, filters,
                       n_dil_layers, conv1_kernel_size,
                       dil_kernel_size,
                       outconv_kernel_size, lr):
        self.input_seq_len = input_seq_len
        self.c_task_weight = c_task_weight
        self.filters = filters
        self.n_dil_layers = n_dil_layers
        self.conv1_kernel_size = conv1_kernel_size
        self.dil_kernel_size = dil_kernel_size
        self.outconv_kernel_size = outconv_kernel_size
        self.lr = lr

    def get_embedding_len(self):
        embedding_len = self.input_seq_len
        embedding_len -= (self.conv1_kernel_size-1)     
        for i in range(1, self.n_dil_layers+1):
            dilation_rate = (2**i)
            embedding_len -= dilation_rate*(self.dil_kernel_size-1)
        return embedding_len

    def get_output_profile_len(self):
        embedding_len = self.get_embedding_len()
        out_profile_len = embedding_len - (self.outconv_kernel_size - 1)
        return out_profile_len

    def get_keras_model(self):

        out_pred_len = self.get_output_profile_len()

        inp = kl.Input(shape=(self.input_seq_len, 4), name='sequence')
        first_conv = RevCompConv1D(filters=self.filters,
                               kernel_size=self.conv1_kernel_size,
                               padding='valid',
                               activation='relu')(inp)
        curr_layer_size = self.input_seq_len - (self.conv1_kernel_size-1)

        prev_layers = [first_conv]
        for i in range(1, self.n_dil_layers + 1):
          dilation_rate = 2**i
          if i == 1:
              prev_sum = first_conv
          else:
              print(prev_layers)
              prev_sum = kl.merge.Average()(prev_layers)
          conv_output = RevCompConv1D(filters=self.filters,
                                  kernel_size=self.dil_kernel_size,
                                  padding='valid',
                                  activation='relu',
                                  dilation_rate=dilation_rate)(prev_sum)          
          width_to_trim = dilation_rate*(self.dil_kernel_size-1)
          curr_layer_size = (curr_layer_size - width_to_trim)
          prev_layers = [trim_flanks_of_conv_layer(
              conv_layer=x, output_len=curr_layer_size,
              width_to_trim=width_to_trim, filters=2*self.filters)
              for x in prev_layers]
          prev_layers.append(conv_output)

        combined_conv = kl.merge.Average()(prev_layers)

        #Counts prediction
        gap_combined_conv = kl.GlobalAvgPool1D()(combined_conv)
        count_out = kl.Reshape((-1,), name="task0_logcount")(
            RevCompConv1D(filters=1, kernel_size=1)(
              kl.Reshape((1,-1))(gap_combined_conv)))
#                   kl.concatenate([
#                   #concatenation of the bias layer both before and after
#                   # is needed for rc symmetry
#                   kl.Lambda(lambda x: x[:, ::-1])(bias_counts_input),
#                   gap_combined_conv,
#                   bias_counts_input], axis=-1))))

        profile_out_prebias = RevCompConv1D(
                               filters=1,
                               kernel_size=self.outconv_kernel_size,
                               padding='valid')(combined_conv)
        profile_out = RevCompConv1D(
            filters=1, kernel_size=1, name="task0_profile")(profile_out_prebias)
#                     kl.concatenate([
#                         #concatenation of the bias layer both before and after
#                         # is needed for rc symmetry
#                         kl.Lambda(lambda x: x[:, :, ::-1])(bias_profile_input),
#                         profile_out_prebias,
#                         bias_profile_input], axis=-1))

        model = keras.models.Model(
          inputs=[inp],
          outputs=[count_out, profile_out])
        model.compile(keras.optimizers.Adam(lr=self.lr),
                      loss=['mse', MultichannelMultinomialNLL(2)],
                      loss_weights=[self.c_task_weight, 1])
        return model

# %%
seq_len = 546 # remember to update

modelwrapper = RcBPnetArch(
    input_seq_len=seq_len, c_task_weight=100,
    filters=25,
    n_dil_layers=6,
    conv1_kernel_size=21,
    dil_kernel_size=3,
    outconv_kernel_size=25,
    lr=0.001)
out_pred_len = modelwrapper.get_output_profile_len()
print(out_pred_len, seq_len-out_pred_len)
# Out:
# 250 296

# %%
# seq_len = 546 # remember to update

# modelwrapper = RcBPnetArch(
#     input_seq_len=seq_len, c_task_weight=100,
#     filters=64,
#     n_dil_layers=6,
#     conv1_kernel_size=21,
#     dil_kernel_size=3,
#     outconv_kernel_size=75,
#     lr=0.001)
# out_pred_len = modelwrapper.get_output_profile_len()
# print(out_pred_len, seq_len-out_pred_len)

# %%
inputs_coordstovals = coordstovals.core.CoordsToValsJoiner(
    coordstovals_list=[
      coordbased.coordstovals.fasta.PyfaidxCoordsToVals(
        genome_fasta_path="/users/amr1/pho4/data/genome/saccer/sacCer3.genome.fa",
        mode_name="sequence",
        center_size_to_use=seq_len)])

targets_coordstovals = coordstovals.bigwig.PosAndNegSeparateLogCounts(
    pos_strand_bigwig_path="/users/amr1/pho4/data/cbf1_nexus/pos.bw",
    neg_strand_bigwig_path="/users/amr1/pho4/data/cbf1_nexus/neg.bw",
    counts_mode_name="task0_logcount",
    profile_mode_name="task0_profile",
    center_size_to_use=out_pred_len)

# def qc_func(inputs, targets):
#     return (np.where(np.logical_and(targets['task0_logcount'][:,0] >= 1.0,
#                                     targets['task0_logcount'][:,1] >= 1.0)))

keras_train_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
      bed_file="/users/amr1/pho4/data/cbf1_nexus/train.bed.gz",
      coord_batch_transformer=
          coordbatchtransformers.ReverseComplementAugmenter().chain(
          coordbatchtransformers.UniformJitter(
              maxshift=100, chromsizes_file="/users/amr1/pho4/data/genome/saccer/sacCer3.chrom.sizes")),
      batch_size=128,
      shuffle_before_epoch=True, 
      seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)#, qc_func=qc_func)

keras_valid_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
            bed_file="/users/amr1/pho4/data/cbf1_nexus/valid.bed.gz",
            batch_size=64,
            shuffle_before_epoch=False, 
            seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)#, qc_func=qc_func)

keras_test_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
            bed_file="/users/amr1/pho4/data/cbf1_nexus/test.bed.gz",
            batch_size=64,
            shuffle_before_epoch=False, 
            seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)#, qc_func=qc_func)

thebatch = keras_train_batch_generator[0]
for tupleidx,tupleentry in enumerate(thebatch):
  print("Tuple entry",tupleidx)
  for key in tupleentry:
    print(key, tupleentry[key].shape)
# Out:
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Tuple entry 0
# sequence (256, 546, 4)
# Tuple entry 1
# task0_logcount (256, 2)
# task0_profile (256, 250, 2)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0,3"

model = modelwrapper.get_keras_model()
print(model.summary())
early_stopping_callback = keras.callbacks.EarlyStopping(
                          patience=10, restore_best_weights=True)
loss_history = model.fit_generator(keras_train_batch_generator,
                  epochs=200,
                  validation_data=keras_valid_batch_generator,
                  callbacks=[early_stopping_callback])
model.set_weights(early_stopping_callback.best_weights)
# Out:
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# [<tf.Tensor 'lambda_1/strided_slice:0' shape=(?, 522, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_2/Relu:0' shape=(?, 522, 50) dtype=float32>]
# [<tf.Tensor 'lambda_2/strided_slice:0' shape=(?, 514, 50) dtype=float32>, <tf.Tensor 'lambda_3/strided_slice:0' shape=(?, 514, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_3/Relu:0' shape=(?, 514, 50) dtype=float32>]
# [<tf.Tensor 'lambda_4/strided_slice:0' shape=(?, 498, 50) dtype=float32>, <tf.Tensor 'lambda_5/strided_slice:0' shape=(?, 498, 50) dtype=float32>, <tf.Tensor 'lambda_6/strided_slice:0' shape=(?, 498, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_4/Relu:0' shape=(?, 498, 50) dtype=float32>]
# [<tf.Tensor 'lambda_7/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'lambda_8/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'lambda_9/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'lambda_10/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_5/Relu:0' shape=(?, 466, 50) dtype=float32>]
# [<tf.Tensor 'lambda_11/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_12/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_13/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_14/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_15/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_6/Relu:0' shape=(?, 402, 50) dtype=float32>]
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From <ipython-input-9-d13c4d7fc80c>:28: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           (None, 546, 4)       0
# __________________________________________________________________________________________________
# rev_comp_conv1d_1 (RevCompConv1 (None, 526, 50)      2125        sequence[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 522, 50)      0           rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_2 (RevCompConv1 (None, 522, 50)      3775        rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 522, 50)      0           lambda_1[0][0]
#                                                                  rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 514, 50)      0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 514, 50)      0           rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_3 (RevCompConv1 (None, 514, 50)      3775        average_1[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 514, 50)      0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 498, 50)      0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 498, 50)      0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 498, 50)      0           rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_4 (RevCompConv1 (None, 498, 50)      3775        average_2[0][0]
# __________________________________________________________________________________________________
# average_3 (Average)             (None, 498, 50)      0           lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 466, 50)      0           lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 466, 50)      0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 466, 50)      0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 466, 50)      0           rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_5 (RevCompConv1 (None, 466, 50)      3775        average_3[0][0]
# __________________________________________________________________________________________________
# average_4 (Average)             (None, 466, 50)      0           lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 402, 50)      0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 402, 50)      0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 402, 50)      0           lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 402, 50)      0           lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 402, 50)      0           rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_6 (RevCompConv1 (None, 402, 50)      3775        average_4[0][0]
# __________________________________________________________________________________________________
# average_5 (Average)             (None, 402, 50)      0           lambda_11[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
#                                                                  rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 274, 50)      0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 274, 50)      0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 274, 50)      0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 274, 50)      0           lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 274, 50)      0           lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 274, 50)      0           rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_7 (RevCompConv1 (None, 274, 50)      3775        average_5[0][0]
# __________________________________________________________________________________________________
# average_6 (Average)             (None, 274, 50)      0           lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_21[0][0]
#                                                                  rev_comp_conv1d_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 50)           0           average_6[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 50)        0           global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_8 (RevCompConv1 (None, 1, 2)         51          reshape_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_9 (RevCompConv1 (None, 250, 2)       1251        average_6[0][0]
# __________________________________________________________________________________________________
# task0_logcount (Reshape)        (None, 2)            0           rev_comp_conv1d_8[0][0]
# __________________________________________________________________________________________________
# task0_profile (RevCompConv1D)   (None, 250, 2)       3           rev_comp_conv1d_9[0][0]
# ==================================================================================================
# Total params: 26,080
# Trainable params: 26,080
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/200
# 11/11 [==============================] - 6s 566ms/step - loss: 1440.9534 - task0_logcount_loss: 8.6661 - task0_profile_loss: 574.3440 - val_loss: 704.2242 - val_task0_logcount_loss: 1.1455 - val_task0_profile_loss: 589.6735
# Epoch 2/200
# 11/11 [==============================] - 2s 199ms/step - loss: 714.9101 - task0_logcount_loss: 1.6419 - task0_profile_loss: 550.7223 - val_loss: 690.5542 - val_task0_logcount_loss: 1.1522 - val_task0_profile_loss: 575.3315
# Epoch 3/200
# 11/11 [==============================] - 3s 246ms/step - loss: 656.8081 - task0_logcount_loss: 1.1170 - task0_profile_loss: 545.1077 - val_loss: 655.3011 - val_task0_logcount_loss: 0.8437 - val_task0_profile_loss: 570.9324
# Epoch 4/200
# 11/11 [==============================] - 3s 235ms/step - loss: 641.4442 - task0_logcount_loss: 1.0067 - task0_profile_loss: 540.7697 - val_loss: 649.4547 - val_task0_logcount_loss: 0.8165 - val_task0_profile_loss: 567.8022
# Epoch 5/200
# 11/11 [==============================] - 3s 253ms/step - loss: 628.6348 - task0_logcount_loss: 0.9433 - task0_profile_loss: 534.3032 - val_loss: 655.4553 - val_task0_logcount_loss: 0.9245 - val_task0_profile_loss: 563.0051
# Epoch 6/200
# 11/11 [==============================] - 3s 246ms/step - loss: 624.8333 - task0_logcount_loss: 0.9514 - task0_profile_loss: 529.6943 - val_loss: 639.1031 - val_task0_logcount_loss: 0.8245 - val_task0_profile_loss: 556.6560
# Epoch 7/200
# 11/11 [==============================] - 3s 241ms/step - loss: 616.1426 - task0_logcount_loss: 0.9357 - task0_profile_loss: 522.5754 - val_loss: 635.5712 - val_task0_logcount_loss: 0.8531 - val_task0_profile_loss: 550.2595
# Epoch 8/200
# 11/11 [==============================] - 2s 225ms/step - loss: 609.3337 - task0_logcount_loss: 0.9276 - task0_profile_loss: 516.5747 - val_loss: 627.3359 - val_task0_logcount_loss: 0.8348 - val_task0_profile_loss: 543.8609
# Epoch 9/200
# 11/11 [==============================] - 3s 242ms/step - loss: 601.5080 - task0_logcount_loss: 0.9187 - task0_profile_loss: 509.6428 - val_loss: 621.2535 - val_task0_logcount_loss: 0.8361 - val_task0_profile_loss: 537.6471
# Epoch 10/200
# 11/11 [==============================] - 3s 239ms/step - loss: 595.9178 - task0_logcount_loss: 0.9153 - task0_profile_loss: 504.3893 - val_loss: 616.4385 - val_task0_logcount_loss: 0.8439 - val_task0_profile_loss: 532.0493
# Epoch 11/200
# 11/11 [==============================] - 3s 247ms/step - loss: 591.5492 - task0_logcount_loss: 0.9187 - task0_profile_loss: 499.6824 - val_loss: 608.4137 - val_task0_logcount_loss: 0.8291 - val_task0_profile_loss: 525.4999
# Epoch 12/200
# 11/11 [==============================] - 3s 256ms/step - loss: 584.7750 - task0_logcount_loss: 0.9226 - task0_profile_loss: 492.5189 - val_loss: 602.6144 - val_task0_logcount_loss: 0.8260 - val_task0_profile_loss: 520.0122
# Epoch 13/200
# 11/11 [==============================] - 3s 228ms/step - loss: 579.9144 - task0_logcount_loss: 0.9090 - task0_profile_loss: 489.0121 - val_loss: 601.8035 - val_task0_logcount_loss: 0.8564 - val_task0_profile_loss: 516.1665
# Epoch 14/200
# 11/11 [==============================] - 3s 249ms/step - loss: 575.3180 - task0_logcount_loss: 0.9259 - task0_profile_loss: 482.7316 - val_loss: 597.1371 - val_task0_logcount_loss: 0.8511 - val_task0_profile_loss: 512.0293
# Epoch 15/200
# 11/11 [==============================] - 3s 229ms/step - loss: 570.7374 - task0_logcount_loss: 0.9061 - task0_profile_loss: 480.1259 - val_loss: 595.4792 - val_task0_logcount_loss: 0.8665 - val_task0_profile_loss: 508.8317
# Epoch 16/200
# 11/11 [==============================] - 3s 248ms/step - loss: 567.3945 - task0_logcount_loss: 0.9151 - task0_profile_loss: 475.8875 - val_loss: 595.5372 - val_task0_logcount_loss: 0.8942 - val_task0_profile_loss: 506.1190
# Epoch 17/200
# 11/11 [==============================] - 3s 249ms/step - loss: 566.6849 - task0_logcount_loss: 0.9309 - task0_profile_loss: 473.5953 - val_loss: 589.4782 - val_task0_logcount_loss: 0.8521 - val_task0_profile_loss: 504.2680
# Epoch 18/200
# 11/11 [==============================] - 3s 255ms/step - loss: 562.2230 - task0_logcount_loss: 0.9272 - task0_profile_loss: 469.5047 - val_loss: 582.8779 - val_task0_logcount_loss: 0.8177 - val_task0_profile_loss: 501.1087
# Epoch 19/200
# 11/11 [==============================] - 2s 219ms/step - loss: 557.7464 - task0_logcount_loss: 0.9040 - task0_profile_loss: 467.3488 - val_loss: 581.2248 - val_task0_logcount_loss: 0.8086 - val_task0_profile_loss: 500.3658
# Epoch 20/200
# 11/11 [==============================] - 3s 258ms/step - loss: 554.1443 - task0_logcount_loss: 0.8952 - task0_profile_loss: 464.6208 - val_loss: 579.0281 - val_task0_logcount_loss: 0.8174 - val_task0_profile_loss: 497.2844
# Epoch 21/200
# 11/11 [==============================] - 3s 241ms/step - loss: 550.9353 - task0_logcount_loss: 0.8907 - task0_profile_loss: 461.8647 - val_loss: 576.6862 - val_task0_logcount_loss: 0.8034 - val_task0_profile_loss: 496.3512
# Epoch 22/200
# 11/11 [==============================] - 3s 238ms/step - loss: 549.0367 - task0_logcount_loss: 0.8912 - task0_profile_loss: 459.9209 - val_loss: 578.7932 - val_task0_logcount_loss: 0.8323 - val_task0_profile_loss: 495.5608
# Epoch 23/200
# 11/11 [==============================] - 3s 235ms/step - loss: 547.3156 - task0_logcount_loss: 0.8844 - task0_profile_loss: 458.8711 - val_loss: 575.9419 - val_task0_logcount_loss: 0.7976 - val_task0_profile_loss: 496.1803
# Epoch 24/200
# 11/11 [==============================] - 3s 248ms/step - loss: 544.3814 - task0_logcount_loss: 0.8812 - task0_profile_loss: 456.2602 - val_loss: 576.1375 - val_task0_logcount_loss: 0.8218 - val_task0_profile_loss: 493.9541
# Epoch 25/200
# 11/11 [==============================] - 3s 234ms/step - loss: 542.6693 - task0_logcount_loss: 0.8770 - task0_profile_loss: 454.9681 - val_loss: 573.1286 - val_task0_logcount_loss: 0.7930 - val_task0_profile_loss: 493.8293
# Epoch 26/200
# 11/11 [==============================] - 3s 249ms/step - loss: 541.5662 - task0_logcount_loss: 0.8736 - task0_profile_loss: 454.2013 - val_loss: 576.0560 - val_task0_logcount_loss: 0.8356 - val_task0_profile_loss: 492.4986
# Epoch 27/200
# 11/11 [==============================] - 3s 246ms/step - loss: 538.8217 - task0_logcount_loss: 0.8714 - task0_profile_loss: 451.6787 - val_loss: 577.6711 - val_task0_logcount_loss: 0.8672 - val_task0_profile_loss: 490.9542
# Epoch 28/200
# 11/11 [==============================] - 3s 247ms/step - loss: 538.3779 - task0_logcount_loss: 0.8733 - task0_profile_loss: 451.0444 - val_loss: 581.6648 - val_task0_logcount_loss: 0.9036 - val_task0_profile_loss: 491.3010
# Epoch 29/200
# 11/11 [==============================] - 3s 248ms/step - loss: 537.6193 - task0_logcount_loss: 0.8754 - task0_profile_loss: 450.0824 - val_loss: 575.5039 - val_task0_logcount_loss: 0.8385 - val_task0_profile_loss: 491.6520
# Epoch 30/200
# 11/11 [==============================] - 3s 245ms/step - loss: 536.6686 - task0_logcount_loss: 0.8680 - task0_profile_loss: 449.8729 - val_loss: 575.2690 - val_task0_logcount_loss: 0.8530 - val_task0_profile_loss: 489.9646
# Epoch 31/200
# 11/11 [==============================] - 3s 247ms/step - loss: 535.4561 - task0_logcount_loss: 0.8687 - task0_profile_loss: 448.5880 - val_loss: 578.7443 - val_task0_logcount_loss: 0.9045 - val_task0_profile_loss: 488.2936
# Epoch 32/200
# 11/11 [==============================] - 3s 248ms/step - loss: 534.9640 - task0_logcount_loss: 0.8785 - task0_profile_loss: 447.1182 - val_loss: 569.9496 - val_task0_logcount_loss: 0.8330 - val_task0_profile_loss: 486.6457
# Epoch 33/200
# 11/11 [==============================] - 3s 240ms/step - loss: 531.6895 - task0_logcount_loss: 0.8529 - task0_profile_loss: 446.4030 - val_loss: 565.2941 - val_task0_logcount_loss: 0.7859 - val_task0_profile_loss: 486.7029
# Epoch 34/200
# 11/11 [==============================] - 3s 241ms/step - loss: 531.4386 - task0_logcount_loss: 0.8496 - task0_profile_loss: 446.4739 - val_loss: 565.9365 - val_task0_logcount_loss: 0.7828 - val_task0_profile_loss: 487.6568
# Epoch 35/200
# 11/11 [==============================] - 3s 242ms/step - loss: 529.1360 - task0_logcount_loss: 0.8504 - task0_profile_loss: 444.0942 - val_loss: 564.8782 - val_task0_logcount_loss: 0.7824 - val_task0_profile_loss: 486.6365
# Epoch 36/200
# 11/11 [==============================] - 3s 255ms/step - loss: 528.6403 - task0_logcount_loss: 0.8459 - task0_profile_loss: 444.0499 - val_loss: 565.8374 - val_task0_logcount_loss: 0.7928 - val_task0_profile_loss: 486.5549
# Epoch 37/200
# 11/11 [==============================] - 3s 257ms/step - loss: 528.5535 - task0_logcount_loss: 0.8399 - task0_profile_loss: 444.5625 - val_loss: 565.9929 - val_task0_logcount_loss: 0.7817 - val_task0_profile_loss: 487.8205
# Epoch 38/200
# 11/11 [==============================] - 3s 234ms/step - loss: 527.5386 - task0_logcount_loss: 0.8412 - task0_profile_loss: 443.4203 - val_loss: 564.4930 - val_task0_logcount_loss: 0.7804 - val_task0_profile_loss: 486.4513
# Epoch 39/200
# 11/11 [==============================] - 3s 259ms/step - loss: 528.4192 - task0_logcount_loss: 0.8437 - task0_profile_loss: 444.0536 - val_loss: 567.9373 - val_task0_logcount_loss: 0.8236 - val_task0_profile_loss: 485.5820
# Epoch 40/200
# 11/11 [==============================] - 3s 241ms/step - loss: 527.5266 - task0_logcount_loss: 0.8490 - task0_profile_loss: 442.6264 - val_loss: 565.7010 - val_task0_logcount_loss: 0.8013 - val_task0_profile_loss: 485.5740
# Epoch 41/200
# 11/11 [==============================] - 3s 243ms/step - loss: 525.2468 - task0_logcount_loss: 0.8281 - task0_profile_loss: 442.4340 - val_loss: 563.7143 - val_task0_logcount_loss: 0.7859 - val_task0_profile_loss: 485.1197
# Epoch 42/200
# 11/11 [==============================] - 3s 257ms/step - loss: 528.3124 - task0_logcount_loss: 0.8549 - task0_profile_loss: 442.8262 - val_loss: 562.4673 - val_task0_logcount_loss: 0.7816 - val_task0_profile_loss: 484.3041
# Epoch 43/200
# 11/11 [==============================] - 3s 257ms/step - loss: 523.0432 - task0_logcount_loss: 0.8229 - task0_profile_loss: 440.7561 - val_loss: 563.8221 - val_task0_logcount_loss: 0.7784 - val_task0_profile_loss: 485.9849
# Epoch 44/200
# 11/11 [==============================] - 3s 227ms/step - loss: 522.9278 - task0_logcount_loss: 0.8117 - task0_profile_loss: 441.7597 - val_loss: 575.8007 - val_task0_logcount_loss: 0.9134 - val_task0_profile_loss: 484.4606
# Epoch 45/200
# 11/11 [==============================] - 3s 243ms/step - loss: 523.4499 - task0_logcount_loss: 0.8254 - task0_profile_loss: 440.9110 - val_loss: 563.2798 - val_task0_logcount_loss: 0.7962 - val_task0_profile_loss: 483.6636
# Epoch 46/200
# 11/11 [==============================] - 3s 248ms/step - loss: 521.7143 - task0_logcount_loss: 0.8092 - task0_profile_loss: 440.7929 - val_loss: 563.9085 - val_task0_logcount_loss: 0.7689 - val_task0_profile_loss: 487.0186
# Epoch 47/200
# 11/11 [==============================] - 3s 238ms/step - loss: 521.2365 - task0_logcount_loss: 0.8086 - task0_profile_loss: 440.3788 - val_loss: 560.4476 - val_task0_logcount_loss: 0.7696 - val_task0_profile_loss: 483.4892
# Epoch 48/200
# 11/11 [==============================] - 3s 240ms/step - loss: 516.6938 - task0_logcount_loss: 0.7849 - task0_profile_loss: 438.2082 - val_loss: 562.5572 - val_task0_logcount_loss: 0.7721 - val_task0_profile_loss: 485.3430
# Epoch 49/200
# 11/11 [==============================] - 3s 242ms/step - loss: 517.1463 - task0_logcount_loss: 0.7753 - task0_profile_loss: 439.6197 - val_loss: 561.6550 - val_task0_logcount_loss: 0.7771 - val_task0_profile_loss: 483.9410
# Epoch 50/200
# 11/11 [==============================] - 3s 238ms/step - loss: 516.2331 - task0_logcount_loss: 0.7759 - task0_profile_loss: 438.6470 - val_loss: 567.8574 - val_task0_logcount_loss: 0.8451 - val_task0_profile_loss: 483.3501
# Epoch 51/200
# 11/11 [==============================] - 3s 254ms/step - loss: 516.7261 - task0_logcount_loss: 0.7794 - task0_profile_loss: 438.7837 - val_loss: 558.8751 - val_task0_logcount_loss: 0.7526 - val_task0_profile_loss: 483.6111
# Epoch 52/200
# 11/11 [==============================] - 3s 244ms/step - loss: 514.9032 - task0_logcount_loss: 0.7694 - task0_profile_loss: 437.9630 - val_loss: 558.5965 - val_task0_logcount_loss: 0.7672 - val_task0_profile_loss: 481.8720
# Epoch 53/200
# 11/11 [==============================] - 3s 250ms/step - loss: 514.8771 - task0_logcount_loss: 0.7644 - task0_profile_loss: 438.4411 - val_loss: 562.4852 - val_task0_logcount_loss: 0.7788 - val_task0_profile_loss: 484.6029
# Epoch 54/200
# 11/11 [==============================] - 3s 252ms/step - loss: 513.8738 - task0_logcount_loss: 0.7520 - task0_profile_loss: 438.6757 - val_loss: 560.0593 - val_task0_logcount_loss: 0.7655 - val_task0_profile_loss: 483.5052
# Epoch 55/200
# 11/11 [==============================] - 3s 244ms/step - loss: 511.9795 - task0_logcount_loss: 0.7367 - task0_profile_loss: 438.3113 - val_loss: 557.7999 - val_task0_logcount_loss: 0.7423 - val_task0_profile_loss: 483.5664
# Epoch 56/200
# 11/11 [==============================] - 3s 256ms/step - loss: 510.0334 - task0_logcount_loss: 0.7262 - task0_profile_loss: 437.4165 - val_loss: 557.8223 - val_task0_logcount_loss: 0.7314 - val_task0_profile_loss: 484.6844
# Epoch 57/200
# 11/11 [==============================] - 3s 228ms/step - loss: 511.7573 - task0_logcount_loss: 0.7387 - task0_profile_loss: 437.8879 - val_loss: 559.0176 - val_task0_logcount_loss: 0.7933 - val_task0_profile_loss: 479.6922
# Epoch 58/200
# 11/11 [==============================] - 3s 250ms/step - loss: 510.6430 - task0_logcount_loss: 0.7181 - task0_profile_loss: 438.8341 - val_loss: 556.1051 - val_task0_logcount_loss: 0.7326 - val_task0_profile_loss: 482.8488
# Epoch 59/200
# 11/11 [==============================] - 3s 249ms/step - loss: 505.7452 - task0_logcount_loss: 0.6999 - task0_profile_loss: 435.7591 - val_loss: 559.1623 - val_task0_logcount_loss: 0.7050 - val_task0_profile_loss: 488.6598
# Epoch 60/200
# 11/11 [==============================] - 3s 238ms/step - loss: 506.4884 - task0_logcount_loss: 0.6965 - task0_profile_loss: 436.8339 - val_loss: 555.4249 - val_task0_logcount_loss: 0.7001 - val_task0_profile_loss: 485.4178
# Epoch 61/200
# 11/11 [==============================] - 3s 247ms/step - loss: 505.2115 - task0_logcount_loss: 0.6892 - task0_profile_loss: 436.2934 - val_loss: 554.9408 - val_task0_logcount_loss: 0.7062 - val_task0_profile_loss: 484.3200
# Epoch 62/200
# 11/11 [==============================] - 3s 247ms/step - loss: 501.8307 - task0_logcount_loss: 0.6612 - task0_profile_loss: 435.7091 - val_loss: 551.3584 - val_task0_logcount_loss: 0.6807 - val_task0_profile_loss: 483.2890
# Epoch 63/200
# 11/11 [==============================] - 3s 248ms/step - loss: 500.5270 - task0_logcount_loss: 0.6351 - task0_profile_loss: 437.0218 - val_loss: 561.5373 - val_task0_logcount_loss: 0.7090 - val_task0_profile_loss: 490.6404
# Epoch 64/200
# 11/11 [==============================] - 3s 251ms/step - loss: 502.5646 - task0_logcount_loss: 0.6313 - task0_profile_loss: 439.4356 - val_loss: 569.5694 - val_task0_logcount_loss: 0.6655 - val_task0_profile_loss: 503.0155
# Epoch 65/200
# 11/11 [==============================] - 3s 248ms/step - loss: 504.7376 - task0_logcount_loss: 0.6480 - task0_profile_loss: 439.9416 - val_loss: 546.0167 - val_task0_logcount_loss: 0.6537 - val_task0_profile_loss: 480.6512
# Epoch 66/200
# 11/11 [==============================] - 3s 233ms/step - loss: 500.8464 - task0_logcount_loss: 0.6384 - task0_profile_loss: 437.0101 - val_loss: 555.6900 - val_task0_logcount_loss: 0.6997 - val_task0_profile_loss: 485.7153
# Epoch 67/200
# 11/11 [==============================] - 3s 241ms/step - loss: 496.7916 - task0_logcount_loss: 0.6074 - task0_profile_loss: 436.0518 - val_loss: 552.8735 - val_task0_logcount_loss: 0.6456 - val_task0_profile_loss: 488.3111
# Epoch 68/200
# 11/11 [==============================] - 3s 231ms/step - loss: 495.6476 - task0_logcount_loss: 0.6052 - task0_profile_loss: 435.1248 - val_loss: 551.9393 - val_task0_logcount_loss: 0.6579 - val_task0_profile_loss: 486.1517
# Epoch 69/200
# 11/11 [==============================] - 3s 247ms/step - loss: 492.7515 - task0_logcount_loss: 0.5805 - task0_profile_loss: 434.6966 - val_loss: 547.4969 - val_task0_logcount_loss: 0.6329 - val_task0_profile_loss: 484.2045
# Epoch 70/200
# 11/11 [==============================] - 3s 241ms/step - loss: 492.1740 - task0_logcount_loss: 0.5521 - task0_profile_loss: 436.9617 - val_loss: 553.2212 - val_task0_logcount_loss: 0.6350 - val_task0_profile_loss: 489.7220
# Epoch 71/200
# 11/11 [==============================] - 3s 234ms/step - loss: 491.5911 - task0_logcount_loss: 0.5501 - task0_profile_loss: 436.5761 - val_loss: 553.8435 - val_task0_logcount_loss: 0.6708 - val_task0_profile_loss: 486.7592
# Epoch 72/200
# 11/11 [==============================] - 3s 239ms/step - loss: 489.3373 - task0_logcount_loss: 0.5481 - task0_profile_loss: 434.5306 - val_loss: 549.8731 - val_task0_logcount_loss: 0.6040 - val_task0_profile_loss: 489.4760
# Epoch 73/200
# 11/11 [==============================] - 3s 252ms/step - loss: 486.6792 - task0_logcount_loss: 0.5232 - task0_profile_loss: 434.3583 - val_loss: 545.5248 - val_task0_logcount_loss: 0.5999 - val_task0_profile_loss: 485.5349
# Epoch 74/200
# 11/11 [==============================] - 3s 254ms/step - loss: 485.2308 - task0_logcount_loss: 0.5115 - task0_profile_loss: 434.0823 - val_loss: 541.9230 - val_task0_logcount_loss: 0.5857 - val_task0_profile_loss: 483.3521
# Epoch 75/200
# 11/11 [==============================] - 3s 255ms/step - loss: 484.2210 - task0_logcount_loss: 0.4954 - task0_profile_loss: 434.6799 - val_loss: 537.9986 - val_task0_logcount_loss: 0.5748 - val_task0_profile_loss: 480.5206
# Epoch 76/200
# 11/11 [==============================] - 3s 249ms/step - loss: 483.5386 - task0_logcount_loss: 0.4931 - task0_profile_loss: 434.2256 - val_loss: 542.2232 - val_task0_logcount_loss: 0.5819 - val_task0_profile_loss: 484.0289
# Epoch 77/200
# 11/11 [==============================] - 3s 234ms/step - loss: 480.8769 - task0_logcount_loss: 0.4784 - task0_profile_loss: 433.0331 - val_loss: 544.8194 - val_task0_logcount_loss: 0.6069 - val_task0_profile_loss: 484.1288
# Epoch 78/200
# 11/11 [==============================] - 3s 238ms/step - loss: 482.5918 - task0_logcount_loss: 0.4973 - task0_profile_loss: 432.8637 - val_loss: 546.3307 - val_task0_logcount_loss: 0.6407 - val_task0_profile_loss: 482.2565
# Epoch 79/200
# 11/11 [==============================] - 3s 251ms/step - loss: 480.3473 - task0_logcount_loss: 0.4748 - task0_profile_loss: 432.8673 - val_loss: 538.6959 - val_task0_logcount_loss: 0.5663 - val_task0_profile_loss: 482.0659
# Epoch 80/200
# 11/11 [==============================] - 3s 237ms/step - loss: 476.6298 - task0_logcount_loss: 0.4399 - task0_profile_loss: 432.6356 - val_loss: 539.4531 - val_task0_logcount_loss: 0.5476 - val_task0_profile_loss: 484.6890
# Epoch 81/200
# 11/11 [==============================] - 3s 247ms/step - loss: 477.1123 - task0_logcount_loss: 0.4311 - task0_profile_loss: 434.0067 - val_loss: 542.6404 - val_task0_logcount_loss: 0.6378 - val_task0_profile_loss: 478.8616
# Epoch 82/200
# 11/11 [==============================] - 3s 253ms/step - loss: 478.4511 - task0_logcount_loss: 0.4496 - task0_profile_loss: 433.4862 - val_loss: 539.4734 - val_task0_logcount_loss: 0.5745 - val_task0_profile_loss: 482.0195
# Epoch 83/200
# 11/11 [==============================] - 3s 253ms/step - loss: 478.1502 - task0_logcount_loss: 0.4552 - task0_profile_loss: 432.6328 - val_loss: 531.6463 - val_task0_logcount_loss: 0.5301 - val_task0_profile_loss: 478.6352
# Epoch 84/200
# 11/11 [==============================] - 3s 228ms/step - loss: 474.1117 - task0_logcount_loss: 0.4070 - task0_profile_loss: 433.4110 - val_loss: 543.1174 - val_task0_logcount_loss: 0.5288 - val_task0_profile_loss: 490.2355
# Epoch 85/200
# 11/11 [==============================] - 3s 245ms/step - loss: 475.1953 - task0_logcount_loss: 0.4155 - task0_profile_loss: 433.6423 - val_loss: 537.8893 - val_task0_logcount_loss: 0.5824 - val_task0_profile_loss: 479.6522
# Epoch 86/200
# 11/11 [==============================] - 3s 248ms/step - loss: 475.3087 - task0_logcount_loss: 0.4066 - task0_profile_loss: 434.6524 - val_loss: 531.5193 - val_task0_logcount_loss: 0.5193 - val_task0_profile_loss: 479.5852
# Epoch 87/200
# 11/11 [==============================] - 3s 238ms/step - loss: 469.5189 - task0_logcount_loss: 0.3821 - task0_profile_loss: 431.3067 - val_loss: 537.4509 - val_task0_logcount_loss: 0.5315 - val_task0_profile_loss: 484.2960
# Epoch 88/200
# 11/11 [==============================] - 3s 245ms/step - loss: 469.0212 - task0_logcount_loss: 0.3798 - task0_profile_loss: 431.0459 - val_loss: 530.8709 - val_task0_logcount_loss: 0.5200 - val_task0_profile_loss: 478.8691
# Epoch 89/200
# 11/11 [==============================] - 3s 262ms/step - loss: 469.5061 - task0_logcount_loss: 0.3878 - task0_profile_loss: 430.7251 - val_loss: 534.4547 - val_task0_logcount_loss: 0.5113 - val_task0_profile_loss: 483.3210
# Epoch 90/200
# 11/11 [==============================] - 3s 238ms/step - loss: 467.9307 - task0_logcount_loss: 0.3667 - task0_profile_loss: 431.2606 - val_loss: 533.6488 - val_task0_logcount_loss: 0.5522 - val_task0_profile_loss: 478.4277
# Epoch 91/200
# 11/11 [==============================] - 3s 253ms/step - loss: 467.6536 - task0_logcount_loss: 0.3592 - task0_profile_loss: 431.7339 - val_loss: 538.3942 - val_task0_logcount_loss: 0.5168 - val_task0_profile_loss: 486.7161
# Epoch 92/200
# 11/11 [==============================] - 3s 254ms/step - loss: 472.6961 - task0_logcount_loss: 0.3592 - task0_profile_loss: 436.7756 - val_loss: 550.2710 - val_task0_logcount_loss: 0.5121 - val_task0_profile_loss: 499.0610
# Epoch 93/200
# 11/11 [==============================] - 3s 229ms/step - loss: 476.3782 - task0_logcount_loss: 0.3809 - task0_profile_loss: 438.2928 - val_loss: 533.2920 - val_task0_logcount_loss: 0.5086 - val_task0_profile_loss: 482.4328
# Epoch 94/200
# 11/11 [==============================] - 3s 248ms/step - loss: 469.6864 - task0_logcount_loss: 0.3722 - task0_profile_loss: 432.4650 - val_loss: 529.2012 - val_task0_logcount_loss: 0.5175 - val_task0_profile_loss: 477.4474
# Epoch 95/200
# 11/11 [==============================] - 3s 246ms/step - loss: 469.2565 - task0_logcount_loss: 0.3710 - task0_profile_loss: 432.1589 - val_loss: 530.8588 - val_task0_logcount_loss: 0.5055 - val_task0_profile_loss: 480.3110
# Epoch 96/200
# 11/11 [==============================] - 3s 247ms/step - loss: 465.7503 - task0_logcount_loss: 0.3584 - task0_profile_loss: 429.9117 - val_loss: 531.8245 - val_task0_logcount_loss: 0.5146 - val_task0_profile_loss: 480.3619
# Epoch 97/200
# 11/11 [==============================] - 3s 249ms/step - loss: 465.2153 - task0_logcount_loss: 0.3570 - task0_profile_loss: 429.5157 - val_loss: 532.0261 - val_task0_logcount_loss: 0.5059 - val_task0_profile_loss: 481.4386
# Epoch 98/200
# 11/11 [==============================] - 3s 238ms/step - loss: 464.3420 - task0_logcount_loss: 0.3444 - task0_profile_loss: 429.8979 - val_loss: 530.3193 - val_task0_logcount_loss: 0.5230 - val_task0_profile_loss: 478.0148
# Epoch 99/200
# 11/11 [==============================] - 3s 244ms/step - loss: 463.5874 - task0_logcount_loss: 0.3351 - task0_profile_loss: 430.0786 - val_loss: 540.2415 - val_task0_logcount_loss: 0.6087 - val_task0_profile_loss: 479.3682
# Epoch 100/200
# 11/11 [==============================] - 3s 253ms/step - loss: 464.8755 - task0_logcount_loss: 0.3548 - task0_profile_loss: 429.3925 - val_loss: 540.6472 - val_task0_logcount_loss: 0.5320 - val_task0_profile_loss: 487.4505
# Epoch 101/200
# 11/11 [==============================] - 3s 243ms/step - loss: 462.8147 - task0_logcount_loss: 0.3224 - task0_profile_loss: 430.5748 - val_loss: 540.3132 - val_task0_logcount_loss: 0.5056 - val_task0_profile_loss: 489.7545
# Epoch 102/200
# 11/11 [==============================] - 3s 235ms/step - loss: 464.0750 - task0_logcount_loss: 0.3371 - task0_profile_loss: 430.3641 - val_loss: 535.0422 - val_task0_logcount_loss: 0.5174 - val_task0_profile_loss: 483.3004
# Epoch 103/200
# 11/11 [==============================] - 3s 247ms/step - loss: 463.8081 - task0_logcount_loss: 0.3462 - task0_profile_loss: 429.1835 - val_loss: 535.7542 - val_task0_logcount_loss: 0.5282 - val_task0_profile_loss: 482.9363
# Epoch 104/200
# 11/11 [==============================] - 3s 239ms/step - loss: 461.8817 - task0_logcount_loss: 0.3315 - task0_profile_loss: 428.7356 - val_loss: 535.7379 - val_task0_logcount_loss: 0.5491 - val_task0_profile_loss: 480.8319

# %%
model.save('/users/amr1/pho4/data/models/nexus_cbf1_model.h5')

# %% [markdown]
# evaluate

# %%
from keras.models import load_model
from keras.utils import CustomObjectScope

with CustomObjectScope({'MultichannelMultinomialNLL': MultichannelMultinomialNLL,'RevCompConv1D': RevCompConv1D}):
    model = load_model('/users/amr1/pho4/data/models/nexus_cbf1_model.h5')

# %%
# %matplotlib inline

test_preds_logcount = []
test_seqs = []
test_preds_profile = []
test_labels_logcount = []
test_labels_profile = []
for batch_idx in range(len(keras_test_batch_generator)):
    batch_inputs, batch_labels = keras_test_batch_generator[batch_idx]
    test_seqs.append(batch_inputs['sequence'])
    test_preds = model.predict(batch_inputs)
    test_preds_logcount.append(test_preds[0])
    test_preds_profile.append(test_preds[1])
    test_labels_logcount.append(batch_labels['task0_logcount'])
    test_labels_profile.append(batch_labels['task0_profile'])
test_seqs = np.concatenate(test_seqs,axis=0)
test_preds_logcount = np.concatenate(test_preds_logcount, axis=0)
test_preds_profile = np.concatenate(test_preds_profile, axis=0)
test_labels_logcount = np.concatenate(test_labels_logcount, axis=0)
test_labels_profile = np.concatenate(test_labels_profile, axis=0)

from matplotlib import pyplot as plt
from scipy.stats import spearmanr

test_labels_logtotalcount = np.log(np.sum(np.exp(test_labels_logcount) - 1,axis=-1) + 1)

#do a scatterplot of total count predictions
plt.scatter(test_preds_logcount[:,0], test_labels_logcount[:,0], alpha=0.1)
plt.xlabel("Predicted log counts - Forward Strand")
plt.ylabel("True log counts - Forward Strand")
plt.plot([np.min(test_preds_logcount[:,0]), np.max(test_preds_logcount[:,0])],
         [np.min(test_preds_logcount[:,0]), np.max(test_preds_logcount[:,0])],
         color="black")
plt.show()
print(spearmanr(test_preds_logcount[:,0], test_labels_logcount[:,0]))

plt.scatter(test_preds_logcount[:,1], test_labels_logcount[:,1], alpha=0.1)
plt.xlabel("Predicted log counts - Reverse Strand")
plt.ylabel("True log counts - Reverse Strand")
plt.plot([np.min(test_preds_logcount[:,1]), np.max(test_preds_logcount[:,1])],
         [np.min(test_preds_logcount[:,1]), np.max(test_preds_logcount[:,1])],
         color="black")
plt.show()
print(spearmanr(test_preds_logcount[:,1], test_labels_logcount[:,1]))
# Out:
# SpearmanrResult(correlation=0.6395614981561337, pvalue=1.5014372720418658e-19)
# SpearmanrResult(correlation=0.6062776682526926, pvalue=3.134973221311976e-17)

# %%
o_train_preds_logcount = []
o_train_seqs = []
o_train_preds_profile = []
o_train_labels_logcount = []
o_train_labels_profile = []

orig_seqs = []

for batch_idx in range(len(keras_train_batch_generator)):
    batch_inputs, batch_labels = keras_train_batch_generator[batch_idx]
    o_train_seqs.append(batch_inputs['sequence'])    
    train_preds = model.predict(batch_inputs)
    o_train_preds_logcount.append(train_preds[0])
    o_train_preds_profile.append(train_preds[1])
    o_train_labels_logcount.append(batch_labels['task0_logcount'])
    o_train_labels_profile.append(batch_labels['task0_profile'])
o_train_seqs = np.concatenate(o_train_seqs,axis=0)
o_train_preds_logcount = np.concatenate(o_train_preds_logcount, axis=0)
o_train_preds_profile = np.concatenate(o_train_preds_profile, axis=0)
o_train_labels_logcount = np.concatenate(o_train_labels_logcount, axis=0)
o_train_labels_profile = np.concatenate(o_train_labels_profile, axis=0)

from matplotlib import pyplot as plt
from scipy.stats import spearmanr

o_train_labels_logtotalcount = np.log(np.sum(np.exp(o_train_labels_logcount) - 1,axis=-1) + 1)

#do a scatterplot of total count predictions
plt.scatter(o_train_preds_logcount[:,0], o_train_labels_logcount[:,0], alpha=0.1)
plt.xlabel("Predicted log counts - Forward Strand")
plt.ylabel("True log counts - Forward Strand")
plt.plot([np.min(o_train_preds_logcount[:,0]), np.max(o_train_preds_logcount[:,0])],
         [np.min(o_train_preds_logcount[:,0]), np.max(o_train_preds_logcount[:,0])],
         color="black")
plt.show()
print(spearmanr(o_train_preds_logcount[:,0], o_train_labels_logcount[:,0]))

plt.scatter(o_train_preds_logcount[:,1], o_train_labels_logcount[:,1], alpha=0.1)
plt.xlabel("Predicted log counts - Reverse Strand")
plt.ylabel("True log counts - Reverse Strand")
plt.plot([np.min(o_train_preds_logcount[:,1]), np.max(o_train_preds_logcount[:,1])],
         [np.min(o_train_preds_logcount[:,1]), np.max(o_train_preds_logcount[:,1])],
         color="black")
plt.show()
print(spearmanr(o_train_preds_logcount[:,1], o_train_labels_logcount[:,1]))
# Out:
# SpearmanrResult(correlation=0.6529761743387746, pvalue=0.0)
# SpearmanrResult(correlation=0.651581224807135, pvalue=0.0)

# %% [markdown]
# Interpretation

# %%
import shap
from deeplift.dinuc_shuffle import dinuc_shuffle

def combine_mult_and_diffref(mult, orig_inp, bg_data):
    assert len(orig_inp)==1
    projected_hypothetical_contribs = np.zeros_like(bg_data[0]).astype("float")
    assert len(orig_inp[0].shape)==2
    #At each position in the input sequence, we iterate over the one-hot encoding
    # possibilities (eg: for genomic sequence, this is ACGT i.e.
    # 1000, 0100, 0010 and 0001) and compute the hypothetical 
    # difference-from-reference in each case. We then multiply the hypothetical
    # differences-from-reference with the multipliers to get the hypothetical contributions.
    #For each of the one-hot encoding possibilities,
    # the hypothetical contributions are then summed across the ACGT axis to estimate
    # the total hypothetical contribution of each position. This per-position hypothetical
    # contribution is then assigned ("projected") onto whichever base was present in the
    # hypothetical sequence.
    #The reason this is a fast estimate of what the importance scores *would* look
    # like if different bases were present in the underlying sequence is that
    # the multipliers are computed once using the original sequence, and are not
    # computed again for each hypothetical sequence.
    for i in range(orig_inp[0].shape[-1]):
        hypothetical_input = np.zeros_like(orig_inp[0]).astype("float")
        hypothetical_input[:,i] = 1.0
        hypothetical_difference_from_reference = (hypothetical_input[None,:,:]-bg_data[0])
        hypothetical_contribs = hypothetical_difference_from_reference*mult[0]
        projected_hypothetical_contribs[:,:,i] = np.sum(hypothetical_contribs,axis=-1) 
    return [np.mean(projected_hypothetical_contribs,axis=0)]

def shuffle_several_times(s):
    numshuffles=20
    return [np.array([dinuc_shuffle(s[0]) for i in range(numshuffles)])]

profile_model_counts_explainer = shap.explainers.deep.TFDeepExplainer(
    (model.input,
     tf.reduce_sum(model.outputs[0],axis=-1)),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)

#See Google slide deck for explanations
#We meannorm as per section titled "Adjustments for Softmax Layers"
# in the DeepLIFT paper
meannormed_logits = (
    model.outputs[1]-
    tf.reduce_mean(model.outputs[1],axis=1)[:,None,:])
#'stop_gradient' will prevent importance from being propagated through
# this operation; we do this because we just want to treat the post-softmax
# probabilities as 'weights' on the different logits, without having the
# network explain how the probabilities themselves were derived
#Could be worth contrasting explanations derived with and without stop_gradient
# enabled...
stopgrad_meannormed_logits = tf.stop_gradient(meannormed_logits)
softmax_out = tf.nn.softmax(stopgrad_meannormed_logits,axis=1)
#Weight the logits according to the softmax probabilities, take the sum for each
# example. This mirrors what was done for the bpnet paper.
weightedsum_meannormed_logits = tf.reduce_sum(softmax_out*meannormed_logits,
                                              axis=(1,2))
profile_model_profile_explainer = shap.explainers.deep.TFDeepExplainer(
    (model.input,
     weightedsum_meannormed_logits),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)
# Out:
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  StopGradient used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients

# %%
#The shap scores
post_counts_hypimps = profile_model_counts_explainer.shap_values(
    test_seqs,
    progress_message=10)
post_profile_hypimps = profile_model_profile_explainer.shap_values(
    test_seqs,
    progress_message=10)

post_counts_actualimps = post_counts_hypimps*test_seqs
post_profile_actualimps = post_profile_hypimps*test_seqs
# Out:
# Done 0 examples of 158
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/shap/explainers/deep/deep_tf.py:493: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Done 10 examples of 158
# Done 20 examples of 158
# Done 30 examples of 158
# Done 40 examples of 158
# Done 50 examples of 158
# Done 60 examples of 158
# Done 70 examples of 158
# Done 80 examples of 158
# Done 90 examples of 158
# Done 100 examples of 158
# Done 110 examples of 158
# Done 120 examples of 158
# Done 130 examples of 158
# Done 140 examples of 158
# Done 150 examples of 158
# Done 0 examples of 158
# Done 10 examples of 158
# Done 20 examples of 158
# Done 30 examples of 158
# Done 40 examples of 158
# Done 50 examples of 158
# Done 60 examples of 158
# Done 70 examples of 158
# Done 80 examples of 158
# Done 90 examples of 158
# Done 100 examples of 158
# Done 110 examples of 158
# Done 120 examples of 158
# Done 130 examples of 158
# Done 140 examples of 158
# Done 150 examples of 158

# %%
from deeplift.visualization import viz_sequence
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter

sorted_test_indices = [x[0] for x in 
                       sorted(enumerate(test_labels_logtotalcount[:1000]),
                              key=lambda x: -x[1])]

def smooth(vals):
    return np.convolve(vals, np.ones(1,)/1, mode='same')

for idx in sorted_test_indices[:10]: 
    true_profile = test_labels_profile[idx] 
    print("idx",idx)
    print("Counts",np.sum(true_profile,axis=0))
    print("Predcounts",np.exp(test_preds_logcount[idx])-1)
    
    for oneovertemp in [1.0]:
        print("oneovertemp",oneovertemp)
        print(test_labels_profile[idx].shape)
        print("Pred profile shape", test_preds_profile[idx].shape)
        pred_profile = (np.sum(test_labels_profile[idx], axis=0)[None,:] #total counts
                      *(np.exp(test_preds_profile[idx]*oneovertemp)/
                        np.sum(np.exp(test_preds_profile[idx]*oneovertemp),axis=0)[None,:]) )   
        plt.figure(figsize=(20,2))

        start_view = 0
        end_view = seq_len
        total_flanking = seq_len - out_pred_len
        left_flank = int(0.5*total_flanking)
        right_flank = total_flanking - left_flank
        plt.plot(np.arange(out_pred_len)+left_flank, smooth(true_profile[:,0]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, -smooth(true_profile[:,1]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, pred_profile[:,0])
        plt.plot(np.arange(out_pred_len)+left_flank, -pred_profile[:,1])
        plt.xlim(start_view,end_view)
        plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
        plt.show()

    print("counts imp")
    viz_sequence.plot_weights(post_counts_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
    print("profile imp")
    viz_sequence.plot_weights(post_profile_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
# Out:
# idx 131
# Counts [2071. 2500.]
# Predcounts [730.1201  862.62897]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 130
# Counts [2063. 2496.]
# Predcounts [729.52704 865.3747 ]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 138
# Counts [2049. 1859.]
# Predcounts [632.8433 659.5829]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 139
# Counts [2058. 1834.]
# Predcounts [672.8385  693.47363]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 37
# Counts [ 843. 1058.]
# Predcounts [454.21008 446.71762]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 36
# Counts [ 843. 1055.]
# Predcounts [453.29065 443.81082]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 42
# Counts [676. 940.]
# Predcounts [352.6024  357.99036]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 43
# Counts [699. 915.]
# Predcounts [347.4131  353.59808]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 45
# Counts [506. 649.]
# Predcounts [175.62315 190.39944]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 44
# Counts [505. 643.]
# Predcounts [182.51466 196.41458]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp

# %%
for idx in sorted_test_indices[:10]: 
    true_profile = test_labels_profile[idx] 
    print("idx",idx)
    print("Counts",np.sum(true_profile,axis=0))
    print("Predcounts",np.exp(test_preds_logcount[idx])-1)
    
    for oneovertemp in [1.0]:
        print("oneovertemp",oneovertemp)
        print(test_labels_profile[idx].shape)
        print("Pred profile shape", test_preds_profile[idx].shape)
        pred_profile = (np.sum(test_labels_profile[idx], axis=0)[None,:] #total counts
                      *(np.exp(test_preds_profile[idx]*oneovertemp)/
                        np.sum(np.exp(test_preds_profile[idx]*oneovertemp),axis=0)[None,:]))
        plt.figure(figsize=(20,2))

        start_view = 220
        end_view = 325
        total_flanking = seq_len - out_pred_len
        left_flank = int(0.5*total_flanking)
        right_flank = total_flanking - left_flank
        plt.plot(np.arange(out_pred_len)+left_flank, smooth(true_profile[:,0]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, -smooth(true_profile[:,1]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, pred_profile[:,0])
        plt.plot(np.arange(out_pred_len)+left_flank, -pred_profile[:,1])
        plt.xlim(start_view,end_view)
        plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
        plt.show()

    print("counts imp")
    viz_sequence.plot_weights(post_counts_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
    print("profile imp")
    viz_sequence.plot_weights(post_profile_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
# Out:
# idx 131
# Counts [2071. 2500.]
# Predcounts [730.1201  862.62897]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 130
# Counts [2063. 2496.]
# Predcounts [729.52704 865.3747 ]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 138
# Counts [2049. 1859.]
# Predcounts [632.8433 659.5829]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 139
# Counts [2058. 1834.]
# Predcounts [672.8385  693.47363]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 37
# Counts [ 843. 1058.]
# Predcounts [454.21008 446.71762]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 36
# Counts [ 843. 1055.]
# Predcounts [453.29065 443.81082]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 42
# Counts [676. 940.]
# Predcounts [352.6024  357.99036]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 43
# Counts [699. 915.]
# Predcounts [347.4131  353.59808]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 45
# Counts [506. 649.]
# Predcounts [175.62315 190.39944]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 44
# Counts [505. 643.]
# Predcounts [182.51466 196.41458]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
