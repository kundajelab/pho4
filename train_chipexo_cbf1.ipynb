# %% [markdown]
# Train Model

# %%
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers
# Out:
# Using TensorFlow backend.
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import numpy as np
import gzip
import keras
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import keras_genomics
from keras_genomics.layers.convolutional import RevCompConv1D
import keras
import keras.layers as kl
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers

def multinomial_nll(true_counts, logits):
    """Compute the multinomial negative log-likelihood
    Args:
      true_counts: observed count values
      logits: predicted logit values
    """
    counts_per_example = tf.reduce_sum(true_counts, axis=-1)
    dist = tfp.distributions.Multinomial(total_count=counts_per_example,
                                         logits=logits)
    return (-tf.reduce_sum(dist.log_prob(true_counts)) / 
            tf.to_float(tf.shape(true_counts)[0]))


#from https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/losses.py#L87
class MultichannelMultinomialNLL(object):
    def __init__(self, n):
        self.__name__ = "MultichannelMultinomialNLL"
        self.n = n

    def __call__(self, true_counts, logits):
        for i in range(self.n):
            loss = multinomial_nll(true_counts[..., i], logits[..., i])
            if i == 0:
                total = loss
            else:
                total += loss
        return total

    def get_config(self):
        return {"n": self.n}

#If we want to avoid zero-padding, then the input seq len will be determined
# by parameters of the convolutions
class AbstractProfileModel(object):

    def get_output_profile_len(self):
        raise NotImplementedError()

    def get_model(self):
        raise NotImplementedError()

def trim_flanks_of_conv_layer(conv_layer, output_len, width_to_trim, filters):
    layer = keras.layers.Lambda(
        lambda x: x[:,
          int(0.5*(width_to_trim)):-(width_to_trim-int(0.5*(width_to_trim)))],
        output_shape=(output_len, filters))(conv_layer)
    return layer

#model architecture is based on 
#https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/models.py#L534
#The non-cli parameters are specified in:
# https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/src/chipnexus/train/seqmodel/joint-model-valid.gin
#The cli parameters are in line 165 of:
# https://docs.google.com/spreadsheets/d/1n3l2HXKSNpmNUOifD41uRzDEAgmOqXMQDxquRaz6WLg/edit#gid=0
# which seems to match https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/src/chipnexus/train/seqmodel/ChIP-seq-default.gin
class RcBPnetArch(AbstractProfileModel):   

    def __init__(self, input_seq_len, c_task_weight, filters,
                       n_dil_layers, conv1_kernel_size,
                       dil_kernel_size,
                       outconv_kernel_size, lr):
        self.input_seq_len = input_seq_len
        self.c_task_weight = c_task_weight
        self.filters = filters
        self.n_dil_layers = n_dil_layers
        self.conv1_kernel_size = conv1_kernel_size
        self.dil_kernel_size = dil_kernel_size
        self.outconv_kernel_size = outconv_kernel_size
        self.lr = lr

    def get_embedding_len(self):
        embedding_len = self.input_seq_len
        embedding_len -= (self.conv1_kernel_size-1)     
        for i in range(1, self.n_dil_layers+1):
            dilation_rate = (2**i)
            embedding_len -= dilation_rate*(self.dil_kernel_size-1)
        return embedding_len

    def get_output_profile_len(self):
        embedding_len = self.get_embedding_len()
        out_profile_len = embedding_len - (self.outconv_kernel_size - 1)
        return out_profile_len

    def get_keras_model(self):

        out_pred_len = self.get_output_profile_len()

        inp = kl.Input(shape=(self.input_seq_len, 4), name='sequence')
        first_conv = RevCompConv1D(filters=self.filters,
                               kernel_size=self.conv1_kernel_size,
                               padding='valid',
                               activation='relu')(inp)
        curr_layer_size = self.input_seq_len - (self.conv1_kernel_size-1)
        bias_counts_input = kl.Input(shape=(1,), name="control_logcount")
        bias_profile_input = kl.Input(shape=(out_pred_len, 2),
                                      name="control_profile")
        prev_layers = [first_conv]
        for i in range(1, self.n_dil_layers + 1):
          dilation_rate = 2**i
          if i == 1:
              prev_sum = first_conv
          else:
              print(prev_layers)
              prev_sum = kl.merge.Average()(prev_layers)
          conv_output = RevCompConv1D(filters=self.filters,
                                  kernel_size=self.dil_kernel_size,
                                  padding='valid',
                                  activation='relu',
                                  dilation_rate=dilation_rate)(prev_sum)          
          width_to_trim = dilation_rate*(self.dil_kernel_size-1)
          curr_layer_size = (curr_layer_size - width_to_trim)
          prev_layers = [trim_flanks_of_conv_layer(
              conv_layer=x, output_len=curr_layer_size,
              width_to_trim=width_to_trim, filters=2*self.filters)
              for x in prev_layers]
          prev_layers.append(conv_output)

        combined_conv = kl.merge.Average()(prev_layers)

        #Counts prediction
        gap_combined_conv = kl.GlobalAvgPool1D()(combined_conv)
        count_out = kl.Reshape((-1,), name="task0_logcount")(
            RevCompConv1D(filters=1, kernel_size=1)(
              kl.Reshape((1,-1))(kl.concatenate([
                  #concatenation of the bias layer both before and after
                  # is needed for rc symmetry
                  kl.Lambda(lambda x: x[:, ::-1])(bias_counts_input),
                  gap_combined_conv,
                  bias_counts_input], axis=-1))))

        profile_out_prebias = RevCompConv1D(
                               filters=1,
                               kernel_size=self.outconv_kernel_size,
                               padding='valid')(combined_conv)
        profile_out = RevCompConv1D(
            filters=1, kernel_size=1, name="task0_profile")(
                    kl.concatenate([
                        #concatenation of the bias layer both before and after
                        # is needed for rc symmetry
                        kl.Lambda(lambda x: x[:, :, ::-1])(bias_profile_input),
                        profile_out_prebias,
                        bias_profile_input], axis=-1))

        model = keras.models.Model(
          inputs=[inp, bias_counts_input, bias_profile_input],
          outputs=[count_out, profile_out])
        model.compile(keras.optimizers.Adam(lr=self.lr),
                      loss=['mse', MultichannelMultinomialNLL(2)],
                      loss_weights=[self.c_task_weight, 1])
        return model

# %%
# seq_len = 546
# modelwrapper = RcBPnetArch(
#     input_seq_len=seq_len, c_task_weight=250,
#     filters=25,
#     n_dil_layers=6,
#     conv1_kernel_size=21,
#     dil_kernel_size=3,
#     outconv_kernel_size=50,
#     lr=0.001)
# out_pred_len = modelwrapper.get_output_profile_len()
# print(out_pred_len, seq_len-out_pred_len)

# %%
seq_len = 546

modelwrapper = RcBPnetArch(
    input_seq_len=seq_len, c_task_weight=10,
    filters=25,
    n_dil_layers=6,
    conv1_kernel_size=21,
    dil_kernel_size=3,
    outconv_kernel_size=25,
    lr=0.001)
out_pred_len = modelwrapper.get_output_profile_len()
print(out_pred_len, seq_len-out_pred_len)
# Out:
# 250 296

# %%
pos_neg_smooth_log_counts =\
  coordstovals.bigwig.PosAndNegSmoothWindowCollapsedLogCounts(
        pos_strand_bigwig_path="/users/amr1/pho4/data/ctl_chipexo/chipexo.pos_strand.bw",
        neg_strand_bigwig_path="/users/amr1/pho4/data/ctl_chipexo/chipexo.neg_strand.bw",
        counts_mode_name="control_logcount",
        profile_mode_name="control_profile",
        center_size_to_use=out_pred_len,
        smoothing_windows=[1,50])
inputs_coordstovals = coordstovals.core.CoordsToValsJoiner(
    coordstovals_list=[
      coordbased.coordstovals.fasta.PyfaidxCoordsToVals(
        genome_fasta_path="/users/amr1/pho4/data/genome/sacCer3.genome.fa",
        mode_name="sequence",
        center_size_to_use=seq_len),
      pos_neg_smooth_log_counts])

targets_coordstovals = coordstovals.bigwig.PosAndNegSeparateLogCounts(
    pos_strand_bigwig_path="/users/amr1/pho4/data/cbf1_chipexo/basename_prefix.pooled.positive.bigwig",
    neg_strand_bigwig_path="/users/amr1/pho4/data/cbf1_chipexo/basename_prefix.pooled.negative.bigwig",
    counts_mode_name="task0_logcount",
    profile_mode_name="task0_profile",
    center_size_to_use=out_pred_len)

keras_train_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
      bed_file="/users/amr1/pho4/data/genome/train.bed.gz",
      coord_batch_transformer=
          coordbatchtransformers.ReverseComplementAugmenter().chain(
          coordbatchtransformers.UniformJitter(
              maxshift=200, chromsizes_file="/users/amr1/pho4/data/genome/sacCer3.chrom.sizes")),
      batch_size=64,
      shuffle_before_epoch=True, 
      seed=1234),
    inputs_coordstovals=inputs_coordstovals,
    targets_coordstovals=targets_coordstovals)

keras_valid_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
            bed_file="/users/amr1/pho4/data/genome/valid.bed.gz",
            batch_size=64,
            shuffle_before_epoch=False, 
            seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)

thebatch = keras_train_batch_generator[0]
for tupleidx,tupleentry in enumerate(thebatch):
  print("Tuple entry",tupleidx)
  for key in tupleentry:
    print(key, tupleentry[key].shape)
# Out:
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Tuple entry 0
# sequence (128, 546, 4)
# control_logcount (128,)
# control_profile (128, 250, 2)
# Tuple entry 1
# task0_logcount (128, 2)
# task0_profile (128, 250, 2)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2,3"

model = modelwrapper.get_keras_model()
print(model.summary())
early_stopping_callback = keras.callbacks.EarlyStopping(
                          patience=25, restore_best_weights=True)
loss_history = model.fit_generator(keras_train_batch_generator,
                  epochs=500,
                  validation_data=keras_valid_batch_generator,
                  callbacks=[early_stopping_callback])
model.set_weights(early_stopping_callback.best_weights)
# Out:
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# [<tf.Tensor 'lambda_1/strided_slice:0' shape=(?, 522, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_2/Relu:0' shape=(?, 522, 50) dtype=float32>]
# [<tf.Tensor 'lambda_2/strided_slice:0' shape=(?, 514, 50) dtype=float32>, <tf.Tensor 'lambda_3/strided_slice:0' shape=(?, 514, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_3/Relu:0' shape=(?, 514, 50) dtype=float32>]
# [<tf.Tensor 'lambda_4/strided_slice:0' shape=(?, 498, 50) dtype=float32>, <tf.Tensor 'lambda_5/strided_slice:0' shape=(?, 498, 50) dtype=float32>, <tf.Tensor 'lambda_6/strided_slice:0' shape=(?, 498, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_4/Relu:0' shape=(?, 498, 50) dtype=float32>]
# [<tf.Tensor 'lambda_7/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'lambda_8/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'lambda_9/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'lambda_10/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_5/Relu:0' shape=(?, 466, 50) dtype=float32>]
# [<tf.Tensor 'lambda_11/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_12/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_13/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_14/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_15/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_6/Relu:0' shape=(?, 402, 50) dtype=float32>]
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From <ipython-input-2-dbf16efbe78d>:28: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           (None, 546, 4)       0
# __________________________________________________________________________________________________
# rev_comp_conv1d_1 (RevCompConv1 (None, 526, 50)      2125        sequence[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 522, 50)      0           rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_2 (RevCompConv1 (None, 522, 50)      3775        rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 522, 50)      0           lambda_1[0][0]
#                                                                  rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 514, 50)      0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 514, 50)      0           rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_3 (RevCompConv1 (None, 514, 50)      3775        average_1[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 514, 50)      0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 498, 50)      0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 498, 50)      0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 498, 50)      0           rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_4 (RevCompConv1 (None, 498, 50)      3775        average_2[0][0]
# __________________________________________________________________________________________________
# average_3 (Average)             (None, 498, 50)      0           lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 466, 50)      0           lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 466, 50)      0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 466, 50)      0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 466, 50)      0           rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_5 (RevCompConv1 (None, 466, 50)      3775        average_3[0][0]
# __________________________________________________________________________________________________
# average_4 (Average)             (None, 466, 50)      0           lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 402, 50)      0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 402, 50)      0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 402, 50)      0           lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 402, 50)      0           lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 402, 50)      0           rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_6 (RevCompConv1 (None, 402, 50)      3775        average_4[0][0]
# __________________________________________________________________________________________________
# average_5 (Average)             (None, 402, 50)      0           lambda_11[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
#                                                                  rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 274, 50)      0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 274, 50)      0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 274, 50)      0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 274, 50)      0           lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 274, 50)      0           lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 274, 50)      0           rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_7 (RevCompConv1 (None, 274, 50)      3775        average_5[0][0]
# __________________________________________________________________________________________________
# control_logcount (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# average_6 (Average)             (None, 274, 50)      0           lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_21[0][0]
#                                                                  rev_comp_conv1d_7[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           control_logcount[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 50)           0           average_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 52)           0           lambda_22[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  control_logcount[0][0]
# __________________________________________________________________________________________________
# control_profile (InputLayer)    (None, 250, 2)       0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 52)        0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 250, 2)       0           control_profile[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_9 (RevCompConv1 (None, 250, 2)       1251        average_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_8 (RevCompConv1 (None, 1, 2)         53          reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 250, 6)       0           lambda_23[0][0]
#                                                                  rev_comp_conv1d_9[0][0]
#                                                                  control_profile[0][0]
# __________________________________________________________________________________________________
# task0_logcount (Reshape)        (None, 2)            0           rev_comp_conv1d_8[0][0]
# __________________________________________________________________________________________________
# task0_profile (RevCompConv1D)   (None, 250, 2)       7           concatenate_2[0][0]
# ==================================================================================================
# Total params: 26,086
# Trainable params: 26,086
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/500
# 267/267 [==============================] - 56s 209ms/step - loss: 509.5728 - task0_logcount_loss: 1.6601 - task0_profile_loss: 492.9718 - val_loss: 416.2638 - val_task0_logcount_loss: 0.8848 - val_task0_profile_loss: 407.4160
# Epoch 2/500
# 267/267 [==============================] - 45s 168ms/step - loss: 433.1222 - task0_logcount_loss: 0.9353 - task0_profile_loss: 423.7688 - val_loss: 386.6456 - val_task0_logcount_loss: 0.7788 - val_task0_profile_loss: 378.8572
# Epoch 3/500
# 267/267 [==============================] - 45s 168ms/step - loss: 401.5327 - task0_logcount_loss: 0.8792 - task0_profile_loss: 392.7406 - val_loss: 371.1710 - val_task0_logcount_loss: 0.7479 - val_task0_profile_loss: 363.6917
# Epoch 4/500
# 267/267 [==============================] - 45s 167ms/step - loss: 375.9875 - task0_logcount_loss: 0.8861 - task0_profile_loss: 367.1269 - val_loss: 360.8873 - val_task0_logcount_loss: 0.7487 - val_task0_profile_loss: 353.4001
# Epoch 5/500
# 267/267 [==============================] - 45s 169ms/step - loss: 359.7971 - task0_logcount_loss: 0.8638 - task0_profile_loss: 351.1587 - val_loss: 359.6457 - val_task0_logcount_loss: 0.9910 - val_task0_profile_loss: 349.7352
# Epoch 6/500
# 267/267 [==============================] - 44s 165ms/step - loss: 358.1300 - task0_logcount_loss: 0.8812 - task0_profile_loss: 349.3177 - val_loss: 356.8785 - val_task0_logcount_loss: 0.7411 - val_task0_profile_loss: 349.4676
# Epoch 7/500
# 267/267 [==============================] - 46s 171ms/step - loss: 357.0595 - task0_logcount_loss: 0.8621 - task0_profile_loss: 348.4381 - val_loss: 356.6635 - val_task0_logcount_loss: 0.7362 - val_task0_profile_loss: 349.3011
# Epoch 8/500
# 267/267 [==============================] - 44s 164ms/step - loss: 357.4350 - task0_logcount_loss: 0.8695 - task0_profile_loss: 348.7397 - val_loss: 356.6996 - val_task0_logcount_loss: 0.7520 - val_task0_profile_loss: 349.1795
# Epoch 9/500
# 267/267 [==============================] - 44s 166ms/step - loss: 357.4868 - task0_logcount_loss: 0.8700 - task0_profile_loss: 348.7868 - val_loss: 356.5005 - val_task0_logcount_loss: 0.7369 - val_task0_profile_loss: 349.1312
# Epoch 10/500
# 267/267 [==============================] - 45s 169ms/step - loss: 357.3955 - task0_logcount_loss: 0.8723 - task0_profile_loss: 348.6729 - val_loss: 356.4971 - val_task0_logcount_loss: 0.7425 - val_task0_profile_loss: 349.0722
# Epoch 11/500
# 267/267 [==============================] - 45s 169ms/step - loss: 357.0042 - task0_logcount_loss: 0.8755 - task0_profile_loss: 348.2490 - val_loss: 356.4259 - val_task0_logcount_loss: 0.7498 - val_task0_profile_loss: 348.9278
# Epoch 12/500
# 267/267 [==============================] - 44s 166ms/step - loss: 356.9845 - task0_logcount_loss: 0.8627 - task0_profile_loss: 348.3576 - val_loss: 357.3684 - val_task0_logcount_loss: 0.8465 - val_task0_profile_loss: 348.9036
# Epoch 13/500
# 267/267 [==============================] - 45s 170ms/step - loss: 357.1585 - task0_logcount_loss: 0.8700 - task0_profile_loss: 348.4584 - val_loss: 356.1486 - val_task0_logcount_loss: 0.7311 - val_task0_profile_loss: 348.8376
# Epoch 14/500
# 267/267 [==============================] - 45s 169ms/step - loss: 356.9040 - task0_logcount_loss: 0.8525 - task0_profile_loss: 348.3792 - val_loss: 356.1772 - val_task0_logcount_loss: 0.7405 - val_task0_profile_loss: 348.7723
# Epoch 15/500
# 267/267 [==============================] - 44s 165ms/step - loss: 356.3192 - task0_logcount_loss: 0.8473 - task0_profile_loss: 347.8458 - val_loss: 355.9861 - val_task0_logcount_loss: 0.7264 - val_task0_profile_loss: 348.7222
# Epoch 16/500
# 267/267 [==============================] - 45s 170ms/step - loss: 356.8050 - task0_logcount_loss: 0.8658 - task0_profile_loss: 348.1469 - val_loss: 356.2851 - val_task0_logcount_loss: 0.7283 - val_task0_profile_loss: 349.0018
# Epoch 17/500
# 267/267 [==============================] - 45s 167ms/step - loss: 356.2940 - task0_logcount_loss: 0.8439 - task0_profile_loss: 347.8551 - val_loss: 355.7870 - val_task0_logcount_loss: 0.7244 - val_task0_profile_loss: 348.5432
# Epoch 18/500
# 267/267 [==============================] - 45s 170ms/step - loss: 356.4777 - task0_logcount_loss: 0.8419 - task0_profile_loss: 348.0589 - val_loss: 355.6884 - val_task0_logcount_loss: 0.7366 - val_task0_profile_loss: 348.3219
# Epoch 19/500
# 267/267 [==============================] - 45s 168ms/step - loss: 356.8259 - task0_logcount_loss: 0.8529 - task0_profile_loss: 348.2971 - val_loss: 355.6579 - val_task0_logcount_loss: 0.7622 - val_task0_profile_loss: 348.0355
# Epoch 20/500
# 267/267 [==============================] - 45s 167ms/step - loss: 356.1426 - task0_logcount_loss: 0.8271 - task0_profile_loss: 347.8715 - val_loss: 355.2674 - val_task0_logcount_loss: 0.7530 - val_task0_profile_loss: 347.7369
# Epoch 21/500
# 267/267 [==============================] - 44s 166ms/step - loss: 355.8879 - task0_logcount_loss: 0.8338 - task0_profile_loss: 347.5499 - val_loss: 355.0217 - val_task0_logcount_loss: 0.7190 - val_task0_profile_loss: 347.8317
# Epoch 22/500
# 267/267 [==============================] - 44s 165ms/step - loss: 355.7713 - task0_logcount_loss: 0.8343 - task0_profile_loss: 347.4280 - val_loss: 355.3553 - val_task0_logcount_loss: 0.7797 - val_task0_profile_loss: 347.5580
# Epoch 23/500
# 267/267 [==============================] - 44s 166ms/step - loss: 355.5930 - task0_logcount_loss: 0.8219 - task0_profile_loss: 347.3743 - val_loss: 354.5843 - val_task0_logcount_loss: 0.7084 - val_task0_profile_loss: 347.5008
# Epoch 24/500
# 267/267 [==============================] - 45s 167ms/step - loss: 355.8669 - task0_logcount_loss: 0.8225 - task0_profile_loss: 347.6422 - val_loss: 354.5775 - val_task0_logcount_loss: 0.7039 - val_task0_profile_loss: 347.5382
# Epoch 25/500
# 267/267 [==============================] - 44s 166ms/step - loss: 355.7159 - task0_logcount_loss: 0.8124 - task0_profile_loss: 347.5916 - val_loss: 355.0208 - val_task0_logcount_loss: 0.7578 - val_task0_profile_loss: 347.4429
# Epoch 26/500
# 267/267 [==============================] - 44s 164ms/step - loss: 355.4117 - task0_logcount_loss: 0.8087 - task0_profile_loss: 347.3250 - val_loss: 354.9667 - val_task0_logcount_loss: 0.7436 - val_task0_profile_loss: 347.5310
# Epoch 27/500
# 267/267 [==============================] - 45s 167ms/step - loss: 355.7297 - task0_logcount_loss: 0.8077 - task0_profile_loss: 347.6527 - val_loss: 354.8506 - val_task0_logcount_loss: 0.7257 - val_task0_profile_loss: 347.5936
# Epoch 28/500
# 267/267 [==============================] - 45s 169ms/step - loss: 355.2092 - task0_logcount_loss: 0.8002 - task0_profile_loss: 347.2068 - val_loss: 354.5685 - val_task0_logcount_loss: 0.6967 - val_task0_profile_loss: 347.6012
# Epoch 29/500
# 267/267 [==============================] - 45s 169ms/step - loss: 355.1675 - task0_logcount_loss: 0.7961 - task0_profile_loss: 347.2068 - val_loss: 354.4648 - val_task0_logcount_loss: 0.6947 - val_task0_profile_loss: 347.5177
# Epoch 30/500
# 267/267 [==============================] - 44s 166ms/step - loss: 355.7316 - task0_logcount_loss: 0.7954 - task0_profile_loss: 347.7780 - val_loss: 354.3248 - val_task0_logcount_loss: 0.6852 - val_task0_profile_loss: 347.4729
# Epoch 31/500
# 267/267 [==============================] - 45s 169ms/step - loss: 354.5466 - task0_logcount_loss: 0.7783 - task0_profile_loss: 346.7634 - val_loss: 354.2999 - val_task0_logcount_loss: 0.6873 - val_task0_profile_loss: 347.4269
# Epoch 32/500
# 267/267 [==============================] - 45s 169ms/step - loss: 355.6159 - task0_logcount_loss: 0.7868 - task0_profile_loss: 347.7477 - val_loss: 354.2251 - val_task0_logcount_loss: 0.6818 - val_task0_profile_loss: 347.4072
# Epoch 33/500
# 267/267 [==============================] - 45s 168ms/step - loss: 354.8259 - task0_logcount_loss: 0.7653 - task0_profile_loss: 347.1730 - val_loss: 354.0232 - val_task0_logcount_loss: 0.6612 - val_task0_profile_loss: 347.4115
# Epoch 34/500
# 267/267 [==============================] - 45s 168ms/step - loss: 354.7290 - task0_logcount_loss: 0.7596 - task0_profile_loss: 347.1331 - val_loss: 354.0197 - val_task0_logcount_loss: 0.6534 - val_task0_profile_loss: 347.4856
# Epoch 35/500
# 267/267 [==============================] - 44s 165ms/step - loss: 354.6451 - task0_logcount_loss: 0.7514 - task0_profile_loss: 347.1308 - val_loss: 353.8488 - val_task0_logcount_loss: 0.6428 - val_task0_profile_loss: 347.4207
# Epoch 36/500
# 267/267 [==============================] - 44s 166ms/step - loss: 354.7362 - task0_logcount_loss: 0.7455 - task0_profile_loss: 347.2808 - val_loss: 355.3544 - val_task0_logcount_loss: 0.7977 - val_task0_profile_loss: 347.3772
# Epoch 37/500
# 267/267 [==============================] - 45s 168ms/step - loss: 354.6911 - task0_logcount_loss: 0.7361 - task0_profile_loss: 347.3299 - val_loss: 353.6742 - val_task0_logcount_loss: 0.6317 - val_task0_profile_loss: 347.3568
# Epoch 38/500
# 267/267 [==============================] - 45s 170ms/step - loss: 355.1267 - task0_logcount_loss: 0.7312 - task0_profile_loss: 347.8152 - val_loss: 354.0888 - val_task0_logcount_loss: 0.6258 - val_task0_profile_loss: 347.8308
# Epoch 39/500
# 267/267 [==============================] - 45s 167ms/step - loss: 354.6136 - task0_logcount_loss: 0.7351 - task0_profile_loss: 347.2622 - val_loss: 355.1206 - val_task0_logcount_loss: 0.7316 - val_task0_profile_loss: 347.8046
# Epoch 40/500
# 267/267 [==============================] - 44s 166ms/step - loss: 354.3863 - task0_logcount_loss: 0.7158 - task0_profile_loss: 347.2286 - val_loss: 354.9712 - val_task0_logcount_loss: 0.6992 - val_task0_profile_loss: 347.9792
# Epoch 41/500
# 267/267 [==============================] - 45s 170ms/step - loss: 354.0867 - task0_logcount_loss: 0.7003 - task0_profile_loss: 347.0837 - val_loss: 353.4497 - val_task0_logcount_loss: 0.6048 - val_task0_profile_loss: 347.4018
# Epoch 42/500
# 267/267 [==============================] - 45s 169ms/step - loss: 354.4881 - task0_logcount_loss: 0.6914 - task0_profile_loss: 347.5742 - val_loss: 353.8321 - val_task0_logcount_loss: 0.6093 - val_task0_profile_loss: 347.7396
# Epoch 43/500
# 267/267 [==============================] - 45s 167ms/step - loss: 354.4545 - task0_logcount_loss: 0.6869 - task0_profile_loss: 347.5856 - val_loss: 356.3269 - val_task0_logcount_loss: 0.5903 - val_task0_profile_loss: 350.4241
# Epoch 44/500
# 267/267 [==============================] - 45s 167ms/step - loss: 360.0404 - task0_logcount_loss: 0.6895 - task0_profile_loss: 353.1456 - val_loss: 354.1346 - val_task0_logcount_loss: 0.5926 - val_task0_profile_loss: 348.2082
# Epoch 45/500
# 267/267 [==============================] - 44s 166ms/step - loss: 354.5609 - task0_logcount_loss: 0.6723 - task0_profile_loss: 347.8378 - val_loss: 355.4383 - val_task0_logcount_loss: 0.7951 - val_task0_profile_loss: 347.4875
# Epoch 46/500
# 267/267 [==============================] - 46s 171ms/step - loss: 353.9424 - task0_logcount_loss: 0.6629 - task0_profile_loss: 347.3129 - val_loss: 354.4161 - val_task0_logcount_loss: 0.6818 - val_task0_profile_loss: 347.5981
# Epoch 47/500
# 267/267 [==============================] - 45s 170ms/step - loss: 353.4559 - task0_logcount_loss: 0.6453 - task0_profile_loss: 347.0032 - val_loss: 353.9831 - val_task0_logcount_loss: 0.6094 - val_task0_profile_loss: 347.8887
# Epoch 48/500
# 267/267 [==============================] - 45s 169ms/step - loss: 353.6151 - task0_logcount_loss: 0.6380 - task0_profile_loss: 347.2353 - val_loss: 353.1949 - val_task0_logcount_loss: 0.5872 - val_task0_profile_loss: 347.3229
# Epoch 49/500
# 267/267 [==============================] - 44s 165ms/step - loss: 353.3633 - task0_logcount_loss: 0.6183 - task0_profile_loss: 347.1799 - val_loss: 353.2586 - val_task0_logcount_loss: 0.5909 - val_task0_profile_loss: 347.3491
# Epoch 50/500
# 267/267 [==============================] - 45s 168ms/step - loss: 353.5376 - task0_logcount_loss: 0.6173 - task0_profile_loss: 347.3647 - val_loss: 352.9090 - val_task0_logcount_loss: 0.5518 - val_task0_profile_loss: 347.3911
# Epoch 51/500
# 267/267 [==============================] - 45s 167ms/step - loss: 353.0626 - task0_logcount_loss: 0.5927 - task0_profile_loss: 347.1361 - val_loss: 352.7882 - val_task0_logcount_loss: 0.5433 - val_task0_profile_loss: 347.3551
# Epoch 52/500
# 267/267 [==============================] - 45s 167ms/step - loss: 353.1975 - task0_logcount_loss: 0.5978 - task0_profile_loss: 347.2192 - val_loss: 353.4768 - val_task0_logcount_loss: 0.5992 - val_task0_profile_loss: 347.4845
# Epoch 53/500
# 267/267 [==============================] - 45s 168ms/step - loss: 352.9255 - task0_logcount_loss: 0.5445 - task0_profile_loss: 347.4807 - val_loss: 353.3204 - val_task0_logcount_loss: 0.5760 - val_task0_profile_loss: 347.5605
# Epoch 54/500
# 267/267 [==============================] - 45s 167ms/step - loss: 352.5696 - task0_logcount_loss: 0.5345 - task0_profile_loss: 347.2244 - val_loss: 352.3607 - val_task0_logcount_loss: 0.4816 - val_task0_profile_loss: 347.5451
# Epoch 55/500
# 267/267 [==============================] - 44s 165ms/step - loss: 352.6754 - task0_logcount_loss: 0.5101 - task0_profile_loss: 347.5739 - val_loss: 353.5112 - val_task0_logcount_loss: 0.5653 - val_task0_profile_loss: 347.8586
# Epoch 56/500
# 267/267 [==============================] - 45s 168ms/step - loss: 352.5080 - task0_logcount_loss: 0.5001 - task0_profile_loss: 347.5066 - val_loss: 352.3221 - val_task0_logcount_loss: 0.4661 - val_task0_profile_loss: 347.6606
# Epoch 57/500
# 267/267 [==============================] - 45s 170ms/step - loss: 352.1254 - task0_logcount_loss: 0.4641 - task0_profile_loss: 347.4841 - val_loss: 351.9825 - val_task0_logcount_loss: 0.4557 - val_task0_profile_loss: 347.4256
# Epoch 58/500
# 267/267 [==============================] - 45s 169ms/step - loss: 351.7826 - task0_logcount_loss: 0.4653 - task0_profile_loss: 347.1294 - val_loss: 352.3701 - val_task0_logcount_loss: 0.5013 - val_task0_profile_loss: 347.3574
# Epoch 59/500
# 267/267 [==============================] - 44s 165ms/step - loss: 351.9374 - task0_logcount_loss: 0.4603 - task0_profile_loss: 347.3345 - val_loss: 351.7807 - val_task0_logcount_loss: 0.4430 - val_task0_profile_loss: 347.3510
# Epoch 60/500
# 267/267 [==============================] - 44s 167ms/step - loss: 351.6048 - task0_logcount_loss: 0.4410 - task0_profile_loss: 347.1945 - val_loss: 352.1369 - val_task0_logcount_loss: 0.4758 - val_task0_profile_loss: 347.3785
# Epoch 61/500
# 267/267 [==============================] - 45s 168ms/step - loss: 351.6727 - task0_logcount_loss: 0.4229 - task0_profile_loss: 347.4438 - val_loss: 351.9180 - val_task0_logcount_loss: 0.4576 - val_task0_profile_loss: 347.3418
# Epoch 62/500
# 267/267 [==============================] - 45s 168ms/step - loss: 351.5991 - task0_logcount_loss: 0.4352 - task0_profile_loss: 347.2470 - val_loss: 352.0693 - val_task0_logcount_loss: 0.4729 - val_task0_profile_loss: 347.3408
# Epoch 63/500
# 267/267 [==============================] - 44s 166ms/step - loss: 351.3824 - task0_logcount_loss: 0.4166 - task0_profile_loss: 347.2162 - val_loss: 351.9423 - val_task0_logcount_loss: 0.4416 - val_task0_profile_loss: 347.5263
# Epoch 64/500
# 267/267 [==============================] - 45s 167ms/step - loss: 351.0930 - task0_logcount_loss: 0.4039 - task0_profile_loss: 347.0545 - val_loss: 351.7672 - val_task0_logcount_loss: 0.4271 - val_task0_profile_loss: 347.4957
# Epoch 65/500
# 267/267 [==============================] - 45s 168ms/step - loss: 351.5269 - task0_logcount_loss: 0.3981 - task0_profile_loss: 347.5460 - val_loss: 351.8769 - val_task0_logcount_loss: 0.4576 - val_task0_profile_loss: 347.3013
# Epoch 66/500
# 267/267 [==============================] - 45s 167ms/step - loss: 351.0981 - task0_logcount_loss: 0.3859 - task0_profile_loss: 347.2386 - val_loss: 352.0865 - val_task0_logcount_loss: 0.4302 - val_task0_profile_loss: 347.7843
# Epoch 67/500
# 267/267 [==============================] - 44s 166ms/step - loss: 350.7705 - task0_logcount_loss: 0.3851 - task0_profile_loss: 346.9194 - val_loss: 351.7538 - val_task0_logcount_loss: 0.4224 - val_task0_profile_loss: 347.5302
# Epoch 68/500
# 267/267 [==============================] - 45s 167ms/step - loss: 350.9778 - task0_logcount_loss: 0.3742 - task0_profile_loss: 347.2358 - val_loss: 351.6001 - val_task0_logcount_loss: 0.4265 - val_task0_profile_loss: 347.3347
# Epoch 69/500
# 267/267 [==============================] - 45s 170ms/step - loss: 350.7692 - task0_logcount_loss: 0.3668 - task0_profile_loss: 347.1009 - val_loss: 351.9773 - val_task0_logcount_loss: 0.4689 - val_task0_profile_loss: 347.2887
# Epoch 70/500
# 267/267 [==============================] - 45s 168ms/step - loss: 350.7947 - task0_logcount_loss: 0.3758 - task0_profile_loss: 347.0364 - val_loss: 351.3022 - val_task0_logcount_loss: 0.4084 - val_task0_profile_loss: 347.2180
# Epoch 71/500
# 267/267 [==============================] - 45s 168ms/step - loss: 351.7986 - task0_logcount_loss: 0.3598 - task0_profile_loss: 348.2004 - val_loss: 352.3419 - val_task0_logcount_loss: 0.4642 - val_task0_profile_loss: 347.6995
# Epoch 72/500
# 267/267 [==============================] - 45s 169ms/step - loss: 350.6696 - task0_logcount_loss: 0.3607 - task0_profile_loss: 347.0627 - val_loss: 351.3744 - val_task0_logcount_loss: 0.4136 - val_task0_profile_loss: 347.2380
# Epoch 73/500
# 267/267 [==============================] - 45s 168ms/step - loss: 350.7523 - task0_logcount_loss: 0.3610 - task0_profile_loss: 347.1428 - val_loss: 351.2416 - val_task0_logcount_loss: 0.4009 - val_task0_profile_loss: 347.2325
# Epoch 74/500
# 267/267 [==============================] - 45s 170ms/step - loss: 350.7901 - task0_logcount_loss: 0.3357 - task0_profile_loss: 347.4332 - val_loss: 351.0831 - val_task0_logcount_loss: 0.3906 - val_task0_profile_loss: 347.1775
# Epoch 75/500
# 267/267 [==============================] - 45s 170ms/step - loss: 350.5334 - task0_logcount_loss: 0.3438 - task0_profile_loss: 347.0959 - val_loss: 351.2662 - val_task0_logcount_loss: 0.4003 - val_task0_profile_loss: 347.2635
# Epoch 76/500
# 267/267 [==============================] - 45s 170ms/step - loss: 350.7958 - task0_logcount_loss: 0.3461 - task0_profile_loss: 347.3353 - val_loss: 351.1216 - val_task0_logcount_loss: 0.3900 - val_task0_profile_loss: 347.2218
# Epoch 77/500
# 267/267 [==============================] - 45s 168ms/step - loss: 350.3793 - task0_logcount_loss: 0.3302 - task0_profile_loss: 347.0769 - val_loss: 351.1865 - val_task0_logcount_loss: 0.3899 - val_task0_profile_loss: 347.2873
# Epoch 78/500
# 267/267 [==============================] - 45s 169ms/step - loss: 352.3649 - task0_logcount_loss: 0.3382 - task0_profile_loss: 348.9833 - val_loss: 351.5722 - val_task0_logcount_loss: 0.4173 - val_task0_profile_loss: 347.3995
# Epoch 79/500
# 267/267 [==============================] - 45s 169ms/step - loss: 350.0320 - task0_logcount_loss: 0.3211 - task0_profile_loss: 346.8205 - val_loss: 351.0157 - val_task0_logcount_loss: 0.3809 - val_task0_profile_loss: 347.2065
# Epoch 80/500
# 267/267 [==============================] - 45s 169ms/step - loss: 350.1952 - task0_logcount_loss: 0.3256 - task0_profile_loss: 346.9396 - val_loss: 351.6466 - val_task0_logcount_loss: 0.4300 - val_task0_profile_loss: 347.3467
# Epoch 81/500
# 267/267 [==============================] - 46s 171ms/step - loss: 350.5286 - task0_logcount_loss: 0.3167 - task0_profile_loss: 347.3619 - val_loss: 351.5416 - val_task0_logcount_loss: 0.4332 - val_task0_profile_loss: 347.2092
# Epoch 82/500
# 267/267 [==============================] - 45s 169ms/step - loss: 350.1268 - task0_logcount_loss: 0.3158 - task0_profile_loss: 346.9685 - val_loss: 351.2963 - val_task0_logcount_loss: 0.3939 - val_task0_profile_loss: 347.3578
# Epoch 83/500
# 267/267 [==============================] - 45s 170ms/step - loss: 350.0418 - task0_logcount_loss: 0.3040 - task0_profile_loss: 347.0021 - val_loss: 351.0332 - val_task0_logcount_loss: 0.3828 - val_task0_profile_loss: 347.2054
# Epoch 84/500
# 267/267 [==============================] - 45s 170ms/step - loss: 349.9844 - task0_logcount_loss: 0.3022 - task0_profile_loss: 346.9624 - val_loss: 351.3042 - val_task0_logcount_loss: 0.3932 - val_task0_profile_loss: 347.3725
# Epoch 85/500
# 267/267 [==============================] - 45s 168ms/step - loss: 349.8671 - task0_logcount_loss: 0.3040 - task0_profile_loss: 346.8272 - val_loss: 351.8602 - val_task0_logcount_loss: 0.4619 - val_task0_profile_loss: 347.2413
# Epoch 86/500
# 267/267 [==============================] - 46s 171ms/step - loss: 350.3402 - task0_logcount_loss: 0.3236 - task0_profile_loss: 347.1044 - val_loss: 351.2848 - val_task0_logcount_loss: 0.4070 - val_task0_profile_loss: 347.2149
# Epoch 87/500
# 267/267 [==============================] - 45s 169ms/step - loss: 350.5193 - task0_logcount_loss: 0.3012 - task0_profile_loss: 347.5076 - val_loss: 351.4433 - val_task0_logcount_loss: 0.4215 - val_task0_profile_loss: 347.2279
# Epoch 88/500
# 267/267 [==============================] - 44s 166ms/step - loss: 350.2865 - task0_logcount_loss: 0.3121 - task0_profile_loss: 347.1657 - val_loss: 350.9730 - val_task0_logcount_loss: 0.3746 - val_task0_profile_loss: 347.2266
# Epoch 89/500
# 267/267 [==============================] - 45s 170ms/step - loss: 349.7081 - task0_logcount_loss: 0.2879 - task0_profile_loss: 346.8287 - val_loss: 351.0957 - val_task0_logcount_loss: 0.3800 - val_task0_profile_loss: 347.2959
# Epoch 90/500
# 267/267 [==============================] - 45s 170ms/step - loss: 349.7776 - task0_logcount_loss: 0.2871 - task0_profile_loss: 346.9068 - val_loss: 350.9643 - val_task0_logcount_loss: 0.3686 - val_task0_profile_loss: 347.2782
# Epoch 91/500
# 267/267 [==============================] - 45s 170ms/step - loss: 349.8825 - task0_logcount_loss: 0.2931 - task0_profile_loss: 346.9510 - val_loss: 351.1649 - val_task0_logcount_loss: 0.3860 - val_task0_profile_loss: 347.3048
# Epoch 92/500
# 267/267 [==============================] - 46s 171ms/step - loss: 349.6883 - task0_logcount_loss: 0.2862 - task0_profile_loss: 346.8263 - val_loss: 351.4028 - val_task0_logcount_loss: 0.4238 - val_task0_profile_loss: 347.1649
# Epoch 93/500
# 267/267 [==============================] - 45s 169ms/step - loss: 350.0025 - task0_logcount_loss: 0.2844 - task0_profile_loss: 347.1580 - val_loss: 352.0165 - val_task0_logcount_loss: 0.4694 - val_task0_profile_loss: 347.3222
# Epoch 94/500
# 267/267 [==============================] - 45s 170ms/step - loss: 350.1005 - task0_logcount_loss: 0.2832 - task0_profile_loss: 347.2686 - val_loss: 351.7210 - val_task0_logcount_loss: 0.4144 - val_task0_profile_loss: 347.5765
# Epoch 95/500
# 267/267 [==============================] - 45s 169ms/step - loss: 350.1510 - task0_logcount_loss: 0.2790 - task0_profile_loss: 347.3610 - val_loss: 350.9260 - val_task0_logcount_loss: 0.3727 - val_task0_profile_loss: 347.1987
# Epoch 96/500
# 267/267 [==============================] - 46s 170ms/step - loss: 349.7181 - task0_logcount_loss: 0.2761 - task0_profile_loss: 346.9570 - val_loss: 351.3781 - val_task0_logcount_loss: 0.4086 - val_task0_profile_loss: 347.2924
# Epoch 97/500
# 267/267 [==============================] - 45s 170ms/step - loss: 349.8798 - task0_logcount_loss: 0.2755 - task0_profile_loss: 347.1250 - val_loss: 350.8591 - val_task0_logcount_loss: 0.3671 - val_task0_profile_loss: 347.1878
# Epoch 98/500
# 267/267 [==============================] - 45s 169ms/step - loss: 349.8695 - task0_logcount_loss: 0.2799 - task0_profile_loss: 347.0705 - val_loss: 350.9957 - val_task0_logcount_loss: 0.3715 - val_task0_profile_loss: 347.2806
# Epoch 99/500
# 267/267 [==============================] - 45s 169ms/step - loss: 349.7086 - task0_logcount_loss: 0.2754 - task0_profile_loss: 346.9545 - val_loss: 352.8444 - val_task0_logcount_loss: 0.5556 - val_task0_profile_loss: 347.2883
# Epoch 100/500
# 267/267 [==============================] - 45s 169ms/step - loss: 350.2714 - task0_logcount_loss: 0.2587 - task0_profile_loss: 347.6842 - val_loss: 351.0460 - val_task0_logcount_loss: 0.3769 - val_task0_profile_loss: 347.2766
# Epoch 101/500
# 267/267 [==============================] - 45s 167ms/step - loss: 349.6709 - task0_logcount_loss: 0.2675 - task0_profile_loss: 346.9963 - val_loss: 350.7630 - val_task0_logcount_loss: 0.3557 - val_task0_profile_loss: 347.2060
# Epoch 102/500
# 267/267 [==============================] - 45s 168ms/step - loss: 349.6313 - task0_logcount_loss: 0.2602 - task0_profile_loss: 347.0295 - val_loss: 351.1800 - val_task0_logcount_loss: 0.3844 - val_task0_profile_loss: 347.3364
# Epoch 103/500
# 267/267 [==============================] - 45s 169ms/step - loss: 349.6999 - task0_logcount_loss: 0.2603 - task0_profile_loss: 347.0973 - val_loss: 350.8977 - val_task0_logcount_loss: 0.3619 - val_task0_profile_loss: 347.2790
# Epoch 104/500
# 267/267 [==============================] - 45s 168ms/step - loss: 349.5136 - task0_logcount_loss: 0.2553 - task0_profile_loss: 346.9605 - val_loss: 351.8898 - val_task0_logcount_loss: 0.4646 - val_task0_profile_loss: 347.2434
# Epoch 105/500
# 267/267 [==============================] - 44s 166ms/step - loss: 349.1902 - task0_logcount_loss: 0.2484 - task0_profile_loss: 346.7065 - val_loss: 350.7635 - val_task0_logcount_loss: 0.3569 - val_task0_profile_loss: 347.1950
# Epoch 106/500
# 267/267 [==============================] - 45s 169ms/step - loss: 349.4516 - task0_logcount_loss: 0.2495 - task0_profile_loss: 346.9563 - val_loss: 350.9743 - val_task0_logcount_loss: 0.3655 - val_task0_profile_loss: 347.3190
# Epoch 107/500
# 267/267 [==============================] - 45s 169ms/step - loss: 349.8144 - task0_logcount_loss: 0.2560 - task0_profile_loss: 347.2542 - val_loss: 350.8436 - val_task0_logcount_loss: 0.3469 - val_task0_profile_loss: 347.3746
# Epoch 108/500
# 267/267 [==============================] - 45s 169ms/step - loss: 349.7550 - task0_logcount_loss: 0.2750 - task0_profile_loss: 347.0053 - val_loss: 351.0248 - val_task0_logcount_loss: 0.3800 - val_task0_profile_loss: 347.2253
# Epoch 109/500
# 267/267 [==============================] - 45s 169ms/step - loss: 349.8580 - task0_logcount_loss: 0.2370 - task0_profile_loss: 347.4878 - val_loss: 351.4179 - val_task0_logcount_loss: 0.4114 - val_task0_profile_loss: 347.3044
# Epoch 110/500
# 267/267 [==============================] - 45s 168ms/step - loss: 349.6191 - task0_logcount_loss: 0.2482 - task0_profile_loss: 347.1367 - val_loss: 351.2009 - val_task0_logcount_loss: 0.3919 - val_task0_profile_loss: 347.2823
# Epoch 111/500
# 267/267 [==============================] - 45s 169ms/step - loss: 349.4377 - task0_logcount_loss: 0.2390 - task0_profile_loss: 347.0475 - val_loss: 351.4355 - val_task0_logcount_loss: 0.3811 - val_task0_profile_loss: 347.6247
# Epoch 112/500
# 267/267 [==============================] - 45s 168ms/step - loss: 349.4791 - task0_logcount_loss: 0.2414 - task0_profile_loss: 347.0650 - val_loss: 351.0416 - val_task0_logcount_loss: 0.3801 - val_task0_profile_loss: 347.2401
# Epoch 113/500
# 267/267 [==============================] - 45s 169ms/step - loss: 349.5798 - task0_logcount_loss: 0.2452 - task0_profile_loss: 347.1281 - val_loss: 350.6300 - val_task0_logcount_loss: 0.3434 - val_task0_profile_loss: 347.1959
# Epoch 114/500
# 267/267 [==============================] - 45s 167ms/step - loss: 349.3155 - task0_logcount_loss: 0.2345 - task0_profile_loss: 346.9703 - val_loss: 350.9674 - val_task0_logcount_loss: 0.3556 - val_task0_profile_loss: 347.4117
# Epoch 115/500
# 267/267 [==============================] - 45s 168ms/step - loss: 349.6527 - task0_logcount_loss: 0.2375 - task0_profile_loss: 347.2774 - val_loss: 351.2493 - val_task0_logcount_loss: 0.4023 - val_task0_profile_loss: 347.2266
# Epoch 116/500
# 267/267 [==============================] - 44s 166ms/step - loss: 349.4099 - task0_logcount_loss: 0.2360 - task0_profile_loss: 347.0499 - val_loss: 351.2009 - val_task0_logcount_loss: 0.3980 - val_task0_profile_loss: 347.2209
# Epoch 117/500
# 267/267 [==============================] - 44s 166ms/step - loss: 350.5625 - task0_logcount_loss: 0.2419 - task0_profile_loss: 348.1436 - val_loss: 350.9485 - val_task0_logcount_loss: 0.3709 - val_task0_profile_loss: 347.2392
# Epoch 118/500
# 267/267 [==============================] - 45s 169ms/step - loss: 349.2946 - task0_logcount_loss: 0.2360 - task0_profile_loss: 346.9346 - val_loss: 351.3634 - val_task0_logcount_loss: 0.4147 - val_task0_profile_loss: 347.2168
# Epoch 119/500
# 267/267 [==============================] - 44s 165ms/step - loss: 349.1548 - task0_logcount_loss: 0.2300 - task0_profile_loss: 346.8544 - val_loss: 350.8916 - val_task0_logcount_loss: 0.3668 - val_task0_profile_loss: 347.2233
# Epoch 120/500
# 267/267 [==============================] - 44s 167ms/step - loss: 348.9129 - task0_logcount_loss: 0.2221 - task0_profile_loss: 346.6916 - val_loss: 350.6850 - val_task0_logcount_loss: 0.3436 - val_task0_profile_loss: 347.2489
# Epoch 121/500
# 267/267 [==============================] - 44s 165ms/step - loss: 349.3172 - task0_logcount_loss: 0.2231 - task0_profile_loss: 347.0865 - val_loss: 350.6784 - val_task0_logcount_loss: 0.3310 - val_task0_profile_loss: 347.3687
# Epoch 122/500
# 267/267 [==============================] - 45s 169ms/step - loss: 350.2150 - task0_logcount_loss: 0.2530 - task0_profile_loss: 347.6854 - val_loss: 350.6458 - val_task0_logcount_loss: 0.3433 - val_task0_profile_loss: 347.2133
# Epoch 123/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.7255 - task0_logcount_loss: 0.2192 - task0_profile_loss: 346.5332 - val_loss: 350.8607 - val_task0_logcount_loss: 0.3637 - val_task0_profile_loss: 347.2240
# Epoch 124/500
# 267/267 [==============================] - 44s 166ms/step - loss: 349.1846 - task0_logcount_loss: 0.2197 - task0_profile_loss: 346.9872 - val_loss: 350.8146 - val_task0_logcount_loss: 0.3624 - val_task0_profile_loss: 347.1903
# Epoch 125/500
# 267/267 [==============================] - 45s 168ms/step - loss: 349.0397 - task0_logcount_loss: 0.2179 - task0_profile_loss: 346.8604 - val_loss: 350.5332 - val_task0_logcount_loss: 0.3322 - val_task0_profile_loss: 347.2115
# Epoch 126/500
# 267/267 [==============================] - 45s 169ms/step - loss: 349.3072 - task0_logcount_loss: 0.2217 - task0_profile_loss: 347.0900 - val_loss: 350.5320 - val_task0_logcount_loss: 0.3316 - val_task0_profile_loss: 347.2157
# Epoch 127/500
# 267/267 [==============================] - 45s 167ms/step - loss: 348.4952 - task0_logcount_loss: 0.2101 - task0_profile_loss: 346.3946 - val_loss: 350.5258 - val_task0_logcount_loss: 0.3291 - val_task0_profile_loss: 347.2344
# Epoch 128/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.7818 - task0_logcount_loss: 0.2077 - task0_profile_loss: 346.7046 - val_loss: 350.4935 - val_task0_logcount_loss: 0.3264 - val_task0_profile_loss: 347.2299
# Epoch 129/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.9541 - task0_logcount_loss: 0.2111 - task0_profile_loss: 346.8429 - val_loss: 351.3344 - val_task0_logcount_loss: 0.4103 - val_task0_profile_loss: 347.2314
# Epoch 130/500
# 267/267 [==============================] - 45s 169ms/step - loss: 348.8809 - task0_logcount_loss: 0.2156 - task0_profile_loss: 346.7251 - val_loss: 350.9264 - val_task0_logcount_loss: 0.3556 - val_task0_profile_loss: 347.3703
# Epoch 131/500
# 267/267 [==============================] - 44s 166ms/step - loss: 349.2473 - task0_logcount_loss: 0.2209 - task0_profile_loss: 347.0379 - val_loss: 350.6779 - val_task0_logcount_loss: 0.3465 - val_task0_profile_loss: 347.2133
# Epoch 132/500
# 267/267 [==============================] - 45s 167ms/step - loss: 348.8693 - task0_logcount_loss: 0.2044 - task0_profile_loss: 346.8255 - val_loss: 350.9964 - val_task0_logcount_loss: 0.3773 - val_task0_profile_loss: 347.2236
# Epoch 133/500
# 267/267 [==============================] - 45s 168ms/step - loss: 349.4848 - task0_logcount_loss: 0.2213 - task0_profile_loss: 347.2714 - val_loss: 351.3487 - val_task0_logcount_loss: 0.4056 - val_task0_profile_loss: 347.2930
# Epoch 134/500
# 267/267 [==============================] - 44s 165ms/step - loss: 349.0726 - task0_logcount_loss: 0.2176 - task0_profile_loss: 346.8965 - val_loss: 350.6469 - val_task0_logcount_loss: 0.3257 - val_task0_profile_loss: 347.3896
# Epoch 135/500
# 267/267 [==============================] - 44s 167ms/step - loss: 349.0343 - task0_logcount_loss: 0.2156 - task0_profile_loss: 346.8778 - val_loss: 350.9406 - val_task0_logcount_loss: 0.3702 - val_task0_profile_loss: 347.2382
# Epoch 136/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.7970 - task0_logcount_loss: 0.2042 - task0_profile_loss: 346.7551 - val_loss: 350.4686 - val_task0_logcount_loss: 0.3238 - val_task0_profile_loss: 347.2301
# Epoch 137/500
# 267/267 [==============================] - 44s 166ms/step - loss: 348.9416 - task0_logcount_loss: 0.2074 - task0_profile_loss: 346.8676 - val_loss: 351.1684 - val_task0_logcount_loss: 0.3812 - val_task0_profile_loss: 347.3566
# Epoch 138/500
# 267/267 [==============================] - 44s 167ms/step - loss: 348.7023 - task0_logcount_loss: 0.2033 - task0_profile_loss: 346.6688 - val_loss: 350.3241 - val_task0_logcount_loss: 0.3163 - val_task0_profile_loss: 347.1609
# Epoch 139/500
# 267/267 [==============================] - 44s 166ms/step - loss: 348.8707 - task0_logcount_loss: 0.2075 - task0_profile_loss: 346.7959 - val_loss: 350.6751 - val_task0_logcount_loss: 0.3470 - val_task0_profile_loss: 347.2053
# Epoch 140/500
# 267/267 [==============================] - 45s 167ms/step - loss: 348.9223 - task0_logcount_loss: 0.1946 - task0_profile_loss: 346.9762 - val_loss: 350.4740 - val_task0_logcount_loss: 0.3254 - val_task0_profile_loss: 347.2204
# Epoch 141/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.9078 - task0_logcount_loss: 0.1935 - task0_profile_loss: 346.9729 - val_loss: 350.5930 - val_task0_logcount_loss: 0.3362 - val_task0_profile_loss: 347.2312
# Epoch 142/500
# 267/267 [==============================] - 45s 167ms/step - loss: 349.3670 - task0_logcount_loss: 0.1960 - task0_profile_loss: 347.4070 - val_loss: 352.3433 - val_task0_logcount_loss: 0.4230 - val_task0_profile_loss: 348.1131
# Epoch 143/500
# 267/267 [==============================] - 45s 167ms/step - loss: 348.7219 - task0_logcount_loss: 0.1947 - task0_profile_loss: 346.7745 - val_loss: 350.3455 - val_task0_logcount_loss: 0.3148 - val_task0_profile_loss: 347.1978
# Epoch 144/500
# 267/267 [==============================] - 45s 169ms/step - loss: 348.7744 - task0_logcount_loss: 0.2097 - task0_profile_loss: 346.6774 - val_loss: 350.8545 - val_task0_logcount_loss: 0.3622 - val_task0_profile_loss: 347.2328
# Epoch 145/500
# 267/267 [==============================] - 45s 169ms/step - loss: 348.5929 - task0_logcount_loss: 0.1912 - task0_profile_loss: 346.6806 - val_loss: 350.6028 - val_task0_logcount_loss: 0.3380 - val_task0_profile_loss: 347.2230
# Epoch 146/500
# 267/267 [==============================] - 45s 169ms/step - loss: 348.4579 - task0_logcount_loss: 0.1888 - task0_profile_loss: 346.5696 - val_loss: 350.8563 - val_task0_logcount_loss: 0.3608 - val_task0_profile_loss: 347.2481
# Epoch 147/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.6949 - task0_logcount_loss: 0.1863 - task0_profile_loss: 346.8315 - val_loss: 350.9501 - val_task0_logcount_loss: 0.3355 - val_task0_profile_loss: 347.5953
# Epoch 148/500
# 267/267 [==============================] - 45s 169ms/step - loss: 348.9499 - task0_logcount_loss: 0.1916 - task0_profile_loss: 347.0336 - val_loss: 350.7271 - val_task0_logcount_loss: 0.3492 - val_task0_profile_loss: 347.2352
# Epoch 149/500
# 267/267 [==============================] - 44s 164ms/step - loss: 348.7178 - task0_logcount_loss: 0.1871 - task0_profile_loss: 346.8471 - val_loss: 350.8139 - val_task0_logcount_loss: 0.3597 - val_task0_profile_loss: 347.2171
# Epoch 150/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.8237 - task0_logcount_loss: 0.2003 - task0_profile_loss: 346.8203 - val_loss: 350.5806 - val_task0_logcount_loss: 0.3353 - val_task0_profile_loss: 347.2274
# Epoch 151/500
# 267/267 [==============================] - 45s 167ms/step - loss: 348.5143 - task0_logcount_loss: 0.1866 - task0_profile_loss: 346.6484 - val_loss: 350.3568 - val_task0_logcount_loss: 0.3145 - val_task0_profile_loss: 347.2113
# Epoch 152/500
# 267/267 [==============================] - 44s 165ms/step - loss: 348.4045 - task0_logcount_loss: 0.1834 - task0_profile_loss: 346.5705 - val_loss: 350.6414 - val_task0_logcount_loss: 0.3469 - val_task0_profile_loss: 347.1726
# Epoch 153/500
# 267/267 [==============================] - 44s 165ms/step - loss: 348.4178 - task0_logcount_loss: 0.1850 - task0_profile_loss: 346.5683 - val_loss: 350.4098 - val_task0_logcount_loss: 0.3053 - val_task0_profile_loss: 347.3569
# Epoch 154/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.5199 - task0_logcount_loss: 0.1796 - task0_profile_loss: 346.7243 - val_loss: 350.5906 - val_task0_logcount_loss: 0.3394 - val_task0_profile_loss: 347.1962
# Epoch 155/500
# 267/267 [==============================] - 45s 167ms/step - loss: 348.6465 - task0_logcount_loss: 0.1910 - task0_profile_loss: 346.7363 - val_loss: 350.8459 - val_task0_logcount_loss: 0.3466 - val_task0_profile_loss: 347.3797
# Epoch 156/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.9533 - task0_logcount_loss: 0.1791 - task0_profile_loss: 347.1626 - val_loss: 350.4474 - val_task0_logcount_loss: 0.3230 - val_task0_profile_loss: 347.2173
# Epoch 157/500
# 267/267 [==============================] - 44s 166ms/step - loss: 348.7827 - task0_logcount_loss: 0.1827 - task0_profile_loss: 346.9562 - val_loss: 350.8397 - val_task0_logcount_loss: 0.3422 - val_task0_profile_loss: 347.4173
# Epoch 158/500
# 267/267 [==============================] - 45s 167ms/step - loss: 348.2612 - task0_logcount_loss: 0.1848 - task0_profile_loss: 346.4135 - val_loss: 350.2584 - val_task0_logcount_loss: 0.3036 - val_task0_profile_loss: 347.2228
# Epoch 159/500
# 267/267 [==============================] - 45s 167ms/step - loss: 348.5648 - task0_logcount_loss: 0.1811 - task0_profile_loss: 346.7534 - val_loss: 350.2608 - val_task0_logcount_loss: 0.3159 - val_task0_profile_loss: 347.1015
# Epoch 160/500
# 267/267 [==============================] - 44s 165ms/step - loss: 349.0696 - task0_logcount_loss: 0.1822 - task0_profile_loss: 347.2472 - val_loss: 350.6530 - val_task0_logcount_loss: 0.3340 - val_task0_profile_loss: 347.3134
# Epoch 161/500
# 267/267 [==============================] - 44s 167ms/step - loss: 348.5484 - task0_logcount_loss: 0.1769 - task0_profile_loss: 346.7792 - val_loss: 350.9802 - val_task0_logcount_loss: 0.3590 - val_task0_profile_loss: 347.3898
# Epoch 162/500
# 267/267 [==============================] - 45s 167ms/step - loss: 348.1378 - task0_logcount_loss: 0.1843 - task0_profile_loss: 346.2950 - val_loss: 350.2471 - val_task0_logcount_loss: 0.3065 - val_task0_profile_loss: 347.1818
# Epoch 163/500
# 267/267 [==============================] - 44s 166ms/step - loss: 348.3839 - task0_logcount_loss: 0.1809 - task0_profile_loss: 346.5747 - val_loss: 350.7909 - val_task0_logcount_loss: 0.3620 - val_task0_profile_loss: 347.1714
# Epoch 164/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.6162 - task0_logcount_loss: 0.1872 - task0_profile_loss: 346.7442 - val_loss: 350.1973 - val_task0_logcount_loss: 0.3034 - val_task0_profile_loss: 347.1633
# Epoch 165/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.2836 - task0_logcount_loss: 0.1720 - task0_profile_loss: 346.5633 - val_loss: 350.8974 - val_task0_logcount_loss: 0.3675 - val_task0_profile_loss: 347.2227
# Epoch 166/500
# 267/267 [==============================] - 44s 166ms/step - loss: 348.4541 - task0_logcount_loss: 0.1744 - task0_profile_loss: 346.7098 - val_loss: 350.5246 - val_task0_logcount_loss: 0.3081 - val_task0_profile_loss: 347.4434
# Epoch 167/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.2318 - task0_logcount_loss: 0.1791 - task0_profile_loss: 346.4412 - val_loss: 350.8075 - val_task0_logcount_loss: 0.3420 - val_task0_profile_loss: 347.3877
# Epoch 168/500
# 267/267 [==============================] - 44s 166ms/step - loss: 348.3132 - task0_logcount_loss: 0.1788 - task0_profile_loss: 346.5256 - val_loss: 351.0325 - val_task0_logcount_loss: 0.3569 - val_task0_profile_loss: 347.4638
# Epoch 169/500
# 267/267 [==============================] - 44s 167ms/step - loss: 348.6348 - task0_logcount_loss: 0.1700 - task0_profile_loss: 346.9346 - val_loss: 350.9239 - val_task0_logcount_loss: 0.3289 - val_task0_profile_loss: 347.6350
# Epoch 170/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.8459 - task0_logcount_loss: 0.1824 - task0_profile_loss: 347.0216 - val_loss: 351.8689 - val_task0_logcount_loss: 0.4527 - val_task0_profile_loss: 347.3422
# Epoch 171/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.4432 - task0_logcount_loss: 0.1770 - task0_profile_loss: 346.6736 - val_loss: 350.3626 - val_task0_logcount_loss: 0.3165 - val_task0_profile_loss: 347.1979
# Epoch 172/500
# 267/267 [==============================] - 45s 167ms/step - loss: 348.5625 - task0_logcount_loss: 0.1769 - task0_profile_loss: 346.7931 - val_loss: 350.3208 - val_task0_logcount_loss: 0.3121 - val_task0_profile_loss: 347.1993
# Epoch 173/500
# 267/267 [==============================] - 45s 167ms/step - loss: 348.6308 - task0_logcount_loss: 0.1739 - task0_profile_loss: 346.8919 - val_loss: 350.1452 - val_task0_logcount_loss: 0.3008 - val_task0_profile_loss: 347.1370
# Epoch 174/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.3584 - task0_logcount_loss: 0.1640 - task0_profile_loss: 346.7188 - val_loss: 350.1586 - val_task0_logcount_loss: 0.3084 - val_task0_profile_loss: 347.0749
# Epoch 175/500
# 267/267 [==============================] - 45s 169ms/step - loss: 347.9683 - task0_logcount_loss: 0.1622 - task0_profile_loss: 346.3465 - val_loss: 350.6945 - val_task0_logcount_loss: 0.3318 - val_task0_profile_loss: 347.3760
# Epoch 176/500
# 267/267 [==============================] - 45s 170ms/step - loss: 348.0150 - task0_logcount_loss: 0.1678 - task0_profile_loss: 346.3367 - val_loss: 350.3722 - val_task0_logcount_loss: 0.3189 - val_task0_profile_loss: 347.1832
# Epoch 177/500
# 267/267 [==============================] - 45s 170ms/step - loss: 349.2234 - task0_logcount_loss: 0.1764 - task0_profile_loss: 347.4594 - val_loss: 350.4860 - val_task0_logcount_loss: 0.3242 - val_task0_profile_loss: 347.2443
# Epoch 178/500
# 267/267 [==============================] - 46s 171ms/step - loss: 348.6874 - task0_logcount_loss: 0.1686 - task0_profile_loss: 347.0018 - val_loss: 350.2814 - val_task0_logcount_loss: 0.3137 - val_task0_profile_loss: 347.1441
# Epoch 179/500
# 267/267 [==============================] - 45s 170ms/step - loss: 348.4516 - task0_logcount_loss: 0.1810 - task0_profile_loss: 346.6412 - val_loss: 350.2543 - val_task0_logcount_loss: 0.3038 - val_task0_profile_loss: 347.2166
# Epoch 180/500
# 267/267 [==============================] - 45s 169ms/step - loss: 348.4903 - task0_logcount_loss: 0.1742 - task0_profile_loss: 346.7484 - val_loss: 350.2849 - val_task0_logcount_loss: 0.3096 - val_task0_profile_loss: 347.1890
# Epoch 181/500
# 267/267 [==============================] - 45s 170ms/step - loss: 348.0509 - task0_logcount_loss: 0.1716 - task0_profile_loss: 346.3344 - val_loss: 350.1487 - val_task0_logcount_loss: 0.2888 - val_task0_profile_loss: 347.2607
# Epoch 182/500
# 267/267 [==============================] - 44s 167ms/step - loss: 348.2461 - task0_logcount_loss: 0.1687 - task0_profile_loss: 346.5596 - val_loss: 350.4688 - val_task0_logcount_loss: 0.3234 - val_task0_profile_loss: 347.2346
# Epoch 183/500
# 267/267 [==============================] - 46s 171ms/step - loss: 348.0806 - task0_logcount_loss: 0.1712 - task0_profile_loss: 346.3685 - val_loss: 350.1596 - val_task0_logcount_loss: 0.2972 - val_task0_profile_loss: 347.1871
# Epoch 184/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.0925 - task0_logcount_loss: 0.1621 - task0_profile_loss: 346.4712 - val_loss: 350.3789 - val_task0_logcount_loss: 0.3122 - val_task0_profile_loss: 347.2573
# Epoch 185/500
# 267/267 [==============================] - 45s 169ms/step - loss: 347.9342 - task0_logcount_loss: 0.1654 - task0_profile_loss: 346.2806 - val_loss: 350.5114 - val_task0_logcount_loss: 0.3224 - val_task0_profile_loss: 347.2870
# Epoch 186/500
# 267/267 [==============================] - 45s 170ms/step - loss: 348.2153 - task0_logcount_loss: 0.1663 - task0_profile_loss: 346.5526 - val_loss: 350.6312 - val_task0_logcount_loss: 0.3366 - val_task0_profile_loss: 347.2657
# Epoch 187/500
# 267/267 [==============================] - 46s 170ms/step - loss: 349.2111 - task0_logcount_loss: 0.1613 - task0_profile_loss: 347.5981 - val_loss: 353.2658 - val_task0_logcount_loss: 0.3039 - val_task0_profile_loss: 350.2266
# Epoch 188/500
# 267/267 [==============================] - 45s 169ms/step - loss: 349.4694 - task0_logcount_loss: 0.1646 - task0_profile_loss: 347.8232 - val_loss: 350.3543 - val_task0_logcount_loss: 0.3121 - val_task0_profile_loss: 347.2330
# Epoch 189/500
# 267/267 [==============================] - 45s 169ms/step - loss: 348.5612 - task0_logcount_loss: 0.1688 - task0_profile_loss: 346.8728 - val_loss: 350.4047 - val_task0_logcount_loss: 0.3193 - val_task0_profile_loss: 347.2112
# Epoch 190/500
# 267/267 [==============================] - 46s 171ms/step - loss: 347.9677 - task0_logcount_loss: 0.1562 - task0_profile_loss: 346.4058 - val_loss: 350.3829 - val_task0_logcount_loss: 0.3148 - val_task0_profile_loss: 347.2346
# Epoch 191/500
# 267/267 [==============================] - 45s 169ms/step - loss: 348.2569 - task0_logcount_loss: 0.1718 - task0_profile_loss: 346.5391 - val_loss: 350.9032 - val_task0_logcount_loss: 0.3651 - val_task0_profile_loss: 347.2522
# Epoch 192/500
# 267/267 [==============================] - 45s 169ms/step - loss: 348.1710 - task0_logcount_loss: 0.1733 - task0_profile_loss: 346.4376 - val_loss: 350.3001 - val_task0_logcount_loss: 0.3091 - val_task0_profile_loss: 347.2094
# Epoch 193/500
# 267/267 [==============================] - 46s 171ms/step - loss: 347.9497 - task0_logcount_loss: 0.1554 - task0_profile_loss: 346.3954 - val_loss: 350.3236 - val_task0_logcount_loss: 0.2907 - val_task0_profile_loss: 347.4167
# Epoch 194/500
# 267/267 [==============================] - 45s 168ms/step - loss: 348.2290 - task0_logcount_loss: 0.1709 - task0_profile_loss: 346.5203 - val_loss: 350.2897 - val_task0_logcount_loss: 0.3032 - val_task0_profile_loss: 347.2573
# Epoch 195/500
# 267/267 [==============================] - 45s 169ms/step - loss: 348.0516 - task0_logcount_loss: 0.1670 - task0_profile_loss: 346.3812 - val_loss: 350.2934 - val_task0_logcount_loss: 0.3070 - val_task0_profile_loss: 347.2239
# Epoch 196/500
# 267/267 [==============================] - 45s 168ms/step - loss: 347.9249 - task0_logcount_loss: 0.1596 - task0_profile_loss: 346.3284 - val_loss: 350.2723 - val_task0_logcount_loss: 0.3096 - val_task0_profile_loss: 347.1766
# Epoch 197/500
# 267/267 [==============================] - 45s 170ms/step - loss: 348.4180 - task0_logcount_loss: 0.1619 - task0_profile_loss: 346.7990 - val_loss: 350.4271 - val_task0_logcount_loss: 0.3191 - val_task0_profile_loss: 347.2363
# Epoch 198/500
# 267/267 [==============================] - 45s 169ms/step - loss: 348.5787 - task0_logcount_loss: 0.1639 - task0_profile_loss: 346.9401 - val_loss: 350.7424 - val_task0_logcount_loss: 0.3444 - val_task0_profile_loss: 347.2988

# %%
model.save('/users/amr1/pho4/data/models/gw_cbf1_chipexo_model.h5')

# %%
from keras.models import load_model
from keras.utils import CustomObjectScope

with CustomObjectScope({'MultichannelMultinomialNLL': MultichannelMultinomialNLL,'RevCompConv1D': RevCompConv1D}):
    model = load_model('/users/amr1/pho4/data/models/gw_cbf1_chipexo_model.h5')
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           (None, 546, 4)       0
# __________________________________________________________________________________________________
# rev_comp_conv1d_1 (RevCompConv1 (None, 526, 50)      2125        sequence[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 522, 50)      0           rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_2 (RevCompConv1 (None, 522, 50)      3775        rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 522, 50)      0           lambda_1[0][0]
#                                                                  rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 514, 50)      0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 514, 50)      0           rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_3 (RevCompConv1 (None, 514, 50)      3775        average_1[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 514, 50)      0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 498, 50)      0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 498, 50)      0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 498, 50)      0           rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_4 (RevCompConv1 (None, 498, 50)      3775        average_2[0][0]
# __________________________________________________________________________________________________
# average_3 (Average)             (None, 498, 50)      0           lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 466, 50)      0           lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 466, 50)      0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 466, 50)      0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 466, 50)      0           rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_5 (RevCompConv1 (None, 466, 50)      3775        average_3[0][0]
# __________________________________________________________________________________________________
# average_4 (Average)             (None, 466, 50)      0           lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 402, 50)      0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 402, 50)      0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 402, 50)      0           lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 402, 50)      0           lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 402, 50)      0           rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_6 (RevCompConv1 (None, 402, 50)      3775        average_4[0][0]
# __________________________________________________________________________________________________
# average_5 (Average)             (None, 402, 50)      0           lambda_11[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
#                                                                  rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 274, 50)      0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 274, 50)      0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 274, 50)      0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 274, 50)      0           lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 274, 50)      0           lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 274, 50)      0           rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_7 (RevCompConv1 (None, 274, 50)      3775        average_5[0][0]
# __________________________________________________________________________________________________
# control_logcount (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# average_6 (Average)             (None, 274, 50)      0           lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_21[0][0]
#                                                                  rev_comp_conv1d_7[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           control_logcount[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 50)           0           average_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 52)           0           lambda_22[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  control_logcount[0][0]
# __________________________________________________________________________________________________
# control_profile (InputLayer)    (None, 250, 2)       0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 52)        0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 250, 2)       0           control_profile[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_9 (RevCompConv1 (None, 250, 2)       1251        average_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_8 (RevCompConv1 (None, 1, 2)         53          reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 250, 6)       0           lambda_23[0][0]
#                                                                  rev_comp_conv1d_9[0][0]
#                                                                  control_profile[0][0]
# __________________________________________________________________________________________________
# task0_logcount (Reshape)        (None, 2)            0           rev_comp_conv1d_8[0][0]
# __________________________________________________________________________________________________
# task0_profile (RevCompConv1D)   (None, 250, 2)       7           concatenate_2[0][0]
# ==================================================================================================
# Total params: 26,086
# Trainable params: 26,086
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# evaluate

# %%
o_test_preds_logcount = []
o_test_biastrack_logcount = []
o_test_biastrack_profile = []
o_test_seqs = []
o_test_preds_profile = []
o_test_labels_logcount = []
o_test_labels_profile = []

keras_test_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
            bed_file="/users/amr1/pho4/data/genome/test.bed.gz",
            batch_size=64,
            shuffle_before_epoch=False, 
            seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)

orig_seqs = []

for batch_idx in range(len(keras_test_batch_generator)):
    batch_inputs, batch_labels = keras_test_batch_generator[batch_idx]
    o_test_seqs.append(batch_inputs['sequence']) 
    o_test_biastrack_logcount.append(batch_inputs['control_logcount'])
    o_test_biastrack_profile.append(batch_inputs['control_profile'])    
    test_preds = model.predict(batch_inputs)
    o_test_preds_logcount.append(test_preds[0])
    o_test_preds_profile.append(test_preds[1])
    o_test_labels_logcount.append(batch_labels['task0_logcount'])
    o_test_labels_profile.append(batch_labels['task0_profile'])
o_test_biastrack_logcount = np.concatenate(o_test_biastrack_logcount, axis=0)
o_test_biastrack_profile = np.concatenate(o_test_biastrack_profile,axis=0)
o_test_seqs = np.concatenate(o_test_seqs,axis=0)
o_test_preds_logcount = np.concatenate(o_test_preds_logcount, axis=0)
o_test_preds_profile = np.concatenate(o_test_preds_profile, axis=0)
o_test_labels_logcount = np.concatenate(o_test_labels_logcount, axis=0)
o_test_labels_profile = np.concatenate(o_test_labels_profile, axis=0)

from matplotlib import pyplot as plt
from scipy.stats import spearmanr

o_test_labels_logtotalcount = np.log(np.sum(np.exp(o_test_labels_logcount) - 1,axis=-1) + 1)

plt.scatter(o_test_biastrack_logcount, o_test_labels_logtotalcount, alpha=0.1)
plt.xlabel("Bias track log counts")
plt.ylabel("True log total counts")
plt.plot([np.min(o_test_biastrack_logcount), np.max(o_test_biastrack_logcount)],
         [np.min(o_test_biastrack_logcount), np.max(o_test_biastrack_logcount)],
         color="black")
plt.show()
print(spearmanr(o_test_biastrack_logcount, o_test_labels_logtotalcount))


#do a scatterplot of total count predictions
plt.scatter(o_test_preds_logcount[:,0], o_test_labels_logcount[:,0], alpha=0.1)
plt.xlabel("Predicted log counts - Forward Strand")
plt.ylabel("True log counts - Forward Strand")
plt.plot([np.min(o_test_preds_logcount[:,0]), np.max(o_test_preds_logcount[:,0])],
         [np.min(o_test_preds_logcount[:,0]), np.max(o_test_preds_logcount[:,0])],
         color="black")
plt.show()
print(spearmanr(o_test_preds_logcount[:,0], o_test_labels_logcount[:,0]))

plt.scatter(o_test_preds_logcount[:,1], o_test_labels_logcount[:,1], alpha=0.1)
plt.xlabel("Predicted log counts - Reverse Strand")
plt.ylabel("True log counts - Reverse Strand")
plt.plot([np.min(o_test_preds_logcount[:,1]), np.max(o_test_preds_logcount[:,1])],
         [np.min(o_test_preds_logcount[:,1]), np.max(o_test_preds_logcount[:,1])],
         color="black")
plt.show()
print(spearmanr(o_test_preds_logcount[:,1], o_test_labels_logcount[:,1]))
# Out:
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# SpearmanrResult(correlation=0.11971781875069964, pvalue=1.0002358441095523e-09)
# SpearmanrResult(correlation=0.4949259106666994, pvalue=5.270975539773329e-160)
# SpearmanrResult(correlation=0.5127173483293533, pvalue=1.6323900987605805e-173)

# %%
# %matplotlib inline

o_train_preds_logcount = []
o_train_biastrack_logcount = []
o_train_biastrack_profile = []
o_train_seqs = []
o_train_preds_profile = []
o_train_labels_logcount = []
o_train_labels_profile = []

orig_seqs = []

for batch_idx in range(len(keras_train_batch_generator)):
    batch_inputs, batch_labels = keras_train_batch_generator[batch_idx]
    o_train_seqs.append(batch_inputs['sequence']) 
    o_train_biastrack_logcount.append(batch_inputs['control_logcount'])
    o_train_biastrack_profile.append(batch_inputs['control_profile'])    
    train_preds = model.predict(batch_inputs)
    o_train_preds_logcount.append(train_preds[0])
    o_train_preds_profile.append(train_preds[1])
    o_train_labels_logcount.append(batch_labels['task0_logcount'])
    o_train_labels_profile.append(batch_labels['task0_profile'])
o_train_biastrack_logcount = np.concatenate(o_train_biastrack_logcount, axis=0)
o_train_biastrack_profile = np.concatenate(o_train_biastrack_profile,axis=0)
o_train_seqs = np.concatenate(o_train_seqs,axis=0)
o_train_preds_logcount = np.concatenate(o_train_preds_logcount, axis=0)
o_train_preds_profile = np.concatenate(o_train_preds_profile, axis=0)
o_train_labels_logcount = np.concatenate(o_train_labels_logcount, axis=0)
o_train_labels_profile = np.concatenate(o_train_labels_profile, axis=0)

from matplotlib import pyplot as plt
from scipy.stats import spearmanr

o_train_labels_logtotalcount = np.log(np.sum(np.exp(o_train_labels_logcount) - 1,axis=-1) + 1)

plt.scatter(o_train_biastrack_logcount, o_train_labels_logtotalcount, alpha=0.1)
plt.xlabel("Bias track log counts")
plt.ylabel("True log total counts")
plt.plot([np.min(o_train_biastrack_logcount), np.max(o_train_biastrack_logcount)],
         [np.min(o_train_biastrack_logcount), np.max(o_train_biastrack_logcount)],
         color="black")
plt.show()
print(spearmanr(o_train_biastrack_logcount, o_train_labels_logtotalcount))


#do a scatterplot of total count predictions
plt.scatter(o_train_preds_logcount[:,0], o_train_labels_logcount[:,0], alpha=0.1)
plt.xlabel("Predicted log counts - Forward Strand")
plt.ylabel("True log counts - Forward Strand")
plt.plot([np.min(o_train_preds_logcount[:,0]), np.max(o_train_preds_logcount[:,0])],
         [np.min(o_train_preds_logcount[:,0]), np.max(o_train_preds_logcount[:,0])],
         color="black")
plt.show()
print(spearmanr(o_train_preds_logcount[:,0], o_train_labels_logcount[:,0]))

plt.scatter(o_train_preds_logcount[:,1], o_train_labels_logcount[:,1], alpha=0.1)
plt.xlabel("Predicted log counts - Reverse Strand")
plt.ylabel("True log counts - Reverse Strand")
plt.plot([np.min(o_train_preds_logcount[:,1]), np.max(o_train_preds_logcount[:,1])],
         [np.min(o_train_preds_logcount[:,1]), np.max(o_train_preds_logcount[:,1])],
         color="black")
plt.show()
print(spearmanr(o_train_preds_logcount[:,1], o_train_labels_logcount[:,1]))
# Out:
# SpearmanrResult(correlation=0.09933722840927896, pvalue=1.467108033992146e-75)
# SpearmanrResult(correlation=0.5839570103135131, pvalue=0.0)
# SpearmanrResult(correlation=0.5833402489791909, pvalue=0.0)

# %% [markdown]
# Interpretation

# %%
import shap
from deeplift.dinuc_shuffle import dinuc_shuffle

def combine_mult_and_diffref(mult, orig_inp, bg_data):
    to_return = []
    for l in [0]:
        projected_hypothetical_contribs = np.zeros_like(bg_data[l]).astype("float")
        assert len(orig_inp[l].shape)==2
        #At each position in the input sequence, we iterate over the one-hot encoding
        # possibilities (eg: for genomic sequence, this is ACGT i.e.
        # 1000, 0100, 0010 and 0001) and compute the hypothetical 
        # difference-from-reference in each case. We then multiply the hypothetical
        # differences-from-reference with the multipliers to get the hypothetical contributions.
        #For each of the one-hot encoding possibilities,
        # the hypothetical contributions are then summed across the ACGT axis to estimate
        # the total hypothetical contribution of each position. This per-position hypothetical
        # contribution is then assigned ("projected") onto whichever base was present in the
        # hypothetical sequence.
        #The reason this is a fast estimate of what the importance scores *would* look
        # like if different bases were present in the underlying sequence is that
        # the multipliers are computed once using the original sequence, and are not
        # computed again for each hypothetical sequence.
        for i in range(orig_inp[l].shape[-1]):
            hypothetical_input = np.zeros_like(orig_inp[l]).astype("float")
            hypothetical_input[:,i] = 1.0
            hypothetical_difference_from_reference = (hypothetical_input[None,:,:]-bg_data[l])
            hypothetical_contribs = hypothetical_difference_from_reference*mult[l]
            projected_hypothetical_contribs[:,:,i] = np.sum(hypothetical_contribs,axis=-1) 
        to_return.append(np.mean(projected_hypothetical_contribs,axis=0))
    to_return.append(np.zeros_like(orig_inp[1]))
    return to_return

def shuffle_several_times(s):
    numshuffles=20
    return [np.array([dinuc_shuffle(s[0]) for i in range(numshuffles)]),
            np.array([s[1] for i in range(numshuffles)])]

profile_model_counts_explainer = shap.explainers.deep.TFDeepExplainer(
    ([model.input[0], model.input[1]],
     tf.reduce_sum(model.outputs[0],axis=-1)),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)

#See Google slide deck for explanations
#We meannorm as per section titled "Adjustments for Softmax Layers"
# in the DeepLIFT paper
meannormed_logits = (
    model.outputs[1]-
    tf.reduce_mean(model.outputs[1],axis=1)[:,None,:])
#'stop_gradient' will prevent importance from being propagated through
# this operation; we do this because we just want to treat the post-softmax
# probabilities as 'weights' on the different logits, without having the
# network explain how the probabilities themselves were derived
#Could be worth contrasting explanations derived with and without stop_gradient
# enabled...
stopgrad_meannormed_logits = tf.stop_gradient(meannormed_logits)
softmax_out = tf.nn.softmax(stopgrad_meannormed_logits,axis=1)
#Weight the logits according to the softmax probabilities, take the sum for each
# example. This mirrors what was done for the bpnet paper.
weightedsum_meannormed_logits = tf.reduce_sum(softmax_out*meannormed_logits,
                                              axis=(1,2))
profile_model_profile_explainer = shap.explainers.deep.TFDeepExplainer(
    ([model.input[0], model.input[2]],
     weightedsum_meannormed_logits),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)
# Out:
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  StopGradient used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients

# %%
#The shap scores
post_counts_hypimps,_ = profile_model_counts_explainer.shap_values(
    [o_test_seqs, np.zeros((len(o_test_seqs), 1))],
    progress_message=10)
post_profile_hypimps,_ = profile_model_profile_explainer.shap_values(
    [o_test_seqs, np.zeros((len(o_test_seqs), out_pred_len, 2))],
    progress_message=10)

post_counts_actualimps = post_counts_hypimps*o_test_seqs
post_profile_actualimps = post_profile_hypimps*o_test_seqs
# Out:
# Done 0 examples of 2588
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/shap/explainers/deep/deep_tf.py:493: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Done 10 examples of 2588
# Done 20 examples of 2588
# Done 30 examples of 2588
# Done 40 examples of 2588
# Done 50 examples of 2588
# Done 60 examples of 2588
# Done 70 examples of 2588
# Done 80 examples of 2588
# Done 90 examples of 2588
# Done 100 examples of 2588
# Done 110 examples of 2588
# Done 120 examples of 2588
# Done 130 examples of 2588
# Done 140 examples of 2588
# Done 150 examples of 2588
# Done 160 examples of 2588
# Done 170 examples of 2588
# Done 180 examples of 2588
# Done 190 examples of 2588
# Done 200 examples of 2588
# Done 210 examples of 2588
# Done 220 examples of 2588
# Done 230 examples of 2588
# Done 240 examples of 2588
# Done 250 examples of 2588
# Done 260 examples of 2588
# Done 270 examples of 2588
# Done 280 examples of 2588
# Done 290 examples of 2588
# Done 300 examples of 2588
# Done 310 examples of 2588
# Done 320 examples of 2588
# Done 330 examples of 2588
# Done 340 examples of 2588
# Done 350 examples of 2588
# Done 360 examples of 2588
# Done 370 examples of 2588
# Done 380 examples of 2588
# Done 390 examples of 2588
# Done 400 examples of 2588
# Done 410 examples of 2588
# Done 420 examples of 2588
# Done 430 examples of 2588
# Done 440 examples of 2588
# Done 450 examples of 2588
# Done 460 examples of 2588
# Done 470 examples of 2588
# Done 480 examples of 2588
# Done 490 examples of 2588
# Done 500 examples of 2588
# Done 510 examples of 2588
# Done 520 examples of 2588
# Done 530 examples of 2588
# Done 540 examples of 2588
# Done 550 examples of 2588
# Done 560 examples of 2588
# Done 570 examples of 2588
# Done 580 examples of 2588
# Done 590 examples of 2588
# Done 600 examples of 2588
# Done 610 examples of 2588
# Done 620 examples of 2588
# Done 630 examples of 2588
# Done 640 examples of 2588
# Done 650 examples of 2588
# Done 660 examples of 2588
# Done 670 examples of 2588
# Done 680 examples of 2588
# Done 690 examples of 2588
# Done 700 examples of 2588
# Done 710 examples of 2588
# Done 720 examples of 2588
# Done 730 examples of 2588
# Done 740 examples of 2588
# Done 750 examples of 2588
# Done 760 examples of 2588
# Done 770 examples of 2588
# Done 780 examples of 2588
# Done 790 examples of 2588
# Done 800 examples of 2588
# Done 810 examples of 2588
# Done 820 examples of 2588
# Done 830 examples of 2588
# Done 840 examples of 2588
# Done 850 examples of 2588
# Done 860 examples of 2588
# Done 870 examples of 2588
# Done 880 examples of 2588
# Done 890 examples of 2588
# Done 900 examples of 2588
# Done 910 examples of 2588
# Done 920 examples of 2588
# Done 930 examples of 2588
# Done 940 examples of 2588
# Done 950 examples of 2588
# Done 960 examples of 2588
# Done 970 examples of 2588
# Done 980 examples of 2588
# Done 990 examples of 2588
# Done 1000 examples of 2588
# Done 1010 examples of 2588
# Done 1020 examples of 2588
# Done 1030 examples of 2588
# Done 1040 examples of 2588
# Done 1050 examples of 2588
# Done 1060 examples of 2588
# Done 1070 examples of 2588
# Done 1080 examples of 2588
# Done 1090 examples of 2588
# Done 1100 examples of 2588
# Done 1110 examples of 2588
# Done 1120 examples of 2588
# Done 1130 examples of 2588
# Done 1140 examples of 2588
# Done 1150 examples of 2588
# Done 1160 examples of 2588
# Done 1170 examples of 2588
# Done 1180 examples of 2588
# Done 1190 examples of 2588
# Done 1200 examples of 2588
# Done 1210 examples of 2588
# Done 1220 examples of 2588
# Done 1230 examples of 2588
# Done 1240 examples of 2588
# Done 1250 examples of 2588
# Done 1260 examples of 2588
# Done 1270 examples of 2588
# Done 1280 examples of 2588
# Done 1290 examples of 2588
# Done 1300 examples of 2588
# Done 1310 examples of 2588
# Done 1320 examples of 2588
# Done 1330 examples of 2588
# Done 1340 examples of 2588
# Done 1350 examples of 2588
# Done 1360 examples of 2588
# Done 1370 examples of 2588
# Done 1380 examples of 2588
# Done 1390 examples of 2588
# Done 1400 examples of 2588
# Done 1410 examples of 2588
# Done 1420 examples of 2588
# Done 1430 examples of 2588
# Done 1440 examples of 2588
# Done 1450 examples of 2588
# Done 1460 examples of 2588
# Done 1470 examples of 2588
# Done 1480 examples of 2588
# Done 1490 examples of 2588
# Done 1500 examples of 2588
# Done 1510 examples of 2588
# Done 1520 examples of 2588
# Done 1530 examples of 2588
# Done 1540 examples of 2588
# Done 1550 examples of 2588
# Done 1560 examples of 2588
# Done 1570 examples of 2588
# Done 1580 examples of 2588
# Done 1590 examples of 2588
# Done 1600 examples of 2588
# Done 1610 examples of 2588
# Done 1620 examples of 2588
# Done 1630 examples of 2588
# Done 1640 examples of 2588
# Done 1650 examples of 2588
# Done 1660 examples of 2588
# Done 1670 examples of 2588
# Done 1680 examples of 2588
# Done 1690 examples of 2588
# Done 1700 examples of 2588
# Done 1710 examples of 2588
# Done 1720 examples of 2588
# Done 1730 examples of 2588
# Done 1740 examples of 2588
# Done 1750 examples of 2588
# Done 1760 examples of 2588
# Done 1770 examples of 2588
# Done 1780 examples of 2588
# Done 1790 examples of 2588
# Done 1800 examples of 2588
# Done 1810 examples of 2588
# Done 1820 examples of 2588
# Done 1830 examples of 2588
# Done 1840 examples of 2588
# Done 1850 examples of 2588
# Done 1860 examples of 2588
# Done 1870 examples of 2588
# Done 1880 examples of 2588
# Done 1890 examples of 2588
# Done 1900 examples of 2588
# Done 1910 examples of 2588
# Done 1920 examples of 2588
# Done 1930 examples of 2588
# Done 1940 examples of 2588
# Done 1950 examples of 2588
# Done 1960 examples of 2588
# Done 1970 examples of 2588
# Done 1980 examples of 2588
# Done 1990 examples of 2588
# Done 2000 examples of 2588
# Done 2010 examples of 2588
# Done 2020 examples of 2588
# Done 2030 examples of 2588
# Done 2040 examples of 2588
# Done 2050 examples of 2588
# Done 2060 examples of 2588
# Done 2070 examples of 2588
# Done 2080 examples of 2588
# Done 2090 examples of 2588
# Done 2100 examples of 2588
# Done 2110 examples of 2588
# Done 2120 examples of 2588
# Done 2130 examples of 2588
# Done 2140 examples of 2588
# Done 2150 examples of 2588
# Done 2160 examples of 2588
# Done 2170 examples of 2588
# Done 2180 examples of 2588
# Done 2190 examples of 2588
# Done 2200 examples of 2588
# Done 2210 examples of 2588
# Done 2220 examples of 2588
# Done 2230 examples of 2588
# Done 2240 examples of 2588
# Done 2250 examples of 2588
# Done 2260 examples of 2588
# Done 2270 examples of 2588
# Done 2280 examples of 2588
# Done 2290 examples of 2588
# Done 2300 examples of 2588
# Done 2310 examples of 2588
# Done 2320 examples of 2588
# Done 2330 examples of 2588
# Done 2340 examples of 2588
# Done 2350 examples of 2588
# Done 2360 examples of 2588
# Done 2370 examples of 2588
# Done 2380 examples of 2588
# Done 2390 examples of 2588
# Done 2400 examples of 2588
# Done 2410 examples of 2588
# Done 2420 examples of 2588
# Done 2430 examples of 2588
# Done 2440 examples of 2588
# Done 2450 examples of 2588
# Done 2460 examples of 2588
# Done 2470 examples of 2588
# Done 2480 examples of 2588
# Done 2490 examples of 2588
# Done 2500 examples of 2588
# Done 2510 examples of 2588
# Done 2520 examples of 2588
# Done 2530 examples of 2588
# Done 2540 examples of 2588
# Done 2550 examples of 2588
# Done 2560 examples of 2588
# Done 2570 examples of 2588
# Done 2580 examples of 2588
# Done 0 examples of 2588
# Done 10 examples of 2588
# Done 20 examples of 2588
# Done 30 examples of 2588
# Done 40 examples of 2588
# Done 50 examples of 2588
# Done 60 examples of 2588
# Done 70 examples of 2588
# Done 80 examples of 2588
# Done 90 examples of 2588
# Done 100 examples of 2588
# Done 110 examples of 2588
# Done 120 examples of 2588
# Done 130 examples of 2588
# Done 140 examples of 2588
# Done 150 examples of 2588
# Done 160 examples of 2588
# Done 170 examples of 2588
# Done 180 examples of 2588
# Done 190 examples of 2588
# Done 200 examples of 2588
# Done 210 examples of 2588
# Done 220 examples of 2588
# Done 230 examples of 2588
# Done 240 examples of 2588
# Done 250 examples of 2588
# Done 260 examples of 2588
# Done 270 examples of 2588
# Done 280 examples of 2588
# Done 290 examples of 2588
# Done 300 examples of 2588
# Done 310 examples of 2588
# Done 320 examples of 2588
# Done 330 examples of 2588
# Done 340 examples of 2588
# Done 350 examples of 2588
# Done 360 examples of 2588
# Done 370 examples of 2588
# Done 380 examples of 2588
# Done 390 examples of 2588
# Done 400 examples of 2588
# Done 410 examples of 2588
# Done 420 examples of 2588
# Done 430 examples of 2588
# Done 440 examples of 2588
# Done 450 examples of 2588
# Done 460 examples of 2588
# Done 470 examples of 2588
# Done 480 examples of 2588
# Done 490 examples of 2588
# Done 500 examples of 2588
# Done 510 examples of 2588
# Done 520 examples of 2588
# Done 530 examples of 2588
# Done 540 examples of 2588
# Done 550 examples of 2588
# Done 560 examples of 2588
# Done 570 examples of 2588
# Done 580 examples of 2588
# Done 590 examples of 2588
# Done 600 examples of 2588
# Done 610 examples of 2588
# Done 620 examples of 2588
# Done 630 examples of 2588
# Done 640 examples of 2588
# Done 650 examples of 2588
# Done 660 examples of 2588
# Done 670 examples of 2588
# Done 680 examples of 2588
# Done 690 examples of 2588
# Done 700 examples of 2588
# Done 710 examples of 2588
# Done 720 examples of 2588
# Done 730 examples of 2588
# Done 740 examples of 2588
# Done 750 examples of 2588
# Done 760 examples of 2588
# Done 770 examples of 2588
# Done 780 examples of 2588
# Done 790 examples of 2588
# Done 800 examples of 2588
# Done 810 examples of 2588
# Done 820 examples of 2588
# Done 830 examples of 2588
# Done 840 examples of 2588
# Done 850 examples of 2588
# Done 860 examples of 2588
# Done 870 examples of 2588
# Done 880 examples of 2588
# Done 890 examples of 2588
# Done 900 examples of 2588
# Done 910 examples of 2588
# Done 920 examples of 2588
# Done 930 examples of 2588
# Done 940 examples of 2588
# Done 950 examples of 2588
# Done 960 examples of 2588
# Done 970 examples of 2588
# Done 980 examples of 2588
# Done 990 examples of 2588
# Done 1000 examples of 2588
# Done 1010 examples of 2588
# Done 1020 examples of 2588
# Done 1030 examples of 2588
# Done 1040 examples of 2588
# Done 1050 examples of 2588
# Done 1060 examples of 2588
# Done 1070 examples of 2588
# Done 1080 examples of 2588
# Done 1090 examples of 2588
# Done 1100 examples of 2588
# Done 1110 examples of 2588
# Done 1120 examples of 2588
# Done 1130 examples of 2588
# Done 1140 examples of 2588
# Done 1150 examples of 2588
# Done 1160 examples of 2588
# Done 1170 examples of 2588
# Done 1180 examples of 2588
# Done 1190 examples of 2588
# Done 1200 examples of 2588
# Done 1210 examples of 2588
# Done 1220 examples of 2588
# Done 1230 examples of 2588
# Done 1240 examples of 2588
# Done 1250 examples of 2588
# Done 1260 examples of 2588
# Done 1270 examples of 2588
# Done 1280 examples of 2588
# Done 1290 examples of 2588
# Done 1300 examples of 2588
# Done 1310 examples of 2588
# Done 1320 examples of 2588
# Done 1330 examples of 2588
# Done 1340 examples of 2588
# Done 1350 examples of 2588
# Done 1360 examples of 2588
# Done 1370 examples of 2588
# Done 1380 examples of 2588
# Done 1390 examples of 2588
# Done 1400 examples of 2588
# Done 1410 examples of 2588
# Done 1420 examples of 2588
# Done 1430 examples of 2588
# Done 1440 examples of 2588
# Done 1450 examples of 2588
# Done 1460 examples of 2588
# Done 1470 examples of 2588
# Done 1480 examples of 2588
# Done 1490 examples of 2588
# Done 1500 examples of 2588
# Done 1510 examples of 2588
# Done 1520 examples of 2588
# Done 1530 examples of 2588
# Done 1540 examples of 2588
# Done 1550 examples of 2588
# Done 1560 examples of 2588
# Done 1570 examples of 2588
# Done 1580 examples of 2588
# Done 1590 examples of 2588
# Done 1600 examples of 2588
# Done 1610 examples of 2588
# Done 1620 examples of 2588
# Done 1630 examples of 2588
# Done 1640 examples of 2588
# Done 1650 examples of 2588
# Done 1660 examples of 2588
# Done 1670 examples of 2588
# Done 1680 examples of 2588
# Done 1690 examples of 2588
# Done 1700 examples of 2588
# Done 1710 examples of 2588
# Done 1720 examples of 2588
# Done 1730 examples of 2588
# Done 1740 examples of 2588
# Done 1750 examples of 2588
# Done 1760 examples of 2588
# Done 1770 examples of 2588
# Done 1780 examples of 2588
# Done 1790 examples of 2588
# Done 1800 examples of 2588
# Done 1810 examples of 2588
# Done 1820 examples of 2588
# Done 1830 examples of 2588
# Done 1840 examples of 2588
# Done 1850 examples of 2588
# Done 1860 examples of 2588
# Done 1870 examples of 2588
# Done 1880 examples of 2588
# Done 1890 examples of 2588
# Done 1900 examples of 2588
# Done 1910 examples of 2588
# Done 1920 examples of 2588
# Done 1930 examples of 2588
# Done 1940 examples of 2588
# Done 1950 examples of 2588
# Done 1960 examples of 2588
# Done 1970 examples of 2588
# Done 1980 examples of 2588
# Done 1990 examples of 2588
# Done 2000 examples of 2588
# Done 2010 examples of 2588
# Done 2020 examples of 2588
# Done 2030 examples of 2588
# Done 2040 examples of 2588
# Done 2050 examples of 2588
# Done 2060 examples of 2588
# Done 2070 examples of 2588
# Done 2080 examples of 2588
# Done 2090 examples of 2588
# Done 2100 examples of 2588
# Done 2110 examples of 2588
# Done 2120 examples of 2588
# Done 2130 examples of 2588
# Done 2140 examples of 2588
# Done 2150 examples of 2588
# Done 2160 examples of 2588
# Done 2170 examples of 2588
# Done 2180 examples of 2588
# Done 2190 examples of 2588
# Done 2200 examples of 2588
# Done 2210 examples of 2588
# Done 2220 examples of 2588
# Done 2230 examples of 2588
# Done 2240 examples of 2588
# Done 2250 examples of 2588
# Done 2260 examples of 2588
# Done 2270 examples of 2588
# Done 2280 examples of 2588
# Done 2290 examples of 2588
# Done 2300 examples of 2588
# Done 2310 examples of 2588
# Done 2320 examples of 2588
# Done 2330 examples of 2588
# Done 2340 examples of 2588
# Done 2350 examples of 2588
# Done 2360 examples of 2588
# Done 2370 examples of 2588
# Done 2380 examples of 2588
# Done 2390 examples of 2588
# Done 2400 examples of 2588
# Done 2410 examples of 2588
# Done 2420 examples of 2588
# Done 2430 examples of 2588
# Done 2440 examples of 2588
# Done 2450 examples of 2588
# Done 2460 examples of 2588
# Done 2470 examples of 2588
# Done 2480 examples of 2588
# Done 2490 examples of 2588
# Done 2500 examples of 2588
# Done 2510 examples of 2588
# Done 2520 examples of 2588
# Done 2530 examples of 2588
# Done 2540 examples of 2588
# Done 2550 examples of 2588
# Done 2560 examples of 2588
# Done 2570 examples of 2588
# Done 2580 examples of 2588

# %%
from deeplift.visualization import viz_sequence
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter

sorted_test_indices = [x[0] for x in 
                       sorted(enumerate(o_test_labels_logtotalcount),
                              key=lambda x: -x[1])]

def smooth(vals):
    return np.convolve(vals, np.ones(1,)/1, mode='same')

for idx in sorted_test_indices[:10]: 
    true_profile = o_test_labels_profile[idx] 
    print("idx",idx)
    print("Counts",np.sum(true_profile,axis=0))
    print("Predcounts",np.exp(o_test_preds_logcount[idx])-1)
    
    for oneovertemp in [1.0]:
        print("oneovertemp",oneovertemp)
        print(o_test_labels_profile[idx].shape)
        print("Pred profile shape", o_test_preds_profile[idx].shape)
        pred_profile = (np.sum(o_test_labels_profile[idx], axis=0)[None,:] #total counts
                      *(np.exp(o_test_preds_profile[idx]*oneovertemp)/
                        np.sum(np.exp(o_test_preds_profile[idx]*oneovertemp),axis=0)[None,:]) )   
        plt.figure(figsize=(20,2))

        start_view = 0
        end_view = seq_len
        total_flanking = seq_len - out_pred_len
        left_flank = int(0.5*total_flanking)
        right_flank = total_flanking - left_flank
        plt.plot(np.arange(out_pred_len)+left_flank, smooth(true_profile[:,0]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, -smooth(true_profile[:,1]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, pred_profile[:,0])
        plt.plot(np.arange(out_pred_len)+left_flank, -pred_profile[:,1])
        plt.xlim(start_view,end_view)
        plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
        plt.show()

    print("counts imp")
    viz_sequence.plot_weights(post_counts_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
    print("profile imp")
    viz_sequence.plot_weights(post_profile_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
# Out:
# idx 1115
# Counts [1248. 1476.]
# Predcounts [434.18835 532.7104 ]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 191
# Counts [1931.  322.]
# Predcounts [699.95154 293.52118]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 293
# Counts [742. 999.]
# Predcounts [345.3926  453.33313]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 1253
# Counts [684. 543.]
# Predcounts [590.64594 476.68863]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 2113
# Counts [975. 135.]
# Predcounts [2748.0918   322.32065]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 433
# Counts [550. 409.]
# Predcounts [422.0884  349.54913]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 145
# Counts [792. 102.]
# Predcounts [354.70462  114.568306]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 2425
# Counts [628. 190.]
# Predcounts [145.83301 104.89181]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 799
# Counts [264. 517.]
# Predcounts [ 79.927925 186.32532 ]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 1265
# Counts [212. 511.]
# Predcounts [ 94.47406 144.6059 ]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp

# %%
for idx in sorted_test_indices[:10]: 
    true_profile = o_test_labels_profile[idx] 
    print("idx",idx)
    print("Counts",np.sum(true_profile,axis=0))
    print("Predcounts",np.exp(o_test_preds_logcount[idx])-1)
    
    for oneovertemp in [1.0]:
        print("oneovertemp",oneovertemp)
        print(o_test_labels_profile[idx].shape)
        print("Pred profile shape", o_test_preds_profile[idx].shape)
        pred_profile = (np.sum(o_test_labels_profile[idx], axis=0)[None,:] #total counts
                      *(np.exp(o_test_preds_profile[idx]*oneovertemp)/
                        np.sum(np.exp(o_test_preds_profile[idx]*oneovertemp),axis=0)[None,:]) )   
        plt.figure(figsize=(20,2))

        start_view = 220
        end_view = 325
        total_flanking = seq_len - out_pred_len
        left_flank = int(0.5*total_flanking)
        right_flank = total_flanking - left_flank
        plt.plot(np.arange(out_pred_len)+left_flank, smooth(true_profile[:,0]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, -smooth(true_profile[:,1]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, pred_profile[:,0])
        plt.plot(np.arange(out_pred_len)+left_flank, -pred_profile[:,1])
        plt.xlim(start_view,end_view)
        plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
        plt.show()

    print("counts imp")
    viz_sequence.plot_weights(post_counts_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
    print("profile imp")
    viz_sequence.plot_weights(post_profile_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
# Out:
# idx 1115
# Counts [1248. 1476.]
# Predcounts [434.18835 532.7104 ]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 191
# Counts [1931.  322.]
# Predcounts [699.95154 293.52118]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 293
# Counts [742. 999.]
# Predcounts [345.3926  453.33313]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 1253
# Counts [684. 543.]
# Predcounts [590.64594 476.68863]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 2113
# Counts [975. 135.]
# Predcounts [2748.0918   322.32065]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 433
# Counts [550. 409.]
# Predcounts [422.0884  349.54913]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 145
# Counts [792. 102.]
# Predcounts [354.70462  114.568306]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 2425
# Counts [628. 190.]
# Predcounts [145.83301 104.89181]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 799
# Counts [264. 517.]
# Predcounts [ 79.927925 186.32532 ]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
# idx 1265
# Counts [212. 511.]
# Predcounts [ 94.47406 144.6059 ]
# oneovertemp 1.0
# (250, 2)
# Pred profile shape (250, 2)
# counts imp
# profile imp
