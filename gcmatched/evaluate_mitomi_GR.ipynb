# %%
import keras_genomics
from keras_genomics.layers.convolutional import RevCompConv1D
import keras
import keras.layers as kl
from keras import backend as K 
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers
from keras.models import load_model
from keras.utils import CustomObjectScope
import json
import gzip
import codecs
import os
from matplotlib import pyplot as plt
from scipy.stats import spearmanr, pearsonr, gaussian_kde
import math
from numpy import log, exp
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression as LR
from scipy.optimize import minimize
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
seqToDdg = {}
firstLine = True
with open("../data/experimental/GR_bindingcurves_WT_1_out.csv") as inp:
    for line in inp:
        if firstLine:
            firstLine = False
            continue
        Oligo,Kd_estimate,ddG,Motif,Sequence = line.strip().split(',')
        seq = Sequence.upper()[14:32]
        pre = Sequence.upper()[:14]
        post = Sequence.upper()[32:]
        if pre != "CGCAATTGCGAGTC":
            print(pre)
            print("CGCAATTGCGAGTC")
        if post != "GACCTTCCTCTCCGGCGGTATGAC":
            print(post)
            print("GACCTTCCTCTCCGGCGGTATGAC")
        if seq not in seqToDdg:
            seqToDdg[seq] = []
        seqToDdg[seq].append(float(ddG))

firstLine = True
with open("../data/experimental/GR_bindingcurves_WT_2_out.csv") as inp:
    for line in inp:
        if firstLine:
            firstLine = False
            continue
        Oligo,Kd_estimate,ddG,Motif,Sequence = line.strip().split(',')
        seq = Sequence.upper()[14:32]
        pre = Sequence.upper()[:14]
        post = Sequence.upper()[32:]
        if pre != "CGCAATTGCGAGTC":
            print(pre)
            print("CGCAATTGCGAGTC")
        if post != "GACCTTCCTCTCCGGCGGTATGAC":
            print(post)
            print("GACCTTCCTCTCCGGCGGTATGAC")
        seqToDdg[seq].append(float(ddG))

# %%
fastapath = "../data/genome/hg38/hg38.genome.fa"
GenomeDict={}
sequence=''
inputdatafile = open(fastapath)
for line in inputdatafile:
    if line[0]=='>':
        if sequence != '':
            GenomeDict[chrm] = ''.join(sequence)
        chrm = line.strip().split('>')[1]
        sequence=[]
        Keep=False
        continue
    else:
        sequence.append(line.strip())
GenomeDict[chrm] = ''.join(sequence)

seq_len = 1346
out_pred_len = 1000
test_chrms = ["chr1", "chr8", "chr21"]
peaks = []
with gzip.open("/oak/stanford/groups/akundaje/amr1/pho4/data/a549_GR/tseries/2hr/2hr.bed.gz", 'rt') as inp:
    for line in inp:
        chrm = line.strip().split('\t')[0]
        if chrm not in test_chrms:
            continue
        pStart = int(line.strip().split('\t')[1])
        summit = pStart + int(line.strip().split('\t')[-1])
        start = int(summit - (seq_len/2))
        end = int(summit + (seq_len/2))
        peaks.append(GenomeDict[chrm][start:end].upper())

# %%
from deeplift.dinuc_shuffle import dinuc_shuffle

def fill_into_center(seq, insert):
    start = int((len(seq)/2.0)-(len(insert)/2.0))
    new_seq = seq[:start]+insert+seq[start+len(insert):]
    return new_seq

ltrdict = {'a':[1,0,0,0],'c':[0,1,0,0],'g':[0,0,1,0],'t':[0,0,0,1],
           'n':[0,0,0,0],'A':[1,0,0,0],'C':[0,1,0,0],'G':[0,0,1,0],
           'T':[0,0,0,1],'N':[0,0,0,0]}
def getOneHot(ISM_sequences):
  # takes in list of sequences
    one_hot_seqs = []
    for seq in ISM_sequences:
        one_hot = []
        for i in range(len(seq)):
            one_hot.append(ltrdict[seq[i:i+1]])
        one_hot_seqs.append(one_hot)
    return np.array(one_hot_seqs)

def multinomial_nll(true_counts, logits):
    """Compute the multinomial negative log-likelihood
    Args:
      true_counts: observed count values
      logits: predicted logit values
    """
    counts_per_example = tf.reduce_sum(true_counts, axis=-1)
    dist = tfp.distributions.Multinomial(total_count=counts_per_example,
                                         logits=logits)
    return (-tf.reduce_sum(dist.log_prob(true_counts)) / 
            tf.to_float(tf.shape(true_counts)[0]))

#from https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/losses.py#L87
class MultichannelMultinomialNLL(object):
    def __init__(self, n):
        self.__name__ = "MultichannelMultinomialNLL"
        self.n = n

    def __call__(self, true_counts, logits):
        for i in range(self.n):
            loss = multinomial_nll(true_counts[..., i], logits[..., i])
            if i == 0:
                total = loss
            else:
                total += loss
        return total

    def get_config(self):
        return {"n": self.n}

# %%
with CustomObjectScope({'MultichannelMultinomialNLL': MultichannelMultinomialNLL,'RevCompConv1D': RevCompConv1D}):
    model = load_model("../data/models/gr_a549_2hr_matched_model.h5")
# Out:
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# ...

# %%
num_samples = 100
xvals = []
yvals = []
seqToMatchedDeltaLogCount = {}
seqToMatchedDeltaCount = {}
for curr_seq in seqToDdg:
    pre_seqs = []
    post_seqs = []
    indices = np.random.choice(len(peaks), num_samples, replace=False)
    for idx in indices:
        pre_seq = dinuc_shuffle(peaks[idx])
        post_seq = fill_into_center(pre_seq, curr_seq)
        pre_seqs.append(pre_seq)
        post_seqs.append(post_seq)
    pre = model.predict([getOneHot(pre_seqs), np.zeros((num_samples,)), np.zeros((num_samples,out_pred_len,2))])
    post = model.predict([getOneHot(post_seqs), np.zeros((num_samples,)), np.zeros((num_samples,out_pred_len,2))])
    seqToMatchedDeltaLogCount[curr_seq] = np.mean(post[0]-pre[0])
    seqToMatchedDeltaCount[curr_seq] = np.mean(np.exp(post[0])-np.exp(pre[0]))
    yvals.append(seqToMatchedDeltaLogCount[curr_seq])
    xvals.append(np.mean(seqToDdg[curr_seq]))

xy = np.vstack([xvals,yvals])
z = gaussian_kde(xy)(xy)
smallFont = {'size' : 10}
plt.rc('font', **smallFont)
fig, ax = plt.subplots()
ax.scatter(xvals, yvals, c=z, edgecolor='', alpha=0.5)
plt.xlabel("DDG")
plt.ylabel("Delta Log Counts")
plt.title("DDG vs matched model predictions\n"+str(spearmanr(xvals, yvals)[0])+", "+str(pearsonr(xvals, yvals)[0]))
plt.show()

# %%
K.clear_session()
del model

# %%
with CustomObjectScope({'MultichannelMultinomialNLL': MultichannelMultinomialNLL,'RevCompConv1D': RevCompConv1D}):
    model = load_model("../data/models/a5_tseries_model_2hr.h5")

# %%
xvals = []
yvals = []
seqToDeltaLogCount = {}
seqToDeltaCount = {}
for curr_seq in seqToDdg:
    pre_seqs = []
    post_seqs = []
    indices = np.random.choice(len(peaks), num_samples, replace=False)
    for idx in indices:
        pre_seq = dinuc_shuffle(peaks[idx])
        post_seq = fill_into_center(pre_seq, curr_seq)
        pre_seqs.append(pre_seq)
        post_seqs.append(post_seq)
    pre = model.predict([getOneHot(pre_seqs), np.zeros((num_samples,)), np.zeros((num_samples,out_pred_len,2))])
    post = model.predict([getOneHot(post_seqs), np.zeros((num_samples,)), np.zeros((num_samples,out_pred_len,2))])
    seqToDeltaLogCount[curr_seq] = np.mean(post[0]-pre[0])
    seqToDeltaCount[curr_seq] = np.mean(np.exp(post[0])-np.exp(pre[0]))
    yvals.append(seqToDeltaLogCount[curr_seq])
    xvals.append(np.mean(seqToDdg[curr_seq]))

xy = np.vstack([xvals,yvals])
z = gaussian_kde(xy)(xy)
smallFont = {'size' : 10}
plt.rc('font', **smallFont)
fig, ax = plt.subplots()
ax.scatter(xvals, yvals, c=z, edgecolor='', alpha=0.5)
plt.xlabel("DDG")
plt.ylabel("Delta Log Counts")
plt.title("DDG vs standard model predictions\n"+str(spearmanr(xvals, yvals)[0])+", "+str(pearsonr(xvals, yvals)[0]))
plt.show()

# %%
def sigmoid(x):
    return 1 / (1 + exp(-x))

def logit(p):
    return log(p) - log(1 - p)

class CalibratorFactory(object):
    def __call__(self, valid_preacts, valid_labels):
        raise NotImplementedError()

class LinearRegression(CalibratorFactory):
    def __init__(self, verbose=True):
        self.verbose = verbose 

    def __call__(self, valid_preacts, valid_labels):
        lr = LR().fit(valid_preacts.reshape(-1, 1), valid_labels)
    
        def calibration_func(preact):
            return lr.predict(preact.reshape(-1, 1))

        return calibration_func
    
class CalibratorFactory(object):
    def __call__(self, valid_preacts, valid_labels):
        raise NotImplementedError()

class SigmoidFit(CalibratorFactory):
    def __init__(self, verbose=True):
        self.verbose = verbose

    def __call__(self, valid_preacts, valid_labels):
        def loss_func(x):
            new_preacts = (x[0]*sigmoid(-valid_labels+x[1]))+x[2]
            return mean_squared_error(new_preacts, valid_preacts)

        x0 = np.array([1.0, 0.0, 0.0])
        res = None
        for c in range(10):
            curr = minimize(loss_func, x0, method='BFGS', options={'gtol': 1e-9, 'disp': True, 'maxiter': 1000})
            if res == None or curr.fun < res.fun:
                res = curr
        print("multiplier: ",res.x[0],", in sigmoid bias: ",res.x[1],", out of sigmoid bias: ",res.x[2])

        def calibration_func(label):
            return (res.x[0]*sigmoid(-label+res.x[1]))+res.x[2]

        def inv_func(preact):
            return -logit((preact-res.x[2])/res.x[0])+res.x[1]

        return calibration_func, inv_func

# %%
valid_keys = np.random.choice(list(seqToDdg.keys()), 62, replace=False)
valid_labels = []
valid_log_preacts_matched = []
valid_log_preacts_standard = []
valid_preacts_matched = []
valid_preacts_standard = []
for curr_seq in valid_keys:
    valid_labels.append(np.mean(seqToDdg[curr_seq]))
    valid_log_preacts_matched.append(seqToMatchedDeltaLogCount[curr_seq])
    valid_log_preacts_standard.append(seqToDeltaLogCount[curr_seq])
    valid_preacts_matched.append(seqToMatchedDeltaCount[curr_seq])
    valid_preacts_standard.append(seqToDeltaCount[curr_seq])
valid_labels = np.array(valid_labels)
valid_log_preacts_matched = np.array(valid_log_preacts_matched)
valid_log_preacts_standard = np.array(valid_log_preacts_standard)
valid_preacts_matched = np.array(valid_preacts_matched)
valid_preacts_standard = np.array(valid_preacts_standard)
test_keys = []
test_labels = []
test_log_preacts_matched = []
test_log_preacts_standard = []
test_preacts_matched = []
test_preacts_standard = []
for curr_seq in seqToDdg.keys():
    if curr_seq in valid_keys: continue
    test_keys.append(curr_seq)
    test_labels.append(np.mean(seqToDdg[curr_seq]))
    test_log_preacts_matched.append(seqToMatchedDeltaLogCount[curr_seq])
    test_log_preacts_standard.append(seqToDeltaLogCount[curr_seq])
    test_preacts_matched.append(seqToMatchedDeltaCount[curr_seq])
    test_preacts_standard.append(seqToDeltaCount[curr_seq])
test_labels = np.array(test_labels)
test_log_preacts_matched = np.array(test_log_preacts_matched)
test_log_preacts_standard = np.array(test_log_preacts_standard)
test_preacts_matched = np.array(test_preacts_matched)
test_preacts_standard = np.array(test_preacts_standard)

# %%
def plotCorrs(xvals, yvals, xlabel, ylabel, title):
    if np.isnan(xvals).any() or np.isinf(xvals).any(): return
    xy = np.vstack([xvals,yvals])
    z = gaussian_kde(xy)(xy)
    smallFont = {'size' : 10}
    plt.rc('font', **smallFont)
    fig, ax = plt.subplots()
    ax.scatter(xvals, yvals, c=z, edgecolor='', alpha=0.5)
    axes = plt.gca()
    p, residuals, _, _, _ = np.polyfit(xvals, yvals, 1, full=True)
    m, b = p
    X_plot = np.linspace(axes.get_xlim()[0],axes.get_xlim()[1],100)
    plt.plot(X_plot, m*X_plot + b, '-')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(" spearman: "+str(spearmanr(xvals, yvals)[0])+
              "\n pearson: "+str(pearsonr(xvals, yvals)[0])+
              "\n residuals: "+str(residuals[0]))
    plt.show()

# %%
key = "Matched"
print(key+" linear fit with counts")
lr = LinearRegression()
calibration_func = lr(valid_preacts_matched, valid_labels)
calibrated_labels = calibration_func(test_preacts_matched)
plotCorrs(calibrated_labels, test_labels, "predicted ddG", "true ddG", key+"_LR")
print(key+" linear fit with log counts")
lr = LinearRegression()
calibration_func = lr(valid_log_preacts_matched, valid_labels)
calibrated_labels = calibration_func(test_log_preacts_matched)
plotCorrs(calibrated_labels, test_labels, "predicted ddG", "true ddG", key+"_LR_log")
print(key+" logit fit with counts")
sf = SigmoidFit()
calibration_func, inv_func = sf(valid_preacts_matched, valid_labels)
calibrated_labels = inv_func(test_preacts_matched)
plotCorrs(calibrated_labels, test_labels, "predicted ddG", "true ddG", key+"_SF")
print(key+" logit fit with log counts")
sf = SigmoidFit()
calibration_func, inv_func = sf(valid_log_preacts_matched, valid_labels)
calibrated_labels = inv_func(test_log_preacts_matched)
plotCorrs(calibrated_labels, test_labels, "predicted ddG", "true ddG", key+"_SF_log")
# Out:
# Matched linear fit with counts
# Matched linear fit with log counts
# Matched logit fit with counts
# Optimization terminated successfully.
#          Current function value: 0.001228
#          Iterations: 24
#          Function evaluations: 145
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.001228
#          Iterations: 24
#          Function evaluations: 145
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.001228
#          Iterations: 24
#          Function evaluations: 145
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.001228
#          Iterations: 24
#          Function evaluations: 145
#          Gradient evaluations: 29
# Optimization terminated successfully.
#          Current function value: 0.001228
#          Iterations: 24
#          Function evaluations: 145
# ...

# %%
key = "Standard"
print(key+" linear fit with counts")
lr = LinearRegression()
calibration_func = lr(valid_preacts_standard, valid_labels)
calibrated_labels = calibration_func(test_preacts_standard)
plotCorrs(calibrated_labels, test_labels, "predicted ddG", "true ddG", key+"_LR")
print(key+" linear fit with log counts")
lr = LinearRegression()
calibration_func = lr(valid_log_preacts_standard, valid_labels)
calibrated_labels = calibration_func(test_log_preacts_standard)
plotCorrs(calibrated_labels, test_labels, "predicted ddG", "true ddG", key+"_LR_log")
print(key+" logit fit with counts")
sf = SigmoidFit()
calibration_func, inv_func = sf(valid_preacts_standard, valid_labels)
calibrated_labels = inv_func(test_preacts_standard)
plotCorrs(calibrated_labels, test_labels, "predicted ddG", "true ddG", key+"_SF")
print(key+" logit fit with log counts")
sf = SigmoidFit()
calibration_func, inv_func = sf(valid_log_preacts_standard, valid_labels)
calibrated_labels = inv_func(test_log_preacts_standard)
plotCorrs(calibrated_labels, test_labels, "predicted ddG", "true ddG", key+"_SF_log")
# Out:
# Standard linear fit with counts
# Standard linear fit with log counts
# Standard logit fit with counts
# Optimization terminated successfully.
#          Current function value: 0.012676
#          Iterations: 20
#          Function evaluations: 125
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.012676
#          Iterations: 20
#          Function evaluations: 125
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.012676
#          Iterations: 20
#          Function evaluations: 125
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.012676
#          Iterations: 20
#          Function evaluations: 125
#          Gradient evaluations: 25
# Optimization terminated successfully.
#          Current function value: 0.012676
#          Iterations: 20
#          Function evaluations: 125
# ...
