# %% [markdown]
# Train Model

# %%
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers
# Out:
# Using TensorFlow backend.
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import numpy as np
import gzip
import keras
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import keras_genomics
from keras_genomics.layers.convolutional import RevCompConv1D
import keras
import keras.layers as kl
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers

def multinomial_nll(true_counts, logits):
    """Compute the multinomial negative log-likelihood
    Args:
      true_counts: observed count values
      logits: predicted logit values
    """
    counts_per_example = tf.reduce_sum(true_counts, axis=-1)
    dist = tfp.distributions.Multinomial(total_count=counts_per_example,
                                         logits=logits)
    return (-tf.reduce_sum(dist.log_prob(true_counts)) / 
            tf.to_float(tf.shape(true_counts)[0]))


#from https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/losses.py#L87
class MultichannelMultinomialNLL(object):
    def __init__(self, n):
        self.__name__ = "MultichannelMultinomialNLL"
        self.n = n

    def __call__(self, true_counts, logits):
        for i in range(self.n):
            loss = multinomial_nll(true_counts[..., i], logits[..., i])
            if i == 0:
                total = loss
            else:
                total += loss
        return total

    def get_config(self):
        return {"n": self.n}

#If we want to avoid zero-padding, then the input seq len will be determined
# by parameters of the convolutions
class AbstractProfileModel(object):

    def get_output_profile_len(self):
        raise NotImplementedError()

    def get_model(self):
        raise NotImplementedError()

def trim_flanks_of_conv_layer(conv_layer, output_len, width_to_trim, filters):
    layer = keras.layers.Lambda(
        lambda x: x[:,
          int(0.5*(width_to_trim)):-(width_to_trim-int(0.5*(width_to_trim)))],
        output_shape=(output_len, filters))(conv_layer)
    return layer

#model architecture is based on 
#https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/models.py#L534
#The non-cli parameters are specified in:
# https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/src/chipnexus/train/seqmodel/joint-model-valid.gin
#The cli parameters are in line 165 of:
# https://docs.google.com/spreadsheets/d/1n3l2HXKSNpmNUOifD41uRzDEAgmOqXMQDxquRaz6WLg/edit#gid=0
# which seems to match https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/src/chipnexus/train/seqmodel/ChIP-seq-default.gin
class RcBPnetArch(AbstractProfileModel):   

    def __init__(self, input_seq_len, c_task_weight, filters,
                       n_dil_layers, conv1_kernel_size,
                       dil_kernel_size,
                       outconv_kernel_size, lr):
        self.input_seq_len = input_seq_len
        self.c_task_weight = c_task_weight
        self.filters = filters
        self.n_dil_layers = n_dil_layers
        self.conv1_kernel_size = conv1_kernel_size
        self.dil_kernel_size = dil_kernel_size
        self.outconv_kernel_size = outconv_kernel_size
        self.lr = lr

    def get_embedding_len(self):
        embedding_len = self.input_seq_len
        embedding_len -= (self.conv1_kernel_size-1)     
        for i in range(1, self.n_dil_layers+1):
            dilation_rate = (2**i)
            embedding_len -= dilation_rate*(self.dil_kernel_size-1)
        return embedding_len

    def get_output_profile_len(self):
        embedding_len = self.get_embedding_len()
        out_profile_len = embedding_len - (self.outconv_kernel_size - 1)
        return out_profile_len

    def get_keras_model(self):

        out_pred_len = self.get_output_profile_len()

        inp = kl.Input(shape=(self.input_seq_len, 4), name='sequence')
        first_conv = RevCompConv1D(filters=self.filters,
                               kernel_size=self.conv1_kernel_size,
                               padding='valid',
                               activation='relu')(inp)
        curr_layer_size = self.input_seq_len - (self.conv1_kernel_size-1)
        bias_counts_input = kl.Input(shape=(1,), name="control_logcount")
        bias_profile_input = kl.Input(shape=(out_pred_len, 2),
                                      name="control_profile")
        prev_layers = [first_conv]
        for i in range(1, self.n_dil_layers + 1):
          dilation_rate = 2**i
          if i == 1:
              prev_sum = first_conv
          else:
              print(prev_layers)
              prev_sum = kl.merge.Average()(prev_layers)
          conv_output = RevCompConv1D(filters=self.filters,
                                  kernel_size=self.dil_kernel_size,
                                  padding='valid',
                                  activation='relu',
                                  dilation_rate=dilation_rate)(prev_sum)          
          width_to_trim = dilation_rate*(self.dil_kernel_size-1)
          curr_layer_size = (curr_layer_size - width_to_trim)
          prev_layers = [trim_flanks_of_conv_layer(
              conv_layer=x, output_len=curr_layer_size,
              width_to_trim=width_to_trim, filters=2*self.filters)
              for x in prev_layers]
          prev_layers.append(conv_output)

        combined_conv = kl.merge.Average()(prev_layers)

        #Counts prediction
        gap_combined_conv = kl.GlobalAvgPool1D()(combined_conv)
        count_out = kl.Reshape((-1,), name="task0_logcount")(
            RevCompConv1D(filters=1, kernel_size=1)(
              kl.Reshape((1,-1))(kl.concatenate([
                  #concatenation of the bias layer both before and after
                  # is needed for rc symmetry
                  kl.Lambda(lambda x: x[:, ::-1])(bias_counts_input),
                  gap_combined_conv,
                  bias_counts_input], axis=-1))))

        profile_out_prebias = RevCompConv1D(
                               filters=1,
                               kernel_size=self.outconv_kernel_size,
                               padding='valid')(combined_conv)
        profile_out = RevCompConv1D(
            filters=1, kernel_size=1, name="task0_profile")(
                    kl.concatenate([
                        #concatenation of the bias layer both before and after
                        # is needed for rc symmetry
                        kl.Lambda(lambda x: x[:, :, ::-1])(bias_profile_input),
                        profile_out_prebias,
                        bias_profile_input], axis=-1))

        model = keras.models.Model(
          inputs=[inp, bias_counts_input, bias_profile_input],
          outputs=[count_out, profile_out])
        model.compile(keras.optimizers.Adam(lr=self.lr),
                      loss=['mse', MultichannelMultinomialNLL(2)],
                      loss_weights=[self.c_task_weight, 1])
        return model

# %%
seq_len = 546
modelwrapper = RcBPnetArch(
    input_seq_len=seq_len, c_task_weight=250,
    filters=25,
    n_dil_layers=6,
    conv1_kernel_size=21,
    dil_kernel_size=3,
    outconv_kernel_size=50,
    lr=0.001)
out_pred_len = modelwrapper.get_output_profile_len()
print(out_pred_len, seq_len-out_pred_len)
# Out:
# 225 321

# %%
pos_neg_smooth_log_counts =\
  coordstovals.bigwig.PosAndNegSmoothWindowCollapsedLogCounts(
        pos_strand_bigwig_path="/users/amr1/pho4/data/ctl_chipexo/chipexo.pos_strand.bw",
        neg_strand_bigwig_path="/users/amr1/pho4/data/ctl_chipexo/chipexo.neg_strand.bw",
        counts_mode_name="control_logcount",
        profile_mode_name="control_profile",
        center_size_to_use=out_pred_len,
        smoothing_windows=[1,50])
inputs_coordstovals = coordstovals.core.CoordsToValsJoiner(
    coordstovals_list=[
      coordbased.coordstovals.fasta.PyfaidxCoordsToVals(
        genome_fasta_path="/users/amr1/pho4/data/genome/sacCer3.genome.fa",
        mode_name="sequence",
        center_size_to_use=seq_len),
      pos_neg_smooth_log_counts])

targets_coordstovals = coordstovals.bigwig.PosAndNegSeparateLogCounts(
    pos_strand_bigwig_path="/users/amr1/pho4/data/limited_conditions/cbf1_eth/cbf1.eth.pos.bigwig",
    neg_strand_bigwig_path="/users/amr1/pho4/data/limited_conditions/cbf1_eth/cbf1.eth.neg.bigwig",
    counts_mode_name="task0_logcount",
    profile_mode_name="task0_profile",
    center_size_to_use=out_pred_len)

keras_train_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
      bed_file="/users/amr1/pho4/data/limited_conditions/train_1000_around_eth_cbf1.bed.gz",
      coord_batch_transformer=
          coordbatchtransformers.ReverseComplementAugmenter().chain(
          coordbatchtransformers.UniformJitter(
              maxshift=200, chromsizes_file="/users/amr1/pho4/data/genome/sacCer3.chrom.sizes")),
      batch_size=64,
      shuffle_before_epoch=True, 
      seed=1234),
    inputs_coordstovals=inputs_coordstovals,
    targets_coordstovals=targets_coordstovals)

keras_valid_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
            bed_file="/users/amr1/pho4/data/limited_conditions/valid_1000_around_eth_cbf1.bed.gz",
            batch_size=64,
            shuffle_before_epoch=False, 
            seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)

thebatch = keras_train_batch_generator[0]
for tupleidx,tupleentry in enumerate(thebatch):
  print("Tuple entry",tupleidx)
  for key in tupleentry:
    print(key, tupleentry[key].shape)
# Out:
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Tuple entry 0
# sequence (128, 546, 4)
# control_logcount (128,)
# control_profile (128, 225, 2)
# Tuple entry 1
# task0_logcount (128, 2)
# task0_profile (128, 225, 2)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

model = modelwrapper.get_keras_model()
print(model.summary())
early_stopping_callback = keras.callbacks.EarlyStopping(
                          patience=25, restore_best_weights=True)
loss_history = model.fit_generator(keras_train_batch_generator,
                  epochs=500,
                  validation_data=keras_valid_batch_generator,
                  callbacks=[early_stopping_callback])
model.set_weights(early_stopping_callback.best_weights)
# Out:
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# [<tf.Tensor 'lambda_1/strided_slice:0' shape=(?, 522, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_2/Relu:0' shape=(?, 522, 50) dtype=float32>]
# [<tf.Tensor 'lambda_2/strided_slice:0' shape=(?, 514, 50) dtype=float32>, <tf.Tensor 'lambda_3/strided_slice:0' shape=(?, 514, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_3/Relu:0' shape=(?, 514, 50) dtype=float32>]
# [<tf.Tensor 'lambda_4/strided_slice:0' shape=(?, 498, 50) dtype=float32>, <tf.Tensor 'lambda_5/strided_slice:0' shape=(?, 498, 50) dtype=float32>, <tf.Tensor 'lambda_6/strided_slice:0' shape=(?, 498, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_4/Relu:0' shape=(?, 498, 50) dtype=float32>]
# [<tf.Tensor 'lambda_7/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'lambda_8/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'lambda_9/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'lambda_10/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_5/Relu:0' shape=(?, 466, 50) dtype=float32>]
# [<tf.Tensor 'lambda_11/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_12/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_13/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_14/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_15/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_6/Relu:0' shape=(?, 402, 50) dtype=float32>]
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From <ipython-input-2-dbf16efbe78d>:28: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           (None, 546, 4)       0
# __________________________________________________________________________________________________
# rev_comp_conv1d_1 (RevCompConv1 (None, 526, 50)      2125        sequence[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 522, 50)      0           rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_2 (RevCompConv1 (None, 522, 50)      3775        rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 522, 50)      0           lambda_1[0][0]
#                                                                  rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 514, 50)      0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 514, 50)      0           rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_3 (RevCompConv1 (None, 514, 50)      3775        average_1[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 514, 50)      0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 498, 50)      0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 498, 50)      0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 498, 50)      0           rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_4 (RevCompConv1 (None, 498, 50)      3775        average_2[0][0]
# __________________________________________________________________________________________________
# average_3 (Average)             (None, 498, 50)      0           lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 466, 50)      0           lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 466, 50)      0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 466, 50)      0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 466, 50)      0           rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_5 (RevCompConv1 (None, 466, 50)      3775        average_3[0][0]
# __________________________________________________________________________________________________
# average_4 (Average)             (None, 466, 50)      0           lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 402, 50)      0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 402, 50)      0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 402, 50)      0           lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 402, 50)      0           lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 402, 50)      0           rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_6 (RevCompConv1 (None, 402, 50)      3775        average_4[0][0]
# __________________________________________________________________________________________________
# average_5 (Average)             (None, 402, 50)      0           lambda_11[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
#                                                                  rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 274, 50)      0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 274, 50)      0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 274, 50)      0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 274, 50)      0           lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 274, 50)      0           lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 274, 50)      0           rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_7 (RevCompConv1 (None, 274, 50)      3775        average_5[0][0]
# __________________________________________________________________________________________________
# control_logcount (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# average_6 (Average)             (None, 274, 50)      0           lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_21[0][0]
#                                                                  rev_comp_conv1d_7[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           control_logcount[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 50)           0           average_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 52)           0           lambda_22[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  control_logcount[0][0]
# __________________________________________________________________________________________________
# control_profile (InputLayer)    (None, 225, 2)       0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 52)        0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 225, 2)       0           control_profile[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_9 (RevCompConv1 (None, 225, 2)       2501        average_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_8 (RevCompConv1 (None, 1, 2)         53          reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 225, 6)       0           lambda_23[0][0]
#                                                                  rev_comp_conv1d_9[0][0]
#                                                                  control_profile[0][0]
# __________________________________________________________________________________________________
# task0_logcount (Reshape)        (None, 2)            0           rev_comp_conv1d_8[0][0]
# __________________________________________________________________________________________________
# task0_profile (RevCompConv1D)   (None, 225, 2)       7           concatenate_2[0][0]
# ==================================================================================================
# Total params: 27,336
# Trainable params: 27,336
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/500
# 11/11 [==============================] - 5s 488ms/step - loss: 1773.6370 - task0_logcount_loss: 5.4772 - task0_profile_loss: 404.3441 - val_loss: 647.8899 - val_task0_logcount_loss: 0.8959 - val_task0_profile_loss: 423.9203
# Epoch 2/500
# 11/11 [==============================] - 1s 111ms/step - loss: 769.9195 - task0_logcount_loss: 1.5307 - task0_profile_loss: 387.2569 - val_loss: 597.6516 - val_task0_logcount_loss: 0.7150 - val_task0_profile_loss: 418.8995
# Epoch 3/500
# 11/11 [==============================] - 2s 161ms/step - loss: 651.8701 - task0_logcount_loss: 1.0258 - task0_profile_loss: 395.4228 - val_loss: 671.1326 - val_task0_logcount_loss: 1.0234 - val_task0_profile_loss: 415.2704
# Epoch 4/500
# 11/11 [==============================] - 2s 163ms/step - loss: 681.1683 - task0_logcount_loss: 1.0947 - task0_profile_loss: 407.4984 - val_loss: 587.1288 - val_task0_logcount_loss: 0.6984 - val_task0_profile_loss: 412.5380
# Epoch 5/500
# 11/11 [==============================] - 2s 148ms/step - loss: 610.7100 - task0_logcount_loss: 0.9210 - task0_profile_loss: 380.4511 - val_loss: 615.6788 - val_task0_logcount_loss: 0.8225 - val_task0_profile_loss: 410.0655
# Epoch 6/500
# 11/11 [==============================] - 2s 151ms/step - loss: 608.2311 - task0_logcount_loss: 0.8865 - task0_profile_loss: 386.6063 - val_loss: 602.5133 - val_task0_logcount_loss: 0.7788 - val_task0_profile_loss: 407.8027
# Epoch 7/500
# 11/11 [==============================] - 2s 162ms/step - loss: 602.2180 - task0_logcount_loss: 0.8522 - task0_profile_loss: 389.1619 - val_loss: 578.8333 - val_task0_logcount_loss: 0.6919 - val_task0_profile_loss: 405.8464
# Epoch 8/500
# 11/11 [==============================] - 2s 161ms/step - loss: 588.7481 - task0_logcount_loss: 0.8390 - task0_profile_loss: 378.9990 - val_loss: 603.5452 - val_task0_logcount_loss: 0.7975 - val_task0_profile_loss: 404.1579
# Epoch 9/500
# 11/11 [==============================] - 2s 158ms/step - loss: 593.0565 - task0_logcount_loss: 0.8792 - task0_profile_loss: 373.2684 - val_loss: 587.8211 - val_task0_logcount_loss: 0.7424 - val_task0_profile_loss: 402.2252
# Epoch 10/500
# 11/11 [==============================] - 2s 150ms/step - loss: 568.5748 - task0_logcount_loss: 0.8231 - task0_profile_loss: 362.7912 - val_loss: 596.5871 - val_task0_logcount_loss: 0.7851 - val_task0_profile_loss: 400.3131
# Epoch 11/500
# 11/11 [==============================] - 2s 154ms/step - loss: 628.4198 - task0_logcount_loss: 0.9312 - task0_profile_loss: 395.6218 - val_loss: 617.5224 - val_task0_logcount_loss: 0.8770 - val_task0_profile_loss: 398.2730
# Epoch 12/500
# 11/11 [==============================] - 2s 151ms/step - loss: 584.3993 - task0_logcount_loss: 0.8753 - task0_profile_loss: 365.5852 - val_loss: 563.6044 - val_task0_logcount_loss: 0.6686 - val_task0_profile_loss: 396.4585
# Epoch 13/500
# 11/11 [==============================] - 2s 159ms/step - loss: 599.8862 - task0_logcount_loss: 0.9349 - task0_profile_loss: 366.1719 - val_loss: 563.2948 - val_task0_logcount_loss: 0.6749 - val_task0_profile_loss: 394.5658
# Epoch 14/500
# 11/11 [==============================] - 2s 167ms/step - loss: 590.1278 - task0_logcount_loss: 0.8487 - task0_profile_loss: 377.9646 - val_loss: 570.2045 - val_task0_logcount_loss: 0.7094 - val_task0_profile_loss: 392.8479
# Epoch 15/500
# 11/11 [==============================] - 2s 151ms/step - loss: 594.7172 - task0_logcount_loss: 0.8805 - task0_profile_loss: 374.5999 - val_loss: 587.5493 - val_task0_logcount_loss: 0.7863 - val_task0_profile_loss: 390.9620
# Epoch 16/500
# 11/11 [==============================] - 2s 161ms/step - loss: 596.1835 - task0_logcount_loss: 0.8959 - task0_profile_loss: 372.2133 - val_loss: 574.3327 - val_task0_logcount_loss: 0.7418 - val_task0_profile_loss: 388.8845
# Epoch 17/500
# 11/11 [==============================] - 2s 159ms/step - loss: 561.7632 - task0_logcount_loss: 0.8551 - task0_profile_loss: 347.9946 - val_loss: 578.8057 - val_task0_logcount_loss: 0.7661 - val_task0_profile_loss: 387.2895
# Epoch 18/500
# 11/11 [==============================] - 2s 150ms/step - loss: 559.1754 - task0_logcount_loss: 0.8373 - task0_profile_loss: 349.8469 - val_loss: 565.4658 - val_task0_logcount_loss: 0.7197 - val_task0_profile_loss: 385.5427
# Epoch 19/500
# 11/11 [==============================] - 2s 162ms/step - loss: 564.7627 - task0_logcount_loss: 0.8535 - task0_profile_loss: 351.3756 - val_loss: 547.4508 - val_task0_logcount_loss: 0.6544 - val_task0_profile_loss: 383.8632
# Epoch 20/500
# 11/11 [==============================] - 2s 154ms/step - loss: 562.7790 - task0_logcount_loss: 0.8698 - task0_profile_loss: 345.3371 - val_loss: 543.2229 - val_task0_logcount_loss: 0.6437 - val_task0_profile_loss: 382.2951
# Epoch 21/500
# 11/11 [==============================] - 2s 159ms/step - loss: 555.6483 - task0_logcount_loss: 0.8064 - task0_profile_loss: 354.0537 - val_loss: 560.3333 - val_task0_logcount_loss: 0.7181 - val_task0_profile_loss: 380.8126
# Epoch 22/500
# 11/11 [==============================] - 2s 162ms/step - loss: 561.3694 - task0_logcount_loss: 0.8445 - task0_profile_loss: 350.2560 - val_loss: 552.9986 - val_task0_logcount_loss: 0.6966 - val_task0_profile_loss: 378.8453
# Epoch 23/500
# 11/11 [==============================] - 2s 148ms/step - loss: 561.5846 - task0_logcount_loss: 0.8402 - task0_profile_loss: 351.5435 - val_loss: 579.9957 - val_task0_logcount_loss: 0.8108 - val_task0_profile_loss: 377.2976
# Epoch 24/500
# 11/11 [==============================] - 2s 157ms/step - loss: 550.2949 - task0_logcount_loss: 0.8385 - task0_profile_loss: 340.6759 - val_loss: 534.7816 - val_task0_logcount_loss: 0.6368 - val_task0_profile_loss: 375.5727
# Epoch 25/500
# 11/11 [==============================] - 2s 152ms/step - loss: 561.8413 - task0_logcount_loss: 0.8733 - task0_profile_loss: 343.5052 - val_loss: 544.4002 - val_task0_logcount_loss: 0.6828 - val_task0_profile_loss: 373.7031
# Epoch 26/500
# 11/11 [==============================] - 2s 158ms/step - loss: 553.4635 - task0_logcount_loss: 0.8301 - task0_profile_loss: 345.9465 - val_loss: 532.1960 - val_task0_logcount_loss: 0.6407 - val_task0_profile_loss: 372.0193
# Epoch 27/500
# 11/11 [==============================] - 2s 163ms/step - loss: 541.1517 - task0_logcount_loss: 0.8082 - task0_profile_loss: 339.0925 - val_loss: 536.4344 - val_task0_logcount_loss: 0.6634 - val_task0_profile_loss: 370.5827
# Epoch 28/500
# 11/11 [==============================] - 2s 153ms/step - loss: 557.4878 - task0_logcount_loss: 0.8917 - task0_profile_loss: 334.5526 - val_loss: 569.4075 - val_task0_logcount_loss: 0.8019 - val_task0_profile_loss: 368.9414
# Epoch 29/500
# 11/11 [==============================] - 2s 152ms/step - loss: 549.2785 - task0_logcount_loss: 0.8502 - task0_profile_loss: 336.7227 - val_loss: 583.1652 - val_task0_logcount_loss: 0.8644 - val_task0_profile_loss: 367.0626
# Epoch 30/500
# 11/11 [==============================] - 2s 158ms/step - loss: 550.4947 - task0_logcount_loss: 0.8703 - task0_profile_loss: 332.9112 - val_loss: 560.8347 - val_task0_logcount_loss: 0.7826 - val_task0_profile_loss: 365.1937
# Epoch 31/500
# 11/11 [==============================] - 2s 162ms/step - loss: 540.2038 - task0_logcount_loss: 0.8391 - task0_profile_loss: 330.4298 - val_loss: 553.6559 - val_task0_logcount_loss: 0.7606 - val_task0_profile_loss: 363.4964
# Epoch 32/500
# 11/11 [==============================] - 2s 158ms/step - loss: 539.3064 - task0_logcount_loss: 0.8324 - task0_profile_loss: 331.1946 - val_loss: 518.6839 - val_task0_logcount_loss: 0.6280 - val_task0_profile_loss: 361.6935
# Epoch 33/500
# 11/11 [==============================] - 2s 164ms/step - loss: 523.3907 - task0_logcount_loss: 0.7935 - task0_profile_loss: 325.0088 - val_loss: 528.6450 - val_task0_logcount_loss: 0.6743 - val_task0_profile_loss: 360.0718
# Epoch 34/500
# 11/11 [==============================] - 2s 163ms/step - loss: 544.9371 - task0_logcount_loss: 0.8461 - task0_profile_loss: 333.4145 - val_loss: 516.8617 - val_task0_logcount_loss: 0.6334 - val_task0_profile_loss: 358.5009
# Epoch 35/500
# 11/11 [==============================] - 2s 166ms/step - loss: 522.5850 - task0_logcount_loss: 0.7960 - task0_profile_loss: 323.5961 - val_loss: 513.4759 - val_task0_logcount_loss: 0.6263 - val_task0_profile_loss: 356.8895
# Epoch 36/500
# 11/11 [==============================] - 2s 160ms/step - loss: 515.4164 - task0_logcount_loss: 0.8172 - task0_profile_loss: 311.1052 - val_loss: 525.4081 - val_task0_logcount_loss: 0.6813 - val_task0_profile_loss: 355.0785
# Epoch 37/500
# 11/11 [==============================] - 2s 157ms/step - loss: 507.7624 - task0_logcount_loss: 0.7682 - task0_profile_loss: 315.7106 - val_loss: 519.4206 - val_task0_logcount_loss: 0.6640 - val_task0_profile_loss: 353.4227
# Epoch 38/500
# 11/11 [==============================] - 2s 157ms/step - loss: 520.3425 - task0_logcount_loss: 0.7962 - task0_profile_loss: 321.2941 - val_loss: 514.0607 - val_task0_logcount_loss: 0.6488 - val_task0_profile_loss: 351.8570
# Epoch 39/500
# 11/11 [==============================] - 2s 161ms/step - loss: 518.5702 - task0_logcount_loss: 0.8035 - task0_profile_loss: 317.7006 - val_loss: 511.9206 - val_task0_logcount_loss: 0.6475 - val_task0_profile_loss: 350.0413
# Epoch 40/500
# 11/11 [==============================] - 2s 148ms/step - loss: 515.6720 - task0_logcount_loss: 0.8107 - task0_profile_loss: 312.9982 - val_loss: 501.6979 - val_task0_logcount_loss: 0.6126 - val_task0_profile_loss: 348.5597
# Epoch 41/500
# 11/11 [==============================] - 2s 151ms/step - loss: 522.3986 - task0_logcount_loss: 0.8275 - task0_profile_loss: 315.5176 - val_loss: 499.5055 - val_task0_logcount_loss: 0.6119 - val_task0_profile_loss: 346.5308
# Epoch 42/500
# 11/11 [==============================] - 2s 162ms/step - loss: 536.8173 - task0_logcount_loss: 0.8895 - task0_profile_loss: 314.4402 - val_loss: 504.5954 - val_task0_logcount_loss: 0.6384 - val_task0_profile_loss: 344.9941
# Epoch 43/500
# 11/11 [==============================] - 2s 155ms/step - loss: 525.5853 - task0_logcount_loss: 0.8850 - task0_profile_loss: 304.3320 - val_loss: 497.1262 - val_task0_logcount_loss: 0.6169 - val_task0_profile_loss: 342.9026
# Epoch 44/500
# 11/11 [==============================] - 2s 153ms/step - loss: 539.0711 - task0_logcount_loss: 0.9668 - task0_profile_loss: 297.3671 - val_loss: 494.7454 - val_task0_logcount_loss: 0.6138 - val_task0_profile_loss: 341.2934
# Epoch 45/500
# 11/11 [==============================] - 2s 155ms/step - loss: 552.5230 - task0_logcount_loss: 0.9657 - task0_profile_loss: 311.0934 - val_loss: 532.9920 - val_task0_logcount_loss: 0.7745 - val_task0_profile_loss: 339.3752
# Epoch 46/500
# 11/11 [==============================] - 2s 159ms/step - loss: 511.2919 - task0_logcount_loss: 0.8438 - task0_profile_loss: 300.3530 - val_loss: 537.7734 - val_task0_logcount_loss: 0.8006 - val_task0_profile_loss: 337.6276
# Epoch 47/500
# 11/11 [==============================] - 2s 159ms/step - loss: 514.7332 - task0_logcount_loss: 0.8575 - task0_profile_loss: 300.3669 - val_loss: 516.2692 - val_task0_logcount_loss: 0.7214 - val_task0_profile_loss: 335.9151
# Epoch 48/500
# 11/11 [==============================] - 2s 150ms/step - loss: 496.6439 - task0_logcount_loss: 0.7954 - task0_profile_loss: 297.7944 - val_loss: 556.5787 - val_task0_logcount_loss: 0.8905 - val_task0_profile_loss: 333.9639
# Epoch 49/500
# 11/11 [==============================] - 2s 159ms/step - loss: 520.8451 - task0_logcount_loss: 0.8718 - task0_profile_loss: 302.8908 - val_loss: 485.4309 - val_task0_logcount_loss: 0.6115 - val_task0_profile_loss: 332.5574
# Epoch 50/500
# 11/11 [==============================] - 2s 157ms/step - loss: 499.1859 - task0_logcount_loss: 0.8062 - task0_profile_loss: 297.6433 - val_loss: 490.7844 - val_task0_logcount_loss: 0.6401 - val_task0_profile_loss: 330.7556
# Epoch 51/500
# 11/11 [==============================] - 2s 160ms/step - loss: 499.4995 - task0_logcount_loss: 0.8246 - task0_profile_loss: 293.3497 - val_loss: 484.0545 - val_task0_logcount_loss: 0.6184 - val_task0_profile_loss: 329.4572
# Epoch 52/500
# 11/11 [==============================] - 2s 160ms/step - loss: 489.8597 - task0_logcount_loss: 0.7930 - task0_profile_loss: 291.6172 - val_loss: 485.2703 - val_task0_logcount_loss: 0.6290 - val_task0_profile_loss: 328.0253
# Epoch 53/500
# 11/11 [==============================] - 2s 164ms/step - loss: 515.6636 - task0_logcount_loss: 0.8729 - task0_profile_loss: 297.4361 - val_loss: 484.1494 - val_task0_logcount_loss: 0.6287 - val_task0_profile_loss: 326.9642
# Epoch 54/500
# 11/11 [==============================] - 2s 160ms/step - loss: 498.9194 - task0_logcount_loss: 0.8715 - task0_profile_loss: 281.0451 - val_loss: 477.6624 - val_task0_logcount_loss: 0.6043 - val_task0_profile_loss: 326.5963
# Epoch 55/500
# 11/11 [==============================] - 2s 150ms/step - loss: 488.0050 - task0_logcount_loss: 0.8014 - task0_profile_loss: 287.6508 - val_loss: 482.4760 - val_task0_logcount_loss: 0.6237 - val_task0_profile_loss: 326.5446
# Epoch 56/500
# 11/11 [==============================] - 2s 162ms/step - loss: 486.0332 - task0_logcount_loss: 0.7997 - task0_profile_loss: 286.1121 - val_loss: 490.6345 - val_task0_logcount_loss: 0.6561 - val_task0_profile_loss: 326.6050
# Epoch 57/500
# 11/11 [==============================] - 2s 149ms/step - loss: 489.2945 - task0_logcount_loss: 0.7749 - task0_profile_loss: 295.5774 - val_loss: 517.4248 - val_task0_logcount_loss: 0.7641 - val_task0_profile_loss: 326.3992
# Epoch 58/500
# 11/11 [==============================] - 2s 160ms/step - loss: 496.5752 - task0_logcount_loss: 0.8417 - task0_profile_loss: 286.1505 - val_loss: 497.8167 - val_task0_logcount_loss: 0.6859 - val_task0_profile_loss: 326.3430
# Epoch 59/500
# 11/11 [==============================] - 2s 155ms/step - loss: 472.7869 - task0_logcount_loss: 0.7654 - task0_profile_loss: 281.4261 - val_loss: 536.5220 - val_task0_logcount_loss: 0.8410 - val_task0_profile_loss: 326.2761
# Epoch 60/500
# 11/11 [==============================] - 2s 165ms/step - loss: 488.4258 - task0_logcount_loss: 0.8214 - task0_profile_loss: 283.0770 - val_loss: 546.8649 - val_task0_logcount_loss: 0.8825 - val_task0_profile_loss: 326.2413
# Epoch 61/500
# 11/11 [==============================] - 2s 159ms/step - loss: 503.9307 - task0_logcount_loss: 0.8632 - task0_profile_loss: 288.1207 - val_loss: 506.8513 - val_task0_logcount_loss: 0.7227 - val_task0_profile_loss: 326.1794
# Epoch 62/500
# 11/11 [==============================] - 2s 159ms/step - loss: 480.3697 - task0_logcount_loss: 0.7829 - task0_profile_loss: 284.6488 - val_loss: 492.1432 - val_task0_logcount_loss: 0.6639 - val_task0_profile_loss: 326.1673
# Epoch 63/500
# 11/11 [==============================] - 2s 162ms/step - loss: 485.6159 - task0_logcount_loss: 0.7742 - task0_profile_loss: 292.0605 - val_loss: 476.9654 - val_task0_logcount_loss: 0.6018 - val_task0_profile_loss: 326.5073
# Epoch 64/500
# 11/11 [==============================] - 2s 150ms/step - loss: 513.3691 - task0_logcount_loss: 0.8827 - task0_profile_loss: 292.6948 - val_loss: 479.7235 - val_task0_logcount_loss: 0.6131 - val_task0_profile_loss: 326.4531
# Epoch 65/500
# 11/11 [==============================] - 2s 160ms/step - loss: 495.3158 - task0_logcount_loss: 0.8292 - task0_profile_loss: 288.0138 - val_loss: 477.2535 - val_task0_logcount_loss: 0.6037 - val_task0_profile_loss: 326.3398
# Epoch 66/500
# 11/11 [==============================] - 2s 164ms/step - loss: 516.9210 - task0_logcount_loss: 0.8969 - task0_profile_loss: 292.7085 - val_loss: 480.2349 - val_task0_logcount_loss: 0.6170 - val_task0_profile_loss: 325.9893
# Epoch 67/500
# 11/11 [==============================] - 2s 151ms/step - loss: 507.7433 - task0_logcount_loss: 0.8928 - task0_profile_loss: 284.5366 - val_loss: 483.3253 - val_task0_logcount_loss: 0.6292 - val_task0_profile_loss: 326.0144
# Epoch 68/500
# 11/11 [==============================] - 2s 164ms/step - loss: 488.3093 - task0_logcount_loss: 0.8142 - task0_profile_loss: 284.7470 - val_loss: 494.7428 - val_task0_logcount_loss: 0.6744 - val_task0_profile_loss: 326.1520
# Epoch 69/500
# 11/11 [==============================] - 2s 144ms/step - loss: 476.4536 - task0_logcount_loss: 0.7556 - task0_profile_loss: 287.5585 - val_loss: 492.6856 - val_task0_logcount_loss: 0.6677 - val_task0_profile_loss: 325.7506
# Epoch 70/500
# 11/11 [==============================] - 2s 160ms/step - loss: 490.9816 - task0_logcount_loss: 0.8093 - task0_profile_loss: 288.6541 - val_loss: 487.7522 - val_task0_logcount_loss: 0.6467 - val_task0_profile_loss: 326.0727
# Epoch 71/500
# 11/11 [==============================] - 2s 160ms/step - loss: 493.2378 - task0_logcount_loss: 0.8026 - task0_profile_loss: 292.5834 - val_loss: 499.8562 - val_task0_logcount_loss: 0.6955 - val_task0_profile_loss: 325.9926
# Epoch 72/500
# 11/11 [==============================] - 2s 160ms/step - loss: 482.5781 - task0_logcount_loss: 0.7835 - task0_profile_loss: 286.7034 - val_loss: 491.2181 - val_task0_logcount_loss: 0.6608 - val_task0_profile_loss: 326.0118
# Epoch 73/500
# 11/11 [==============================] - 2s 151ms/step - loss: 488.7164 - task0_logcount_loss: 0.7899 - task0_profile_loss: 291.2334 - val_loss: 506.7287 - val_task0_logcount_loss: 0.7219 - val_task0_profile_loss: 326.2426
# Epoch 74/500
# 11/11 [==============================] - 2s 159ms/step - loss: 489.8469 - task0_logcount_loss: 0.7901 - task0_profile_loss: 292.3236 - val_loss: 499.4829 - val_task0_logcount_loss: 0.6942 - val_task0_profile_loss: 325.9300
# Epoch 75/500
# 11/11 [==============================] - 2s 158ms/step - loss: 492.9891 - task0_logcount_loss: 0.8403 - task0_profile_loss: 282.9034 - val_loss: 505.5499 - val_task0_logcount_loss: 0.7180 - val_task0_profile_loss: 326.0527
# Epoch 76/500
# 11/11 [==============================] - 2s 150ms/step - loss: 491.7813 - task0_logcount_loss: 0.8073 - task0_profile_loss: 289.9610 - val_loss: 487.0382 - val_task0_logcount_loss: 0.6437 - val_task0_profile_loss: 326.1066
# Epoch 77/500
# 11/11 [==============================] - 2s 167ms/step - loss: 498.4140 - task0_logcount_loss: 0.8395 - task0_profile_loss: 288.5497 - val_loss: 488.8691 - val_task0_logcount_loss: 0.6528 - val_task0_profile_loss: 325.6632
# Epoch 78/500
# 11/11 [==============================] - 2s 148ms/step - loss: 502.2368 - task0_logcount_loss: 0.8937 - task0_profile_loss: 278.8012 - val_loss: 588.8541 - val_task0_logcount_loss: 1.0522 - val_task0_profile_loss: 325.8067
# Epoch 79/500
# 11/11 [==============================] - 2s 143ms/step - loss: 498.9210 - task0_logcount_loss: 0.8712 - task0_profile_loss: 281.1130 - val_loss: 514.2489 - val_task0_logcount_loss: 0.7552 - val_task0_profile_loss: 325.4526
# Epoch 80/500
# 11/11 [==============================] - 2s 160ms/step - loss: 505.0112 - task0_logcount_loss: 0.8405 - task0_profile_loss: 294.8951 - val_loss: 486.2563 - val_task0_logcount_loss: 0.6410 - val_task0_profile_loss: 326.0104
# Epoch 81/500
# 11/11 [==============================] - 2s 149ms/step - loss: 476.4123 - task0_logcount_loss: 0.7705 - task0_profile_loss: 283.7944 - val_loss: 539.3448 - val_task0_logcount_loss: 0.8543 - val_task0_profile_loss: 325.7574
# Epoch 82/500
# 11/11 [==============================] - 2s 170ms/step - loss: 495.1537 - task0_logcount_loss: 0.8297 - task0_profile_loss: 287.7321 - val_loss: 515.9708 - val_task0_logcount_loss: 0.7599 - val_task0_profile_loss: 326.0070
# Epoch 83/500
# 11/11 [==============================] - 2s 143ms/step - loss: 487.8883 - task0_logcount_loss: 0.7891 - task0_profile_loss: 290.6241 - val_loss: 499.6606 - val_task0_logcount_loss: 0.6964 - val_task0_profile_loss: 325.5712
# Epoch 84/500
# 11/11 [==============================] - 2s 160ms/step - loss: 477.6294 - task0_logcount_loss: 0.7539 - task0_profile_loss: 289.1430 - val_loss: 481.6480 - val_task0_logcount_loss: 0.6243 - val_task0_profile_loss: 325.5788
# Epoch 85/500
# 11/11 [==============================] - 2s 153ms/step - loss: 476.2014 - task0_logcount_loss: 0.7779 - task0_profile_loss: 281.7383 - val_loss: 475.1769 - val_task0_logcount_loss: 0.5985 - val_task0_profile_loss: 325.5483
# Epoch 86/500
# 11/11 [==============================] - 2s 160ms/step - loss: 464.4062 - task0_logcount_loss: 0.7365 - task0_profile_loss: 280.2755 - val_loss: 474.9021 - val_task0_logcount_loss: 0.5975 - val_task0_profile_loss: 325.5284
# Epoch 87/500
# 11/11 [==============================] - 2s 160ms/step - loss: 482.8784 - task0_logcount_loss: 0.7652 - task0_profile_loss: 291.5694 - val_loss: 475.0253 - val_task0_logcount_loss: 0.5985 - val_task0_profile_loss: 325.3992
# Epoch 88/500
# 11/11 [==============================] - 2s 166ms/step - loss: 465.5627 - task0_logcount_loss: 0.7316 - task0_profile_loss: 282.6672 - val_loss: 494.6706 - val_task0_logcount_loss: 0.6752 - val_task0_profile_loss: 325.8695
# Epoch 89/500
# 11/11 [==============================] - 2s 146ms/step - loss: 498.9419 - task0_logcount_loss: 0.8137 - task0_profile_loss: 295.5269 - val_loss: 478.8053 - val_task0_logcount_loss: 0.6134 - val_task0_profile_loss: 325.4562
# Epoch 90/500
# 11/11 [==============================] - 2s 167ms/step - loss: 479.7058 - task0_logcount_loss: 0.7800 - task0_profile_loss: 284.6962 - val_loss: 484.0955 - val_task0_logcount_loss: 0.6320 - val_task0_profile_loss: 326.0966
# Epoch 91/500
# 11/11 [==============================] - 2s 148ms/step - loss: 474.8941 - task0_logcount_loss: 0.7566 - task0_profile_loss: 285.7486 - val_loss: 515.6543 - val_task0_logcount_loss: 0.7611 - val_task0_profile_loss: 325.3877
# Epoch 92/500
# 11/11 [==============================] - 2s 153ms/step - loss: 481.3808 - task0_logcount_loss: 0.7659 - task0_profile_loss: 289.9014 - val_loss: 530.5879 - val_task0_logcount_loss: 0.8195 - val_task0_profile_loss: 325.7026
# Epoch 93/500
# 11/11 [==============================] - 2s 161ms/step - loss: 470.1300 - task0_logcount_loss: 0.7244 - task0_profile_loss: 289.0211 - val_loss: 542.0749 - val_task0_logcount_loss: 0.8625 - val_task0_profile_loss: 326.4470
# Epoch 94/500
# 11/11 [==============================] - 2s 162ms/step - loss: 476.4776 - task0_logcount_loss: 0.7746 - task0_profile_loss: 282.8211 - val_loss: 492.7274 - val_task0_logcount_loss: 0.6689 - val_task0_profile_loss: 325.5007
# Epoch 95/500
# 11/11 [==============================] - 2s 158ms/step - loss: 470.7538 - task0_logcount_loss: 0.7490 - task0_profile_loss: 283.5009 - val_loss: 476.2044 - val_task0_logcount_loss: 0.6051 - val_task0_profile_loss: 324.9346
# Epoch 96/500
# 11/11 [==============================] - 2s 163ms/step - loss: 478.6514 - task0_logcount_loss: 0.7616 - task0_profile_loss: 288.2395 - val_loss: 479.7494 - val_task0_logcount_loss: 0.6158 - val_task0_profile_loss: 325.8005
# Epoch 97/500
# 11/11 [==============================] - 2s 150ms/step - loss: 480.6995 - task0_logcount_loss: 0.7606 - task0_profile_loss: 290.5374 - val_loss: 474.8940 - val_task0_logcount_loss: 0.5937 - val_task0_profile_loss: 326.4715
# Epoch 98/500
# 11/11 [==============================] - 2s 161ms/step - loss: 463.2980 - task0_logcount_loss: 0.7147 - task0_profile_loss: 284.6342 - val_loss: 473.8335 - val_task0_logcount_loss: 0.5933 - val_task0_profile_loss: 325.4987
# Epoch 99/500
# 11/11 [==============================] - 2s 151ms/step - loss: 461.2313 - task0_logcount_loss: 0.7008 - task0_profile_loss: 286.0397 - val_loss: 466.1270 - val_task0_logcount_loss: 0.5580 - val_task0_profile_loss: 326.6309
# Epoch 100/500
# 11/11 [==============================] - 2s 148ms/step - loss: 489.1084 - task0_logcount_loss: 0.7756 - task0_profile_loss: 295.1985 - val_loss: 461.7140 - val_task0_logcount_loss: 0.5400 - val_task0_profile_loss: 326.7095
# Epoch 101/500
# 11/11 [==============================] - 2s 163ms/step - loss: 465.7372 - task0_logcount_loss: 0.7389 - task0_profile_loss: 281.0019 - val_loss: 461.4335 - val_task0_logcount_loss: 0.5433 - val_task0_profile_loss: 325.6175
# Epoch 102/500
# 11/11 [==============================] - 2s 159ms/step - loss: 467.0352 - task0_logcount_loss: 0.7121 - task0_profile_loss: 289.0160 - val_loss: 465.8142 - val_task0_logcount_loss: 0.5602 - val_task0_profile_loss: 325.7688
# Epoch 103/500
# 11/11 [==============================] - 2s 150ms/step - loss: 459.9430 - task0_logcount_loss: 0.6659 - task0_profile_loss: 293.4768 - val_loss: 462.3196 - val_task0_logcount_loss: 0.5403 - val_task0_profile_loss: 327.2420
# Epoch 104/500
# 11/11 [==============================] - 2s 148ms/step - loss: 477.1840 - task0_logcount_loss: 0.7454 - task0_profile_loss: 290.8363 - val_loss: 469.8775 - val_task0_logcount_loss: 0.5712 - val_task0_profile_loss: 327.0890
# Epoch 105/500
# 11/11 [==============================] - 2s 154ms/step - loss: 457.4734 - task0_logcount_loss: 0.6970 - task0_profile_loss: 283.2236 - val_loss: 510.3616 - val_task0_logcount_loss: 0.7301 - val_task0_profile_loss: 327.8366
# Epoch 106/500
# 11/11 [==============================] - 2s 159ms/step - loss: 465.8651 - task0_logcount_loss: 0.6940 - task0_profile_loss: 292.3623 - val_loss: 502.6742 - val_task0_logcount_loss: 0.7079 - val_task0_profile_loss: 325.7027
# Epoch 107/500
# 11/11 [==============================] - 2s 161ms/step - loss: 465.9321 - task0_logcount_loss: 0.7076 - task0_profile_loss: 289.0327 - val_loss: 450.5256 - val_task0_logcount_loss: 0.4984 - val_task0_profile_loss: 325.9193
# Epoch 108/500
# 11/11 [==============================] - 2s 163ms/step - loss: 456.5695 - task0_logcount_loss: 0.7105 - task0_profile_loss: 278.9333 - val_loss: 493.6314 - val_task0_logcount_loss: 0.6731 - val_task0_profile_loss: 325.3590
# Epoch 109/500
# 11/11 [==============================] - 2s 150ms/step - loss: 451.6017 - task0_logcount_loss: 0.6835 - task0_profile_loss: 280.7229 - val_loss: 451.8916 - val_task0_logcount_loss: 0.5077 - val_task0_profile_loss: 324.9787
# Epoch 110/500
# 11/11 [==============================] - 2s 159ms/step - loss: 462.3340 - task0_logcount_loss: 0.6817 - task0_profile_loss: 291.9187 - val_loss: 449.3254 - val_task0_logcount_loss: 0.4915 - val_task0_profile_loss: 326.4384
# Epoch 111/500
# 11/11 [==============================] - 2s 159ms/step - loss: 460.2182 - task0_logcount_loss: 0.6757 - task0_profile_loss: 291.2885 - val_loss: 441.7098 - val_task0_logcount_loss: 0.4605 - val_task0_profile_loss: 326.5919
# Epoch 112/500
# 11/11 [==============================] - 2s 148ms/step - loss: 450.8057 - task0_logcount_loss: 0.6388 - task0_profile_loss: 291.1173 - val_loss: 443.5060 - val_task0_logcount_loss: 0.4745 - val_task0_profile_loss: 324.8731
# Epoch 113/500
# 11/11 [==============================] - 2s 152ms/step - loss: 439.5141 - task0_logcount_loss: 0.6244 - task0_profile_loss: 283.4108 - val_loss: 452.0460 - val_task0_logcount_loss: 0.5069 - val_task0_profile_loss: 325.3108
# Epoch 114/500
# 11/11 [==============================] - 2s 159ms/step - loss: 446.9605 - task0_logcount_loss: 0.6667 - task0_profile_loss: 280.2971 - val_loss: 442.4313 - val_task0_logcount_loss: 0.4669 - val_task0_profile_loss: 325.7016
# Epoch 115/500
# 11/11 [==============================] - 2s 154ms/step - loss: 448.9392 - task0_logcount_loss: 0.6381 - task0_profile_loss: 289.4116 - val_loss: 430.1814 - val_task0_logcount_loss: 0.4223 - val_task0_profile_loss: 324.5991
# Epoch 116/500
# 11/11 [==============================] - 2s 154ms/step - loss: 433.2889 - task0_logcount_loss: 0.5632 - task0_profile_loss: 292.4871 - val_loss: 444.1957 - val_task0_logcount_loss: 0.4631 - val_task0_profile_loss: 328.4287
# Epoch 117/500
# 11/11 [==============================] - 2s 153ms/step - loss: 429.3791 - task0_logcount_loss: 0.5495 - task0_profile_loss: 292.0134 - val_loss: 428.1263 - val_task0_logcount_loss: 0.4048 - val_task0_profile_loss: 326.9357
# Epoch 118/500
# 11/11 [==============================] - 2s 159ms/step - loss: 436.7787 - task0_logcount_loss: 0.6079 - task0_profile_loss: 284.7955 - val_loss: 442.0204 - val_task0_logcount_loss: 0.3912 - val_task0_profile_loss: 344.2259
# Epoch 119/500
# 11/11 [==============================] - 2s 148ms/step - loss: 420.5025 - task0_logcount_loss: 0.5304 - task0_profile_loss: 287.8936 - val_loss: 434.0996 - val_task0_logcount_loss: 0.4017 - val_task0_profile_loss: 333.6636
# Epoch 120/500
# 11/11 [==============================] - 2s 161ms/step - loss: 428.5101 - task0_logcount_loss: 0.5363 - task0_profile_loss: 294.4349 - val_loss: 431.4112 - val_task0_logcount_loss: 0.3839 - val_task0_profile_loss: 335.4449
# Epoch 121/500
# 11/11 [==============================] - 2s 159ms/step - loss: 472.7822 - task0_logcount_loss: 0.7313 - task0_profile_loss: 289.9554 - val_loss: 420.2907 - val_task0_logcount_loss: 0.3821 - val_task0_profile_loss: 324.7639
# Epoch 122/500
# 11/11 [==============================] - 2s 142ms/step - loss: 425.4416 - task0_logcount_loss: 0.5397 - task0_profile_loss: 290.5251 - val_loss: 419.9139 - val_task0_logcount_loss: 0.3714 - val_task0_profile_loss: 327.0738
# Epoch 123/500
# 11/11 [==============================] - 2s 153ms/step - loss: 431.8844 - task0_logcount_loss: 0.5772 - task0_profile_loss: 287.5733 - val_loss: 423.3676 - val_task0_logcount_loss: 0.3965 - val_task0_profile_loss: 324.2303
# Epoch 124/500
# 11/11 [==============================] - 2s 159ms/step - loss: 405.1004 - task0_logcount_loss: 0.4903 - task0_profile_loss: 282.5143 - val_loss: 415.6893 - val_task0_logcount_loss: 0.3645 - val_task0_profile_loss: 324.5688
# Epoch 125/500
# 11/11 [==============================] - 2s 144ms/step - loss: 412.6930 - task0_logcount_loss: 0.4930 - task0_profile_loss: 289.4337 - val_loss: 413.5095 - val_task0_logcount_loss: 0.3569 - val_task0_profile_loss: 324.2828
# Epoch 126/500
# 11/11 [==============================] - 2s 154ms/step - loss: 421.2010 - task0_logcount_loss: 0.5466 - task0_profile_loss: 284.5505 - val_loss: 434.3122 - val_task0_logcount_loss: 0.4391 - val_task0_profile_loss: 324.5365
# Epoch 127/500
# 11/11 [==============================] - 2s 159ms/step - loss: 412.7187 - task0_logcount_loss: 0.5049 - task0_profile_loss: 286.4980 - val_loss: 426.1834 - val_task0_logcount_loss: 0.4078 - val_task0_profile_loss: 324.2241
# Epoch 128/500
# 11/11 [==============================] - 2s 160ms/step - loss: 400.6049 - task0_logcount_loss: 0.4721 - task0_profile_loss: 282.5896 - val_loss: 407.2067 - val_task0_logcount_loss: 0.3301 - val_task0_profile_loss: 324.6720
# Epoch 129/500
# 11/11 [==============================] - 2s 164ms/step - loss: 406.6960 - task0_logcount_loss: 0.4890 - task0_profile_loss: 284.4399 - val_loss: 410.9214 - val_task0_logcount_loss: 0.3429 - val_task0_profile_loss: 325.2026
# Epoch 130/500
# 11/11 [==============================] - 2s 149ms/step - loss: 414.1929 - task0_logcount_loss: 0.5013 - task0_profile_loss: 288.8577 - val_loss: 420.1223 - val_task0_logcount_loss: 0.3809 - val_task0_profile_loss: 324.8867
# Epoch 131/500
# 11/11 [==============================] - 2s 157ms/step - loss: 429.0378 - task0_logcount_loss: 0.5808 - task0_profile_loss: 283.8295 - val_loss: 442.9227 - val_task0_logcount_loss: 0.4727 - val_task0_profile_loss: 324.7525
# Epoch 132/500
# 11/11 [==============================] - 2s 165ms/step - loss: 418.3851 - task0_logcount_loss: 0.5170 - task0_profile_loss: 289.1426 - val_loss: 422.4594 - val_task0_logcount_loss: 0.3779 - val_task0_profile_loss: 327.9723
# Epoch 133/500
# 11/11 [==============================] - 2s 142ms/step - loss: 415.7005 - task0_logcount_loss: 0.5112 - task0_profile_loss: 287.9081 - val_loss: 414.3388 - val_task0_logcount_loss: 0.3602 - val_task0_profile_loss: 324.2856
# Epoch 134/500
# 11/11 [==============================] - 2s 150ms/step - loss: 418.3950 - task0_logcount_loss: 0.5343 - task0_profile_loss: 284.8148 - val_loss: 411.7271 - val_task0_logcount_loss: 0.3519 - val_task0_profile_loss: 323.7457
# Epoch 135/500
# 11/11 [==============================] - 2s 159ms/step - loss: 404.4468 - task0_logcount_loss: 0.4744 - task0_profile_loss: 285.8504 - val_loss: 411.6024 - val_task0_logcount_loss: 0.3414 - val_task0_profile_loss: 326.2445
# Epoch 136/500
# 11/11 [==============================] - 2s 161ms/step - loss: 406.5945 - task0_logcount_loss: 0.4671 - task0_profile_loss: 289.8179 - val_loss: 401.7763 - val_task0_logcount_loss: 0.3063 - val_task0_profile_loss: 325.2129
# Epoch 137/500
# 11/11 [==============================] - 2s 139ms/step - loss: 396.2469 - task0_logcount_loss: 0.4754 - task0_profile_loss: 277.3935 - val_loss: 404.9142 - val_task0_logcount_loss: 0.3229 - val_task0_profile_loss: 324.1798
# Epoch 138/500
# 11/11 [==============================] - 2s 160ms/step - loss: 406.5208 - task0_logcount_loss: 0.4925 - task0_profile_loss: 283.3864 - val_loss: 416.4008 - val_task0_logcount_loss: 0.3649 - val_task0_profile_loss: 325.1634
# Epoch 139/500
# ...
# Epoch 153/500
# 11/11 [==============================] - 2s 162ms/step - loss: 401.3208 - task0_logcount_loss: 0.4809 - task0_profile_loss: 281.1005 - val_loss: 400.4870 - val_task0_logcount_loss: 0.3083 - val_task0_profile_loss: 323.4009
# Epoch 154/500
# 11/11 [==============================] - 2s 167ms/step - loss: 392.3724 - task0_logcount_loss: 0.4093 - task0_profile_loss: 290.0388 - val_loss: 398.7108 - val_task0_logcount_loss: 0.2996 - val_task0_profile_loss: 323.8179
# Epoch 155/500
# 11/11 [==============================] - 2s 158ms/step - loss: 380.8377 - task0_logcount_loss: 0.3859 - task0_profile_loss: 284.3597 - val_loss: 398.7007 - val_task0_logcount_loss: 0.2949 - val_task0_profile_loss: 324.9820
# Epoch 156/500
# 11/11 [==============================] - 2s 146ms/step - loss: 393.9655 - task0_logcount_loss: 0.4015 - task0_profile_loss: 293.5820 - val_loss: 398.3520 - val_task0_logcount_loss: 0.2985 - val_task0_profile_loss: 323.7172
# Epoch 157/500
# 11/11 [==============================] - 2s 149ms/step - loss: 388.5407 - task0_logcount_loss: 0.4149 - task0_profile_loss: 284.8154 - val_loss: 398.3989 - val_task0_logcount_loss: 0.2967 - val_task0_profile_loss: 324.2131
# Epoch 158/500
# 11/11 [==============================] - 2s 158ms/step - loss: 396.6901 - task0_logcount_loss: 0.4043 - task0_profile_loss: 295.6114 - val_loss: 402.9653 - val_task0_logcount_loss: 0.3040 - val_task0_profile_loss: 326.9683
# Epoch 159/500
# 11/11 [==============================] - 2s 154ms/step - loss: 405.4637 - task0_logcount_loss: 0.4151 - task0_profile_loss: 301.6982 - val_loss: 404.8101 - val_task0_logcount_loss: 0.3064 - val_task0_profile_loss: 328.2214
# Epoch 160/500
# 11/11 [==============================] - 2s 151ms/step - loss: 395.9256 - task0_logcount_loss: 0.4157 - task0_profile_loss: 292.0003 - val_loss: 397.8165 - val_task0_logcount_loss: 0.2900 - val_task0_profile_loss: 325.3089
# Epoch 161/500
# 11/11 [==============================] - 2s 159ms/step - loss: 398.3056 - task0_logcount_loss: 0.4331 - task0_profile_loss: 290.0415 - val_loss: 403.4645 - val_task0_logcount_loss: 0.3107 - val_task0_profile_loss: 325.7845
# Epoch 162/500
# 11/11 [==============================] - 2s 147ms/step - loss: 384.3175 - task0_logcount_loss: 0.4046 - task0_profile_loss: 283.1658 - val_loss: 395.4779 - val_task0_logcount_loss: 0.2895 - val_task0_profile_loss: 323.0917
# Epoch 163/500
# 11/11 [==============================] - 2s 160ms/step - loss: 385.8354 - task0_logcount_loss: 0.3731 - task0_profile_loss: 292.5718 - val_loss: 401.5382 - val_task0_logcount_loss: 0.3088 - val_task0_profile_loss: 324.3293
# Epoch 164/500
# 11/11 [==============================] - 2s 161ms/step - loss: 390.5129 - task0_logcount_loss: 0.4099 - task0_profile_loss: 288.0419 - val_loss: 395.2870 - val_task0_logcount_loss: 0.2865 - val_task0_profile_loss: 323.6585
# Epoch 165/500
# 11/11 [==============================] - 2s 152ms/step - loss: 416.3297 - task0_logcount_loss: 0.5189 - task0_profile_loss: 286.5988 - val_loss: 396.9563 - val_task0_logcount_loss: 0.2931 - val_task0_profile_loss: 323.6744
# Epoch 166/500
# 11/11 [==============================] - 2s 152ms/step - loss: 401.1321 - task0_logcount_loss: 0.4794 - task0_profile_loss: 281.2883 - val_loss: 398.8270 - val_task0_logcount_loss: 0.2949 - val_task0_profile_loss: 325.0950
# Epoch 167/500
# 11/11 [==============================] - 2s 149ms/step - loss: 392.9568 - task0_logcount_loss: 0.4521 - task0_profile_loss: 279.9327 - val_loss: 414.0835 - val_task0_logcount_loss: 0.3627 - val_task0_profile_loss: 323.4169
# Epoch 168/500
# 11/11 [==============================] - 2s 153ms/step - loss: 382.5280 - task0_logcount_loss: 0.3966 - task0_profile_loss: 283.3831 - val_loss: 393.9605 - val_task0_logcount_loss: 0.2837 - val_task0_profile_loss: 323.0278
# Epoch 169/500
# 11/11 [==============================] - 2s 160ms/step - loss: 377.6248 - task0_logcount_loss: 0.3908 - task0_profile_loss: 279.9207 - val_loss: 397.4900 - val_task0_logcount_loss: 0.2956 - val_task0_profile_loss: 323.6024
# Epoch 170/500
# 11/11 [==============================] - 2s 151ms/step - loss: 396.7568 - task0_logcount_loss: 0.3868 - task0_profile_loss: 300.0649 - val_loss: 393.1541 - val_task0_logcount_loss: 0.2841 - val_task0_profile_loss: 322.1213
# Epoch 171/500
# 11/11 [==============================] - 2s 151ms/step - loss: 379.3137 - task0_logcount_loss: 0.3608 - task0_profile_loss: 289.1192 - val_loss: 396.4637 - val_task0_logcount_loss: 0.2899 - val_task0_profile_loss: 323.9951
# Epoch 172/500
# 11/11 [==============================] - 2s 162ms/step - loss: 402.3851 - task0_logcount_loss: 0.4209 - task0_profile_loss: 297.1701 - val_loss: 396.8060 - val_task0_logcount_loss: 0.2923 - val_task0_profile_loss: 323.7246
# Epoch 173/500
# 11/11 [==============================] - 2s 160ms/step - loss: 382.8454 - task0_logcount_loss: 0.3766 - task0_profile_loss: 288.6958 - val_loss: 395.8233 - val_task0_logcount_loss: 0.2819 - val_task0_profile_loss: 325.3581
# Epoch 174/500
# 11/11 [==============================] - 2s 150ms/step - loss: 378.6584 - task0_logcount_loss: 0.3788 - task0_profile_loss: 283.9606 - val_loss: 394.9158 - val_task0_logcount_loss: 0.2859 - val_task0_profile_loss: 323.4419
# Epoch 175/500
# 11/11 [==============================] - 2s 149ms/step - loss: 378.6125 - task0_logcount_loss: 0.3589 - task0_profile_loss: 288.8963 - val_loss: 397.6703 - val_task0_logcount_loss: 0.2895 - val_task0_profile_loss: 325.3074
# Epoch 176/500
# 11/11 [==============================] - 2s 159ms/step - loss: 376.4760 - task0_logcount_loss: 0.3705 - task0_profile_loss: 283.8584 - val_loss: 394.1903 - val_task0_logcount_loss: 0.2790 - val_task0_profile_loss: 324.4520
# Epoch 177/500
# 11/11 [==============================] - 2s 157ms/step - loss: 386.8982 - task0_logcount_loss: 0.4051 - task0_profile_loss: 285.6149 - val_loss: 397.1661 - val_task0_logcount_loss: 0.2909 - val_task0_profile_loss: 324.4324
# Epoch 178/500
# 11/11 [==============================] - 2s 161ms/step - loss: 395.5525 - task0_logcount_loss: 0.4144 - task0_profile_loss: 291.9584 - val_loss: 392.7071 - val_task0_logcount_loss: 0.2796 - val_task0_profile_loss: 322.8017
# Epoch 179/500
# 11/11 [==============================] - 2s 175ms/step - loss: 409.2947 - task0_logcount_loss: 0.4812 - task0_profile_loss: 288.9946 - val_loss: 415.4395 - val_task0_logcount_loss: 0.3660 - val_task0_profile_loss: 323.9430
# Epoch 180/500
# 11/11 [==============================] - 2s 160ms/step - loss: 381.4652 - task0_logcount_loss: 0.3783 - task0_profile_loss: 286.8936 - val_loss: 396.2110 - val_task0_logcount_loss: 0.2955 - val_task0_profile_loss: 322.3461
# Epoch 181/500
# 11/11 [==============================] - 2s 150ms/step - loss: 380.2736 - task0_logcount_loss: 0.3681 - task0_profile_loss: 288.2517 - val_loss: 405.3528 - val_task0_logcount_loss: 0.3212 - val_task0_profile_loss: 325.0411
# Epoch 182/500
# 11/11 [==============================] - 2s 151ms/step - loss: 373.5014 - task0_logcount_loss: 0.3674 - task0_profile_loss: 281.6445 - val_loss: 397.5935 - val_task0_logcount_loss: 0.2949 - val_task0_profile_loss: 323.8688
# Epoch 183/500
# 11/11 [==============================] - 2s 164ms/step - loss: 384.5974 - task0_logcount_loss: 0.3796 - task0_profile_loss: 289.6992 - val_loss: 415.0748 - val_task0_logcount_loss: 0.3636 - val_task0_profile_loss: 324.1730
# Epoch 184/500
# 11/11 [==============================] - 2s 149ms/step - loss: 372.9628 - task0_logcount_loss: 0.3341 - task0_profile_loss: 289.4374 - val_loss: 394.0003 - val_task0_logcount_loss: 0.2788 - val_task0_profile_loss: 324.2952
# Epoch 185/500
# 11/11 [==============================] - 2s 161ms/step - loss: 360.9752 - task0_logcount_loss: 0.2952 - task0_profile_loss: 287.1766 - val_loss: 394.3919 - val_task0_logcount_loss: 0.2827 - val_task0_profile_loss: 323.7188
# Epoch 186/500
# 11/11 [==============================] - 2s 145ms/step - loss: 374.5864 - task0_logcount_loss: 0.3700 - task0_profile_loss: 282.0940 - val_loss: 392.2148 - val_task0_logcount_loss: 0.2778 - val_task0_profile_loss: 322.7671
# Epoch 187/500
# 11/11 [==============================] - 2s 159ms/step - loss: 371.4727 - task0_logcount_loss: 0.3712 - task0_profile_loss: 278.6753 - val_loss: 393.1841 - val_task0_logcount_loss: 0.2809 - val_task0_profile_loss: 322.9660
# Epoch 188/500
# 11/11 [==============================] - 2s 150ms/step - loss: 375.3338 - task0_logcount_loss: 0.3322 - task0_profile_loss: 292.2839 - val_loss: 392.6311 - val_task0_logcount_loss: 0.2779 - val_task0_profile_loss: 323.1614
# Epoch 189/500
# 11/11 [==============================] - 2s 156ms/step - loss: 373.5684 - task0_logcount_loss: 0.3102 - task0_profile_loss: 296.0092 - val_loss: 397.1085 - val_task0_logcount_loss: 0.2824 - val_task0_profile_loss: 326.5168
# Epoch 190/500
# 11/11 [==============================] - 2s 147ms/step - loss: 365.5266 - task0_logcount_loss: 0.3486 - task0_profile_loss: 278.3869 - val_loss: 396.3303 - val_task0_logcount_loss: 0.2925 - val_task0_profile_loss: 323.1971
# Epoch 191/500
# 11/11 [==============================] - 2s 150ms/step - loss: 382.5537 - task0_logcount_loss: 0.3799 - task0_profile_loss: 287.5698 - val_loss: 416.0550 - val_task0_logcount_loss: 0.3740 - val_task0_profile_loss: 322.5440
# Epoch 192/500
# 11/11 [==============================] - 2s 144ms/step - loss: 374.2954 - task0_logcount_loss: 0.3548 - task0_profile_loss: 285.6050 - val_loss: 392.0974 - val_task0_logcount_loss: 0.2784 - val_task0_profile_loss: 322.5026
# Epoch 193/500
# 11/11 [==============================] - 2s 155ms/step - loss: 375.6876 - task0_logcount_loss: 0.3472 - task0_profile_loss: 288.8962 - val_loss: 400.0512 - val_task0_logcount_loss: 0.3062 - val_task0_profile_loss: 323.5022
# Epoch 194/500
# 11/11 [==============================] - 2s 162ms/step - loss: 373.3937 - task0_logcount_loss: 0.3335 - task0_profile_loss: 290.0255 - val_loss: 391.8892 - val_task0_logcount_loss: 0.2772 - val_task0_profile_loss: 322.5779
# Epoch 195/500
# 11/11 [==============================] - 2s 161ms/step - loss: 368.4637 - task0_logcount_loss: 0.3639 - task0_profile_loss: 277.4957 - val_loss: 398.2605 - val_task0_logcount_loss: 0.2963 - val_task0_profile_loss: 324.1777
# Epoch 196/500
# 11/11 [==============================] - 2s 149ms/step - loss: 400.4481 - task0_logcount_loss: 0.3902 - task0_profile_loss: 302.8899 - val_loss: 398.1749 - val_task0_logcount_loss: 0.2975 - val_task0_profile_loss: 323.7950
# Epoch 197/500
# 11/11 [==============================] - 2s 163ms/step - loss: 372.3024 - task0_logcount_loss: 0.3566 - task0_profile_loss: 283.1578 - val_loss: 398.7018 - val_task0_logcount_loss: 0.2869 - val_task0_profile_loss: 326.9830
# Epoch 198/500
# 11/11 [==============================] - 2s 158ms/step - loss: 394.0229 - task0_logcount_loss: 0.3899 - task0_profile_loss: 296.5536 - val_loss: 392.4898 - val_task0_logcount_loss: 0.2735 - val_task0_profile_loss: 324.1054
# Epoch 199/500
# 11/11 [==============================] - 2s 159ms/step - loss: 376.1306 - task0_logcount_loss: 0.3369 - task0_profile_loss: 291.8941 - val_loss: 400.7712 - val_task0_logcount_loss: 0.3093 - val_task0_profile_loss: 323.4376
# Epoch 200/500
# 11/11 [==============================] - 2s 152ms/step - loss: 361.7280 - task0_logcount_loss: 0.3044 - task0_profile_loss: 285.6208 - val_loss: 396.5756 - val_task0_logcount_loss: 0.2944 - val_task0_profile_loss: 322.9743
# Epoch 201/500
# 11/11 [==============================] - 2s 157ms/step - loss: 378.4584 - task0_logcount_loss: 0.3447 - task0_profile_loss: 292.2937 - val_loss: 399.0382 - val_task0_logcount_loss: 0.3041 - val_task0_profile_loss: 323.0188
# Epoch 202/500
# 11/11 [==============================] - 2s 153ms/step - loss: 372.8571 - task0_logcount_loss: 0.3273 - task0_profile_loss: 291.0236 - val_loss: 395.1323 - val_task0_logcount_loss: 0.2866 - val_task0_profile_loss: 323.4857
# Epoch 203/500
# 11/11 [==============================] - 2s 154ms/step - loss: 364.7222 - task0_logcount_loss: 0.3258 - task0_profile_loss: 283.2652 - val_loss: 406.1948 - val_task0_logcount_loss: 0.3303 - val_task0_profile_loss: 323.6296
# Epoch 204/500
# 11/11 [==============================] - 2s 147ms/step - loss: 360.6117 - task0_logcount_loss: 0.3168 - task0_profile_loss: 281.4211 - val_loss: 404.8677 - val_task0_logcount_loss: 0.3262 - val_task0_profile_loss: 323.3069
# Epoch 205/500
# 11/11 [==============================] - 2s 150ms/step - loss: 376.0226 - task0_logcount_loss: 0.3393 - task0_profile_loss: 291.2068 - val_loss: 403.7867 - val_task0_logcount_loss: 0.3175 - val_task0_profile_loss: 324.4169
# Epoch 206/500
# 11/11 [==============================] - 2s 158ms/step - loss: 377.4643 - task0_logcount_loss: 0.3571 - task0_profile_loss: 288.1962 - val_loss: 409.0427 - val_task0_logcount_loss: 0.3427 - val_task0_profile_loss: 323.3633
# Epoch 207/500
# 11/11 [==============================] - 2s 150ms/step - loss: 368.9986 - task0_logcount_loss: 0.3373 - task0_profile_loss: 284.6814 - val_loss: 394.1614 - val_task0_logcount_loss: 0.2850 - val_task0_profile_loss: 322.8989
# Epoch 208/500
# 11/11 [==============================] - 2s 162ms/step - loss: 362.2425 - task0_logcount_loss: 0.3235 - task0_profile_loss: 281.3604 - val_loss: 398.3805 - val_task0_logcount_loss: 0.3015 - val_task0_profile_loss: 322.9937
# Epoch 209/500
# 11/11 [==============================] - 2s 152ms/step - loss: 365.9508 - task0_logcount_loss: 0.3120 - task0_profile_loss: 287.9455 - val_loss: 398.8945 - val_task0_logcount_loss: 0.2943 - val_task0_profile_loss: 325.3137
# Epoch 210/500
# 11/11 [==============================] - 2s 145ms/step - loss: 365.5813 - task0_logcount_loss: 0.3097 - task0_profile_loss: 288.1660 - val_loss: 399.3208 - val_task0_logcount_loss: 0.3002 - val_task0_profile_loss: 324.2594
# Epoch 211/500
# 11/11 [==============================] - 2s 153ms/step - loss: 377.6868 - task0_logcount_loss: 0.3409 - task0_profile_loss: 292.4645 - val_loss: 393.6257 - val_task0_logcount_loss: 0.2798 - val_task0_profile_loss: 323.6789
# Epoch 212/500
# 11/11 [==============================] - 2s 149ms/step - loss: 374.1343 - task0_logcount_loss: 0.3622 - task0_profile_loss: 283.5843 - val_loss: 404.1758 - val_task0_logcount_loss: 0.3289 - val_task0_profile_loss: 321.9624
# Epoch 213/500
# 11/11 [==============================] - 2s 160ms/step - loss: 361.6371 - task0_logcount_loss: 0.3057 - task0_profile_loss: 285.2066 - val_loss: 395.0756 - val_task0_logcount_loss: 0.2894 - val_task0_profile_loss: 322.7380
# Epoch 214/500
# 11/11 [==============================] - 2s 149ms/step - loss: 353.6952 - task0_logcount_loss: 0.2762 - task0_profile_loss: 284.6528 - val_loss: 393.8286 - val_task0_logcount_loss: 0.2813 - val_task0_profile_loss: 323.5043
# Epoch 215/500
# 11/11 [==============================] - 2s 160ms/step - loss: 419.2094 - task0_logcount_loss: 0.5695 - task0_profile_loss: 276.8433 - val_loss: 421.3185 - val_task0_logcount_loss: 0.3901 - val_task0_profile_loss: 323.7969
# Epoch 216/500
# 11/11 [==============================] - 2s 157ms/step - loss: 397.5555 - task0_logcount_loss: 0.4157 - task0_profile_loss: 293.6342 - val_loss: 392.5604 - val_task0_logcount_loss: 0.2733 - val_task0_profile_loss: 324.2244
# Epoch 217/500
# 11/11 [==============================] - 2s 169ms/step - loss: 423.8766 - task0_logcount_loss: 0.4844 - task0_profile_loss: 302.7759 - val_loss: 443.7758 - val_task0_logcount_loss: 0.4824 - val_task0_profile_loss: 323.1881
# Epoch 218/500
# 11/11 [==============================] - 2s 159ms/step - loss: 383.9225 - task0_logcount_loss: 0.4045 - task0_profile_loss: 282.8055 - val_loss: 418.2950 - val_task0_logcount_loss: 0.3805 - val_task0_profile_loss: 323.1692
# Epoch 219/500
# 11/11 [==============================] - 2s 162ms/step - loss: 364.7421 - task0_logcount_loss: 0.3368 - task0_profile_loss: 280.5334 - val_loss: 398.1770 - val_task0_logcount_loss: 0.2990 - val_task0_profile_loss: 323.4389

# %%
model.save('/users/amr1/pho4/data/models/cbf1_limited_eth_model.h5')

# %%
from keras.models import load_model
from keras.utils import CustomObjectScope

with CustomObjectScope({'MultichannelMultinomialNLL': MultichannelMultinomialNLL,'RevCompConv1D': RevCompConv1D}):
    model = load_model('/users/amr1/pho4/data/models/cbf1_limited_eth_model.h5')
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           (None, 546, 4)       0
# __________________________________________________________________________________________________
# rev_comp_conv1d_1 (RevCompConv1 (None, 526, 50)      2125        sequence[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 522, 50)      0           rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_2 (RevCompConv1 (None, 522, 50)      3775        rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 522, 50)      0           lambda_1[0][0]
#                                                                  rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 514, 50)      0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 514, 50)      0           rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_3 (RevCompConv1 (None, 514, 50)      3775        average_1[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 514, 50)      0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 498, 50)      0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 498, 50)      0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 498, 50)      0           rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_4 (RevCompConv1 (None, 498, 50)      3775        average_2[0][0]
# __________________________________________________________________________________________________
# average_3 (Average)             (None, 498, 50)      0           lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 466, 50)      0           lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 466, 50)      0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 466, 50)      0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 466, 50)      0           rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_5 (RevCompConv1 (None, 466, 50)      3775        average_3[0][0]
# __________________________________________________________________________________________________
# average_4 (Average)             (None, 466, 50)      0           lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 402, 50)      0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 402, 50)      0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 402, 50)      0           lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 402, 50)      0           lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 402, 50)      0           rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_6 (RevCompConv1 (None, 402, 50)      3775        average_4[0][0]
# __________________________________________________________________________________________________
# average_5 (Average)             (None, 402, 50)      0           lambda_11[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
#                                                                  rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 274, 50)      0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 274, 50)      0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 274, 50)      0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 274, 50)      0           lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 274, 50)      0           lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 274, 50)      0           rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_7 (RevCompConv1 (None, 274, 50)      3775        average_5[0][0]
# __________________________________________________________________________________________________
# control_logcount (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# average_6 (Average)             (None, 274, 50)      0           lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_21[0][0]
#                                                                  rev_comp_conv1d_7[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           control_logcount[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 50)           0           average_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 52)           0           lambda_22[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  control_logcount[0][0]
# __________________________________________________________________________________________________
# control_profile (InputLayer)    (None, 225, 2)       0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 52)        0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 225, 2)       0           control_profile[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_9 (RevCompConv1 (None, 225, 2)       2501        average_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_8 (RevCompConv1 (None, 1, 2)         53          reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 225, 6)       0           lambda_23[0][0]
#                                                                  rev_comp_conv1d_9[0][0]
#                                                                  control_profile[0][0]
# __________________________________________________________________________________________________
# task0_logcount (Reshape)        (None, 2)            0           rev_comp_conv1d_8[0][0]
# __________________________________________________________________________________________________
# task0_profile (RevCompConv1D)   (None, 225, 2)       7           concatenate_2[0][0]
# ==================================================================================================
# Total params: 27,336
# Trainable params: 27,336
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# evaluate

# %%
o_test_preds_logcount = []
o_test_biastrack_logcount = []
o_test_biastrack_profile = []
o_test_seqs = []
o_test_preds_profile = []
o_test_labels_logcount = []
o_test_labels_profile = []

keras_test_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
            bed_file="/users/amr1/pho4/data/limited_conditions/test_1000_around_eth_cbf1.bed.gz",
            batch_size=64,
            shuffle_before_epoch=False, 
            seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)

orig_seqs = []

for batch_idx in range(len(keras_test_batch_generator)):
    batch_inputs, batch_labels = keras_test_batch_generator[batch_idx]
    o_test_seqs.append(batch_inputs['sequence']) 
    o_test_biastrack_logcount.append(batch_inputs['control_logcount'])
    o_test_biastrack_profile.append(batch_inputs['control_profile'])    
    test_preds = model.predict(batch_inputs)
    o_test_preds_logcount.append(test_preds[0])
    o_test_preds_profile.append(test_preds[1])
    o_test_labels_logcount.append(batch_labels['task0_logcount'])
    o_test_labels_profile.append(batch_labels['task0_profile'])
o_test_biastrack_logcount = np.concatenate(o_test_biastrack_logcount, axis=0)
o_test_biastrack_profile = np.concatenate(o_test_biastrack_profile,axis=0)
o_test_seqs = np.concatenate(o_test_seqs,axis=0)
o_test_preds_logcount = np.concatenate(o_test_preds_logcount, axis=0)
o_test_preds_profile = np.concatenate(o_test_preds_profile, axis=0)
o_test_labels_logcount = np.concatenate(o_test_labels_logcount, axis=0)
o_test_labels_profile = np.concatenate(o_test_labels_profile, axis=0)

from matplotlib import pyplot as plt
from scipy.stats import spearmanr

o_test_labels_logtotalcount = np.log(np.sum(np.exp(o_test_labels_logcount) - 1,axis=-1) + 1)

plt.scatter(o_test_biastrack_logcount, o_test_labels_logtotalcount, alpha=0.1)
plt.xlabel("Bias track log counts")
plt.ylabel("True log total counts")
plt.plot([np.min(o_test_biastrack_logcount), np.max(o_test_biastrack_logcount)],
         [np.min(o_test_biastrack_logcount), np.max(o_test_biastrack_logcount)],
         color="black")
plt.show()
print(spearmanr(o_test_biastrack_logcount, o_test_labels_logtotalcount))


#do a scatterplot of total count predictions
plt.scatter(o_test_preds_logcount[:,0], o_test_labels_logcount[:,0], alpha=0.1)
plt.xlabel("Predicted log counts - Forward Strand")
plt.ylabel("True log counts - Forward Strand")
plt.plot([np.min(o_test_preds_logcount[:,0]), np.max(o_test_preds_logcount[:,0])],
         [np.min(o_test_preds_logcount[:,0]), np.max(o_test_preds_logcount[:,0])],
         color="black")
plt.show()
print(spearmanr(o_test_preds_logcount[:,0], o_test_labels_logcount[:,0]))

plt.scatter(o_test_preds_logcount[:,1], o_test_labels_logcount[:,1], alpha=0.1)
plt.xlabel("Predicted log counts - Reverse Strand")
plt.ylabel("True log counts - Reverse Strand")
plt.plot([np.min(o_test_preds_logcount[:,1]), np.max(o_test_preds_logcount[:,1])],
         [np.min(o_test_preds_logcount[:,1]), np.max(o_test_preds_logcount[:,1])],
         color="black")
plt.show()
print(spearmanr(o_test_preds_logcount[:,1], o_test_labels_logcount[:,1]))
# Out:
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# SpearmanrResult(correlation=-0.0054926220827694805, pvalue=0.9543749506398831)
# SpearmanrResult(correlation=0.7106714233090994, pvalue=2.400017615088497e-18)
# SpearmanrResult(correlation=0.7336788203645229, pvalue=5.2702598798745515e-20)

# %%
# %matplotlib inline

o_train_preds_logcount = []
o_train_biastrack_logcount = []
o_train_biastrack_profile = []
o_train_seqs = []
o_train_preds_profile = []
o_train_labels_logcount = []
o_train_labels_profile = []

orig_seqs = []

for batch_idx in range(len(keras_train_batch_generator)):
    batch_inputs, batch_labels = keras_train_batch_generator[batch_idx]
    o_train_seqs.append(batch_inputs['sequence']) 
    o_train_biastrack_logcount.append(batch_inputs['control_logcount'])
    o_train_biastrack_profile.append(batch_inputs['control_profile'])    
    train_preds = model.predict(batch_inputs)
    o_train_preds_logcount.append(train_preds[0])
    o_train_preds_profile.append(train_preds[1])
    o_train_labels_logcount.append(batch_labels['task0_logcount'])
    o_train_labels_profile.append(batch_labels['task0_profile'])
o_train_biastrack_logcount = np.concatenate(o_train_biastrack_logcount, axis=0)
o_train_biastrack_profile = np.concatenate(o_train_biastrack_profile,axis=0)
o_train_seqs = np.concatenate(o_train_seqs,axis=0)
o_train_preds_logcount = np.concatenate(o_train_preds_logcount, axis=0)
o_train_preds_profile = np.concatenate(o_train_preds_profile, axis=0)
o_train_labels_logcount = np.concatenate(o_train_labels_logcount, axis=0)
o_train_labels_profile = np.concatenate(o_train_labels_profile, axis=0)

from matplotlib import pyplot as plt
from scipy.stats import spearmanr

o_train_labels_logtotalcount = np.log(np.sum(np.exp(o_train_labels_logcount) - 1,axis=-1) + 1)

plt.scatter(o_train_biastrack_logcount, o_train_labels_logtotalcount, alpha=0.1)
plt.xlabel("Bias track log counts")
plt.ylabel("True log total counts")
plt.plot([np.min(o_train_biastrack_logcount), np.max(o_train_biastrack_logcount)],
         [np.min(o_train_biastrack_logcount), np.max(o_train_biastrack_logcount)],
         color="black")
plt.show()
print(spearmanr(o_train_biastrack_logcount, o_train_labels_logtotalcount))


#do a scatterplot of total count predictions
plt.scatter(o_train_preds_logcount[:,0], o_train_labels_logcount[:,0], alpha=0.1)
plt.xlabel("Predicted log counts - Forward Strand")
plt.ylabel("True log counts - Forward Strand")
plt.plot([np.min(o_train_preds_logcount[:,0]), np.max(o_train_preds_logcount[:,0])],
         [np.min(o_train_preds_logcount[:,0]), np.max(o_train_preds_logcount[:,0])],
         color="black")
plt.show()
print(spearmanr(o_train_preds_logcount[:,0], o_train_labels_logcount[:,0]))

plt.scatter(o_train_preds_logcount[:,1], o_train_labels_logcount[:,1], alpha=0.1)
plt.xlabel("Predicted log counts - Reverse Strand")
plt.ylabel("True log counts - Reverse Strand")
plt.plot([np.min(o_train_preds_logcount[:,1]), np.max(o_train_preds_logcount[:,1])],
         [np.min(o_train_preds_logcount[:,1]), np.max(o_train_preds_logcount[:,1])],
         color="black")
plt.show()
print(spearmanr(o_train_preds_logcount[:,1], o_train_labels_logcount[:,1]))
# Out:
# SpearmanrResult(correlation=0.09137322393892565, pvalue=0.0010272563443744663)
# SpearmanrResult(correlation=0.784221651763745, pvalue=7.965701592287074e-269)
# SpearmanrResult(correlation=0.7764021728491779, pvalue=4.16517157018938e-260)

# %% [markdown]
# Interpretation

# %%
import shap
from deeplift.dinuc_shuffle import dinuc_shuffle

def combine_mult_and_diffref(mult, orig_inp, bg_data):
    to_return = []
    for l in [0]:
        projected_hypothetical_contribs = np.zeros_like(bg_data[l]).astype("float")
        assert len(orig_inp[l].shape)==2
        #At each position in the input sequence, we iterate over the one-hot encoding
        # possibilities (eg: for genomic sequence, this is ACGT i.e.
        # 1000, 0100, 0010 and 0001) and compute the hypothetical 
        # difference-from-reference in each case. We then multiply the hypothetical
        # differences-from-reference with the multipliers to get the hypothetical contributions.
        #For each of the one-hot encoding possibilities,
        # the hypothetical contributions are then summed across the ACGT axis to estimate
        # the total hypothetical contribution of each position. This per-position hypothetical
        # contribution is then assigned ("projected") onto whichever base was present in the
        # hypothetical sequence.
        #The reason this is a fast estimate of what the importance scores *would* look
        # like if different bases were present in the underlying sequence is that
        # the multipliers are computed once using the original sequence, and are not
        # computed again for each hypothetical sequence.
        for i in range(orig_inp[l].shape[-1]):
            hypothetical_input = np.zeros_like(orig_inp[l]).astype("float")
            hypothetical_input[:,i] = 1.0
            hypothetical_difference_from_reference = (hypothetical_input[None,:,:]-bg_data[l])
            hypothetical_contribs = hypothetical_difference_from_reference*mult[l]
            projected_hypothetical_contribs[:,:,i] = np.sum(hypothetical_contribs,axis=-1) 
        to_return.append(np.mean(projected_hypothetical_contribs,axis=0))
    to_return.append(np.zeros_like(orig_inp[1]))
    return to_return

def shuffle_several_times(s):
    numshuffles=20
    return [np.array([dinuc_shuffle(s[0]) for i in range(numshuffles)]),
            np.array([s[1] for i in range(numshuffles)])]

profile_model_counts_explainer = shap.explainers.deep.TFDeepExplainer(
    ([model.input[0], model.input[1]],
     tf.reduce_sum(model.outputs[0],axis=-1)),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)

#See Google slide deck for explanations
#We meannorm as per section titled "Adjustments for Softmax Layers"
# in the DeepLIFT paper
meannormed_logits = (
    model.outputs[1]-
    tf.reduce_mean(model.outputs[1],axis=1)[:,None,:])
#'stop_gradient' will prevent importance from being propagated through
# this operation; we do this because we just want to treat the post-softmax
# probabilities as 'weights' on the different logits, without having the
# network explain how the probabilities themselves were derived
#Could be worth contrasting explanations derived with and without stop_gradient
# enabled...
stopgrad_meannormed_logits = tf.stop_gradient(meannormed_logits)
softmax_out = tf.nn.softmax(stopgrad_meannormed_logits,axis=1)
#Weight the logits according to the softmax probabilities, take the sum for each
# example. This mirrors what was done for the bpnet paper.
weightedsum_meannormed_logits = tf.reduce_sum(softmax_out*meannormed_logits,
                                              axis=(1,2))
profile_model_profile_explainer = shap.explainers.deep.TFDeepExplainer(
    ([model.input[0], model.input[2]],
     weightedsum_meannormed_logits),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)
# Out:
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  StopGradient used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients

# %%
#The shap scores
post_counts_hypimps,_ = profile_model_counts_explainer.shap_values(
    [o_test_seqs, np.zeros((len(o_test_seqs), 1))],
    progress_message=10)
post_profile_hypimps,_ = profile_model_profile_explainer.shap_values(
    [o_test_seqs, np.zeros((len(o_test_seqs), out_pred_len, 2))],
    progress_message=10)

post_counts_actualimps = post_counts_hypimps*o_test_seqs
post_profile_actualimps = post_profile_hypimps*o_test_seqs
# Out:
# Done 0 examples of 111
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/shap/explainers/deep/deep_tf.py:493: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Done 10 examples of 111
# Done 20 examples of 111
# Done 30 examples of 111
# Done 40 examples of 111
# Done 50 examples of 111
# Done 60 examples of 111
# Done 70 examples of 111
# Done 80 examples of 111
# Done 90 examples of 111
# Done 100 examples of 111
# Done 110 examples of 111
# Done 0 examples of 111
# Done 10 examples of 111
# Done 20 examples of 111
# Done 30 examples of 111
# Done 40 examples of 111
# Done 50 examples of 111
# Done 60 examples of 111
# Done 70 examples of 111
# Done 80 examples of 111
# Done 90 examples of 111
# Done 100 examples of 111
# Done 110 examples of 111

# %%
from deeplift.visualization import viz_sequence
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter

sorted_test_indices = [x[0] for x in 
                       sorted(enumerate(o_test_labels_logtotalcount),
                              key=lambda x: -x[1])]

def smooth(vals):
    return np.convolve(vals, np.ones(1,)/1, mode='same')

for idx in sorted_test_indices[:10]: 
    true_profile = o_test_labels_profile[idx] 
    print("idx",idx)
    print("Counts",np.sum(true_profile,axis=0))
    print("Predcounts",np.exp(o_test_preds_logcount[idx])-1)
    
    for oneovertemp in [1.0]:
        print("oneovertemp",oneovertemp)
        print(o_test_labels_profile[idx].shape)
        print("Pred profile shape", o_test_preds_profile[idx].shape)
        pred_profile = (np.sum(o_test_labels_profile[idx], axis=0)[None,:] #total counts
                      *(np.exp(o_test_preds_profile[idx]*oneovertemp)/
                        np.sum(np.exp(o_test_preds_profile[idx]*oneovertemp),axis=0)[None,:]) )   
        plt.figure(figsize=(20,2))

        start_view = 0
        end_view = seq_len
        total_flanking = seq_len - out_pred_len
        left_flank = int(0.5*total_flanking)
        right_flank = total_flanking - left_flank
        plt.plot(np.arange(out_pred_len)+left_flank, smooth(true_profile[:,0]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, -smooth(true_profile[:,1]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, pred_profile[:,0])
        plt.plot(np.arange(out_pred_len)+left_flank, -pred_profile[:,1])
        plt.xlim(start_view,end_view)
        plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
        plt.show()

    print("counts imp")
    viz_sequence.plot_weights(post_counts_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
    print("profile imp")
    viz_sequence.plot_weights(post_profile_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
# Out:
# idx 57
# Counts [327. 331.]
# Predcounts [222.10912 254.06142]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 96
# Counts [302. 332.]
# Predcounts [2120.034  2228.9192]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 15
# Counts [354. 274.]
# Predcounts [550.9103  176.35579]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 55
# Counts [335. 254.]
# Predcounts [162.78555   61.732357]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 95
# Counts [287. 294.]
# Predcounts [3626.36   3627.5366]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 49
# Counts [276. 271.]
# Predcounts [87.77088 79.06988]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 42
# Counts [259. 242.]
# Predcounts [119.03973 134.709  ]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 104
# Counts [270. 184.]
# Predcounts [124.688126 124.63186 ]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 107
# Counts [219. 233.]
# Predcounts [255.08963 439.615  ]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 7
# Counts [204. 240.]
# Predcounts [ 76.27601 301.70523]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp

# %%
for idx in sorted_test_indices[:10]: 
    true_profile = o_test_labels_profile[idx] 
    print("idx",idx)
    print("Counts",np.sum(true_profile,axis=0))
    print("Predcounts",np.exp(o_test_preds_logcount[idx])-1)
    
    for oneovertemp in [1.0]:
        print("oneovertemp",oneovertemp)
        print(o_test_labels_profile[idx].shape)
        print("Pred profile shape", o_test_preds_profile[idx].shape)
        pred_profile = (np.sum(o_test_labels_profile[idx], axis=0)[None,:] #total counts
                      *(np.exp(o_test_preds_profile[idx]*oneovertemp)/
                        np.sum(np.exp(o_test_preds_profile[idx]*oneovertemp),axis=0)[None,:]) )   
        plt.figure(figsize=(20,2))

        start_view = 220
        end_view = 325
        total_flanking = seq_len - out_pred_len
        left_flank = int(0.5*total_flanking)
        right_flank = total_flanking - left_flank
        plt.plot(np.arange(out_pred_len)+left_flank, smooth(true_profile[:,0]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, -smooth(true_profile[:,1]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, pred_profile[:,0])
        plt.plot(np.arange(out_pred_len)+left_flank, -pred_profile[:,1])
        plt.xlim(start_view,end_view)
        plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
        plt.show()

    print("counts imp")
    viz_sequence.plot_weights(post_counts_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
    print("profile imp")
    viz_sequence.plot_weights(post_profile_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
# Out:
# idx 57
# Counts [327. 331.]
# Predcounts [222.10912 254.06142]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 96
# Counts [302. 332.]
# Predcounts [2120.034  2228.9192]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 15
# Counts [354. 274.]
# Predcounts [550.9103  176.35579]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 55
# Counts [335. 254.]
# Predcounts [162.78555   61.732357]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 95
# Counts [287. 294.]
# Predcounts [3626.36   3627.5366]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 49
# Counts [276. 271.]
# Predcounts [87.77088 79.06988]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 42
# Counts [259. 242.]
# Predcounts [119.03973 134.709  ]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 104
# Counts [270. 184.]
# Predcounts [124.688126 124.63186 ]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 107
# Counts [219. 233.]
# Predcounts [255.08963 439.615  ]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 7
# Counts [204. 240.]
# Predcounts [ 76.27601 301.70523]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
