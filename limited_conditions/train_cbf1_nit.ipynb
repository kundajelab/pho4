# %% [markdown]
# Train Model

# %%
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers
# Out:
# Using TensorFlow backend.
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import numpy as np
import gzip
import keras
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import keras_genomics
from keras_genomics.layers.convolutional import RevCompConv1D
import keras
import keras.layers as kl
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers

def multinomial_nll(true_counts, logits):
    """Compute the multinomial negative log-likelihood
    Args:
      true_counts: observed count values
      logits: predicted logit values
    """
    counts_per_example = tf.reduce_sum(true_counts, axis=-1)
    dist = tfp.distributions.Multinomial(total_count=counts_per_example,
                                         logits=logits)
    return (-tf.reduce_sum(dist.log_prob(true_counts)) / 
            tf.to_float(tf.shape(true_counts)[0]))


#from https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/losses.py#L87
class MultichannelMultinomialNLL(object):
    def __init__(self, n):
        self.__name__ = "MultichannelMultinomialNLL"
        self.n = n

    def __call__(self, true_counts, logits):
        for i in range(self.n):
            loss = multinomial_nll(true_counts[..., i], logits[..., i])
            if i == 0:
                total = loss
            else:
                total += loss
        return total

    def get_config(self):
        return {"n": self.n}

#If we want to avoid zero-padding, then the input seq len will be determined
# by parameters of the convolutions
class AbstractProfileModel(object):

    def get_output_profile_len(self):
        raise NotImplementedError()

    def get_model(self):
        raise NotImplementedError()

def trim_flanks_of_conv_layer(conv_layer, output_len, width_to_trim, filters):
    layer = keras.layers.Lambda(
        lambda x: x[:,
          int(0.5*(width_to_trim)):-(width_to_trim-int(0.5*(width_to_trim)))],
        output_shape=(output_len, filters))(conv_layer)
    return layer

#model architecture is based on 
#https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/models.py#L534
#The non-cli parameters are specified in:
# https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/src/chipnexus/train/seqmodel/joint-model-valid.gin
#The cli parameters are in line 165 of:
# https://docs.google.com/spreadsheets/d/1n3l2HXKSNpmNUOifD41uRzDEAgmOqXMQDxquRaz6WLg/edit#gid=0
# which seems to match https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/src/chipnexus/train/seqmodel/ChIP-seq-default.gin
class RcBPnetArch(AbstractProfileModel):   

    def __init__(self, input_seq_len, c_task_weight, filters,
                       n_dil_layers, conv1_kernel_size,
                       dil_kernel_size,
                       outconv_kernel_size, lr):
        self.input_seq_len = input_seq_len
        self.c_task_weight = c_task_weight
        self.filters = filters
        self.n_dil_layers = n_dil_layers
        self.conv1_kernel_size = conv1_kernel_size
        self.dil_kernel_size = dil_kernel_size
        self.outconv_kernel_size = outconv_kernel_size
        self.lr = lr

    def get_embedding_len(self):
        embedding_len = self.input_seq_len
        embedding_len -= (self.conv1_kernel_size-1)     
        for i in range(1, self.n_dil_layers+1):
            dilation_rate = (2**i)
            embedding_len -= dilation_rate*(self.dil_kernel_size-1)
        return embedding_len

    def get_output_profile_len(self):
        embedding_len = self.get_embedding_len()
        out_profile_len = embedding_len - (self.outconv_kernel_size - 1)
        return out_profile_len

    def get_keras_model(self):

        out_pred_len = self.get_output_profile_len()

        inp = kl.Input(shape=(self.input_seq_len, 4), name='sequence')
        first_conv = RevCompConv1D(filters=self.filters,
                               kernel_size=self.conv1_kernel_size,
                               padding='valid',
                               activation='relu')(inp)
        curr_layer_size = self.input_seq_len - (self.conv1_kernel_size-1)
        bias_counts_input = kl.Input(shape=(1,), name="control_logcount")
        bias_profile_input = kl.Input(shape=(out_pred_len, 2),
                                      name="control_profile")
        prev_layers = [first_conv]
        for i in range(1, self.n_dil_layers + 1):
          dilation_rate = 2**i
          if i == 1:
              prev_sum = first_conv
          else:
              print(prev_layers)
              prev_sum = kl.merge.Average()(prev_layers)
          conv_output = RevCompConv1D(filters=self.filters,
                                  kernel_size=self.dil_kernel_size,
                                  padding='valid',
                                  activation='relu',
                                  dilation_rate=dilation_rate)(prev_sum)          
          width_to_trim = dilation_rate*(self.dil_kernel_size-1)
          curr_layer_size = (curr_layer_size - width_to_trim)
          prev_layers = [trim_flanks_of_conv_layer(
              conv_layer=x, output_len=curr_layer_size,
              width_to_trim=width_to_trim, filters=2*self.filters)
              for x in prev_layers]
          prev_layers.append(conv_output)

        combined_conv = kl.merge.Average()(prev_layers)

        #Counts prediction
        gap_combined_conv = kl.GlobalAvgPool1D()(combined_conv)
        count_out = kl.Reshape((-1,), name="task0_logcount")(
            RevCompConv1D(filters=1, kernel_size=1)(
              kl.Reshape((1,-1))(kl.concatenate([
                  #concatenation of the bias layer both before and after
                  # is needed for rc symmetry
                  kl.Lambda(lambda x: x[:, ::-1])(bias_counts_input),
                  gap_combined_conv,
                  bias_counts_input], axis=-1))))

        profile_out_prebias = RevCompConv1D(
                               filters=1,
                               kernel_size=self.outconv_kernel_size,
                               padding='valid')(combined_conv)
        profile_out = RevCompConv1D(
            filters=1, kernel_size=1, name="task0_profile")(
                    kl.concatenate([
                        #concatenation of the bias layer both before and after
                        # is needed for rc symmetry
                        kl.Lambda(lambda x: x[:, :, ::-1])(bias_profile_input),
                        profile_out_prebias,
                        bias_profile_input], axis=-1))

        model = keras.models.Model(
          inputs=[inp, bias_counts_input, bias_profile_input],
          outputs=[count_out, profile_out])
        model.compile(keras.optimizers.Adam(lr=self.lr),
                      loss=['mse', MultichannelMultinomialNLL(2)],
                      loss_weights=[self.c_task_weight, 1])
        return model

# %%
seq_len = 546
modelwrapper = RcBPnetArch(
    input_seq_len=seq_len,
    c_task_weight=1000,
    filters=64,
    n_dil_layers=6,
    conv1_kernel_size=21,
    dil_kernel_size=3,
    outconv_kernel_size=75,
    lr=0.001)
out_pred_len = modelwrapper.get_output_profile_len()
print(out_pred_len, seq_len-out_pred_len)
# Out:
# 200 346

# %%
pos_neg_smooth_log_counts =\
  coordstovals.bigwig.PosAndNegSmoothWindowCollapsedLogCounts(
        pos_strand_bigwig_path="/users/amr1/pho4/data/ctl_chipexo/chipexo.pos_strand.bw",
        neg_strand_bigwig_path="/users/amr1/pho4/data/ctl_chipexo/chipexo.neg_strand.bw",
        counts_mode_name="control_logcount",
        profile_mode_name="control_profile",
        center_size_to_use=out_pred_len,
        smoothing_windows=[1,50])
inputs_coordstovals = coordstovals.core.CoordsToValsJoiner(
    coordstovals_list=[
      coordbased.coordstovals.fasta.PyfaidxCoordsToVals(
        genome_fasta_path="/users/amr1/pho4/data/genome/sacCer3.genome.fa",
        mode_name="sequence",
        center_size_to_use=seq_len),
      pos_neg_smooth_log_counts])

targets_coordstovals = coordstovals.bigwig.PosAndNegSeparateLogCounts(
    pos_strand_bigwig_path="/users/amr1/pho4/data/limited_conditions/cbf1_nit/cbf1.nit.pos.bigwig",
    neg_strand_bigwig_path="/users/amr1/pho4/data/limited_conditions/cbf1_nit/cbf1.nit.neg.bigwig",
    counts_mode_name="task0_logcount",
    profile_mode_name="task0_profile",
    center_size_to_use=out_pred_len)

keras_train_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
      bed_file="/users/amr1/pho4/data/limited_conditions/cbf1_nit/train_1000_around_summits.bed.gz",
      coord_batch_transformer=
          coordbatchtransformers.ReverseComplementAugmenter().chain(
          coordbatchtransformers.UniformJitter(
              maxshift=200, chromsizes_file="/users/amr1/pho4/data/genome/sacCer3.chrom.sizes")),
      batch_size=64,
      shuffle_before_epoch=True, 
      seed=1234),
    inputs_coordstovals=inputs_coordstovals,
    targets_coordstovals=targets_coordstovals)

keras_valid_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
            bed_file="/users/amr1/pho4/data/limited_conditions/cbf1_nit/valid_1000_around_summits.bed.gz",
            batch_size=64,
            shuffle_before_epoch=False, 
            seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)

thebatch = keras_train_batch_generator[0]
for tupleidx,tupleentry in enumerate(thebatch):
  print("Tuple entry",tupleidx)
  for key in tupleentry:
    print(key, tupleentry[key].shape)
# Out:
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Tuple entry 0
# sequence (128, 546, 4)
# control_logcount (128,)
# control_profile (128, 200, 2)
# Tuple entry 1
# task0_logcount (128, 2)
# task0_profile (128, 200, 2)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="3"

model = modelwrapper.get_keras_model()
print(model.summary())
early_stopping_callback = keras.callbacks.EarlyStopping(
                          patience=25, restore_best_weights=True)
loss_history = model.fit_generator(keras_train_batch_generator,
                  epochs=500,
                  validation_data=keras_valid_batch_generator,
                  callbacks=[early_stopping_callback])
model.set_weights(early_stopping_callback.best_weights)
# Out:
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# [<tf.Tensor 'lambda_1/strided_slice:0' shape=(?, 522, 128) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_2/Relu:0' shape=(?, 522, 128) dtype=float32>]
# [<tf.Tensor 'lambda_2/strided_slice:0' shape=(?, 514, 128) dtype=float32>, <tf.Tensor 'lambda_3/strided_slice:0' shape=(?, 514, 128) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_3/Relu:0' shape=(?, 514, 128) dtype=float32>]
# [<tf.Tensor 'lambda_4/strided_slice:0' shape=(?, 498, 128) dtype=float32>, <tf.Tensor 'lambda_5/strided_slice:0' shape=(?, 498, 128) dtype=float32>, <tf.Tensor 'lambda_6/strided_slice:0' shape=(?, 498, 128) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_4/Relu:0' shape=(?, 498, 128) dtype=float32>]
# [<tf.Tensor 'lambda_7/strided_slice:0' shape=(?, 466, 128) dtype=float32>, <tf.Tensor 'lambda_8/strided_slice:0' shape=(?, 466, 128) dtype=float32>, <tf.Tensor 'lambda_9/strided_slice:0' shape=(?, 466, 128) dtype=float32>, <tf.Tensor 'lambda_10/strided_slice:0' shape=(?, 466, 128) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_5/Relu:0' shape=(?, 466, 128) dtype=float32>]
# [<tf.Tensor 'lambda_11/strided_slice:0' shape=(?, 402, 128) dtype=float32>, <tf.Tensor 'lambda_12/strided_slice:0' shape=(?, 402, 128) dtype=float32>, <tf.Tensor 'lambda_13/strided_slice:0' shape=(?, 402, 128) dtype=float32>, <tf.Tensor 'lambda_14/strided_slice:0' shape=(?, 402, 128) dtype=float32>, <tf.Tensor 'lambda_15/strided_slice:0' shape=(?, 402, 128) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_6/Relu:0' shape=(?, 402, 128) dtype=float32>]
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From <ipython-input-2-dbf16efbe78d>:28: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           (None, 546, 4)       0
# __________________________________________________________________________________________________
# rev_comp_conv1d_1 (RevCompConv1 (None, 526, 128)     5440        sequence[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 522, 128)     0           rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_2 (RevCompConv1 (None, 522, 128)     24640       rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 522, 128)     0           lambda_1[0][0]
#                                                                  rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 514, 128)     0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 514, 128)     0           rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_3 (RevCompConv1 (None, 514, 128)     24640       average_1[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 514, 128)     0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 498, 128)     0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 498, 128)     0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 498, 128)     0           rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_4 (RevCompConv1 (None, 498, 128)     24640       average_2[0][0]
# __________________________________________________________________________________________________
# average_3 (Average)             (None, 498, 128)     0           lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 466, 128)     0           lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 466, 128)     0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 466, 128)     0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 466, 128)     0           rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_5 (RevCompConv1 (None, 466, 128)     24640       average_3[0][0]
# __________________________________________________________________________________________________
# average_4 (Average)             (None, 466, 128)     0           lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 402, 128)     0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 402, 128)     0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 402, 128)     0           lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 402, 128)     0           lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 402, 128)     0           rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_6 (RevCompConv1 (None, 402, 128)     24640       average_4[0][0]
# __________________________________________________________________________________________________
# average_5 (Average)             (None, 402, 128)     0           lambda_11[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
#                                                                  rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 274, 128)     0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 274, 128)     0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 274, 128)     0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 274, 128)     0           lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 274, 128)     0           lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 274, 128)     0           rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_7 (RevCompConv1 (None, 274, 128)     24640       average_5[0][0]
# __________________________________________________________________________________________________
# control_logcount (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# average_6 (Average)             (None, 274, 128)     0           lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_21[0][0]
#                                                                  rev_comp_conv1d_7[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           control_logcount[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 128)          0           average_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 130)          0           lambda_22[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  control_logcount[0][0]
# __________________________________________________________________________________________________
# control_profile (InputLayer)    (None, 200, 2)       0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 130)       0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 200, 2)       0           control_profile[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_9 (RevCompConv1 (None, 200, 2)       9601        average_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_8 (RevCompConv1 (None, 1, 2)         131         reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 200, 6)       0           lambda_23[0][0]
#                                                                  rev_comp_conv1d_9[0][0]
#                                                                  control_profile[0][0]
# __________________________________________________________________________________________________
# task0_logcount (Reshape)        (None, 2)            0           rev_comp_conv1d_8[0][0]
# __________________________________________________________________________________________________
# task0_profile (RevCompConv1D)   (None, 200, 2)       7           concatenate_2[0][0]
# ==================================================================================================
# Total params: 163,019
# Trainable params: 163,019
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/500
# 7/7 [==============================] - 6s 809ms/step - loss: 112396.7833 - task0_logcount_loss: 18.7013 - task0_profile_loss: 93695.4606 - val_loss: 155034.0811 - val_task0_logcount_loss: 3.9018 - val_task0_profile_loss: 151132.2569
# Epoch 2/500
# 7/7 [==============================] - 1s 141ms/step - loss: 104970.9660 - task0_logcount_loss: 5.2351 - task0_profile_loss: 99735.8497 - val_loss: 150005.3271 - val_task0_logcount_loss: 2.9460 - val_task0_profile_loss: 147059.2864
# Epoch 3/500
# 7/7 [==============================] - 1s 163ms/step - loss: 94226.9459 - task0_logcount_loss: 3.3589 - task0_profile_loss: 90868.0707 - val_loss: 146083.8168 - val_task0_logcount_loss: 3.1662 - val_task0_profile_loss: 142917.5841
# Epoch 4/500
# 7/7 [==============================] - 1s 182ms/step - loss: 86143.7405 - task0_logcount_loss: 2.7857 - task0_profile_loss: 83358.0891 - val_loss: 141195.7035 - val_task0_logcount_loss: 2.6215 - val_task0_profile_loss: 138574.2129
# Epoch 5/500
# 7/7 [==============================] - 1s 167ms/step - loss: 92121.9065 - task0_logcount_loss: 2.5177 - task0_profile_loss: 89604.1687 - val_loss: 136748.3022 - val_task0_logcount_loss: 2.6687 - val_task0_profile_loss: 134079.5748
# Epoch 6/500
# 7/7 [==============================] - 1s 174ms/step - loss: 84924.2807 - task0_logcount_loss: 2.4127 - task0_profile_loss: 82511.6168 - val_loss: 131570.2030 - val_task0_logcount_loss: 2.6112 - val_task0_profile_loss: 128959.0167
# Epoch 7/500
# 7/7 [==============================] - 1s 167ms/step - loss: 70182.5945 - task0_logcount_loss: 2.3527 - task0_profile_loss: 67829.8693 - val_loss: 128445.3495 - val_task0_logcount_loss: 2.9731 - val_task0_profile_loss: 125472.2399
# Epoch 8/500
# 7/7 [==============================] - 1s 165ms/step - loss: 75302.3484 - task0_logcount_loss: 2.3007 - task0_profile_loss: 73001.6679 - val_loss: 125327.6413 - val_task0_logcount_loss: 2.6180 - val_task0_profile_loss: 122709.6885
# Epoch 9/500
# 7/7 [==============================] - 1s 181ms/step - loss: 70716.9452 - task0_logcount_loss: 2.4288 - task0_profile_loss: 68288.1411 - val_loss: 122384.4810 - val_task0_logcount_loss: 2.7622 - val_task0_profile_loss: 119622.3256
# Epoch 10/500
# 7/7 [==============================] - 1s 169ms/step - loss: 70556.6938 - task0_logcount_loss: 2.3764 - task0_profile_loss: 68180.2940 - val_loss: 119732.5257 - val_task0_logcount_loss: 2.8453 - val_task0_profile_loss: 116887.2534
# Epoch 11/500
# 7/7 [==============================] - 1s 172ms/step - loss: 76256.4108 - task0_logcount_loss: 2.5154 - task0_profile_loss: 73741.0371 - val_loss: 116828.7864 - val_task0_logcount_loss: 2.5504 - val_task0_profile_loss: 114278.3762
# Epoch 12/500
# 7/7 [==============================] - 1s 170ms/step - loss: 60855.8557 - task0_logcount_loss: 2.3623 - task0_profile_loss: 58493.5608 - val_loss: 113854.3778 - val_task0_logcount_loss: 2.5419 - val_task0_profile_loss: 111312.5142
# Epoch 13/500
# 7/7 [==============================] - 1s 174ms/step - loss: 61679.8052 - task0_logcount_loss: 2.3025 - task0_profile_loss: 59377.3244 - val_loss: 111421.5385 - val_task0_logcount_loss: 2.6545 - val_task0_profile_loss: 108767.0670
# Epoch 14/500
# 7/7 [==============================] - 1s 172ms/step - loss: 54365.7216 - task0_logcount_loss: 2.4354 - task0_profile_loss: 51930.2770 - val_loss: 107354.4614 - val_task0_logcount_loss: 2.8030 - val_task0_profile_loss: 104551.5107
# Epoch 15/500
# 7/7 [==============================] - 1s 174ms/step - loss: 55840.9934 - task0_logcount_loss: 2.3550 - task0_profile_loss: 53486.0211 - val_loss: 104804.5067 - val_task0_logcount_loss: 2.5796 - val_task0_profile_loss: 102224.9327
# Epoch 16/500
# 7/7 [==============================] - 1s 178ms/step - loss: 54299.0268 - task0_logcount_loss: 2.4313 - task0_profile_loss: 51867.7614 - val_loss: 102256.8791 - val_task0_logcount_loss: 2.4885 - val_task0_profile_loss: 99768.4099
# Epoch 17/500
# 7/7 [==============================] - 1s 172ms/step - loss: 56099.5951 - task0_logcount_loss: 2.4264 - task0_profile_loss: 53673.2249 - val_loss: 97554.6263 - val_task0_logcount_loss: 2.6631 - val_task0_profile_loss: 94891.5572
# Epoch 18/500
# 7/7 [==============================] - 1s 161ms/step - loss: 45965.4045 - task0_logcount_loss: 2.3845 - task0_profile_loss: 43580.9168 - val_loss: 94126.2074 - val_task0_logcount_loss: 3.1615 - val_task0_profile_loss: 90964.6580
# Epoch 19/500
# 7/7 [==============================] - 1s 173ms/step - loss: 47346.6473 - task0_logcount_loss: 2.5197 - task0_profile_loss: 44826.9020 - val_loss: 90486.5239 - val_task0_logcount_loss: 2.9760 - val_task0_profile_loss: 87510.5379
# Epoch 20/500
# 7/7 [==============================] - 1s 173ms/step - loss: 43302.6706 - task0_logcount_loss: 2.4123 - task0_profile_loss: 40890.3804 - val_loss: 87976.2236 - val_task0_logcount_loss: 2.4719 - val_task0_profile_loss: 85504.2805
# Epoch 21/500
# 7/7 [==============================] - 1s 167ms/step - loss: 41815.4371 - task0_logcount_loss: 2.3733 - task0_profile_loss: 39442.1721 - val_loss: 84464.5962 - val_task0_logcount_loss: 2.4872 - val_task0_profile_loss: 81977.4024
# Epoch 22/500
# 7/7 [==============================] - 1s 169ms/step - loss: 37976.2190 - task0_logcount_loss: 2.3848 - task0_profile_loss: 35591.4422 - val_loss: 83623.4635 - val_task0_logcount_loss: 2.4648 - val_task0_profile_loss: 81158.6158
# Epoch 23/500
# 7/7 [==============================] - 1s 181ms/step - loss: 37784.4015 - task0_logcount_loss: 2.5129 - task0_profile_loss: 35271.5416 - val_loss: 78548.6438 - val_task0_logcount_loss: 2.5676 - val_task0_profile_loss: 75980.9952
# Epoch 24/500
# 7/7 [==============================] - 1s 166ms/step - loss: 32929.4037 - task0_logcount_loss: 2.4577 - task0_profile_loss: 30471.7181 - val_loss: 77954.4322 - val_task0_logcount_loss: 2.4517 - val_task0_profile_loss: 75502.7192
# Epoch 25/500
# 7/7 [==============================] - 1s 178ms/step - loss: 31477.6610 - task0_logcount_loss: 2.3914 - task0_profile_loss: 29086.2624 - val_loss: 76567.3349 - val_task0_logcount_loss: 2.4783 - val_task0_profile_loss: 74089.0856
# Epoch 26/500
# 7/7 [==============================] - 1s 176ms/step - loss: 26429.1105 - task0_logcount_loss: 2.4932 - task0_profile_loss: 23935.8886 - val_loss: 72614.5068 - val_task0_logcount_loss: 2.7444 - val_task0_profile_loss: 69870.0705
# Epoch 27/500
# 7/7 [==============================] - 1s 170ms/step - loss: 26270.0686 - task0_logcount_loss: 2.2738 - task0_profile_loss: 23996.2560 - val_loss: 68255.8006 - val_task0_logcount_loss: 2.7382 - val_task0_profile_loss: 65517.6391
# Epoch 28/500
# 7/7 [==============================] - 1s 157ms/step - loss: 23347.8603 - task0_logcount_loss: 2.2620 - task0_profile_loss: 21085.8740 - val_loss: 66148.9534 - val_task0_logcount_loss: 2.5802 - val_task0_profile_loss: 63568.7689
# Epoch 29/500
# 7/7 [==============================] - 1s 169ms/step - loss: 21412.5617 - task0_logcount_loss: 2.2910 - task0_profile_loss: 19121.5808 - val_loss: 61808.5118 - val_task0_logcount_loss: 2.9143 - val_task0_profile_loss: 58894.1725
# Epoch 30/500
# 7/7 [==============================] - 1s 165ms/step - loss: 20633.4626 - task0_logcount_loss: 2.3568 - task0_profile_loss: 18276.6523 - val_loss: 60201.6770 - val_task0_logcount_loss: 2.5330 - val_task0_profile_loss: 57668.6299
# Epoch 31/500
# 7/7 [==============================] - 1s 180ms/step - loss: 20857.4915 - task0_logcount_loss: 2.1684 - task0_profile_loss: 18689.1051 - val_loss: 58601.0416 - val_task0_logcount_loss: 2.6521 - val_task0_profile_loss: 55948.9066
# Epoch 32/500
# 7/7 [==============================] - 1s 175ms/step - loss: 18224.7903 - task0_logcount_loss: 2.2142 - task0_profile_loss: 16010.5566 - val_loss: 55477.2683 - val_task0_logcount_loss: 2.6297 - val_task0_profile_loss: 52847.5697
# Epoch 33/500
# 7/7 [==============================] - 1s 171ms/step - loss: 17840.6697 - task0_logcount_loss: 2.5295 - task0_profile_loss: 15311.1886 - val_loss: 53410.1496 - val_task0_logcount_loss: 2.4354 - val_task0_profile_loss: 50974.7215
# Epoch 34/500
# 7/7 [==============================] - 1s 181ms/step - loss: 16562.9940 - task0_logcount_loss: 2.2141 - task0_profile_loss: 14348.8976 - val_loss: 49262.2862 - val_task0_logcount_loss: 2.5593 - val_task0_profile_loss: 46702.9433
# Epoch 35/500
# 7/7 [==============================] - 1s 167ms/step - loss: 14583.2925 - task0_logcount_loss: 2.2252 - task0_profile_loss: 12358.1290 - val_loss: 45980.7368 - val_task0_logcount_loss: 2.4300 - val_task0_profile_loss: 43550.7144
# Epoch 36/500
# 7/7 [==============================] - 1s 183ms/step - loss: 13568.0543 - task0_logcount_loss: 2.2352 - task0_profile_loss: 11332.8385 - val_loss: 44870.3093 - val_task0_logcount_loss: 2.5492 - val_task0_profile_loss: 42321.1314
# Epoch 37/500
# 7/7 [==============================] - 1s 168ms/step - loss: 13404.0212 - task0_logcount_loss: 2.2778 - task0_profile_loss: 11126.2257 - val_loss: 42037.0956 - val_task0_logcount_loss: 3.1544 - val_task0_profile_loss: 38882.7002
# Epoch 38/500
# 7/7 [==============================] - 1s 161ms/step - loss: 12999.1285 - task0_logcount_loss: 2.3066 - task0_profile_loss: 10692.5357 - val_loss: 39390.1407 - val_task0_logcount_loss: 2.5018 - val_task0_profile_loss: 36888.3029
# Epoch 39/500
# 7/7 [==============================] - 1s 169ms/step - loss: 10401.5183 - task0_logcount_loss: 2.1721 - task0_profile_loss: 8229.4659 - val_loss: 37430.1436 - val_task0_logcount_loss: 2.5101 - val_task0_profile_loss: 34920.0914
# Epoch 40/500
# 7/7 [==============================] - 1s 172ms/step - loss: 10736.2654 - task0_logcount_loss: 2.1861 - task0_profile_loss: 8550.1788 - val_loss: 35640.5480 - val_task0_logcount_loss: 2.4348 - val_task0_profile_loss: 33205.7496
# Epoch 41/500
# 7/7 [==============================] - 1s 170ms/step - loss: 11603.8980 - task0_logcount_loss: 2.3059 - task0_profile_loss: 9298.0025 - val_loss: 33645.8776 - val_task0_logcount_loss: 2.7319 - val_task0_profile_loss: 30914.0196
# Epoch 42/500
# 7/7 [==============================] - 1s 176ms/step - loss: 9249.0886 - task0_logcount_loss: 2.2591 - task0_profile_loss: 6989.9480 - val_loss: 31404.4365 - val_task0_logcount_loss: 2.6427 - val_task0_profile_loss: 28761.7816
# Epoch 43/500
# 7/7 [==============================] - 1s 179ms/step - loss: 8821.1389 - task0_logcount_loss: 2.1452 - task0_profile_loss: 6675.9872 - val_loss: 29973.3332 - val_task0_logcount_loss: 2.5497 - val_task0_profile_loss: 27423.6406
# Epoch 44/500
# 7/7 [==============================] - 1s 171ms/step - loss: 9730.3924 - task0_logcount_loss: 2.1627 - task0_profile_loss: 7567.7027 - val_loss: 28137.9873 - val_task0_logcount_loss: 2.3896 - val_task0_profile_loss: 25748.4234
# Epoch 45/500
# 7/7 [==============================] - 1s 173ms/step - loss: 9009.3019 - task0_logcount_loss: 2.1712 - task0_profile_loss: 6838.0594 - val_loss: 27226.3618 - val_task0_logcount_loss: 2.6572 - val_task0_profile_loss: 24569.1422
# Epoch 46/500
# 7/7 [==============================] - 1s 187ms/step - loss: 7846.6622 - task0_logcount_loss: 2.2271 - task0_profile_loss: 5619.5557 - val_loss: 25339.0209 - val_task0_logcount_loss: 2.8666 - val_task0_profile_loss: 22472.4619
# Epoch 47/500
# 7/7 [==============================] - 1s 173ms/step - loss: 7456.7738 - task0_logcount_loss: 2.2648 - task0_profile_loss: 5191.9628 - val_loss: 23969.2761 - val_task0_logcount_loss: 2.3668 - val_task0_profile_loss: 21602.4385
# Epoch 48/500
# 7/7 [==============================] - 1s 171ms/step - loss: 7982.3788 - task0_logcount_loss: 2.2155 - task0_profile_loss: 5766.8353 - val_loss: 22871.8515 - val_task0_logcount_loss: 2.3636 - val_task0_profile_loss: 20508.2890
# Epoch 49/500
# 7/7 [==============================] - 1s 165ms/step - loss: 7071.1846 - task0_logcount_loss: 2.1998 - task0_profile_loss: 4871.3704 - val_loss: 21812.8838 - val_task0_logcount_loss: 2.7158 - val_task0_profile_loss: 19097.1020
# Epoch 50/500
# 7/7 [==============================] - 1s 179ms/step - loss: 6900.9383 - task0_logcount_loss: 2.1645 - task0_profile_loss: 4736.4410 - val_loss: 20704.4198 - val_task0_logcount_loss: 2.3923 - val_task0_profile_loss: 18312.1170
# Epoch 51/500
# 7/7 [==============================] - 1s 177ms/step - loss: 6785.9602 - task0_logcount_loss: 2.1377 - task0_profile_loss: 4648.3012 - val_loss: 19497.5713 - val_task0_logcount_loss: 2.3666 - val_task0_profile_loss: 17131.0035
# Epoch 52/500
# 7/7 [==============================] - 1s 175ms/step - loss: 6462.0095 - task0_logcount_loss: 2.1576 - task0_profile_loss: 4304.4149 - val_loss: 18849.0851 - val_task0_logcount_loss: 2.5313 - val_task0_profile_loss: 16317.7772
# Epoch 53/500
# 7/7 [==============================] - 1s 178ms/step - loss: 6239.2047 - task0_logcount_loss: 2.1322 - task0_profile_loss: 4106.9648 - val_loss: 17924.2972 - val_task0_logcount_loss: 2.3851 - val_task0_profile_loss: 15539.2319
# Epoch 54/500
# 7/7 [==============================] - 1s 166ms/step - loss: 6649.2328 - task0_logcount_loss: 2.2112 - task0_profile_loss: 4438.0811 - val_loss: 16895.7367 - val_task0_logcount_loss: 2.3721 - val_task0_profile_loss: 14523.6191
# Epoch 55/500
# 7/7 [==============================] - 1s 166ms/step - loss: 6612.0578 - task0_logcount_loss: 2.1862 - task0_profile_loss: 4425.8988 - val_loss: 16332.6376 - val_task0_logcount_loss: 2.3598 - val_task0_profile_loss: 13972.8057
# Epoch 56/500
# 7/7 [==============================] - 1s 169ms/step - loss: 6116.1557 - task0_logcount_loss: 2.0864 - task0_profile_loss: 4029.7657 - val_loss: 15914.0188 - val_task0_logcount_loss: 2.4635 - val_task0_profile_loss: 13450.5315
# Epoch 57/500
# 7/7 [==============================] - 1s 164ms/step - loss: 5912.1475 - task0_logcount_loss: 2.2230 - task0_profile_loss: 3689.1762 - val_loss: 14981.1535 - val_task0_logcount_loss: 2.5167 - val_task0_profile_loss: 12464.4624
# Epoch 58/500
# 7/7 [==============================] - 1s 172ms/step - loss: 5903.0924 - task0_logcount_loss: 2.2315 - task0_profile_loss: 3671.5806 - val_loss: 14675.8458 - val_task0_logcount_loss: 2.7352 - val_task0_profile_loss: 11940.6233
# Epoch 59/500
# 7/7 [==============================] - 1s 170ms/step - loss: 5960.4217 - task0_logcount_loss: 2.2512 - task0_profile_loss: 3709.1836 - val_loss: 13860.4616 - val_task0_logcount_loss: 2.3451 - val_task0_profile_loss: 11515.3218
# Epoch 60/500
# 7/7 [==============================] - 1s 166ms/step - loss: 5743.2040 - task0_logcount_loss: 2.1847 - task0_profile_loss: 3558.4880 - val_loss: 13366.1180 - val_task0_logcount_loss: 2.3546 - val_task0_profile_loss: 11011.4965
# Epoch 61/500
# 7/7 [==============================] - 1s 172ms/step - loss: 5735.7752 - task0_logcount_loss: 2.3376 - task0_profile_loss: 3398.1591 - val_loss: 12920.7213 - val_task0_logcount_loss: 2.3430 - val_task0_profile_loss: 10577.7186
# Epoch 62/500
# 7/7 [==============================] - 1s 169ms/step - loss: 5652.7508 - task0_logcount_loss: 2.1768 - task0_profile_loss: 3475.9836 - val_loss: 12426.2198 - val_task0_logcount_loss: 2.4117 - val_task0_profile_loss: 10014.5052
# Epoch 63/500
# 7/7 [==============================] - 1s 163ms/step - loss: 5812.3875 - task0_logcount_loss: 2.1377 - task0_profile_loss: 3674.6823 - val_loss: 12448.5809 - val_task0_logcount_loss: 2.6543 - val_task0_profile_loss: 9794.2546
# Epoch 64/500
# 7/7 [==============================] - 1s 176ms/step - loss: 5461.0433 - task0_logcount_loss: 2.1287 - task0_profile_loss: 3332.2988 - val_loss: 11724.5088 - val_task0_logcount_loss: 2.4140 - val_task0_profile_loss: 9310.4913
# Epoch 65/500
# 7/7 [==============================] - 1s 178ms/step - loss: 5317.8247 - task0_logcount_loss: 2.0741 - task0_profile_loss: 3243.7065 - val_loss: 11382.1502 - val_task0_logcount_loss: 2.4952 - val_task0_profile_loss: 8886.9938
# Epoch 66/500
# 7/7 [==============================] - 1s 177ms/step - loss: 5435.7533 - task0_logcount_loss: 2.1160 - task0_profile_loss: 3319.7287 - val_loss: 11066.8212 - val_task0_logcount_loss: 2.4950 - val_task0_profile_loss: 8571.8461
# Epoch 67/500
# 7/7 [==============================] - 1s 171ms/step - loss: 5468.7132 - task0_logcount_loss: 2.1288 - task0_profile_loss: 3339.9006 - val_loss: 10568.3903 - val_task0_logcount_loss: 2.3344 - val_task0_profile_loss: 8233.9871
# Epoch 68/500
# 7/7 [==============================] - 1s 182ms/step - loss: 5344.0592 - task0_logcount_loss: 2.1013 - task0_profile_loss: 3242.7849 - val_loss: 10254.3991 - val_task0_logcount_loss: 2.3315 - val_task0_profile_loss: 7922.9121
# Epoch 69/500
# 7/7 [==============================] - 1s 171ms/step - loss: 5378.2640 - task0_logcount_loss: 2.1060 - task0_profile_loss: 3272.2793 - val_loss: 9856.4550 - val_task0_logcount_loss: 2.3391 - val_task0_profile_loss: 7517.3219
# Epoch 70/500
# 7/7 [==============================] - 1s 170ms/step - loss: 5390.1491 - task0_logcount_loss: 2.2476 - task0_profile_loss: 3142.5934 - val_loss: 9805.3051 - val_task0_logcount_loss: 2.4631 - val_task0_profile_loss: 7342.2328
# Epoch 71/500
# 7/7 [==============================] - 1s 186ms/step - loss: 5206.5333 - task0_logcount_loss: 2.1170 - task0_profile_loss: 3089.5508 - val_loss: 9924.3770 - val_task0_logcount_loss: 2.7513 - val_task0_profile_loss: 7173.0975
# Epoch 72/500
# 7/7 [==============================] - 1s 172ms/step - loss: 5183.9052 - task0_logcount_loss: 2.1840 - task0_profile_loss: 2999.9020 - val_loss: 9360.1032 - val_task0_logcount_loss: 2.3230 - val_task0_profile_loss: 7037.0666
# Epoch 73/500
# 7/7 [==============================] - 1s 170ms/step - loss: 4997.2083 - task0_logcount_loss: 2.0591 - task0_profile_loss: 2938.1113 - val_loss: 9146.5331 - val_task0_logcount_loss: 2.3216 - val_task0_profile_loss: 6824.9548
# Epoch 74/500
# 7/7 [==============================] - 1s 179ms/step - loss: 5096.9963 - task0_logcount_loss: 2.1978 - task0_profile_loss: 2899.1687 - val_loss: 9160.4388 - val_task0_logcount_loss: 2.4680 - val_task0_profile_loss: 6692.3921
# Epoch 75/500
# 7/7 [==============================] - 1s 173ms/step - loss: 5025.0678 - task0_logcount_loss: 2.0555 - task0_profile_loss: 2969.5853 - val_loss: 8969.8990 - val_task0_logcount_loss: 2.3265 - val_task0_profile_loss: 6643.4211
# Epoch 76/500
# 7/7 [==============================] - 1s 174ms/step - loss: 5185.8999 - task0_logcount_loss: 2.1480 - task0_profile_loss: 3037.8645 - val_loss: 8809.4798 - val_task0_logcount_loss: 2.3218 - val_task0_profile_loss: 6487.7194
# Epoch 77/500
# 7/7 [==============================] - 1s 182ms/step - loss: 5280.5083 - task0_logcount_loss: 2.2173 - task0_profile_loss: 3063.2341 - val_loss: 8775.8472 - val_task0_logcount_loss: 2.5447 - val_task0_profile_loss: 6231.1735
# Epoch 78/500
# 7/7 [==============================] - 1s 165ms/step - loss: 4977.2175 - task0_logcount_loss: 2.0852 - task0_profile_loss: 2892.0674 - val_loss: 8670.9575 - val_task0_logcount_loss: 2.5639 - val_task0_profile_loss: 6107.0434
# Epoch 79/500
# 7/7 [==============================] - 1s 182ms/step - loss: 4955.9831 - task0_logcount_loss: 2.0681 - task0_profile_loss: 2887.8816 - val_loss: 8498.3515 - val_task0_logcount_loss: 2.3960 - val_task0_profile_loss: 6102.3503
# Epoch 80/500
# 7/7 [==============================] - 1s 169ms/step - loss: 4853.3246 - task0_logcount_loss: 2.0601 - task0_profile_loss: 2793.2274 - val_loss: 8419.3059 - val_task0_logcount_loss: 2.3749 - val_task0_profile_loss: 6044.3741
# Epoch 81/500
# 7/7 [==============================] - 1s 173ms/step - loss: 4930.4820 - task0_logcount_loss: 2.1270 - task0_profile_loss: 2803.5010 - val_loss: 8335.3137 - val_task0_logcount_loss: 2.3273 - val_task0_profile_loss: 6008.0329
# Epoch 82/500
# 7/7 [==============================] - 1s 176ms/step - loss: 4826.0744 - task0_logcount_loss: 2.0581 - task0_profile_loss: 2767.9774 - val_loss: 8284.8083 - val_task0_logcount_loss: 2.3103 - val_task0_profile_loss: 5974.4714
# Epoch 83/500
# 7/7 [==============================] - 1s 167ms/step - loss: 4825.8290 - task0_logcount_loss: 2.0047 - task0_profile_loss: 2821.1464 - val_loss: 8231.7632 - val_task0_logcount_loss: 2.3275 - val_task0_profile_loss: 5904.3109
# Epoch 84/500
# 7/7 [==============================] - 1s 181ms/step - loss: 4954.0906 - task0_logcount_loss: 2.1795 - task0_profile_loss: 2774.6339 - val_loss: 8224.2506 - val_task0_logcount_loss: 2.3910 - val_task0_profile_loss: 5833.2059
# Epoch 85/500
# 7/7 [==============================] - 1s 168ms/step - loss: 4842.8597 - task0_logcount_loss: 2.1120 - task0_profile_loss: 2730.8502 - val_loss: 8142.1786 - val_task0_logcount_loss: 2.3966 - val_task0_profile_loss: 5745.5486
# Epoch 86/500
# 7/7 [==============================] - 1s 171ms/step - loss: 4793.1691 - task0_logcount_loss: 2.0445 - task0_profile_loss: 2748.6423 - val_loss: 8164.6486 - val_task0_logcount_loss: 2.4080 - val_task0_profile_loss: 5756.6626
# Epoch 87/500
# 7/7 [==============================] - 1s 181ms/step - loss: 4907.2075 - task0_logcount_loss: 2.1496 - task0_profile_loss: 2757.6086 - val_loss: 8142.2501 - val_task0_logcount_loss: 2.4913 - val_task0_profile_loss: 5650.9584
# Epoch 88/500
# 7/7 [==============================] - 1s 179ms/step - loss: 4659.1156 - task0_logcount_loss: 1.9864 - task0_profile_loss: 2672.6858 - val_loss: 8016.0532 - val_task0_logcount_loss: 2.2925 - val_task0_profile_loss: 5723.6020
# Epoch 89/500
# 7/7 [==============================] - 1s 159ms/step - loss: 4641.5076 - task0_logcount_loss: 1.9668 - task0_profile_loss: 2674.6878 - val_loss: 7960.2888 - val_task0_logcount_loss: 2.2969 - val_task0_profile_loss: 5663.3730
# Epoch 90/500
# 7/7 [==============================] - 1s 172ms/step - loss: 4688.7903 - task0_logcount_loss: 2.0216 - task0_profile_loss: 2667.2007 - val_loss: 8005.6810 - val_task0_logcount_loss: 2.3997 - val_task0_profile_loss: 5605.9861
# Epoch 91/500
# 7/7 [==============================] - 1s 165ms/step - loss: 4677.0935 - task0_logcount_loss: 1.9888 - task0_profile_loss: 2688.3080 - val_loss: 7985.4548 - val_task0_logcount_loss: 2.3200 - val_task0_profile_loss: 5665.4129
# Epoch 92/500
# 7/7 [==============================] - 1s 170ms/step - loss: 4617.0301 - task0_logcount_loss: 1.9889 - task0_profile_loss: 2628.0995 - val_loss: 7918.0378 - val_task0_logcount_loss: 2.3487 - val_task0_profile_loss: 5569.3843
# Epoch 93/500
# 7/7 [==============================] - 1s 166ms/step - loss: 4633.6530 - task0_logcount_loss: 2.0138 - task0_profile_loss: 2619.8772 - val_loss: 7977.0039 - val_task0_logcount_loss: 2.4941 - val_task0_profile_loss: 5482.9337
# Epoch 94/500
# 7/7 [==============================] - 1s 172ms/step - loss: 4640.9469 - task0_logcount_loss: 2.0106 - task0_profile_loss: 2630.3498 - val_loss: 7926.8527 - val_task0_logcount_loss: 2.3420 - val_task0_profile_loss: 5584.8288
# Epoch 95/500
# 7/7 [==============================] - 1s 170ms/step - loss: 4714.4462 - task0_logcount_loss: 2.0508 - task0_profile_loss: 2663.6752 - val_loss: 8020.9591 - val_task0_logcount_loss: 2.5822 - val_task0_profile_loss: 5438.7445
# Epoch 96/500
# 7/7 [==============================] - 1s 174ms/step - loss: 4757.1693 - task0_logcount_loss: 2.1694 - task0_profile_loss: 2587.7738 - val_loss: 8154.8381 - val_task0_logcount_loss: 2.6888 - val_task0_profile_loss: 5466.0249
# Epoch 97/500
# 7/7 [==============================] - 1s 166ms/step - loss: 4692.1063 - task0_logcount_loss: 2.0795 - task0_profile_loss: 2612.6016 - val_loss: 7778.4363 - val_task0_logcount_loss: 2.2864 - val_task0_profile_loss: 5492.0107
# Epoch 98/500
# 7/7 [==============================] - 1s 172ms/step - loss: 4640.7509 - task0_logcount_loss: 2.0127 - task0_profile_loss: 2628.0222 - val_loss: 7735.2396 - val_task0_logcount_loss: 2.2967 - val_task0_profile_loss: 5438.4952
# Epoch 99/500
# 7/7 [==============================] - 1s 174ms/step - loss: 4600.1103 - task0_logcount_loss: 1.9990 - task0_profile_loss: 2601.1477 - val_loss: 7901.9041 - val_task0_logcount_loss: 2.3960 - val_task0_profile_loss: 5505.9036
# Epoch 100/500
# 7/7 [==============================] - 1s 177ms/step - loss: 4750.3327 - task0_logcount_loss: 2.1890 - task0_profile_loss: 2561.3631 - val_loss: 7854.6063 - val_task0_logcount_loss: 2.2970 - val_task0_profile_loss: 5557.5980
# Epoch 101/500
# 7/7 [==============================] - 1s 181ms/step - loss: 4657.4916 - task0_logcount_loss: 2.1091 - task0_profile_loss: 2548.3486 - val_loss: 7744.4793 - val_task0_logcount_loss: 2.2978 - val_task0_profile_loss: 5446.7177
# Epoch 102/500
# 7/7 [==============================] - 1s 159ms/step - loss: 4666.1039 - task0_logcount_loss: 2.1372 - task0_profile_loss: 2528.8635 - val_loss: 7960.7746 - val_task0_logcount_loss: 2.6161 - val_task0_profile_loss: 5344.6260
# Epoch 103/500
# 7/7 [==============================] - 1s 173ms/step - loss: 4620.0621 - task0_logcount_loss: 2.0893 - task0_profile_loss: 2530.7799 - val_loss: 7868.9148 - val_task0_logcount_loss: 2.4093 - val_task0_profile_loss: 5459.5749
# Epoch 104/500
# 7/7 [==============================] - 1s 175ms/step - loss: 4528.4301 - task0_logcount_loss: 1.9591 - task0_profile_loss: 2569.3489 - val_loss: 7744.9459 - val_task0_logcount_loss: 2.2613 - val_task0_profile_loss: 5483.6076
# Epoch 105/500
# 7/7 [==============================] - 1s 176ms/step - loss: 4634.1304 - task0_logcount_loss: 2.1000 - task0_profile_loss: 2534.1062 - val_loss: 7605.7268 - val_task0_logcount_loss: 2.2625 - val_task0_profile_loss: 5343.1880
# Epoch 106/500
# 7/7 [==============================] - 1s 170ms/step - loss: 4829.0851 - task0_logcount_loss: 2.2852 - task0_profile_loss: 2543.8483 - val_loss: 8040.6663 - val_task0_logcount_loss: 2.7696 - val_task0_profile_loss: 5271.0548
# Epoch 107/500
# 7/7 [==============================] - 1s 168ms/step - loss: 4697.2323 - task0_logcount_loss: 2.1306 - task0_profile_loss: 2566.6066 - val_loss: 8151.6170 - val_task0_logcount_loss: 2.8682 - val_task0_profile_loss: 5283.4461
# Epoch 108/500
# 7/7 [==============================] - 1s 173ms/step - loss: 4697.6503 - task0_logcount_loss: 2.1423 - task0_profile_loss: 2555.3755 - val_loss: 7732.0430 - val_task0_logcount_loss: 2.4627 - val_task0_profile_loss: 5269.2938
# Epoch 109/500
# 7/7 [==============================] - 1s 175ms/step - loss: 4643.9640 - task0_logcount_loss: 2.1233 - task0_profile_loss: 2520.6970 - val_loss: 7723.9777 - val_task0_logcount_loss: 2.3381 - val_task0_profile_loss: 5385.9079
# Epoch 110/500
# 7/7 [==============================] - 1s 178ms/step - loss: 4518.3711 - task0_logcount_loss: 1.9869 - task0_profile_loss: 2531.5079 - val_loss: 7568.1971 - val_task0_logcount_loss: 2.2767 - val_task0_profile_loss: 5291.5233
# Epoch 111/500
# 7/7 [==============================] - 1s 173ms/step - loss: 4452.4572 - task0_logcount_loss: 1.9881 - task0_profile_loss: 2464.3330 - val_loss: 7721.3701 - val_task0_logcount_loss: 2.4596 - val_task0_profile_loss: 5261.7504
# Epoch 112/500
# 7/7 [==============================] - 1s 167ms/step - loss: 4402.3714 - task0_logcount_loss: 1.9425 - task0_profile_loss: 2459.8671 - val_loss: 7604.0226 - val_task0_logcount_loss: 2.2517 - val_task0_profile_loss: 5352.3147
# Epoch 113/500
# 7/7 [==============================] - 1s 159ms/step - loss: 4416.5656 - task0_logcount_loss: 1.9522 - task0_profile_loss: 2464.3608 - val_loss: 7528.6875 - val_task0_logcount_loss: 2.2623 - val_task0_profile_loss: 5266.3511
# Epoch 114/500
# 7/7 [==============================] - 1s 177ms/step - loss: 4452.3124 - task0_logcount_loss: 2.0128 - task0_profile_loss: 2439.4835 - val_loss: 7800.5425 - val_task0_logcount_loss: 2.4954 - val_task0_profile_loss: 5305.1462
# Epoch 115/500
# 7/7 [==============================] - 1s 173ms/step - loss: 4420.0124 - task0_logcount_loss: 1.9909 - task0_profile_loss: 2429.1452 - val_loss: 7480.8119 - val_task0_logcount_loss: 2.2301 - val_task0_profile_loss: 5250.7224
# Epoch 116/500
# 7/7 [==============================] - 1s 174ms/step - loss: 4410.3352 - task0_logcount_loss: 1.9490 - task0_profile_loss: 2461.3270 - val_loss: 7517.9195 - val_task0_logcount_loss: 2.2647 - val_task0_profile_loss: 5253.2242
# Epoch 117/500
# 7/7 [==============================] - 1s 168ms/step - loss: 4345.7009 - task0_logcount_loss: 1.8994 - task0_profile_loss: 2446.2889 - val_loss: 7508.7410 - val_task0_logcount_loss: 2.2465 - val_task0_profile_loss: 5262.2871
# Epoch 118/500
# 7/7 [==============================] - 1s 177ms/step - loss: 4464.0803 - task0_logcount_loss: 1.9969 - task0_profile_loss: 2467.1526 - val_loss: 7535.8855 - val_task0_logcount_loss: 2.2357 - val_task0_profile_loss: 5300.2337
# Epoch 119/500
# 7/7 [==============================] - 1s 180ms/step - loss: 4380.0672 - task0_logcount_loss: 1.9875 - task0_profile_loss: 2392.5324 - val_loss: 7546.4284 - val_task0_logcount_loss: 2.3726 - val_task0_profile_loss: 5173.8022
# Epoch 120/500
# 7/7 [==============================] - 1s 180ms/step - loss: 4389.7861 - task0_logcount_loss: 1.9994 - task0_profile_loss: 2390.3994 - val_loss: 7583.1304 - val_task0_logcount_loss: 2.2604 - val_task0_profile_loss: 5322.7210
# Epoch 121/500
# 7/7 [==============================] - 1s 176ms/step - loss: 4378.4802 - task0_logcount_loss: 1.9570 - task0_profile_loss: 2421.5056 - val_loss: 7525.5762 - val_task0_logcount_loss: 2.3538 - val_task0_profile_loss: 5171.7281
# Epoch 122/500
# 7/7 [==============================] - 1s 172ms/step - loss: 4380.2283 - task0_logcount_loss: 1.9617 - task0_profile_loss: 2418.5179 - val_loss: 7511.5139 - val_task0_logcount_loss: 2.4031 - val_task0_profile_loss: 5108.4265
# Epoch 123/500
# 7/7 [==============================] - 1s 168ms/step - loss: 4424.9062 - task0_logcount_loss: 2.0484 - task0_profile_loss: 2376.4615 - val_loss: 7669.1692 - val_task0_logcount_loss: 2.3741 - val_task0_profile_loss: 5295.1159
# Epoch 124/500
# 7/7 [==============================] - 1s 172ms/step - loss: 4437.9638 - task0_logcount_loss: 2.0606 - task0_profile_loss: 2377.3285 - val_loss: 7353.0776 - val_task0_logcount_loss: 2.2631 - val_task0_profile_loss: 5089.9878
# Epoch 125/500
# 7/7 [==============================] - 1s 179ms/step - loss: 4314.6132 - task0_logcount_loss: 1.9329 - task0_profile_loss: 2381.7529 - val_loss: 7606.7242 - val_task0_logcount_loss: 2.2235 - val_task0_profile_loss: 5383.2694
# Epoch 126/500
# 7/7 [==============================] - 1s 174ms/step - loss: 4287.9167 - task0_logcount_loss: 1.9278 - task0_profile_loss: 2360.0998 - val_loss: 7331.6536 - val_task0_logcount_loss: 2.2357 - val_task0_profile_loss: 5095.9930
# Epoch 127/500
# 7/7 [==============================] - 1s 169ms/step - loss: 4454.3960 - task0_logcount_loss: 2.0756 - task0_profile_loss: 2378.8165 - val_loss: 7542.9899 - val_task0_logcount_loss: 2.1941 - val_task0_profile_loss: 5348.8912
# Epoch 128/500
# 7/7 [==============================] - 1s 171ms/step - loss: 4554.5959 - task0_logcount_loss: 2.1556 - task0_profile_loss: 2399.0412 - val_loss: 7296.2346 - val_task0_logcount_loss: 2.1922 - val_task0_profile_loss: 5104.0715
# Epoch 129/500
# 7/7 [==============================] - 1s 171ms/step - loss: 4363.0722 - task0_logcount_loss: 1.9983 - task0_profile_loss: 2364.8113 - val_loss: 7461.9356 - val_task0_logcount_loss: 2.3206 - val_task0_profile_loss: 5141.3745
# Epoch 130/500
# 7/7 [==============================] - 1s 175ms/step - loss: 4309.4963 - task0_logcount_loss: 1.9519 - task0_profile_loss: 2357.5945 - val_loss: 7729.7572 - val_task0_logcount_loss: 2.7500 - val_task0_profile_loss: 4979.7904
# Epoch 131/500
# 7/7 [==============================] - 1s 176ms/step - loss: 4395.5562 - task0_logcount_loss: 2.0488 - task0_profile_loss: 2346.7848 - val_loss: 7548.2536 - val_task0_logcount_loss: 2.4062 - val_task0_profile_loss: 5142.0960
# Epoch 132/500
# 7/7 [==============================] - 1s 177ms/step - loss: 4303.5048 - task0_logcount_loss: 1.9803 - task0_profile_loss: 2323.1842 - val_loss: 7479.1802 - val_task0_logcount_loss: 2.3222 - val_task0_profile_loss: 5156.9498
# Epoch 133/500
# 7/7 [==============================] - 1s 172ms/step - loss: 4261.2412 - task0_logcount_loss: 1.9128 - task0_profile_loss: 2348.4202 - val_loss: 7394.7696 - val_task0_logcount_loss: 2.2276 - val_task0_profile_loss: 5167.1522
# Epoch 134/500
# 7/7 [==============================] - 1s 177ms/step - loss: 4300.8525 - task0_logcount_loss: 1.9780 - task0_profile_loss: 2322.8993 - val_loss: 7379.9261 - val_task0_logcount_loss: 2.1867 - val_task0_profile_loss: 5193.2536
# Epoch 135/500
# 7/7 [==============================] - 1s 172ms/step - loss: 4325.0696 - task0_logcount_loss: 1.9945 - task0_profile_loss: 2330.5896 - val_loss: 7290.2867 - val_task0_logcount_loss: 2.1926 - val_task0_profile_loss: 5097.6557
# Epoch 136/500
# 7/7 [==============================] - 1s 178ms/step - loss: 4318.8610 - task0_logcount_loss: 2.0151 - task0_profile_loss: 2303.7317 - val_loss: 7469.7626 - val_task0_logcount_loss: 2.2943 - val_task0_profile_loss: 5175.4417
# Epoch 137/500
# ...
# Epoch 268/500
# 7/7 [==============================] - 1s 176ms/step - loss: 3081.6280 - task0_logcount_loss: 0.9645 - task0_profile_loss: 2117.1158 - val_loss: 6842.1407 - val_task0_logcount_loss: 1.0809 - val_task0_profile_loss: 5761.1943
# Epoch 269/500
# 7/7 [==============================] - 1s 177ms/step - loss: 3210.5436 - task0_logcount_loss: 1.1081 - task0_profile_loss: 2102.4433 - val_loss: 7196.8427 - val_task0_logcount_loss: 1.3355 - val_task0_profile_loss: 5861.3510
# Epoch 270/500
# 7/7 [==============================] - 1s 177ms/step - loss: 3180.7182 - task0_logcount_loss: 1.0117 - task0_profile_loss: 2169.0296 - val_loss: 6765.6430 - val_task0_logcount_loss: 1.2161 - val_task0_profile_loss: 5549.4935
# Epoch 271/500
# 7/7 [==============================] - 1s 182ms/step - loss: 3234.6646 - task0_logcount_loss: 1.0629 - task0_profile_loss: 2171.7775 - val_loss: 7457.7802 - val_task0_logcount_loss: 1.1032 - val_task0_profile_loss: 6354.5709
# Epoch 272/500
# 7/7 [==============================] - 1s 166ms/step - loss: 3378.3963 - task0_logcount_loss: 0.9687 - task0_profile_loss: 2409.6959 - val_loss: 6887.2177 - val_task0_logcount_loss: 1.0963 - val_task0_profile_loss: 5790.8978
# Epoch 273/500
# 7/7 [==============================] - 1s 173ms/step - loss: 3413.0142 - task0_logcount_loss: 1.0492 - task0_profile_loss: 2363.8439 - val_loss: 6104.1319 - val_task0_logcount_loss: 1.1811 - val_task0_profile_loss: 4923.0149
# Epoch 274/500
# 7/7 [==============================] - 1s 175ms/step - loss: 3188.9880 - task0_logcount_loss: 0.9947 - task0_profile_loss: 2194.3150 - val_loss: 6084.6959 - val_task0_logcount_loss: 1.1215 - val_task0_profile_loss: 4963.1599
# Epoch 275/500
# 7/7 [==============================] - 1s 176ms/step - loss: 3166.4789 - task0_logcount_loss: 0.9754 - task0_profile_loss: 2191.0625 - val_loss: 5882.8366 - val_task0_logcount_loss: 1.2339 - val_task0_profile_loss: 4648.9543
# Epoch 276/500
# 7/7 [==============================] - 1s 171ms/step - loss: 3116.6736 - task0_logcount_loss: 0.9615 - task0_profile_loss: 2155.1840 - val_loss: 6787.3098 - val_task0_logcount_loss: 1.2146 - val_task0_profile_loss: 5572.7267
# Epoch 277/500
# 7/7 [==============================] - 1s 176ms/step - loss: 3277.5409 - task0_logcount_loss: 1.1773 - task0_profile_loss: 2100.2769 - val_loss: 6679.0191 - val_task0_logcount_loss: 1.4274 - val_task0_profile_loss: 5251.5946
# Epoch 278/500
# 7/7 [==============================] - 1s 170ms/step - loss: 3208.7950 - task0_logcount_loss: 1.1324 - task0_profile_loss: 2076.3453 - val_loss: 6411.6690 - val_task0_logcount_loss: 1.1218 - val_task0_profile_loss: 5289.8518
# Epoch 279/500
# 7/7 [==============================] - 1s 171ms/step - loss: 3149.3558 - task0_logcount_loss: 1.0367 - task0_profile_loss: 2112.6852 - val_loss: 6005.7578 - val_task0_logcount_loss: 0.9847 - val_task0_profile_loss: 5021.0446
# Epoch 280/500
# 7/7 [==============================] - 1s 162ms/step - loss: 3045.5347 - task0_logcount_loss: 0.8901 - task0_profile_loss: 2155.4356 - val_loss: 5648.9870 - val_task0_logcount_loss: 0.9935 - val_task0_profile_loss: 4655.5198
# Epoch 281/500
# 7/7 [==============================] - 1s 159ms/step - loss: 2999.8988 - task0_logcount_loss: 0.9287 - task0_profile_loss: 2071.1603 - val_loss: 5880.3734 - val_task0_logcount_loss: 0.9987 - val_task0_profile_loss: 4881.6296
# Epoch 282/500
# 7/7 [==============================] - 1s 157ms/step - loss: 2916.8557 - task0_logcount_loss: 0.8154 - task0_profile_loss: 2101.4826 - val_loss: 6127.8347 - val_task0_logcount_loss: 0.9793 - val_task0_profile_loss: 5148.4909
# Epoch 283/500
# 7/7 [==============================] - 1s 171ms/step - loss: 2912.5095 - task0_logcount_loss: 0.8520 - task0_profile_loss: 2060.4665 - val_loss: 5961.1383 - val_task0_logcount_loss: 0.9994 - val_task0_profile_loss: 4961.7446
# Epoch 284/500
# 7/7 [==============================] - 1s 170ms/step - loss: 2911.7434 - task0_logcount_loss: 0.9016 - task0_profile_loss: 2010.1078 - val_loss: 5733.6212 - val_task0_logcount_loss: 1.0479 - val_task0_profile_loss: 4685.6752
# Epoch 285/500
# 7/7 [==============================] - 1s 182ms/step - loss: 2851.2608 - task0_logcount_loss: 0.8638 - task0_profile_loss: 1987.4367 - val_loss: 5808.9660 - val_task0_logcount_loss: 0.9973 - val_task0_profile_loss: 4811.6717
# Epoch 286/500
# 7/7 [==============================] - 1s 171ms/step - loss: 2883.7588 - task0_logcount_loss: 0.8851 - task0_profile_loss: 1998.6165 - val_loss: 5726.2701 - val_task0_logcount_loss: 1.0032 - val_task0_profile_loss: 4723.0411
# Epoch 287/500
# 7/7 [==============================] - 1s 174ms/step - loss: 2862.0530 - task0_logcount_loss: 0.8806 - task0_profile_loss: 1981.4849 - val_loss: 5641.6902 - val_task0_logcount_loss: 1.0376 - val_task0_profile_loss: 4604.1315
# Epoch 288/500
# 7/7 [==============================] - 1s 171ms/step - loss: 2847.3021 - task0_logcount_loss: 0.8468 - task0_profile_loss: 2000.4966 - val_loss: 5584.7320 - val_task0_logcount_loss: 0.9443 - val_task0_profile_loss: 4640.4510
# Epoch 289/500
# 7/7 [==============================] - 1s 172ms/step - loss: 2811.4574 - task0_logcount_loss: 0.7867 - task0_profile_loss: 2024.7686 - val_loss: 5811.6702 - val_task0_logcount_loss: 0.9928 - val_task0_profile_loss: 4818.8558
# Epoch 290/500
# 7/7 [==============================] - 1s 173ms/step - loss: 2996.7587 - task0_logcount_loss: 0.9474 - task0_profile_loss: 2049.3858 - val_loss: 6612.3969 - val_task0_logcount_loss: 1.6738 - val_task0_profile_loss: 4938.5651
# Epoch 291/500
# 7/7 [==============================] - 1s 164ms/step - loss: 3104.3419 - task0_logcount_loss: 1.0845 - task0_profile_loss: 2019.8088 - val_loss: 5925.3190 - val_task0_logcount_loss: 1.1907 - val_task0_profile_loss: 4734.5819
# Epoch 292/500
# 7/7 [==============================] - 1s 177ms/step - loss: 3067.0646 - task0_logcount_loss: 1.0235 - task0_profile_loss: 2043.5175 - val_loss: 5954.8389 - val_task0_logcount_loss: 0.8837 - val_task0_profile_loss: 5071.1583
# Epoch 293/500
# 7/7 [==============================] - 1s 174ms/step - loss: 2981.5134 - task0_logcount_loss: 0.9465 - task0_profile_loss: 2034.9921 - val_loss: 5738.2303 - val_task0_logcount_loss: 0.8997 - val_task0_profile_loss: 4838.5796
# Epoch 294/500
# 7/7 [==============================] - 1s 161ms/step - loss: 2936.6770 - task0_logcount_loss: 0.8898 - task0_profile_loss: 2046.8402 - val_loss: 5584.4052 - val_task0_logcount_loss: 0.9276 - val_task0_profile_loss: 4656.8418
# Epoch 295/500
# 7/7 [==============================] - 1s 171ms/step - loss: 2931.3586 - task0_logcount_loss: 0.9252 - task0_profile_loss: 2006.1262 - val_loss: 5611.4554 - val_task0_logcount_loss: 1.0529 - val_task0_profile_loss: 4558.5584
# Epoch 296/500
# 7/7 [==============================] - 1s 176ms/step - loss: 2973.6013 - task0_logcount_loss: 0.9656 - task0_profile_loss: 2008.0494 - val_loss: 5633.6034 - val_task0_logcount_loss: 0.9430 - val_task0_profile_loss: 4690.5900
# Epoch 297/500
# 7/7 [==============================] - 1s 175ms/step - loss: 2883.3626 - task0_logcount_loss: 0.8713 - task0_profile_loss: 2012.0681 - val_loss: 5893.0684 - val_task0_logcount_loss: 1.1638 - val_task0_profile_loss: 4729.2244
# Epoch 298/500
# 7/7 [==============================] - 1s 164ms/step - loss: 2809.7771 - task0_logcount_loss: 0.8024 - task0_profile_loss: 2007.3907 - val_loss: 5529.0263 - val_task0_logcount_loss: 0.9386 - val_task0_profile_loss: 4590.4543
# Epoch 299/500
# 7/7 [==============================] - 1s 167ms/step - loss: 2958.6696 - task0_logcount_loss: 0.9705 - task0_profile_loss: 1988.1578 - val_loss: 5770.8706 - val_task0_logcount_loss: 1.0735 - val_task0_profile_loss: 4697.4153
# Epoch 300/500
# 7/7 [==============================] - 1s 169ms/step - loss: 2853.2038 - task0_logcount_loss: 0.8565 - task0_profile_loss: 1996.6698 - val_loss: 6222.3111 - val_task0_logcount_loss: 0.8801 - val_task0_profile_loss: 5342.1811
# Epoch 301/500
# 7/7 [==============================] - 1s 179ms/step - loss: 2909.6505 - task0_logcount_loss: 0.8575 - task0_profile_loss: 2052.1919 - val_loss: 6601.3617 - val_task0_logcount_loss: 0.9262 - val_task0_profile_loss: 5675.1188
# Epoch 302/500
# 7/7 [==============================] - 1s 165ms/step - loss: 2898.0817 - task0_logcount_loss: 0.8134 - task0_profile_loss: 2084.6507 - val_loss: 6520.1289 - val_task0_logcount_loss: 0.9956 - val_task0_profile_loss: 5524.5385
# Epoch 303/500
# 7/7 [==============================] - 1s 162ms/step - loss: 3012.1147 - task0_logcount_loss: 0.8618 - task0_profile_loss: 2150.3631 - val_loss: 6174.6642 - val_task0_logcount_loss: 0.9365 - val_task0_profile_loss: 5238.1774
# Epoch 304/500
# 7/7 [==============================] - 1s 165ms/step - loss: 2902.3879 - task0_logcount_loss: 0.8300 - task0_profile_loss: 2072.4277 - val_loss: 6920.2130 - val_task0_logcount_loss: 1.0160 - val_task0_profile_loss: 5904.2222
# Epoch 305/500
# 7/7 [==============================] - 1s 180ms/step - loss: 2984.3644 - task0_logcount_loss: 0.8660 - task0_profile_loss: 2118.3166 - val_loss: 6723.7764 - val_task0_logcount_loss: 0.9658 - val_task0_profile_loss: 5757.9436
# Epoch 306/500
# 7/7 [==============================] - 1s 168ms/step - loss: 2944.4363 - task0_logcount_loss: 0.8528 - task0_profile_loss: 2091.5938 - val_loss: 5671.1588 - val_task0_logcount_loss: 1.1029 - val_task0_profile_loss: 4568.3082
# Epoch 307/500
# 7/7 [==============================] - 1s 175ms/step - loss: 2858.1728 - task0_logcount_loss: 0.7838 - task0_profile_loss: 2074.3759 - val_loss: 5576.8030 - val_task0_logcount_loss: 1.0330 - val_task0_profile_loss: 4543.8023
# Epoch 308/500
# 7/7 [==============================] - 1s 171ms/step - loss: 2931.7744 - task0_logcount_loss: 0.8690 - task0_profile_loss: 2062.7761 - val_loss: 5522.7735 - val_task0_logcount_loss: 0.9305 - val_task0_profile_loss: 4592.2590
# Epoch 309/500
# 7/7 [==============================] - 1s 176ms/step - loss: 2773.8603 - task0_logcount_loss: 0.7606 - task0_profile_loss: 2013.2361 - val_loss: 5568.9350 - val_task0_logcount_loss: 0.9227 - val_task0_profile_loss: 4646.2737
# Epoch 310/500
# 7/7 [==============================] - ETA: 0s - loss: 2710.3509 - task0_logcount_loss: 0.7545 - task0_profile_loss: 1955.83 - 1s 172ms/step - loss: 2747.2262 - task0_logcount_loss: 0.7709 - task0_profile_loss: 1976.2883 - val_loss: 5800.3153 - val_task0_logcount_loss: 1.0053 - val_task0_profile_loss: 4795.0578
# Epoch 311/500
# 7/7 [==============================] - 1s 159ms/step - loss: 2692.0503 - task0_logcount_loss: 0.7097 - task0_profile_loss: 1982.3386 - val_loss: 5806.5635 - val_task0_logcount_loss: 0.9903 - val_task0_profile_loss: 4816.2689
# Epoch 312/500
# 7/7 [==============================] - 1s 169ms/step - loss: 2587.6001 - task0_logcount_loss: 0.6424 - task0_profile_loss: 1945.2316 - val_loss: 5599.2152 - val_task0_logcount_loss: 0.9323 - val_task0_profile_loss: 4666.8933
# Epoch 313/500
# 7/7 [==============================] - 1s 171ms/step - loss: 2698.1159 - task0_logcount_loss: 0.7169 - task0_profile_loss: 1981.1710 - val_loss: 5985.8914 - val_task0_logcount_loss: 1.0935 - val_task0_profile_loss: 4892.3731
# Epoch 314/500
# 7/7 [==============================] - 1s 165ms/step - loss: 2682.7712 - task0_logcount_loss: 0.7371 - task0_profile_loss: 1945.7175 - val_loss: 6182.8909 - val_task0_logcount_loss: 1.3607 - val_task0_profile_loss: 4822.1426
# Epoch 315/500
# 7/7 [==============================] - 1s 169ms/step - loss: 2766.8029 - task0_logcount_loss: 0.8180 - task0_profile_loss: 1948.8396 - val_loss: 5770.8026 - val_task0_logcount_loss: 0.9797 - val_task0_profile_loss: 4791.1309
# Epoch 316/500
# 7/7 [==============================] - 1s 168ms/step - loss: 2795.5190 - task0_logcount_loss: 0.8478 - task0_profile_loss: 1947.6760 - val_loss: 5743.7219 - val_task0_logcount_loss: 0.9435 - val_task0_profile_loss: 4800.1827
# Epoch 317/500
# 7/7 [==============================] - 1s 173ms/step - loss: 2706.9828 - task0_logcount_loss: 0.7808 - task0_profile_loss: 1926.2066 - val_loss: 5783.0693 - val_task0_logcount_loss: 0.9538 - val_task0_profile_loss: 4829.2642
# Epoch 318/500
# 7/7 [==============================] - 1s 184ms/step - loss: 2672.4697 - task0_logcount_loss: 0.7203 - task0_profile_loss: 1952.1893 - val_loss: 5737.3918 - val_task0_logcount_loss: 1.0663 - val_task0_profile_loss: 4671.1128
# Epoch 319/500
# 7/7 [==============================] - 1s 168ms/step - loss: 2714.2667 - task0_logcount_loss: 0.7835 - task0_profile_loss: 1930.7232 - val_loss: 5908.6278 - val_task0_logcount_loss: 1.1915 - val_task0_profile_loss: 4717.1457
# Epoch 320/500
# 7/7 [==============================] - 1s 168ms/step - loss: 2674.4131 - task0_logcount_loss: 0.7407 - task0_profile_loss: 1933.6879 - val_loss: 5611.0566 - val_task0_logcount_loss: 1.0250 - val_task0_profile_loss: 4586.0428
# Epoch 321/500
# 7/7 [==============================] - 1s 168ms/step - loss: 2663.9388 - task0_logcount_loss: 0.7504 - task0_profile_loss: 1913.5029 - val_loss: 5855.4430 - val_task0_logcount_loss: 1.1489 - val_task0_profile_loss: 4706.5020
# Epoch 322/500
# 7/7 [==============================] - 1s 160ms/step - loss: 2721.0035 - task0_logcount_loss: 0.8083 - task0_profile_loss: 1912.6826 - val_loss: 5825.3043 - val_task0_logcount_loss: 1.0962 - val_task0_profile_loss: 4729.0773
# Epoch 323/500
# 7/7 [==============================] - 1s 162ms/step - loss: 2658.7627 - task0_logcount_loss: 0.7344 - task0_profile_loss: 1924.3287 - val_loss: 6213.3104 - val_task0_logcount_loss: 1.1837 - val_task0_profile_loss: 5029.6264
# Epoch 324/500
# 7/7 [==============================] - 1s 166ms/step - loss: 2725.0299 - task0_logcount_loss: 0.7896 - task0_profile_loss: 1935.4578 - val_loss: 5864.1706 - val_task0_logcount_loss: 1.0493 - val_task0_profile_loss: 4814.8372
# Epoch 325/500
# 7/7 [==============================] - 1s 175ms/step - loss: 2552.6840 - task0_logcount_loss: 0.6522 - task0_profile_loss: 1900.5009 - val_loss: 5809.2240 - val_task0_logcount_loss: 0.8720 - val_task0_profile_loss: 4937.1858
# Epoch 326/500
# 7/7 [==============================] - 1s 169ms/step - loss: 2602.6750 - task0_logcount_loss: 0.6774 - task0_profile_loss: 1925.2487 - val_loss: 5717.9670 - val_task0_logcount_loss: 0.8559 - val_task0_profile_loss: 4862.0266
# Epoch 327/500
# 7/7 [==============================] - 1s 184ms/step - loss: 2613.8020 - task0_logcount_loss: 0.7004 - task0_profile_loss: 1913.3906 - val_loss: 5740.9646 - val_task0_logcount_loss: 0.8780 - val_task0_profile_loss: 4862.9772
# Epoch 328/500
# 7/7 [==============================] - 1s 174ms/step - loss: 2572.1233 - task0_logcount_loss: 0.6562 - task0_profile_loss: 1915.8798 - val_loss: 5675.0263 - val_task0_logcount_loss: 0.8770 - val_task0_profile_loss: 4798.0152
# Epoch 329/500
# 7/7 [==============================] - 1s 165ms/step - loss: 2566.7428 - task0_logcount_loss: 0.6334 - task0_profile_loss: 1933.3851 - val_loss: 5537.7729 - val_task0_logcount_loss: 0.9067 - val_task0_profile_loss: 4631.1119
# Epoch 330/500
# 7/7 [==============================] - 1s 172ms/step - loss: 2607.3380 - task0_logcount_loss: 0.6863 - task0_profile_loss: 1921.0692 - val_loss: 5787.5774 - val_task0_logcount_loss: 1.0978 - val_task0_profile_loss: 4689.7597
# Epoch 331/500
# 7/7 [==============================] - 1s 161ms/step - loss: 2568.6634 - task0_logcount_loss: 0.6560 - task0_profile_loss: 1912.6743 - val_loss: 5940.2384 - val_task0_logcount_loss: 1.0030 - val_task0_profile_loss: 4937.2206
# Epoch 332/500
# 7/7 [==============================] - 1s 169ms/step - loss: 2581.6290 - task0_logcount_loss: 0.6631 - task0_profile_loss: 1918.5001 - val_loss: 6046.0120 - val_task0_logcount_loss: 0.9278 - val_task0_profile_loss: 5118.2555
# Epoch 333/500
# 7/7 [==============================] - 1s 163ms/step - loss: 2559.3314 - task0_logcount_loss: 0.6349 - task0_profile_loss: 1924.3994 - val_loss: 5741.0409 - val_task0_logcount_loss: 0.8607 - val_task0_profile_loss: 4880.3546

# %%
model.save('/users/amr1/pho4/data/models/cbf1_limited_nit_model.h5')

# %%
from keras.models import load_model
from keras.utils import CustomObjectScope

with CustomObjectScope({'MultichannelMultinomialNLL': MultichannelMultinomialNLL,'RevCompConv1D': RevCompConv1D}):
    model = load_model('/users/amr1/pho4/data/models/cbf1_limited_nit_model.h5')
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           (None, 546, 4)       0
# __________________________________________________________________________________________________
# rev_comp_conv1d_1 (RevCompConv1 (None, 526, 128)     5440        sequence[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 522, 128)     0           rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_2 (RevCompConv1 (None, 522, 128)     24640       rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 522, 128)     0           lambda_1[0][0]
#                                                                  rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 514, 128)     0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 514, 128)     0           rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_3 (RevCompConv1 (None, 514, 128)     24640       average_1[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 514, 128)     0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 498, 128)     0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 498, 128)     0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 498, 128)     0           rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_4 (RevCompConv1 (None, 498, 128)     24640       average_2[0][0]
# __________________________________________________________________________________________________
# average_3 (Average)             (None, 498, 128)     0           lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 466, 128)     0           lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 466, 128)     0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 466, 128)     0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 466, 128)     0           rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_5 (RevCompConv1 (None, 466, 128)     24640       average_3[0][0]
# __________________________________________________________________________________________________
# average_4 (Average)             (None, 466, 128)     0           lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 402, 128)     0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 402, 128)     0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 402, 128)     0           lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 402, 128)     0           lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 402, 128)     0           rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_6 (RevCompConv1 (None, 402, 128)     24640       average_4[0][0]
# __________________________________________________________________________________________________
# average_5 (Average)             (None, 402, 128)     0           lambda_11[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
#                                                                  rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 274, 128)     0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 274, 128)     0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 274, 128)     0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 274, 128)     0           lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 274, 128)     0           lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 274, 128)     0           rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_7 (RevCompConv1 (None, 274, 128)     24640       average_5[0][0]
# __________________________________________________________________________________________________
# control_logcount (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# average_6 (Average)             (None, 274, 128)     0           lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_21[0][0]
#                                                                  rev_comp_conv1d_7[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           control_logcount[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 128)          0           average_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 130)          0           lambda_22[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  control_logcount[0][0]
# __________________________________________________________________________________________________
# control_profile (InputLayer)    (None, 200, 2)       0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 130)       0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 200, 2)       0           control_profile[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_9 (RevCompConv1 (None, 200, 2)       9601        average_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_8 (RevCompConv1 (None, 1, 2)         131         reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 200, 6)       0           lambda_23[0][0]
#                                                                  rev_comp_conv1d_9[0][0]
#                                                                  control_profile[0][0]
# __________________________________________________________________________________________________
# task0_logcount (Reshape)        (None, 2)            0           rev_comp_conv1d_8[0][0]
# __________________________________________________________________________________________________
# task0_profile (RevCompConv1D)   (None, 200, 2)       7           concatenate_2[0][0]
# ==================================================================================================
# Total params: 163,019
# Trainable params: 163,019
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# evaluate

# %%
o_test_preds_logcount = []
o_test_biastrack_logcount = []
o_test_biastrack_profile = []
o_test_seqs = []
o_test_preds_profile = []
o_test_labels_logcount = []
o_test_labels_profile = []

keras_test_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
            bed_file="/users/amr1/pho4/data/limited_conditions/cbf1_nit/test_1000_around_summits.bed.gz",
            batch_size=64,
            shuffle_before_epoch=False, 
            seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)

orig_seqs = []

for batch_idx in range(len(keras_test_batch_generator)):
    batch_inputs, batch_labels = keras_test_batch_generator[batch_idx]
    o_test_seqs.append(batch_inputs['sequence']) 
    o_test_biastrack_logcount.append(batch_inputs['control_logcount'])
    o_test_biastrack_profile.append(batch_inputs['control_profile'])    
    test_preds = model.predict(batch_inputs)
    o_test_preds_logcount.append(test_preds[0])
    o_test_preds_profile.append(test_preds[1])
    o_test_labels_logcount.append(batch_labels['task0_logcount'])
    o_test_labels_profile.append(batch_labels['task0_profile'])
o_test_biastrack_logcount = np.concatenate(o_test_biastrack_logcount, axis=0)
o_test_biastrack_profile = np.concatenate(o_test_biastrack_profile,axis=0)
o_test_seqs = np.concatenate(o_test_seqs,axis=0)
o_test_preds_logcount = np.concatenate(o_test_preds_logcount, axis=0)
o_test_preds_profile = np.concatenate(o_test_preds_profile, axis=0)
o_test_labels_logcount = np.concatenate(o_test_labels_logcount, axis=0)
o_test_labels_profile = np.concatenate(o_test_labels_profile, axis=0)

from matplotlib import pyplot as plt
from scipy.stats import spearmanr

o_test_labels_logtotalcount = np.log(np.sum(np.exp(o_test_labels_logcount) - 1,axis=-1) + 1)

plt.scatter(o_test_biastrack_logcount, o_test_labels_logtotalcount, alpha=0.1)
plt.xlabel("Bias track log counts")
plt.ylabel("True log total counts")
plt.plot([np.min(o_test_biastrack_logcount), np.max(o_test_biastrack_logcount)],
         [np.min(o_test_biastrack_logcount), np.max(o_test_biastrack_logcount)],
         color="black")
plt.show()
print(spearmanr(o_test_biastrack_logcount, o_test_labels_logtotalcount))


#do a scatterplot of total count predictions
plt.scatter(o_test_preds_logcount[:,0], o_test_labels_logcount[:,0], alpha=0.1)
plt.xlabel("Predicted log counts - Forward Strand")
plt.ylabel("True log counts - Forward Strand")
plt.plot([np.min(o_test_preds_logcount[:,0]), np.max(o_test_preds_logcount[:,0])],
         [np.min(o_test_preds_logcount[:,0]), np.max(o_test_preds_logcount[:,0])],
         color="black")
plt.show()
print(spearmanr(o_test_preds_logcount[:,0], o_test_labels_logcount[:,0]))

plt.scatter(o_test_preds_logcount[:,1], o_test_labels_logcount[:,1], alpha=0.1)
plt.xlabel("Predicted log counts - Reverse Strand")
plt.ylabel("True log counts - Reverse Strand")
plt.plot([np.min(o_test_preds_logcount[:,1]), np.max(o_test_preds_logcount[:,1])],
         [np.min(o_test_preds_logcount[:,1]), np.max(o_test_preds_logcount[:,1])],
         color="black")
plt.show()
print(spearmanr(o_test_preds_logcount[:,1], o_test_labels_logcount[:,1]))
# Out:
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# SpearmanrResult(correlation=-0.07304978061915644, pvalue=0.5390920690856065)
# SpearmanrResult(correlation=0.7589148667739373, pvalue=7.303853759827968e-15)
# SpearmanrResult(correlation=0.7535809327483275, pvalue=1.435616124300669e-14)

# %%
# %matplotlib inline

o_train_preds_logcount = []
o_train_biastrack_logcount = []
o_train_biastrack_profile = []
o_train_seqs = []
o_train_preds_profile = []
o_train_labels_logcount = []
o_train_labels_profile = []

orig_seqs = []

for batch_idx in range(len(keras_train_batch_generator)):
    batch_inputs, batch_labels = keras_train_batch_generator[batch_idx]
    o_train_seqs.append(batch_inputs['sequence']) 
    o_train_biastrack_logcount.append(batch_inputs['control_logcount'])
    o_train_biastrack_profile.append(batch_inputs['control_profile'])    
    train_preds = model.predict(batch_inputs)
    o_train_preds_logcount.append(train_preds[0])
    o_train_preds_profile.append(train_preds[1])
    o_train_labels_logcount.append(batch_labels['task0_logcount'])
    o_train_labels_profile.append(batch_labels['task0_profile'])
o_train_biastrack_logcount = np.concatenate(o_train_biastrack_logcount, axis=0)
o_train_biastrack_profile = np.concatenate(o_train_biastrack_profile,axis=0)
o_train_seqs = np.concatenate(o_train_seqs,axis=0)
o_train_preds_logcount = np.concatenate(o_train_preds_logcount, axis=0)
o_train_preds_profile = np.concatenate(o_train_preds_profile, axis=0)
o_train_labels_logcount = np.concatenate(o_train_labels_logcount, axis=0)
o_train_labels_profile = np.concatenate(o_train_labels_profile, axis=0)

from matplotlib import pyplot as plt
from scipy.stats import spearmanr

o_train_labels_logtotalcount = np.log(np.sum(np.exp(o_train_labels_logcount) - 1,axis=-1) + 1)

plt.scatter(o_train_biastrack_logcount, o_train_labels_logtotalcount, alpha=0.1)
plt.xlabel("Bias track log counts")
plt.ylabel("True log total counts")
plt.plot([np.min(o_train_biastrack_logcount), np.max(o_train_biastrack_logcount)],
         [np.min(o_train_biastrack_logcount), np.max(o_train_biastrack_logcount)],
         color="black")
plt.show()
print(spearmanr(o_train_biastrack_logcount, o_train_labels_logtotalcount))


#do a scatterplot of total count predictions
plt.scatter(o_train_preds_logcount[:,0], o_train_labels_logcount[:,0], alpha=0.1)
plt.xlabel("Predicted log counts - Forward Strand")
plt.ylabel("True log counts - Forward Strand")
plt.plot([np.min(o_train_preds_logcount[:,0]), np.max(o_train_preds_logcount[:,0])],
         [np.min(o_train_preds_logcount[:,0]), np.max(o_train_preds_logcount[:,0])],
         color="black")
plt.show()
print(spearmanr(o_train_preds_logcount[:,0], o_train_labels_logcount[:,0]))

plt.scatter(o_train_preds_logcount[:,1], o_train_labels_logcount[:,1], alpha=0.1)
plt.xlabel("Predicted log counts - Reverse Strand")
plt.ylabel("True log counts - Reverse Strand")
plt.plot([np.min(o_train_preds_logcount[:,1]), np.max(o_train_preds_logcount[:,1])],
         [np.min(o_train_preds_logcount[:,1]), np.max(o_train_preds_logcount[:,1])],
         color="black")
plt.show()
print(spearmanr(o_train_preds_logcount[:,1], o_train_labels_logcount[:,1]))
# Out:
# SpearmanrResult(correlation=0.17535371906558223, pvalue=1.497072797506781e-07)
# SpearmanrResult(correlation=0.7826455911493916, pvalue=3.419064054576325e-184)
# SpearmanrResult(correlation=0.8118470397654886, pvalue=8.759248933255339e-209)

# %% [markdown]
# Interpretation

# %%
import shap
from deeplift.dinuc_shuffle import dinuc_shuffle

def combine_mult_and_diffref(mult, orig_inp, bg_data):
    to_return = []
    for l in [0]:
        projected_hypothetical_contribs = np.zeros_like(bg_data[l]).astype("float")
        assert len(orig_inp[l].shape)==2
        #At each position in the input sequence, we iterate over the one-hot encoding
        # possibilities (eg: for genomic sequence, this is ACGT i.e.
        # 1000, 0100, 0010 and 0001) and compute the hypothetical 
        # difference-from-reference in each case. We then multiply the hypothetical
        # differences-from-reference with the multipliers to get the hypothetical contributions.
        #For each of the one-hot encoding possibilities,
        # the hypothetical contributions are then summed across the ACGT axis to estimate
        # the total hypothetical contribution of each position. This per-position hypothetical
        # contribution is then assigned ("projected") onto whichever base was present in the
        # hypothetical sequence.
        #The reason this is a fast estimate of what the importance scores *would* look
        # like if different bases were present in the underlying sequence is that
        # the multipliers are computed once using the original sequence, and are not
        # computed again for each hypothetical sequence.
        for i in range(orig_inp[l].shape[-1]):
            hypothetical_input = np.zeros_like(orig_inp[l]).astype("float")
            hypothetical_input[:,i] = 1.0
            hypothetical_difference_from_reference = (hypothetical_input[None,:,:]-bg_data[l])
            hypothetical_contribs = hypothetical_difference_from_reference*mult[l]
            projected_hypothetical_contribs[:,:,i] = np.sum(hypothetical_contribs,axis=-1) 
        to_return.append(np.mean(projected_hypothetical_contribs,axis=0))
    to_return.append(np.zeros_like(orig_inp[1]))
    return to_return

def shuffle_several_times(s):
    numshuffles=20
    return [np.array([dinuc_shuffle(s[0]) for i in range(numshuffles)]),
            np.array([s[1] for i in range(numshuffles)])]

profile_model_counts_explainer = shap.explainers.deep.TFDeepExplainer(
    ([model.input[0], model.input[1]],
     tf.reduce_sum(model.outputs[0],axis=-1)),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)

#See Google slide deck for explanations
#We meannorm as per section titled "Adjustments for Softmax Layers"
# in the DeepLIFT paper
meannormed_logits = (
    model.outputs[1]-
    tf.reduce_mean(model.outputs[1],axis=1)[:,None,:])
#'stop_gradient' will prevent importance from being propagated through
# this operation; we do this because we just want to treat the post-softmax
# probabilities as 'weights' on the different logits, without having the
# network explain how the probabilities themselves were derived
#Could be worth contrasting explanations derived with and without stop_gradient
# enabled...
stopgrad_meannormed_logits = tf.stop_gradient(meannormed_logits)
softmax_out = tf.nn.softmax(stopgrad_meannormed_logits,axis=1)
#Weight the logits according to the softmax probabilities, take the sum for each
# example. This mirrors what was done for the bpnet paper.
weightedsum_meannormed_logits = tf.reduce_sum(softmax_out*meannormed_logits,
                                              axis=(1,2))
profile_model_profile_explainer = shap.explainers.deep.TFDeepExplainer(
    ([model.input[0], model.input[2]],
     weightedsum_meannormed_logits),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)
# Out:
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  StopGradient used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients

# %%
#The shap scores
post_counts_hypimps,_ = profile_model_counts_explainer.shap_values(
    [o_test_seqs, np.zeros((len(o_test_seqs), 1))],
    progress_message=10)
post_profile_hypimps,_ = profile_model_profile_explainer.shap_values(
    [o_test_seqs, np.zeros((len(o_test_seqs), out_pred_len, 2))],
    progress_message=10)

post_counts_actualimps = post_counts_hypimps*o_test_seqs
post_profile_actualimps = post_profile_hypimps*o_test_seqs
# Out:
# Done 0 examples of 73
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/shap/explainers/deep/deep_tf.py:493: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Done 10 examples of 73
# Done 20 examples of 73
# Done 30 examples of 73
# Done 40 examples of 73
# Done 50 examples of 73
# Done 60 examples of 73
# Done 70 examples of 73
# Done 0 examples of 73
# Done 10 examples of 73
# Done 20 examples of 73
# Done 30 examples of 73
# Done 40 examples of 73
# Done 50 examples of 73
# Done 60 examples of 73
# Done 70 examples of 73

# %%
from deeplift.visualization import viz_sequence
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter

sorted_test_indices = [x[0] for x in 
                       sorted(enumerate(o_test_labels_logtotalcount),
                              key=lambda x: -x[1])]

def smooth(vals):
    return np.convolve(vals, np.ones(1,)/1, mode='same')

for idx in sorted_test_indices[:10]: 
    true_profile = o_test_labels_profile[idx] 
    print("idx",idx)
    print("Counts",np.sum(true_profile,axis=0))
    print("Predcounts",np.exp(o_test_preds_logcount[idx])-1)
    
    for oneovertemp in [1.0]:
        print("oneovertemp",oneovertemp)
        print(o_test_labels_profile[idx].shape)
        print("Pred profile shape", o_test_preds_profile[idx].shape)
        pred_profile = (np.sum(o_test_labels_profile[idx], axis=0)[None,:] #total counts
                      *(np.exp(o_test_preds_profile[idx]*oneovertemp)/
                        np.sum(np.exp(o_test_preds_profile[idx]*oneovertemp),axis=0)[None,:]) )   
        plt.figure(figsize=(20,2))

        start_view = 0
        end_view = seq_len
        total_flanking = seq_len - out_pred_len
        left_flank = int(0.5*total_flanking)
        right_flank = total_flanking - left_flank
        plt.plot(np.arange(out_pred_len)+left_flank, smooth(true_profile[:,0]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, -smooth(true_profile[:,1]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, pred_profile[:,0])
        plt.plot(np.arange(out_pred_len)+left_flank, -pred_profile[:,1])
        plt.xlim(start_view,end_view)
        plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
        plt.show()

    print("counts imp")
    viz_sequence.plot_weights(post_counts_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
    print("profile imp")
    viz_sequence.plot_weights(post_profile_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
# Out:
# idx 59
# Counts [19681. 22214.]
# Predcounts [ 93103.85 127782.03]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 12
# Counts [13167. 20450.]
# Predcounts [5438.017  4622.8853]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 60
# Counts [10506. 14545.]
# Predcounts [20644.549 21905.053]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 40
# Counts [ 8455. 15273.]
# Predcounts [1057.9216 1806.1176]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 5
# Counts [12207. 10441.]
# Predcounts [4487.039 7332.922]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 2
# Counts [ 5878. 11869.]
# Predcounts [1295.5669 2626.2375]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 37
# Counts [5940. 7562.]
# Predcounts [2781.0012 3066.2417]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 15
# Counts [5340. 7742.]
# Predcounts [957.55597 709.67487]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 29
# Counts [8309. 4341.]
# Predcounts [18651.322   1695.2681]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 18
# Counts [6015. 4701.]
# Predcounts [1769.8309 2106.618 ]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp

# %%
for idx in sorted_test_indices[:10]: 
    true_profile = o_test_labels_profile[idx] 
    print("idx",idx)
    print("Counts",np.sum(true_profile,axis=0))
    print("Predcounts",np.exp(o_test_preds_logcount[idx])-1)
    
    for oneovertemp in [1.0]:
        print("oneovertemp",oneovertemp)
        print(o_test_labels_profile[idx].shape)
        print("Pred profile shape", o_test_preds_profile[idx].shape)
        pred_profile = (np.sum(o_test_labels_profile[idx], axis=0)[None,:] #total counts
                      *(np.exp(o_test_preds_profile[idx]*oneovertemp)/
                        np.sum(np.exp(o_test_preds_profile[idx]*oneovertemp),axis=0)[None,:]) )   
        plt.figure(figsize=(20,2))

        start_view = 220
        end_view = 325
        total_flanking = seq_len - out_pred_len
        left_flank = int(0.5*total_flanking)
        right_flank = total_flanking - left_flank
        plt.plot(np.arange(out_pred_len)+left_flank, smooth(true_profile[:,0]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, -smooth(true_profile[:,1]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, pred_profile[:,0])
        plt.plot(np.arange(out_pred_len)+left_flank, -pred_profile[:,1])
        plt.xlim(start_view,end_view)
        plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
        plt.show()

    print("counts imp")
    viz_sequence.plot_weights(post_counts_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
    print("profile imp")
    viz_sequence.plot_weights(post_profile_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
# Out:
# idx 59
# Counts [19681. 22214.]
# Predcounts [ 93103.85 127782.03]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 12
# Counts [13167. 20450.]
# Predcounts [5438.017  4622.8853]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 60
# Counts [10506. 14545.]
# Predcounts [20644.549 21905.053]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 40
# Counts [ 8455. 15273.]
# Predcounts [1057.9216 1806.1176]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 5
# Counts [12207. 10441.]
# Predcounts [4487.039 7332.922]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 2
# Counts [ 5878. 11869.]
# Predcounts [1295.5669 2626.2375]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 37
# Counts [5940. 7562.]
# Predcounts [2781.0012 3066.2417]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 15
# Counts [5340. 7742.]
# Predcounts [957.55597 709.67487]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 29
# Counts [8309. 4341.]
# Predcounts [18651.322   1695.2681]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 18
# Counts [6015. 4701.]
# Predcounts [1769.8309 2106.618 ]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
