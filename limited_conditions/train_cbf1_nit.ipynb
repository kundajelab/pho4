# %% [markdown]
# Train Model

# %%
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers
# Out:
# Using TensorFlow backend.
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import numpy as np
import gzip
import keras
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import keras_genomics
from keras_genomics.layers.convolutional import RevCompConv1D
import keras
import keras.layers as kl
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers

def multinomial_nll(true_counts, logits):
    """Compute the multinomial negative log-likelihood
    Args:
      true_counts: observed count values
      logits: predicted logit values
    """
    counts_per_example = tf.reduce_sum(true_counts, axis=-1)
    dist = tfp.distributions.Multinomial(total_count=counts_per_example,
                                         logits=logits)
    return (-tf.reduce_sum(dist.log_prob(true_counts)) / 
            tf.to_float(tf.shape(true_counts)[0]))


#from https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/losses.py#L87
class MultichannelMultinomialNLL(object):
    def __init__(self, n):
        self.__name__ = "MultichannelMultinomialNLL"
        self.n = n

    def __call__(self, true_counts, logits):
        for i in range(self.n):
            loss = multinomial_nll(true_counts[..., i], logits[..., i])
            if i == 0:
                total = loss
            else:
                total += loss
        return total

    def get_config(self):
        return {"n": self.n}

#If we want to avoid zero-padding, then the input seq len will be determined
# by parameters of the convolutions
class AbstractProfileModel(object):

    def get_output_profile_len(self):
        raise NotImplementedError()

    def get_model(self):
        raise NotImplementedError()

def trim_flanks_of_conv_layer(conv_layer, output_len, width_to_trim, filters):
    layer = keras.layers.Lambda(
        lambda x: x[:,
          int(0.5*(width_to_trim)):-(width_to_trim-int(0.5*(width_to_trim)))],
        output_shape=(output_len, filters))(conv_layer)
    return layer

#model architecture is based on 
#https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/models.py#L534
#The non-cli parameters are specified in:
# https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/src/chipnexus/train/seqmodel/joint-model-valid.gin
#The cli parameters are in line 165 of:
# https://docs.google.com/spreadsheets/d/1n3l2HXKSNpmNUOifD41uRzDEAgmOqXMQDxquRaz6WLg/edit#gid=0
# which seems to match https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/src/chipnexus/train/seqmodel/ChIP-seq-default.gin
class RcBPnetArch(AbstractProfileModel):   

    def __init__(self, input_seq_len, c_task_weight, filters,
                       n_dil_layers, conv1_kernel_size,
                       dil_kernel_size,
                       outconv_kernel_size, lr):
        self.input_seq_len = input_seq_len
        self.c_task_weight = c_task_weight
        self.filters = filters
        self.n_dil_layers = n_dil_layers
        self.conv1_kernel_size = conv1_kernel_size
        self.dil_kernel_size = dil_kernel_size
        self.outconv_kernel_size = outconv_kernel_size
        self.lr = lr

    def get_embedding_len(self):
        embedding_len = self.input_seq_len
        embedding_len -= (self.conv1_kernel_size-1)     
        for i in range(1, self.n_dil_layers+1):
            dilation_rate = (2**i)
            embedding_len -= dilation_rate*(self.dil_kernel_size-1)
        return embedding_len

    def get_output_profile_len(self):
        embedding_len = self.get_embedding_len()
        out_profile_len = embedding_len - (self.outconv_kernel_size - 1)
        return out_profile_len

    def get_keras_model(self):

        out_pred_len = self.get_output_profile_len()

        inp = kl.Input(shape=(self.input_seq_len, 4), name='sequence')
        first_conv = RevCompConv1D(filters=self.filters,
                               kernel_size=self.conv1_kernel_size,
                               padding='valid',
                               activation='relu')(inp)
        curr_layer_size = self.input_seq_len - (self.conv1_kernel_size-1)
        bias_counts_input = kl.Input(shape=(1,), name="control_logcount")
        bias_profile_input = kl.Input(shape=(out_pred_len, 2),
                                      name="control_profile")
        prev_layers = [first_conv]
        for i in range(1, self.n_dil_layers + 1):
          dilation_rate = 2**i
          if i == 1:
              prev_sum = first_conv
          else:
              print(prev_layers)
              prev_sum = kl.merge.Average()(prev_layers)
          conv_output = RevCompConv1D(filters=self.filters,
                                  kernel_size=self.dil_kernel_size,
                                  padding='valid',
                                  activation='relu',
                                  dilation_rate=dilation_rate)(prev_sum)          
          width_to_trim = dilation_rate*(self.dil_kernel_size-1)
          curr_layer_size = (curr_layer_size - width_to_trim)
          prev_layers = [trim_flanks_of_conv_layer(
              conv_layer=x, output_len=curr_layer_size,
              width_to_trim=width_to_trim, filters=2*self.filters)
              for x in prev_layers]
          prev_layers.append(conv_output)

        combined_conv = kl.merge.Average()(prev_layers)

        #Counts prediction
        gap_combined_conv = kl.GlobalAvgPool1D()(combined_conv)
        count_out = kl.Reshape((-1,), name="task0_logcount")(
            RevCompConv1D(filters=1, kernel_size=1)(
              kl.Reshape((1,-1))(kl.concatenate([
                  #concatenation of the bias layer both before and after
                  # is needed for rc symmetry
                  kl.Lambda(lambda x: x[:, ::-1])(bias_counts_input),
                  gap_combined_conv,
                  bias_counts_input], axis=-1))))

        profile_out_prebias = RevCompConv1D(
                               filters=1,
                               kernel_size=self.outconv_kernel_size,
                               padding='valid')(combined_conv)
        profile_out = RevCompConv1D(
            filters=1, kernel_size=1, name="task0_profile")(
                    kl.concatenate([
                        #concatenation of the bias layer both before and after
                        # is needed for rc symmetry
                        kl.Lambda(lambda x: x[:, :, ::-1])(bias_profile_input),
                        profile_out_prebias,
                        bias_profile_input], axis=-1))

        model = keras.models.Model(
          inputs=[inp, bias_counts_input, bias_profile_input],
          outputs=[count_out, profile_out])
        model.compile(keras.optimizers.Adam(lr=self.lr),
                      loss=['mse', MultichannelMultinomialNLL(2)],
                      loss_weights=[self.c_task_weight, 1])
        return model

# %%
seq_len = 546
modelwrapper = RcBPnetArch(
    input_seq_len=seq_len, c_task_weight=250,
    filters=25,
    n_dil_layers=6,
    conv1_kernel_size=21,
    dil_kernel_size=3,
    outconv_kernel_size=50,
    lr=0.001)
out_pred_len = modelwrapper.get_output_profile_len()
print(out_pred_len, seq_len-out_pred_len)
# Out:
# 225 321

# %%
pos_neg_smooth_log_counts =\
  coordstovals.bigwig.PosAndNegSmoothWindowCollapsedLogCounts(
        pos_strand_bigwig_path="/users/amr1/pho4/data/ctl_chipexo/chipexo.pos_strand.bw",
        neg_strand_bigwig_path="/users/amr1/pho4/data/ctl_chipexo/chipexo.neg_strand.bw",
        counts_mode_name="control_logcount",
        profile_mode_name="control_profile",
        center_size_to_use=out_pred_len,
        smoothing_windows=[1,50])
inputs_coordstovals = coordstovals.core.CoordsToValsJoiner(
    coordstovals_list=[
      coordbased.coordstovals.fasta.PyfaidxCoordsToVals(
        genome_fasta_path="/users/amr1/pho4/data/genome/sacCer3.genome.fa",
        mode_name="sequence",
        center_size_to_use=seq_len),
      pos_neg_smooth_log_counts])

targets_coordstovals = coordstovals.bigwig.PosAndNegSeparateLogCounts(
    pos_strand_bigwig_path="/users/amr1/pho4/data/limited_conditions/cbf1_nit/cbf1.nit.pos.bigwig",
    neg_strand_bigwig_path="/users/amr1/pho4/data/limited_conditions/cbf1_nit/cbf1.nit.neg.bigwig",
    counts_mode_name="task0_logcount",
    profile_mode_name="task0_profile",
    center_size_to_use=out_pred_len)

keras_train_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
      bed_file="/users/amr1/pho4/data/limited_conditions/train_1000_around_eth_cbf1.bed.gz",
      coord_batch_transformer=
          coordbatchtransformers.ReverseComplementAugmenter().chain(
          coordbatchtransformers.UniformJitter(
              maxshift=200, chromsizes_file="/users/amr1/pho4/data/genome/sacCer3.chrom.sizes")),
      batch_size=64,
      shuffle_before_epoch=True, 
      seed=1234),
    inputs_coordstovals=inputs_coordstovals,
    targets_coordstovals=targets_coordstovals)

keras_valid_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
            bed_file="/users/amr1/pho4/data/limited_conditions/valid_1000_around_eth_cbf1.bed.gz",
            batch_size=64,
            shuffle_before_epoch=False, 
            seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)

thebatch = keras_train_batch_generator[0]
for tupleidx,tupleentry in enumerate(thebatch):
  print("Tuple entry",tupleidx)
  for key in tupleentry:
    print(key, tupleentry[key].shape)
# Out:
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Tuple entry 0
# sequence (128, 546, 4)
# control_logcount (128,)
# control_profile (128, 225, 2)
# Tuple entry 1
# task0_logcount (128, 2)
# task0_profile (128, 225, 2)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="3"

model = modelwrapper.get_keras_model()
print(model.summary())
early_stopping_callback = keras.callbacks.EarlyStopping(
                          patience=25, restore_best_weights=True)
loss_history = model.fit_generator(keras_train_batch_generator,
                  epochs=500,
                  validation_data=keras_valid_batch_generator,
                  callbacks=[early_stopping_callback])
model.set_weights(early_stopping_callback.best_weights)
# Out:
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# [<tf.Tensor 'lambda_1/strided_slice:0' shape=(?, 522, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_2/Relu:0' shape=(?, 522, 50) dtype=float32>]
# [<tf.Tensor 'lambda_2/strided_slice:0' shape=(?, 514, 50) dtype=float32>, <tf.Tensor 'lambda_3/strided_slice:0' shape=(?, 514, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_3/Relu:0' shape=(?, 514, 50) dtype=float32>]
# [<tf.Tensor 'lambda_4/strided_slice:0' shape=(?, 498, 50) dtype=float32>, <tf.Tensor 'lambda_5/strided_slice:0' shape=(?, 498, 50) dtype=float32>, <tf.Tensor 'lambda_6/strided_slice:0' shape=(?, 498, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_4/Relu:0' shape=(?, 498, 50) dtype=float32>]
# [<tf.Tensor 'lambda_7/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'lambda_8/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'lambda_9/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'lambda_10/strided_slice:0' shape=(?, 466, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_5/Relu:0' shape=(?, 466, 50) dtype=float32>]
# [<tf.Tensor 'lambda_11/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_12/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_13/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_14/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'lambda_15/strided_slice:0' shape=(?, 402, 50) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_6/Relu:0' shape=(?, 402, 50) dtype=float32>]
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From <ipython-input-2-dbf16efbe78d>:28: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           (None, 546, 4)       0
# __________________________________________________________________________________________________
# rev_comp_conv1d_1 (RevCompConv1 (None, 526, 50)      2125        sequence[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 522, 50)      0           rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_2 (RevCompConv1 (None, 522, 50)      3775        rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 522, 50)      0           lambda_1[0][0]
#                                                                  rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 514, 50)      0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 514, 50)      0           rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_3 (RevCompConv1 (None, 514, 50)      3775        average_1[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 514, 50)      0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 498, 50)      0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 498, 50)      0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 498, 50)      0           rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_4 (RevCompConv1 (None, 498, 50)      3775        average_2[0][0]
# __________________________________________________________________________________________________
# average_3 (Average)             (None, 498, 50)      0           lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 466, 50)      0           lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 466, 50)      0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 466, 50)      0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 466, 50)      0           rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_5 (RevCompConv1 (None, 466, 50)      3775        average_3[0][0]
# __________________________________________________________________________________________________
# average_4 (Average)             (None, 466, 50)      0           lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 402, 50)      0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 402, 50)      0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 402, 50)      0           lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 402, 50)      0           lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 402, 50)      0           rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_6 (RevCompConv1 (None, 402, 50)      3775        average_4[0][0]
# __________________________________________________________________________________________________
# average_5 (Average)             (None, 402, 50)      0           lambda_11[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
#                                                                  rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 274, 50)      0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 274, 50)      0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 274, 50)      0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 274, 50)      0           lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 274, 50)      0           lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 274, 50)      0           rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_7 (RevCompConv1 (None, 274, 50)      3775        average_5[0][0]
# __________________________________________________________________________________________________
# control_logcount (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# average_6 (Average)             (None, 274, 50)      0           lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_21[0][0]
#                                                                  rev_comp_conv1d_7[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           control_logcount[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 50)           0           average_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 52)           0           lambda_22[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  control_logcount[0][0]
# __________________________________________________________________________________________________
# control_profile (InputLayer)    (None, 225, 2)       0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 52)        0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 225, 2)       0           control_profile[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_9 (RevCompConv1 (None, 225, 2)       2501        average_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_8 (RevCompConv1 (None, 1, 2)         53          reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 225, 6)       0           lambda_23[0][0]
#                                                                  rev_comp_conv1d_9[0][0]
#                                                                  control_profile[0][0]
# __________________________________________________________________________________________________
# task0_logcount (Reshape)        (None, 2)            0           rev_comp_conv1d_8[0][0]
# __________________________________________________________________________________________________
# task0_profile (RevCompConv1D)   (None, 225, 2)       7           concatenate_2[0][0]
# ==================================================================================================
# Total params: 27,336
# Trainable params: 27,336
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/500
# 11/11 [==============================] - 16s 1s/step - loss: 1406.7498 - task0_logcount_loss: 4.7831 - task0_profile_loss: 210.9724 - val_loss: 659.1976 - val_task0_logcount_loss: 1.7347 - val_task0_profile_loss: 225.5325
# Epoch 2/500
# 11/11 [==============================] - 1s 114ms/step - loss: 590.3910 - task0_logcount_loss: 1.5393 - task0_profile_loss: 205.5687 - val_loss: 726.4929 - val_task0_logcount_loss: 2.0124 - val_task0_profile_loss: 223.3843
# Epoch 3/500
# 11/11 [==============================] - 2s 151ms/step - loss: 555.3257 - task0_logcount_loss: 1.3959 - task0_profile_loss: 206.3582 - val_loss: 583.8453 - val_task0_logcount_loss: 1.4494 - val_task0_profile_loss: 221.4924
# Epoch 4/500
# 11/11 [==============================] - 2s 162ms/step - loss: 621.4276 - task0_logcount_loss: 1.5383 - task0_profile_loss: 236.8569 - val_loss: 582.5016 - val_task0_logcount_loss: 1.4503 - val_task0_profile_loss: 219.9301
# Epoch 5/500
# 11/11 [==============================] - 2s 151ms/step - loss: 567.5584 - task0_logcount_loss: 1.4574 - task0_profile_loss: 203.1981 - val_loss: 591.3761 - val_task0_logcount_loss: 1.4920 - val_task0_profile_loss: 218.3772
# Epoch 6/500
# 11/11 [==============================] - 2s 159ms/step - loss: 560.0225 - task0_logcount_loss: 1.3960 - task0_profile_loss: 211.0197 - val_loss: 574.0113 - val_task0_logcount_loss: 1.4276 - val_task0_profile_loss: 217.1021
# Epoch 7/500
# 11/11 [==============================] - 2s 151ms/step - loss: 561.2648 - task0_logcount_loss: 1.4032 - task0_profile_loss: 210.4666 - val_loss: 575.4079 - val_task0_logcount_loss: 1.4376 - val_task0_profile_loss: 216.0018
# Epoch 8/500
# 11/11 [==============================] - 2s 152ms/step - loss: 535.4769 - task0_logcount_loss: 1.3382 - task0_profile_loss: 200.9323 - val_loss: 604.7956 - val_task0_logcount_loss: 1.5591 - val_task0_profile_loss: 215.0196
# Epoch 9/500
# 11/11 [==============================] - 2s 156ms/step - loss: 530.5995 - task0_logcount_loss: 1.3155 - task0_profile_loss: 201.7217 - val_loss: 570.2999 - val_task0_logcount_loss: 1.4250 - val_task0_profile_loss: 214.0504
# Epoch 10/500
# 11/11 [==============================] - 2s 148ms/step - loss: 520.8545 - task0_logcount_loss: 1.3302 - task0_profile_loss: 188.2965 - val_loss: 622.7877 - val_task0_logcount_loss: 1.6382 - val_task0_profile_loss: 213.2317
# Epoch 11/500
# 11/11 [==============================] - 2s 167ms/step - loss: 585.2361 - task0_logcount_loss: 1.4764 - task0_profile_loss: 216.1328 - val_loss: 567.9473 - val_task0_logcount_loss: 1.4229 - val_task0_profile_loss: 212.2244
# Epoch 12/500
# 11/11 [==============================] - 2s 161ms/step - loss: 522.5674 - task0_logcount_loss: 1.3330 - task0_profile_loss: 189.3118 - val_loss: 599.9975 - val_task0_logcount_loss: 1.5547 - val_task0_profile_loss: 211.3260
# Epoch 13/500
# 11/11 [==============================] - 2s 163ms/step - loss: 564.8357 - task0_logcount_loss: 1.4566 - task0_profile_loss: 200.6927 - val_loss: 578.3998 - val_task0_logcount_loss: 1.4714 - val_task0_profile_loss: 210.5529
# Epoch 14/500
# 11/11 [==============================] - 2s 164ms/step - loss: 563.2189 - task0_logcount_loss: 1.4225 - task0_profile_loss: 207.5994 - val_loss: 567.7621 - val_task0_logcount_loss: 1.4320 - val_task0_profile_loss: 209.7675
# Epoch 15/500
# 11/11 [==============================] - 2s 151ms/step - loss: 545.7283 - task0_logcount_loss: 1.3773 - task0_profile_loss: 201.4119 - val_loss: 568.0870 - val_task0_logcount_loss: 1.4366 - val_task0_profile_loss: 208.9382
# Epoch 16/500
# 11/11 [==============================] - 2s 148ms/step - loss: 543.6223 - task0_logcount_loss: 1.3744 - task0_profile_loss: 200.0270 - val_loss: 571.1298 - val_task0_logcount_loss: 1.4517 - val_task0_profile_loss: 208.1943
# Epoch 17/500
# 11/11 [==============================] - 2s 160ms/step - loss: 533.1609 - task0_logcount_loss: 1.3879 - task0_profile_loss: 186.1947 - val_loss: 571.6113 - val_task0_logcount_loss: 1.4571 - val_task0_profile_loss: 207.3285
# Epoch 18/500
# 11/11 [==============================] - 2s 168ms/step - loss: 547.7610 - task0_logcount_loss: 1.4139 - task0_profile_loss: 194.2964 - val_loss: 561.8571 - val_task0_logcount_loss: 1.4214 - val_task0_profile_loss: 206.5013
# Epoch 19/500
# 11/11 [==============================] - 2s 160ms/step - loss: 528.2141 - task0_logcount_loss: 1.3733 - task0_profile_loss: 184.8807 - val_loss: 575.0925 - val_task0_logcount_loss: 1.4774 - val_task0_profile_loss: 205.7543
# Epoch 20/500
# 11/11 [==============================] - 2s 171ms/step - loss: 526.2414 - task0_logcount_loss: 1.3340 - task0_profile_loss: 192.7515 - val_loss: 581.7207 - val_task0_logcount_loss: 1.5071 - val_task0_profile_loss: 204.9447
# Epoch 21/500
# 11/11 [==============================] - 2s 183ms/step - loss: 510.0565 - task0_logcount_loss: 1.2923 - task0_profile_loss: 186.9901 - val_loss: 562.5685 - val_task0_logcount_loss: 1.4337 - val_task0_profile_loss: 204.1506
# Epoch 22/500
# 11/11 [==============================] - 2s 153ms/step - loss: 553.5912 - task0_logcount_loss: 1.4466 - task0_profile_loss: 191.9380 - val_loss: 558.3161 - val_task0_logcount_loss: 1.4200 - val_task0_profile_loss: 203.3153
# Epoch 23/500
# 11/11 [==============================] - 2s 160ms/step - loss: 513.2403 - task0_logcount_loss: 1.3105 - task0_profile_loss: 185.6032 - val_loss: 567.1334 - val_task0_logcount_loss: 1.4581 - val_task0_profile_loss: 202.6038
# Epoch 24/500
# 11/11 [==============================] - 2s 143ms/step - loss: 509.8815 - task0_logcount_loss: 1.3050 - task0_profile_loss: 183.6376 - val_loss: 602.8621 - val_task0_logcount_loss: 1.6042 - val_task0_profile_loss: 201.8215
# Epoch 25/500
# 11/11 [==============================] - 2s 159ms/step - loss: 513.1178 - task0_logcount_loss: 1.3160 - task0_profile_loss: 184.1148 - val_loss: 561.8421 - val_task0_logcount_loss: 1.4430 - val_task0_profile_loss: 201.0942
# Epoch 26/500
# 11/11 [==============================] - 2s 158ms/step - loss: 547.2840 - task0_logcount_loss: 1.4112 - task0_profile_loss: 194.4744 - val_loss: 574.6518 - val_task0_logcount_loss: 1.4972 - val_task0_profile_loss: 200.3493
# Epoch 27/500
# 11/11 [==============================] - 2s 149ms/step - loss: 529.5217 - task0_logcount_loss: 1.4123 - task0_profile_loss: 176.4528 - val_loss: 653.5042 - val_task0_logcount_loss: 1.8159 - val_task0_profile_loss: 199.5197
# Epoch 28/500
# 11/11 [==============================] - 2s 161ms/step - loss: 558.1496 - task0_logcount_loss: 1.5090 - task0_profile_loss: 180.8970 - val_loss: 576.4875 - val_task0_logcount_loss: 1.5109 - val_task0_profile_loss: 198.7645
# Epoch 29/500
# 11/11 [==============================] - 2s 160ms/step - loss: 523.9037 - task0_logcount_loss: 1.3586 - task0_profile_loss: 184.2613 - val_loss: 553.8264 - val_task0_logcount_loss: 1.4233 - val_task0_profile_loss: 198.0009
# Epoch 30/500
# 11/11 [==============================] - 2s 163ms/step - loss: 498.4651 - task0_logcount_loss: 1.2863 - task0_profile_loss: 176.8842 - val_loss: 566.0953 - val_task0_logcount_loss: 1.4753 - val_task0_profile_loss: 197.2730
# Epoch 31/500
# 11/11 [==============================] - 2s 154ms/step - loss: 519.9941 - task0_logcount_loss: 1.3576 - task0_profile_loss: 180.6024 - val_loss: 571.0970 - val_task0_logcount_loss: 1.4985 - val_task0_profile_loss: 196.4692
# Epoch 32/500
# 11/11 [==============================] - 2s 158ms/step - loss: 515.3461 - task0_logcount_loss: 1.3332 - task0_profile_loss: 182.0500 - val_loss: 558.8601 - val_task0_logcount_loss: 1.4525 - val_task0_profile_loss: 195.7439
# Epoch 33/500
# 11/11 [==============================] - 2s 173ms/step - loss: 488.9607 - task0_logcount_loss: 1.2662 - task0_profile_loss: 172.4063 - val_loss: 558.4428 - val_task0_logcount_loss: 1.4539 - val_task0_profile_loss: 194.9684
# Epoch 34/500
# 11/11 [==============================] - 2s 159ms/step - loss: 554.2349 - task0_logcount_loss: 1.4610 - task0_profile_loss: 188.9756 - val_loss: 558.2754 - val_task0_logcount_loss: 1.4561 - val_task0_profile_loss: 194.2574
# Epoch 35/500
# 11/11 [==============================] - 2s 154ms/step - loss: 524.1313 - task0_logcount_loss: 1.3747 - task0_profile_loss: 180.4626 - val_loss: 548.6745 - val_task0_logcount_loss: 1.4211 - val_task0_profile_loss: 193.4003
# Epoch 36/500
# 11/11 [==============================] - 2s 150ms/step - loss: 502.0663 - task0_logcount_loss: 1.3221 - task0_profile_loss: 171.5387 - val_loss: 547.9723 - val_task0_logcount_loss: 1.4212 - val_task0_profile_loss: 192.6606
# Epoch 37/500
# 11/11 [==============================] - 2s 153ms/step - loss: 500.9435 - task0_logcount_loss: 1.3398 - task0_profile_loss: 166.0009 - val_loss: 619.8625 - val_task0_logcount_loss: 1.7120 - val_task0_profile_loss: 191.8593
# Epoch 38/500
# 11/11 [==============================] - 2s 152ms/step - loss: 533.8465 - task0_logcount_loss: 1.4193 - task0_profile_loss: 179.0111 - val_loss: 554.0932 - val_task0_logcount_loss: 1.4515 - val_task0_profile_loss: 191.2194
# Epoch 39/500
# 11/11 [==============================] - 2s 158ms/step - loss: 493.2965 - task0_logcount_loss: 1.2878 - task0_profile_loss: 171.3557 - val_loss: 545.3555 - val_task0_logcount_loss: 1.4207 - val_task0_profile_loss: 190.1875
# Epoch 40/500
# 11/11 [==============================] - 2s 173ms/step - loss: 494.2376 - task0_logcount_loss: 1.3014 - task0_profile_loss: 168.8762 - val_loss: 552.7651 - val_task0_logcount_loss: 1.4532 - val_task0_profile_loss: 189.4591
# Epoch 41/500
# 11/11 [==============================] - 2s 161ms/step - loss: 503.2518 - task0_logcount_loss: 1.3342 - task0_profile_loss: 169.7068 - val_loss: 552.9946 - val_task0_logcount_loss: 1.4569 - val_task0_profile_loss: 188.7775
# Epoch 42/500
# 11/11 [==============================] - 2s 151ms/step - loss: 511.0097 - task0_logcount_loss: 1.3495 - task0_profile_loss: 173.6330 - val_loss: 572.1370 - val_task0_logcount_loss: 1.5362 - val_task0_profile_loss: 188.0988
# Epoch 43/500
# 11/11 [==============================] - 2s 168ms/step - loss: 501.3009 - task0_logcount_loss: 1.3358 - task0_profile_loss: 167.3526 - val_loss: 542.5644 - val_task0_logcount_loss: 1.4210 - val_task0_profile_loss: 187.3153
# Epoch 44/500
# 11/11 [==============================] - 2s 160ms/step - loss: 494.2738 - task0_logcount_loss: 1.3112 - task0_profile_loss: 166.4681 - val_loss: 543.7090 - val_task0_logcount_loss: 1.4287 - val_task0_profile_loss: 186.5379
# Epoch 45/500
# 11/11 [==============================] - 2s 163ms/step - loss: 532.1265 - task0_logcount_loss: 1.4233 - task0_profile_loss: 176.3134 - val_loss: 541.9613 - val_task0_logcount_loss: 1.4251 - val_task0_profile_loss: 185.6906
# Epoch 46/500
# 11/11 [==============================] - 2s 168ms/step - loss: 492.1265 - task0_logcount_loss: 1.3291 - task0_profile_loss: 159.8453 - val_loss: 607.0574 - val_task0_logcount_loss: 1.6885 - val_task0_profile_loss: 184.9339
# Epoch 47/500
# 11/11 [==============================] - 2s 165ms/step - loss: 518.0415 - task0_logcount_loss: 1.3939 - task0_profile_loss: 169.5702 - val_loss: 539.3675 - val_task0_logcount_loss: 1.4207 - val_task0_profile_loss: 184.2033
# Epoch 48/500
# 11/11 [==============================] - 2s 160ms/step - loss: 473.4275 - task0_logcount_loss: 1.2410 - task0_profile_loss: 163.1886 - val_loss: 576.3751 - val_task0_logcount_loss: 1.5713 - val_task0_profile_loss: 183.5532
# Epoch 49/500
# 11/11 [==============================] - 2s 163ms/step - loss: 516.6582 - task0_logcount_loss: 1.3848 - task0_profile_loss: 170.4491 - val_loss: 545.9649 - val_task0_logcount_loss: 1.4517 - val_task0_profile_loss: 183.0292
# Epoch 50/500
# 11/11 [==============================] - 2s 152ms/step - loss: 510.0319 - task0_logcount_loss: 1.3604 - task0_profile_loss: 169.9347 - val_loss: 547.5501 - val_task0_logcount_loss: 1.4582 - val_task0_profile_loss: 182.9988
# Epoch 51/500
# 11/11 [==============================] - 2s 151ms/step - loss: 492.2071 - task0_logcount_loss: 1.3185 - task0_profile_loss: 162.5800 - val_loss: 567.4953 - val_task0_logcount_loss: 1.5392 - val_task0_profile_loss: 182.7041
# Epoch 52/500
# 11/11 [==============================] - 2s 158ms/step - loss: 478.7935 - task0_logcount_loss: 1.2811 - task0_profile_loss: 158.5121 - val_loss: 541.2544 - val_task0_logcount_loss: 1.4340 - val_task0_profile_loss: 182.7436
# Epoch 53/500
# 11/11 [==============================] - 2s 155ms/step - loss: 531.0149 - task0_logcount_loss: 1.4361 - task0_profile_loss: 171.9780 - val_loss: 550.6236 - val_task0_logcount_loss: 1.4707 - val_task0_profile_loss: 182.9433
# Epoch 54/500
# 11/11 [==============================] - 2s 153ms/step - loss: 485.3768 - task0_logcount_loss: 1.3028 - task0_profile_loss: 159.6651 - val_loss: 550.8388 - val_task0_logcount_loss: 1.4719 - val_task0_profile_loss: 182.8620
# Epoch 55/500
# 11/11 [==============================] - 2s 168ms/step - loss: 491.2386 - task0_logcount_loss: 1.3118 - task0_profile_loss: 163.2964 - val_loss: 553.1599 - val_task0_logcount_loss: 1.4814 - val_task0_profile_loss: 182.8067
# Epoch 56/500
# 11/11 [==============================] - 2s 151ms/step - loss: 475.1836 - task0_logcount_loss: 1.2681 - task0_profile_loss: 158.1481 - val_loss: 537.7675 - val_task0_logcount_loss: 1.4199 - val_task0_profile_loss: 182.7936
# Epoch 57/500
# 11/11 [==============================] - 2s 142ms/step - loss: 501.5525 - task0_logcount_loss: 1.3410 - task0_profile_loss: 166.3122 - val_loss: 544.2715 - val_task0_logcount_loss: 1.4459 - val_task0_profile_loss: 182.7839
# Epoch 58/500
# 11/11 [==============================] - 2s 157ms/step - loss: 474.9073 - task0_logcount_loss: 1.2692 - task0_profile_loss: 157.6189 - val_loss: 546.3914 - val_task0_logcount_loss: 1.4547 - val_task0_profile_loss: 182.7105
# Epoch 59/500
# 11/11 [==============================] - 2s 162ms/step - loss: 466.8070 - task0_logcount_loss: 1.2395 - task0_profile_loss: 156.9248 - val_loss: 554.8282 - val_task0_logcount_loss: 1.4886 - val_task0_profile_loss: 182.6858
# Epoch 60/500
# 11/11 [==============================] - 2s 160ms/step - loss: 487.9182 - task0_logcount_loss: 1.3007 - task0_profile_loss: 162.7317 - val_loss: 552.5732 - val_task0_logcount_loss: 1.4797 - val_task0_profile_loss: 182.6536
# Epoch 61/500
# 11/11 [==============================] - 2s 160ms/step - loss: 485.4853 - task0_logcount_loss: 1.3029 - task0_profile_loss: 159.7657 - val_loss: 537.8673 - val_task0_logcount_loss: 1.4210 - val_task0_profile_loss: 182.6229
# Epoch 62/500
# 11/11 [==============================] - 2s 161ms/step - loss: 479.2440 - task0_logcount_loss: 1.2909 - task0_profile_loss: 156.5176 - val_loss: 543.7137 - val_task0_logcount_loss: 1.4441 - val_task0_profile_loss: 182.6860
# Epoch 63/500
# 11/11 [==============================] - 2s 157ms/step - loss: 512.8599 - task0_logcount_loss: 1.3760 - task0_profile_loss: 168.8613 - val_loss: 537.7935 - val_task0_logcount_loss: 1.4202 - val_task0_profile_loss: 182.7326
# Epoch 64/500
# 11/11 [==============================] - 2s 155ms/step - loss: 510.2274 - task0_logcount_loss: 1.3744 - task0_profile_loss: 166.6245 - val_loss: 540.5401 - val_task0_logcount_loss: 1.4314 - val_task0_profile_loss: 182.6879
# Epoch 65/500
# 11/11 [==============================] - 2s 162ms/step - loss: 500.3817 - task0_logcount_loss: 1.3397 - task0_profile_loss: 165.4556 - val_loss: 548.2393 - val_task0_logcount_loss: 1.4621 - val_task0_profile_loss: 182.7117
# Epoch 66/500
# 11/11 [==============================] - 2s 162ms/step - loss: 544.3030 - task0_logcount_loss: 1.4817 - task0_profile_loss: 173.8690 - val_loss: 567.2480 - val_task0_logcount_loss: 1.5382 - val_task0_profile_loss: 182.7049
# Epoch 67/500
# 11/11 [==============================] - 2s 145ms/step - loss: 498.9773 - task0_logcount_loss: 1.3670 - task0_profile_loss: 157.2222 - val_loss: 550.2077 - val_task0_logcount_loss: 1.4703 - val_task0_profile_loss: 182.6424
# Epoch 68/500
# 11/11 [==============================] - 2s 159ms/step - loss: 491.7548 - task0_logcount_loss: 1.3261 - task0_profile_loss: 160.2360 - val_loss: 537.5548 - val_task0_logcount_loss: 1.4195 - val_task0_profile_loss: 182.6768
# Epoch 69/500
# 11/11 [==============================] - 2s 150ms/step - loss: 497.6773 - task0_logcount_loss: 1.3389 - task0_profile_loss: 162.9639 - val_loss: 544.5352 - val_task0_logcount_loss: 1.4479 - val_task0_profile_loss: 182.5648
# Epoch 70/500
# 11/11 [==============================] - 2s 164ms/step - loss: 523.0672 - task0_logcount_loss: 1.4333 - task0_profile_loss: 164.7452 - val_loss: 539.5938 - val_task0_logcount_loss: 1.4279 - val_task0_profile_loss: 182.6091
# Epoch 71/500
# 11/11 [==============================] - 2s 149ms/step - loss: 476.5090 - task0_logcount_loss: 1.2613 - task0_profile_loss: 161.1721 - val_loss: 547.4389 - val_task0_logcount_loss: 1.4591 - val_task0_profile_loss: 182.6590
# Epoch 72/500
# 11/11 [==============================] - 2s 167ms/step - loss: 484.7427 - task0_logcount_loss: 1.2857 - task0_profile_loss: 163.3298 - val_loss: 545.5264 - val_task0_logcount_loss: 1.4518 - val_task0_profile_loss: 182.5782
# Epoch 73/500
# 11/11 [==============================] - 2s 150ms/step - loss: 468.3312 - task0_logcount_loss: 1.2322 - task0_profile_loss: 160.2747 - val_loss: 552.7505 - val_task0_logcount_loss: 1.4807 - val_task0_profile_loss: 182.5713
# Epoch 74/500
# 11/11 [==============================] - 2s 161ms/step - loss: 494.4109 - task0_logcount_loss: 1.3176 - task0_profile_loss: 164.9987 - val_loss: 539.7626 - val_task0_logcount_loss: 1.4286 - val_task0_profile_loss: 182.6022
# Epoch 75/500
# 11/11 [==============================] - 2s 161ms/step - loss: 506.8107 - task0_logcount_loss: 1.3765 - task0_profile_loss: 162.6954 - val_loss: 552.2075 - val_task0_logcount_loss: 1.4788 - val_task0_profile_loss: 182.5013
# Epoch 76/500
# 11/11 [==============================] - 2s 156ms/step - loss: 499.3565 - task0_logcount_loss: 1.3287 - task0_profile_loss: 167.1918 - val_loss: 545.1383 - val_task0_logcount_loss: 1.4506 - val_task0_profile_loss: 182.4972
# Epoch 77/500
# 11/11 [==============================] - 2s 160ms/step - loss: 504.2510 - task0_logcount_loss: 1.3343 - task0_profile_loss: 170.6795 - val_loss: 545.4335 - val_task0_logcount_loss: 1.4518 - val_task0_profile_loss: 182.4882
# Epoch 78/500
# 11/11 [==============================] - 2s 147ms/step - loss: 517.5893 - task0_logcount_loss: 1.4391 - task0_profile_loss: 157.8035 - val_loss: 548.2401 - val_task0_logcount_loss: 1.4624 - val_task0_profile_loss: 182.6504
# Epoch 79/500
# 11/11 [==============================] - 2s 166ms/step - loss: 512.1284 - task0_logcount_loss: 1.4240 - task0_profile_loss: 156.1182 - val_loss: 610.7073 - val_task0_logcount_loss: 1.7136 - val_task0_profile_loss: 182.3197
# Epoch 80/500
# 11/11 [==============================] - 2s 160ms/step - loss: 522.8869 - task0_logcount_loss: 1.4149 - task0_profile_loss: 169.1666 - val_loss: 574.4947 - val_task0_logcount_loss: 1.5685 - val_task0_profile_loss: 182.3724
# Epoch 81/500
# 11/11 [==============================] - 2s 159ms/step - loss: 500.8958 - task0_logcount_loss: 1.3700 - task0_profile_loss: 158.3836 - val_loss: 545.0544 - val_task0_logcount_loss: 1.4507 - val_task0_profile_loss: 182.3757
# Epoch 82/500
# 11/11 [==============================] - 2s 151ms/step - loss: 502.2633 - task0_logcount_loss: 1.3548 - task0_profile_loss: 163.5731 - val_loss: 551.1438 - val_task0_logcount_loss: 1.4752 - val_task0_profile_loss: 182.3351
# Epoch 83/500
# 11/11 [==============================] - 2s 151ms/step - loss: 470.1798 - task0_logcount_loss: 1.2431 - task0_profile_loss: 159.4073 - val_loss: 543.7084 - val_task0_logcount_loss: 1.4455 - val_task0_profile_loss: 182.3383
# Epoch 84/500
# 11/11 [==============================] - 2s 160ms/step - loss: 489.5714 - task0_logcount_loss: 1.3015 - task0_profile_loss: 164.1993 - val_loss: 534.9923 - val_task0_logcount_loss: 1.4105 - val_task0_profile_loss: 182.3633
# Epoch 85/500
# 11/11 [==============================] - 2s 160ms/step - loss: 482.7795 - task0_logcount_loss: 1.3066 - task0_profile_loss: 156.1351 - val_loss: 544.9772 - val_task0_logcount_loss: 1.4505 - val_task0_profile_loss: 182.3498
# Epoch 86/500
# 11/11 [==============================] - 2s 151ms/step - loss: 492.0566 - task0_logcount_loss: 1.3568 - task0_profile_loss: 152.8672 - val_loss: 537.0202 - val_task0_logcount_loss: 1.4187 - val_task0_profile_loss: 182.3407
# Epoch 87/500
# 11/11 [==============================] - 2s 177ms/step - loss: 512.2984 - task0_logcount_loss: 1.3855 - task0_profile_loss: 165.9183 - val_loss: 565.6517 - val_task0_logcount_loss: 1.5338 - val_task0_profile_loss: 182.1997
# Epoch 88/500
# 11/11 [==============================] - 2s 159ms/step - loss: 474.1513 - task0_logcount_loss: 1.2670 - task0_profile_loss: 157.3897 - val_loss: 557.0102 - val_task0_logcount_loss: 1.4995 - val_task0_profile_loss: 182.1471
# Epoch 89/500
# 11/11 [==============================] - 2s 171ms/step - loss: 502.4077 - task0_logcount_loss: 1.3363 - task0_profile_loss: 168.3290 - val_loss: 534.6300 - val_task0_logcount_loss: 1.4094 - val_task0_profile_loss: 182.2792
# Epoch 90/500
# 11/11 [==============================] - 2s 163ms/step - loss: 476.2922 - task0_logcount_loss: 1.2784 - task0_profile_loss: 156.6817 - val_loss: 562.7737 - val_task0_logcount_loss: 1.5219 - val_task0_profile_loss: 182.2983
# Epoch 91/500
# 11/11 [==============================] - 2s 170ms/step - loss: 487.8131 - task0_logcount_loss: 1.3132 - task0_profile_loss: 159.5102 - val_loss: 565.4993 - val_task0_logcount_loss: 1.5330 - val_task0_profile_loss: 182.2588
# Epoch 92/500
# 11/11 [==============================] - 2s 151ms/step - loss: 480.2163 - task0_logcount_loss: 1.2851 - task0_profile_loss: 158.9311 - val_loss: 540.7634 - val_task0_logcount_loss: 1.4339 - val_task0_profile_loss: 182.2992
# Epoch 93/500
# 11/11 [==============================] - 2s 166ms/step - loss: 472.0690 - task0_logcount_loss: 1.2491 - task0_profile_loss: 159.8035 - val_loss: 574.8138 - val_task0_logcount_loss: 1.5703 - val_task0_profile_loss: 182.2286
# Epoch 94/500
# 11/11 [==============================] - 2s 150ms/step - loss: 495.9819 - task0_logcount_loss: 1.3408 - task0_profile_loss: 160.7702 - val_loss: 534.5298 - val_task0_logcount_loss: 1.4091 - val_task0_profile_loss: 182.2505
# Epoch 95/500
# 11/11 [==============================] - 2s 149ms/step - loss: 474.9973 - task0_logcount_loss: 1.2652 - task0_profile_loss: 158.6928 - val_loss: 536.4923 - val_task0_logcount_loss: 1.4174 - val_task0_profile_loss: 182.1444
# Epoch 96/500
# 11/11 [==============================] - 2s 163ms/step - loss: 491.1875 - task0_logcount_loss: 1.2928 - task0_profile_loss: 167.9754 - val_loss: 541.3785 - val_task0_logcount_loss: 1.4347 - val_task0_profile_loss: 182.7014
# Epoch 97/500
# 11/11 [==============================] - 2s 149ms/step - loss: 484.6209 - task0_logcount_loss: 1.2984 - task0_profile_loss: 160.0110 - val_loss: 532.9446 - val_task0_logcount_loss: 1.4031 - val_task0_profile_loss: 182.1772
# Epoch 98/500
# 11/11 [==============================] - 2s 151ms/step - loss: 469.2411 - task0_logcount_loss: 1.2501 - task0_profile_loss: 156.7081 - val_loss: 543.5886 - val_task0_logcount_loss: 1.4459 - val_task0_profile_loss: 182.1125
# Epoch 99/500
# 11/11 [==============================] - 2s 155ms/step - loss: 499.8004 - task0_logcount_loss: 1.3547 - task0_profile_loss: 161.1346 - val_loss: 546.4790 - val_task0_logcount_loss: 1.4575 - val_task0_profile_loss: 182.1127
# Epoch 100/500
# 11/11 [==============================] - 2s 158ms/step - loss: 505.0239 - task0_logcount_loss: 1.3455 - task0_profile_loss: 168.6562 - val_loss: 532.6211 - val_task0_logcount_loss: 1.4015 - val_task0_profile_loss: 182.2484
# Epoch 101/500
# 11/11 [==============================] - 2s 164ms/step - loss: 487.7776 - task0_logcount_loss: 1.3346 - task0_profile_loss: 154.1320 - val_loss: 580.7300 - val_task0_logcount_loss: 1.5945 - val_task0_profile_loss: 182.1062
# Epoch 102/500
# 11/11 [==============================] - 2s 159ms/step - loss: 478.6908 - task0_logcount_loss: 1.2815 - task0_profile_loss: 158.3237 - val_loss: 534.9424 - val_task0_logcount_loss: 1.4111 - val_task0_profile_loss: 182.1729
# Epoch 103/500
# 11/11 [==============================] - 2s 163ms/step - loss: 516.9961 - task0_logcount_loss: 1.3865 - task0_profile_loss: 170.3799 - val_loss: 535.8316 - val_task0_logcount_loss: 1.4150 - val_task0_profile_loss: 182.0733
# Epoch 104/500
# 11/11 [==============================] - 2s 160ms/step - loss: 481.8165 - task0_logcount_loss: 1.2876 - task0_profile_loss: 159.9287 - val_loss: 533.0493 - val_task0_logcount_loss: 1.4040 - val_task0_profile_loss: 182.0469
# Epoch 105/500
# 11/11 [==============================] - 2s 161ms/step - loss: 476.4849 - task0_logcount_loss: 1.2832 - task0_profile_loss: 155.6745 - val_loss: 532.0830 - val_task0_logcount_loss: 1.4000 - val_task0_profile_loss: 182.0868
# Epoch 106/500
# 11/11 [==============================] - 2s 158ms/step - loss: 513.8490 - task0_logcount_loss: 1.3859 - task0_profile_loss: 167.3841 - val_loss: 532.2537 - val_task0_logcount_loss: 1.4008 - val_task0_profile_loss: 182.0421
# Epoch 107/500
# 11/11 [==============================] - 2s 163ms/step - loss: 516.0535 - task0_logcount_loss: 1.4172 - task0_profile_loss: 161.7513 - val_loss: 566.4177 - val_task0_logcount_loss: 1.5372 - val_task0_profile_loss: 182.1175
# Epoch 108/500
# 11/11 [==============================] - 2s 162ms/step - loss: 471.9610 - task0_logcount_loss: 1.2663 - task0_profile_loss: 155.3972 - val_loss: 553.9809 - val_task0_logcount_loss: 1.4881 - val_task0_profile_loss: 181.9526
# Epoch 109/500
# 11/11 [==============================] - 2s 172ms/step - loss: 472.4725 - task0_logcount_loss: 1.2704 - task0_profile_loss: 154.8767 - val_loss: 531.1229 - val_task0_logcount_loss: 1.3968 - val_task0_profile_loss: 181.9273
# Epoch 110/500
# 11/11 [==============================] - 2s 150ms/step - loss: 500.8037 - task0_logcount_loss: 1.3617 - task0_profile_loss: 160.3753 - val_loss: 532.3597 - val_task0_logcount_loss: 1.4013 - val_task0_profile_loss: 182.0348
# Epoch 111/500
# 11/11 [==============================] - 2s 157ms/step - loss: 474.4571 - task0_logcount_loss: 1.2629 - task0_profile_loss: 158.7210 - val_loss: 560.8439 - val_task0_logcount_loss: 1.5157 - val_task0_profile_loss: 181.9182
# Epoch 112/500
# 11/11 [==============================] - 2s 169ms/step - loss: 499.9688 - task0_logcount_loss: 1.3384 - task0_profile_loss: 165.3613 - val_loss: 557.8243 - val_task0_logcount_loss: 1.5035 - val_task0_profile_loss: 181.9440
# Epoch 113/500
# 11/11 [==============================] - 2s 160ms/step - loss: 481.8423 - task0_logcount_loss: 1.3033 - task0_profile_loss: 156.0060 - val_loss: 538.8871 - val_task0_logcount_loss: 1.4280 - val_task0_profile_loss: 181.8837
# Epoch 114/500
# 11/11 [==============================] - 2s 150ms/step - loss: 488.7826 - task0_logcount_loss: 1.3355 - task0_profile_loss: 154.8955 - val_loss: 555.5775 - val_task0_logcount_loss: 1.4949 - val_task0_profile_loss: 181.8410
# Epoch 115/500
# 11/11 [==============================] - 2s 161ms/step - loss: 488.8272 - task0_logcount_loss: 1.3002 - task0_profile_loss: 163.7865 - val_loss: 555.4050 - val_task0_logcount_loss: 1.4941 - val_task0_profile_loss: 181.8743
# Epoch 116/500
# 11/11 [==============================] - 2s 151ms/step - loss: 506.7278 - task0_logcount_loss: 1.3553 - task0_profile_loss: 167.9098 - val_loss: 536.1251 - val_task0_logcount_loss: 1.4179 - val_task0_profile_loss: 181.6543
# Epoch 117/500
# 11/11 [==============================] - 2s 161ms/step - loss: 485.3251 - task0_logcount_loss: 1.2889 - task0_profile_loss: 163.0933 - val_loss: 532.4553 - val_task0_logcount_loss: 1.4029 - val_task0_profile_loss: 181.7411
# Epoch 118/500
# 11/11 [==============================] - 2s 163ms/step - loss: 495.9002 - task0_logcount_loss: 1.3622 - task0_profile_loss: 155.3577 - val_loss: 530.1569 - val_task0_logcount_loss: 1.3930 - val_task0_profile_loss: 181.9022
# Epoch 119/500
# 11/11 [==============================] - 2s 160ms/step - loss: 478.7016 - task0_logcount_loss: 1.2923 - task0_profile_loss: 155.6189 - val_loss: 533.9747 - val_task0_logcount_loss: 1.4088 - val_task0_profile_loss: 181.7650
# Epoch 120/500
# 11/11 [==============================] - 2s 149ms/step - loss: 490.3758 - task0_logcount_loss: 1.2986 - task0_profile_loss: 165.7230 - val_loss: 530.2229 - val_task0_logcount_loss: 1.3934 - val_task0_profile_loss: 181.8848
# Epoch 121/500
# 11/11 [==============================] - 2s 158ms/step - loss: 490.1791 - task0_logcount_loss: 1.3029 - task0_profile_loss: 164.4534 - val_loss: 531.7580 - val_task0_logcount_loss: 1.3993 - val_task0_profile_loss: 181.9283
# Epoch 122/500
# 11/11 [==============================] - 2s 166ms/step - loss: 486.8302 - task0_logcount_loss: 1.2978 - task0_profile_loss: 162.3698 - val_loss: 539.0015 - val_task0_logcount_loss: 1.4281 - val_task0_profile_loss: 181.9723
# Epoch 123/500
# 11/11 [==============================] - 2s 159ms/step - loss: 481.8262 - task0_logcount_loss: 1.2861 - task0_profile_loss: 160.2997 - val_loss: 529.7573 - val_task0_logcount_loss: 1.3912 - val_task0_profile_loss: 181.9510
# Epoch 124/500
# 11/11 [==============================] - 2s 162ms/step - loss: 472.8538 - task0_logcount_loss: 1.2565 - task0_profile_loss: 158.7312 - val_loss: 551.7321 - val_task0_logcount_loss: 1.4800 - val_task0_profile_loss: 181.7276
# Epoch 125/500
# 11/11 [==============================] - 2s 166ms/step - loss: 494.3857 - task0_logcount_loss: 1.3188 - task0_profile_loss: 164.6918 - val_loss: 552.7887 - val_task0_logcount_loss: 1.4843 - val_task0_profile_loss: 181.7192
# Epoch 126/500
# 11/11 [==============================] - 2s 151ms/step - loss: 502.6209 - task0_logcount_loss: 1.3648 - task0_profile_loss: 161.4114 - val_loss: 575.9932 - val_task0_logcount_loss: 1.5774 - val_task0_profile_loss: 181.6392
# Epoch 127/500
# 11/11 [==============================] - 2s 157ms/step - loss: 492.5875 - task0_logcount_loss: 1.3199 - task0_profile_loss: 162.6123 - val_loss: 529.1340 - val_task0_logcount_loss: 1.3893 - val_task0_profile_loss: 181.8214
# Epoch 128/500
# 11/11 [==============================] - 2s 156ms/step - loss: 490.0461 - task0_logcount_loss: 1.3138 - task0_profile_loss: 161.5888 - val_loss: 527.2970 - val_task0_logcount_loss: 1.3825 - val_task0_profile_loss: 181.6616
# Epoch 129/500
# 11/11 [==============================] - 2s 166ms/step - loss: 472.9906 - task0_logcount_loss: 1.2600 - task0_profile_loss: 157.9997 - val_loss: 537.3765 - val_task0_logcount_loss: 1.4227 - val_task0_profile_loss: 181.7043
# Epoch 130/500
# 11/11 [==============================] - 2s 166ms/step - loss: 501.7806 - task0_logcount_loss: 1.3425 - task0_profile_loss: 166.1564 - val_loss: 532.6841 - val_task0_logcount_loss: 1.4042 - val_task0_profile_loss: 181.6391
# Epoch 131/500
# 11/11 [==============================] - 2s 161ms/step - loss: 497.0812 - task0_logcount_loss: 1.3496 - task0_profile_loss: 159.6925 - val_loss: 530.8968 - val_task0_logcount_loss: 1.3962 - val_task0_profile_loss: 181.8419
# Epoch 132/500
# 11/11 [==============================] - 2s 159ms/step - loss: 488.3084 - task0_logcount_loss: 1.2994 - task0_profile_loss: 163.4511 - val_loss: 538.5233 - val_task0_logcount_loss: 1.4277 - val_task0_profile_loss: 181.6009
# Epoch 133/500
# 11/11 [==============================] - 2s 160ms/step - loss: 486.3484 - task0_logcount_loss: 1.2747 - task0_profile_loss: 167.6639 - val_loss: 525.2115 - val_task0_logcount_loss: 1.3739 - val_task0_profile_loss: 181.7290
# Epoch 134/500
# 11/11 [==============================] - 2s 160ms/step - loss: 459.2398 - task0_logcount_loss: 1.2105 - task0_profile_loss: 156.6248 - val_loss: 530.7082 - val_task0_logcount_loss: 1.3959 - val_task0_profile_loss: 181.7264
# Epoch 135/500
# 11/11 [==============================] - 2s 162ms/step - loss: 462.1884 - task0_logcount_loss: 1.2087 - task0_profile_loss: 160.0181 - val_loss: 537.4785 - val_task0_logcount_loss: 1.4234 - val_task0_profile_loss: 181.6389
# Epoch 136/500
# 11/11 [==============================] - 2s 162ms/step - loss: 499.9554 - task0_logcount_loss: 1.3379 - task0_profile_loss: 165.4855 - val_loss: 577.5250 - val_task0_logcount_loss: 1.5823 - val_task0_profile_loss: 181.9380
# Epoch 137/500
# 11/11 [==============================] - 2s 153ms/step - loss: 474.4423 - task0_logcount_loss: 1.2833 - task0_profile_loss: 153.6257 - val_loss: 532.1107 - val_task0_logcount_loss: 1.4016 - val_task0_profile_loss: 181.7219
# Epoch 138/500
# 11/11 [==============================] - 2s 156ms/step - loss: 458.1236 - task0_logcount_loss: 1.1991 - task0_profile_loss: 158.3519 - val_loss: 532.6583 - val_task0_logcount_loss: 1.4030 - val_task0_profile_loss: 181.9086
# Epoch 139/500
# ...
# Epoch 150/500
# 11/11 [==============================] - 2s 145ms/step - loss: 462.3904 - task0_logcount_loss: 1.2083 - task0_profile_loss: 160.3074 - val_loss: 531.6869 - val_task0_logcount_loss: 1.4006 - val_task0_profile_loss: 181.5299
# Epoch 151/500
# 11/11 [==============================] - 2s 151ms/step - loss: 477.6580 - task0_logcount_loss: 1.2602 - task0_profile_loss: 162.5962 - val_loss: 560.5739 - val_task0_logcount_loss: 1.5169 - val_task0_profile_loss: 181.3449
# Epoch 152/500
# 11/11 [==============================] - 2s 157ms/step - loss: 463.3333 - task0_logcount_loss: 1.2112 - task0_profile_loss: 160.5249 - val_loss: 525.2608 - val_task0_logcount_loss: 1.3753 - val_task0_profile_loss: 181.4320
# Epoch 153/500
# 11/11 [==============================] - 2s 165ms/step - loss: 464.3037 - task0_logcount_loss: 1.2223 - task0_profile_loss: 158.7265 - val_loss: 504.7000 - val_task0_logcount_loss: 1.2876 - val_task0_profile_loss: 182.7970
# Epoch 154/500
# 11/11 [==============================] - 2s 160ms/step - loss: 472.9968 - task0_logcount_loss: 1.2212 - task0_profile_loss: 167.7077 - val_loss: 498.2729 - val_task0_logcount_loss: 1.2624 - val_task0_profile_loss: 182.6773
# Epoch 155/500
# 11/11 [==============================] - 2s 164ms/step - loss: 457.5689 - task0_logcount_loss: 1.1995 - task0_profile_loss: 157.6917 - val_loss: 505.4454 - val_task0_logcount_loss: 1.2950 - val_task0_profile_loss: 181.6921
# Epoch 156/500
# 11/11 [==============================] - 2s 156ms/step - loss: 462.1252 - task0_logcount_loss: 1.1758 - task0_profile_loss: 168.1797 - val_loss: 492.7157 - val_task0_logcount_loss: 1.2394 - val_task0_profile_loss: 182.8751
# Epoch 157/500
# 11/11 [==============================] - 2s 152ms/step - loss: 479.5750 - task0_logcount_loss: 1.2711 - task0_profile_loss: 161.8013 - val_loss: 548.9384 - val_task0_logcount_loss: 1.4587 - val_task0_profile_loss: 184.2569
# Epoch 158/500
# 11/11 [==============================] - 2s 161ms/step - loss: 470.6891 - task0_logcount_loss: 1.2060 - task0_profile_loss: 169.1969 - val_loss: 489.7039 - val_task0_logcount_loss: 1.2300 - val_task0_profile_loss: 182.1958
# Epoch 159/500
# 11/11 [==============================] - 2s 149ms/step - loss: 476.3479 - task0_logcount_loss: 1.2128 - task0_profile_loss: 173.1379 - val_loss: 526.6963 - val_task0_logcount_loss: 1.3790 - val_task0_profile_loss: 181.9480
# Epoch 160/500
# 11/11 [==============================] - 2s 162ms/step - loss: 449.6669 - task0_logcount_loss: 1.1389 - task0_profile_loss: 164.9522 - val_loss: 459.4311 - val_task0_logcount_loss: 1.1126 - val_task0_profile_loss: 181.2774
# Epoch 161/500
# 11/11 [==============================] - 2s 161ms/step - loss: 463.8155 - task0_logcount_loss: 1.2088 - task0_profile_loss: 161.6255 - val_loss: 458.3815 - val_task0_logcount_loss: 1.1064 - val_task0_profile_loss: 181.7720
# Epoch 162/500
# 11/11 [==============================] - 2s 171ms/step - loss: 414.1990 - task0_logcount_loss: 1.0291 - task0_profile_loss: 156.9348 - val_loss: 442.9476 - val_task0_logcount_loss: 1.0429 - val_task0_profile_loss: 182.2140
# Epoch 163/500
# 11/11 [==============================] - 2s 155ms/step - loss: 408.3626 - task0_logcount_loss: 0.9793 - task0_profile_loss: 163.5325 - val_loss: 417.2627 - val_task0_logcount_loss: 0.9412 - val_task0_profile_loss: 181.9680
# Epoch 164/500
# 11/11 [==============================] - 2s 155ms/step - loss: 385.2265 - task0_logcount_loss: 0.8869 - task0_profile_loss: 163.4990 - val_loss: 410.3467 - val_task0_logcount_loss: 0.9130 - val_task0_profile_loss: 182.0898
# Epoch 165/500
# 11/11 [==============================] - 2s 170ms/step - loss: 377.7872 - task0_logcount_loss: 0.8407 - task0_profile_loss: 167.6052 - val_loss: 381.9555 - val_task0_logcount_loss: 0.7914 - val_task0_profile_loss: 184.1136
# Epoch 166/500
# 11/11 [==============================] - 2s 145ms/step - loss: 368.7366 - task0_logcount_loss: 0.8512 - task0_profile_loss: 155.9346 - val_loss: 365.3858 - val_task0_logcount_loss: 0.7238 - val_task0_profile_loss: 184.4319
# Epoch 167/500
# 11/11 [==============================] - 2s 152ms/step - loss: 359.0142 - task0_logcount_loss: 0.7989 - task0_profile_loss: 159.2781 - val_loss: 387.1001 - val_task0_logcount_loss: 0.8199 - val_task0_profile_loss: 182.1347
# Epoch 168/500
# 11/11 [==============================] - 2s 150ms/step - loss: 367.4007 - task0_logcount_loss: 0.8265 - task0_profile_loss: 160.7650 - val_loss: 375.1233 - val_task0_logcount_loss: 0.7731 - val_task0_profile_loss: 181.8536
# Epoch 169/500
# 11/11 [==============================] - 2s 161ms/step - loss: 348.9256 - task0_logcount_loss: 0.7634 - task0_profile_loss: 158.0766 - val_loss: 352.4485 - val_task0_logcount_loss: 0.6718 - val_task0_profile_loss: 184.4878
# Epoch 170/500
# 11/11 [==============================] - 2s 161ms/step - loss: 357.5433 - task0_logcount_loss: 0.7458 - task0_profile_loss: 171.0811 - val_loss: 348.4748 - val_task0_logcount_loss: 0.6699 - val_task0_profile_loss: 181.0055
# Epoch 171/500
# 11/11 [==============================] - 2s 150ms/step - loss: 338.0012 - task0_logcount_loss: 0.6802 - task0_profile_loss: 167.9511 - val_loss: 334.1400 - val_task0_logcount_loss: 0.6071 - val_task0_profile_loss: 182.3528
# Epoch 172/500
# 11/11 [==============================] - 2s 152ms/step - loss: 374.5625 - task0_logcount_loss: 0.8185 - task0_profile_loss: 169.9489 - val_loss: 345.4082 - val_task0_logcount_loss: 0.6550 - val_task0_profile_loss: 181.6572
# Epoch 173/500
# 11/11 [==============================] - 2s 149ms/step - loss: 323.2739 - task0_logcount_loss: 0.6471 - task0_profile_loss: 161.5028 - val_loss: 328.3948 - val_task0_logcount_loss: 0.5904 - val_task0_profile_loss: 180.7835
# Epoch 174/500
# 11/11 [==============================] - 2s 158ms/step - loss: 327.4746 - task0_logcount_loss: 0.6755 - task0_profile_loss: 158.5977 - val_loss: 330.9399 - val_task0_logcount_loss: 0.5951 - val_task0_profile_loss: 182.1703
# Epoch 175/500
# 11/11 [==============================] - 2s 164ms/step - loss: 373.6821 - task0_logcount_loss: 0.8579 - task0_profile_loss: 159.2069 - val_loss: 408.1973 - val_task0_logcount_loss: 0.9031 - val_task0_profile_loss: 182.4115
# Epoch 176/500
# 11/11 [==============================] - 2s 167ms/step - loss: 329.6626 - task0_logcount_loss: 0.6897 - task0_profile_loss: 157.2264 - val_loss: 345.0745 - val_task0_logcount_loss: 0.6573 - val_task0_profile_loss: 180.7605
# Epoch 177/500
# 11/11 [==============================] - 2s 164ms/step - loss: 350.8423 - task0_logcount_loss: 0.7534 - task0_profile_loss: 162.4812 - val_loss: 330.7760 - val_task0_logcount_loss: 0.6014 - val_task0_profile_loss: 180.4377
# Epoch 178/500
# 11/11 [==============================] - 2s 161ms/step - loss: 321.3612 - task0_logcount_loss: 0.6107 - task0_profile_loss: 168.6914 - val_loss: 335.1661 - val_task0_logcount_loss: 0.6156 - val_task0_profile_loss: 181.2647
# Epoch 179/500
# 11/11 [==============================] - ETA: 0s - loss: 337.9727 - task0_logcount_loss: 0.7053 - task0_profile_loss: 161.65 - 2s 154ms/step - loss: 333.5931 - task0_logcount_loss: 0.6830 - task0_profile_loss: 162.8373 - val_loss: 326.2479 - val_task0_logcount_loss: 0.5817 - val_task0_profile_loss: 180.8320
# Epoch 180/500
# 11/11 [==============================] - 2s 150ms/step - loss: 308.6247 - task0_logcount_loss: 0.5941 - task0_profile_loss: 160.1013 - val_loss: 327.8478 - val_task0_logcount_loss: 0.5898 - val_task0_profile_loss: 180.3888
# Epoch 181/500
# 11/11 [==============================] - 2s 158ms/step - loss: 297.2287 - task0_logcount_loss: 0.5577 - task0_profile_loss: 157.8158 - val_loss: 330.0078 - val_task0_logcount_loss: 0.5976 - val_task0_profile_loss: 180.6176
# Epoch 182/500
# 11/11 [==============================] - 2s 164ms/step - loss: 306.2325 - task0_logcount_loss: 0.6051 - task0_profile_loss: 154.9526 - val_loss: 343.4307 - val_task0_logcount_loss: 0.6476 - val_task0_profile_loss: 181.5186
# Epoch 183/500
# 11/11 [==============================] - 2s 157ms/step - loss: 317.1332 - task0_logcount_loss: 0.6049 - task0_profile_loss: 165.9207 - val_loss: 327.0862 - val_task0_logcount_loss: 0.5828 - val_task0_profile_loss: 181.3765
# Epoch 184/500
# 11/11 [==============================] - 2s 159ms/step - loss: 293.0318 - task0_logcount_loss: 0.5338 - task0_profile_loss: 159.5851 - val_loss: 324.2707 - val_task0_logcount_loss: 0.5719 - val_task0_profile_loss: 181.3053
# Epoch 185/500
# 11/11 [==============================] - 2s 170ms/step - loss: 299.8687 - task0_logcount_loss: 0.5627 - task0_profile_loss: 159.2033 - val_loss: 322.7321 - val_task0_logcount_loss: 0.5625 - val_task0_profile_loss: 182.1188
# Epoch 186/500
# 11/11 [==============================] - 2s 156ms/step - loss: 313.2670 - task0_logcount_loss: 0.6023 - task0_profile_loss: 162.6809 - val_loss: 323.0252 - val_task0_logcount_loss: 0.5681 - val_task0_profile_loss: 180.9965
# Epoch 187/500
# 11/11 [==============================] - 2s 159ms/step - loss: 295.0305 - task0_logcount_loss: 0.5584 - task0_profile_loss: 155.4413 - val_loss: 326.0887 - val_task0_logcount_loss: 0.5815 - val_task0_profile_loss: 180.7112
# Epoch 188/500
# 11/11 [==============================] - 2s 149ms/step - loss: 296.9079 - task0_logcount_loss: 0.5299 - task0_profile_loss: 164.4385 - val_loss: 353.0333 - val_task0_logcount_loss: 0.6792 - val_task0_profile_loss: 183.2229
# Epoch 189/500
# 11/11 [==============================] - 2s 158ms/step - loss: 321.7812 - task0_logcount_loss: 0.5754 - task0_profile_loss: 177.9241 - val_loss: 349.0056 - val_task0_logcount_loss: 0.6693 - val_task0_profile_loss: 181.6798
# Epoch 190/500
# 11/11 [==============================] - 2s 149ms/step - loss: 283.4517 - task0_logcount_loss: 0.5166 - task0_profile_loss: 154.2906 - val_loss: 339.6996 - val_task0_logcount_loss: 0.6318 - val_task0_profile_loss: 181.7616
# Epoch 191/500
# 11/11 [==============================] - 2s 164ms/step - loss: 303.7574 - task0_logcount_loss: 0.5728 - task0_profile_loss: 160.5512 - val_loss: 320.6466 - val_task0_logcount_loss: 0.5588 - val_task0_profile_loss: 180.9356
# Epoch 192/500
# 11/11 [==============================] - 2s 163ms/step - loss: 301.9950 - task0_logcount_loss: 0.5598 - task0_profile_loss: 162.0361 - val_loss: 322.8939 - val_task0_logcount_loss: 0.5694 - val_task0_profile_loss: 180.5368
# Epoch 193/500
# 11/11 [==============================] - 2s 160ms/step - loss: 307.9194 - task0_logcount_loss: 0.5451 - task0_profile_loss: 171.6340 - val_loss: 322.5171 - val_task0_logcount_loss: 0.5650 - val_task0_profile_loss: 181.2560
# Epoch 194/500
# 11/11 [==============================] - 2s 157ms/step - loss: 285.0591 - task0_logcount_loss: 0.4913 - task0_profile_loss: 162.2259 - val_loss: 331.9511 - val_task0_logcount_loss: 0.6062 - val_task0_profile_loss: 180.3889
# Epoch 195/500
# 11/11 [==============================] - 2s 161ms/step - loss: 290.3148 - task0_logcount_loss: 0.5304 - task0_profile_loss: 157.7061 - val_loss: 329.1323 - val_task0_logcount_loss: 0.5942 - val_task0_profile_loss: 180.5802
# Epoch 196/500
# 11/11 [==============================] - 2s 152ms/step - loss: 333.7146 - task0_logcount_loss: 0.6239 - task0_profile_loss: 177.7478 - val_loss: 329.5129 - val_task0_logcount_loss: 0.5956 - val_task0_profile_loss: 180.6081
# Epoch 197/500
# 11/11 [==============================] - 2s 158ms/step - loss: 294.9883 - task0_logcount_loss: 0.5545 - task0_profile_loss: 156.3557 - val_loss: 350.5864 - val_task0_logcount_loss: 0.6817 - val_task0_profile_loss: 180.1506
# Epoch 198/500
# 11/11 [==============================] - 2s 171ms/step - loss: 303.1853 - task0_logcount_loss: 0.5400 - task0_profile_loss: 168.1959 - val_loss: 333.6782 - val_task0_logcount_loss: 0.6146 - val_task0_profile_loss: 180.0250
# Epoch 199/500
# 11/11 [==============================] - 2s 150ms/step - loss: 296.1911 - task0_logcount_loss: 0.5144 - task0_profile_loss: 167.5924 - val_loss: 323.8971 - val_task0_logcount_loss: 0.5733 - val_task0_profile_loss: 180.5642
# Epoch 200/500
# 11/11 [==============================] - 2s 166ms/step - loss: 271.9650 - task0_logcount_loss: 0.4618 - task0_profile_loss: 156.5234 - val_loss: 325.8392 - val_task0_logcount_loss: 0.5822 - val_task0_profile_loss: 180.2812
# Epoch 201/500
# 11/11 [==============================] - 2s 159ms/step - loss: 288.6169 - task0_logcount_loss: 0.4898 - task0_profile_loss: 166.1596 - val_loss: 328.7330 - val_task0_logcount_loss: 0.5928 - val_task0_profile_loss: 180.5391
# Epoch 202/500
# 11/11 [==============================] - 2s 156ms/step - loss: 292.9898 - task0_logcount_loss: 0.5172 - task0_profile_loss: 163.6809 - val_loss: 334.5690 - val_task0_logcount_loss: 0.6178 - val_task0_profile_loss: 180.1238
# Epoch 203/500
# 11/11 [==============================] - 2s 160ms/step - loss: 278.0363 - task0_logcount_loss: 0.4692 - task0_profile_loss: 160.7388 - val_loss: 327.3326 - val_task0_logcount_loss: 0.5865 - val_task0_profile_loss: 180.6993
# Epoch 204/500
# 11/11 [==============================] - 2s 162ms/step - loss: 271.0591 - task0_logcount_loss: 0.4647 - task0_profile_loss: 154.8719 - val_loss: 327.2478 - val_task0_logcount_loss: 0.5873 - val_task0_profile_loss: 180.4175
# Epoch 205/500
# 11/11 [==============================] - 2s 162ms/step - loss: 271.4859 - task0_logcount_loss: 0.4199 - task0_profile_loss: 166.5173 - val_loss: 333.2193 - val_task0_logcount_loss: 0.6122 - val_task0_profile_loss: 180.1718
# Epoch 206/500
# 11/11 [==============================] - 2s 164ms/step - loss: 296.6819 - task0_logcount_loss: 0.5238 - task0_profile_loss: 165.7217 - val_loss: 321.4961 - val_task0_logcount_loss: 0.5610 - val_task0_profile_loss: 181.2464
# Epoch 207/500
# 11/11 [==============================] - 2s 151ms/step - loss: 279.4912 - task0_logcount_loss: 0.4712 - task0_profile_loss: 161.6996 - val_loss: 323.1461 - val_task0_logcount_loss: 0.5676 - val_task0_profile_loss: 181.2477
# Epoch 208/500
# 11/11 [==============================] - 2s 169ms/step - loss: 272.0768 - task0_logcount_loss: 0.4666 - task0_profile_loss: 155.4340 - val_loss: 326.3014 - val_task0_logcount_loss: 0.5698 - val_task0_profile_loss: 183.8629
# Epoch 209/500
# 11/11 [==============================] - 2s 152ms/step - loss: 277.4436 - task0_logcount_loss: 0.4506 - task0_profile_loss: 164.8058 - val_loss: 326.2674 - val_task0_logcount_loss: 0.5736 - val_task0_profile_loss: 182.8597
# Epoch 210/500
# 11/11 [==============================] - 2s 153ms/step - loss: 270.9201 - task0_logcount_loss: 0.4345 - task0_profile_loss: 162.2909 - val_loss: 327.7055 - val_task0_logcount_loss: 0.5828 - val_task0_profile_loss: 181.9962
# Epoch 211/500
# 11/11 [==============================] - 2s 153ms/step - loss: 279.1110 - task0_logcount_loss: 0.4508 - task0_profile_loss: 166.4229 - val_loss: 332.8502 - val_task0_logcount_loss: 0.6043 - val_task0_profile_loss: 181.7767
# Epoch 212/500
# 11/11 [==============================] - 2s 164ms/step - loss: 266.6940 - task0_logcount_loss: 0.4216 - task0_profile_loss: 161.2908 - val_loss: 328.4155 - val_task0_logcount_loss: 0.5902 - val_task0_profile_loss: 180.8655
# Epoch 213/500
# 11/11 [==============================] - 2s 143ms/step - loss: 265.1265 - task0_logcount_loss: 0.4311 - task0_profile_loss: 157.3549 - val_loss: 332.0820 - val_task0_logcount_loss: 0.6070 - val_task0_profile_loss: 180.3246
# Epoch 214/500
# 11/11 [==============================] - 2s 162ms/step - loss: 261.6252 - task0_logcount_loss: 0.4236 - task0_profile_loss: 155.7175 - val_loss: 325.1123 - val_task0_logcount_loss: 0.5771 - val_task0_profile_loss: 180.8315
# Epoch 215/500
# 11/11 [==============================] - 2s 159ms/step - loss: 269.0622 - task0_logcount_loss: 0.4523 - task0_profile_loss: 155.9946 - val_loss: 335.9061 - val_task0_logcount_loss: 0.6162 - val_task0_profile_loss: 181.8502
# Epoch 216/500
# 11/11 [==============================] - 2s 164ms/step - loss: 278.5757 - task0_logcount_loss: 0.4386 - task0_profile_loss: 168.9162 - val_loss: 343.6198 - val_task0_logcount_loss: 0.6484 - val_task0_profile_loss: 181.5111

# %%
model.save('/users/amr1/pho4/data/models/cbf1_limited_nit_model.h5')

# %%
from keras.models import load_model
from keras.utils import CustomObjectScope

with CustomObjectScope({'MultichannelMultinomialNLL': MultichannelMultinomialNLL,'RevCompConv1D': RevCompConv1D}):
    model = load_model('/users/amr1/pho4/data/models/cbf1_limited_nit_model.h5')
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           (None, 546, 4)       0
# __________________________________________________________________________________________________
# rev_comp_conv1d_1 (RevCompConv1 (None, 526, 50)      2125        sequence[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 522, 50)      0           rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_2 (RevCompConv1 (None, 522, 50)      3775        rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 522, 50)      0           lambda_1[0][0]
#                                                                  rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 514, 50)      0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 514, 50)      0           rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_3 (RevCompConv1 (None, 514, 50)      3775        average_1[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 514, 50)      0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 498, 50)      0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 498, 50)      0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 498, 50)      0           rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_4 (RevCompConv1 (None, 498, 50)      3775        average_2[0][0]
# __________________________________________________________________________________________________
# average_3 (Average)             (None, 498, 50)      0           lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 466, 50)      0           lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 466, 50)      0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 466, 50)      0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 466, 50)      0           rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_5 (RevCompConv1 (None, 466, 50)      3775        average_3[0][0]
# __________________________________________________________________________________________________
# average_4 (Average)             (None, 466, 50)      0           lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 402, 50)      0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 402, 50)      0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 402, 50)      0           lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 402, 50)      0           lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 402, 50)      0           rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_6 (RevCompConv1 (None, 402, 50)      3775        average_4[0][0]
# __________________________________________________________________________________________________
# average_5 (Average)             (None, 402, 50)      0           lambda_11[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
#                                                                  rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 274, 50)      0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 274, 50)      0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 274, 50)      0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 274, 50)      0           lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 274, 50)      0           lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 274, 50)      0           rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_7 (RevCompConv1 (None, 274, 50)      3775        average_5[0][0]
# __________________________________________________________________________________________________
# control_logcount (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# average_6 (Average)             (None, 274, 50)      0           lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_21[0][0]
#                                                                  rev_comp_conv1d_7[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           control_logcount[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 50)           0           average_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 52)           0           lambda_22[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  control_logcount[0][0]
# __________________________________________________________________________________________________
# control_profile (InputLayer)    (None, 225, 2)       0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 52)        0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 225, 2)       0           control_profile[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_9 (RevCompConv1 (None, 225, 2)       2501        average_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_8 (RevCompConv1 (None, 1, 2)         53          reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 225, 6)       0           lambda_23[0][0]
#                                                                  rev_comp_conv1d_9[0][0]
#                                                                  control_profile[0][0]
# __________________________________________________________________________________________________
# task0_logcount (Reshape)        (None, 2)            0           rev_comp_conv1d_8[0][0]
# __________________________________________________________________________________________________
# task0_profile (RevCompConv1D)   (None, 225, 2)       7           concatenate_2[0][0]
# ==================================================================================================
# Total params: 27,336
# Trainable params: 27,336
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# evaluate

# %%
o_test_preds_logcount = []
o_test_biastrack_logcount = []
o_test_biastrack_profile = []
o_test_seqs = []
o_test_preds_profile = []
o_test_labels_logcount = []
o_test_labels_profile = []

keras_test_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
            bed_file="/users/amr1/pho4/data/limited_conditions/test_1000_around_eth_cbf1.bed.gz",
            batch_size=64,
            shuffle_before_epoch=False, 
            seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)

orig_seqs = []

for batch_idx in range(len(keras_test_batch_generator)):
    batch_inputs, batch_labels = keras_test_batch_generator[batch_idx]
    o_test_seqs.append(batch_inputs['sequence']) 
    o_test_biastrack_logcount.append(batch_inputs['control_logcount'])
    o_test_biastrack_profile.append(batch_inputs['control_profile'])    
    test_preds = model.predict(batch_inputs)
    o_test_preds_logcount.append(test_preds[0])
    o_test_preds_profile.append(test_preds[1])
    o_test_labels_logcount.append(batch_labels['task0_logcount'])
    o_test_labels_profile.append(batch_labels['task0_profile'])
o_test_biastrack_logcount = np.concatenate(o_test_biastrack_logcount, axis=0)
o_test_biastrack_profile = np.concatenate(o_test_biastrack_profile,axis=0)
o_test_seqs = np.concatenate(o_test_seqs,axis=0)
o_test_preds_logcount = np.concatenate(o_test_preds_logcount, axis=0)
o_test_preds_profile = np.concatenate(o_test_preds_profile, axis=0)
o_test_labels_logcount = np.concatenate(o_test_labels_logcount, axis=0)
o_test_labels_profile = np.concatenate(o_test_labels_profile, axis=0)

from matplotlib import pyplot as plt
from scipy.stats import spearmanr

o_test_labels_logtotalcount = np.log(np.sum(np.exp(o_test_labels_logcount) - 1,axis=-1) + 1)

plt.scatter(o_test_biastrack_logcount, o_test_labels_logtotalcount, alpha=0.1)
plt.xlabel("Bias track log counts")
plt.ylabel("True log total counts")
plt.plot([np.min(o_test_biastrack_logcount), np.max(o_test_biastrack_logcount)],
         [np.min(o_test_biastrack_logcount), np.max(o_test_biastrack_logcount)],
         color="black")
plt.show()
print(spearmanr(o_test_biastrack_logcount, o_test_labels_logtotalcount))


#do a scatterplot of total count predictions
plt.scatter(o_test_preds_logcount[:,0], o_test_labels_logcount[:,0], alpha=0.1)
plt.xlabel("Predicted log counts - Forward Strand")
plt.ylabel("True log counts - Forward Strand")
plt.plot([np.min(o_test_preds_logcount[:,0]), np.max(o_test_preds_logcount[:,0])],
         [np.min(o_test_preds_logcount[:,0]), np.max(o_test_preds_logcount[:,0])],
         color="black")
plt.show()
print(spearmanr(o_test_preds_logcount[:,0], o_test_labels_logcount[:,0]))

plt.scatter(o_test_preds_logcount[:,1], o_test_labels_logcount[:,1], alpha=0.1)
plt.xlabel("Predicted log counts - Reverse Strand")
plt.ylabel("True log counts - Reverse Strand")
plt.plot([np.min(o_test_preds_logcount[:,1]), np.max(o_test_preds_logcount[:,1])],
         [np.min(o_test_preds_logcount[:,1]), np.max(o_test_preds_logcount[:,1])],
         color="black")
plt.show()
print(spearmanr(o_test_preds_logcount[:,1], o_test_labels_logcount[:,1]))
# Out:
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# SpearmanrResult(correlation=0.0566158490800022, pvalue=0.5550522496859907)
# SpearmanrResult(correlation=0.7875507242687877, pvalue=1.167026974965616e-24)
# SpearmanrResult(correlation=0.7704536038420559, pvalue=4.796162887687618e-23)

# %%
# %matplotlib inline

o_train_preds_logcount = []
o_train_biastrack_logcount = []
o_train_biastrack_profile = []
o_train_seqs = []
o_train_preds_profile = []
o_train_labels_logcount = []
o_train_labels_profile = []

orig_seqs = []

for batch_idx in range(len(keras_train_batch_generator)):
    batch_inputs, batch_labels = keras_train_batch_generator[batch_idx]
    o_train_seqs.append(batch_inputs['sequence']) 
    o_train_biastrack_logcount.append(batch_inputs['control_logcount'])
    o_train_biastrack_profile.append(batch_inputs['control_profile'])    
    train_preds = model.predict(batch_inputs)
    o_train_preds_logcount.append(train_preds[0])
    o_train_preds_profile.append(train_preds[1])
    o_train_labels_logcount.append(batch_labels['task0_logcount'])
    o_train_labels_profile.append(batch_labels['task0_profile'])
o_train_biastrack_logcount = np.concatenate(o_train_biastrack_logcount, axis=0)
o_train_biastrack_profile = np.concatenate(o_train_biastrack_profile,axis=0)
o_train_seqs = np.concatenate(o_train_seqs,axis=0)
o_train_preds_logcount = np.concatenate(o_train_preds_logcount, axis=0)
o_train_preds_profile = np.concatenate(o_train_preds_profile, axis=0)
o_train_labels_logcount = np.concatenate(o_train_labels_logcount, axis=0)
o_train_labels_profile = np.concatenate(o_train_labels_profile, axis=0)

from matplotlib import pyplot as plt
from scipy.stats import spearmanr

o_train_labels_logtotalcount = np.log(np.sum(np.exp(o_train_labels_logcount) - 1,axis=-1) + 1)

plt.scatter(o_train_biastrack_logcount, o_train_labels_logtotalcount, alpha=0.1)
plt.xlabel("Bias track log counts")
plt.ylabel("True log total counts")
plt.plot([np.min(o_train_biastrack_logcount), np.max(o_train_biastrack_logcount)],
         [np.min(o_train_biastrack_logcount), np.max(o_train_biastrack_logcount)],
         color="black")
plt.show()
print(spearmanr(o_train_biastrack_logcount, o_train_labels_logtotalcount))


#do a scatterplot of total count predictions
plt.scatter(o_train_preds_logcount[:,0], o_train_labels_logcount[:,0], alpha=0.1)
plt.xlabel("Predicted log counts - Forward Strand")
plt.ylabel("True log counts - Forward Strand")
plt.plot([np.min(o_train_preds_logcount[:,0]), np.max(o_train_preds_logcount[:,0])],
         [np.min(o_train_preds_logcount[:,0]), np.max(o_train_preds_logcount[:,0])],
         color="black")
plt.show()
print(spearmanr(o_train_preds_logcount[:,0], o_train_labels_logcount[:,0]))

plt.scatter(o_train_preds_logcount[:,1], o_train_labels_logcount[:,1], alpha=0.1)
plt.xlabel("Predicted log counts - Reverse Strand")
plt.ylabel("True log counts - Reverse Strand")
plt.plot([np.min(o_train_preds_logcount[:,1]), np.max(o_train_preds_logcount[:,1])],
         [np.min(o_train_preds_logcount[:,1]), np.max(o_train_preds_logcount[:,1])],
         color="black")
plt.show()
print(spearmanr(o_train_preds_logcount[:,1], o_train_labels_logcount[:,1]))
# Out:
# SpearmanrResult(correlation=0.07669795227707785, pvalue=0.005887610834970497)
# SpearmanrResult(correlation=0.728518853280265, pvalue=1.597965620581236e-213)
# SpearmanrResult(correlation=0.7448331017334576, pvalue=3.2411974839297487e-228)

# %% [markdown]
# Interpretation

# %%
import shap
from deeplift.dinuc_shuffle import dinuc_shuffle

def combine_mult_and_diffref(mult, orig_inp, bg_data):
    to_return = []
    for l in [0]:
        projected_hypothetical_contribs = np.zeros_like(bg_data[l]).astype("float")
        assert len(orig_inp[l].shape)==2
        #At each position in the input sequence, we iterate over the one-hot encoding
        # possibilities (eg: for genomic sequence, this is ACGT i.e.
        # 1000, 0100, 0010 and 0001) and compute the hypothetical 
        # difference-from-reference in each case. We then multiply the hypothetical
        # differences-from-reference with the multipliers to get the hypothetical contributions.
        #For each of the one-hot encoding possibilities,
        # the hypothetical contributions are then summed across the ACGT axis to estimate
        # the total hypothetical contribution of each position. This per-position hypothetical
        # contribution is then assigned ("projected") onto whichever base was present in the
        # hypothetical sequence.
        #The reason this is a fast estimate of what the importance scores *would* look
        # like if different bases were present in the underlying sequence is that
        # the multipliers are computed once using the original sequence, and are not
        # computed again for each hypothetical sequence.
        for i in range(orig_inp[l].shape[-1]):
            hypothetical_input = np.zeros_like(orig_inp[l]).astype("float")
            hypothetical_input[:,i] = 1.0
            hypothetical_difference_from_reference = (hypothetical_input[None,:,:]-bg_data[l])
            hypothetical_contribs = hypothetical_difference_from_reference*mult[l]
            projected_hypothetical_contribs[:,:,i] = np.sum(hypothetical_contribs,axis=-1) 
        to_return.append(np.mean(projected_hypothetical_contribs,axis=0))
    to_return.append(np.zeros_like(orig_inp[1]))
    return to_return

def shuffle_several_times(s):
    numshuffles=20
    return [np.array([dinuc_shuffle(s[0]) for i in range(numshuffles)]),
            np.array([s[1] for i in range(numshuffles)])]

profile_model_counts_explainer = shap.explainers.deep.TFDeepExplainer(
    ([model.input[0], model.input[1]],
     tf.reduce_sum(model.outputs[0],axis=-1)),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)

#See Google slide deck for explanations
#We meannorm as per section titled "Adjustments for Softmax Layers"
# in the DeepLIFT paper
meannormed_logits = (
    model.outputs[1]-
    tf.reduce_mean(model.outputs[1],axis=1)[:,None,:])
#'stop_gradient' will prevent importance from being propagated through
# this operation; we do this because we just want to treat the post-softmax
# probabilities as 'weights' on the different logits, without having the
# network explain how the probabilities themselves were derived
#Could be worth contrasting explanations derived with and without stop_gradient
# enabled...
stopgrad_meannormed_logits = tf.stop_gradient(meannormed_logits)
softmax_out = tf.nn.softmax(stopgrad_meannormed_logits,axis=1)
#Weight the logits according to the softmax probabilities, take the sum for each
# example. This mirrors what was done for the bpnet paper.
weightedsum_meannormed_logits = tf.reduce_sum(softmax_out*meannormed_logits,
                                              axis=(1,2))
profile_model_profile_explainer = shap.explainers.deep.TFDeepExplainer(
    ([model.input[0], model.input[2]],
     weightedsum_meannormed_logits),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)
# Out:
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  StopGradient used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients

# %%
#The shap scores
post_counts_hypimps,_ = profile_model_counts_explainer.shap_values(
    [o_test_seqs, np.zeros((len(o_test_seqs), 1))],
    progress_message=10)
post_profile_hypimps,_ = profile_model_profile_explainer.shap_values(
    [o_test_seqs, np.zeros((len(o_test_seqs), out_pred_len, 2))],
    progress_message=10)

post_counts_actualimps = post_counts_hypimps*o_test_seqs
post_profile_actualimps = post_profile_hypimps*o_test_seqs
# Out:
# Done 0 examples of 111
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/shap/explainers/deep/deep_tf.py:493: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Done 10 examples of 111
# Done 20 examples of 111
# Done 30 examples of 111
# Done 40 examples of 111
# Done 50 examples of 111
# Done 60 examples of 111
# Done 70 examples of 111
# Done 80 examples of 111
# Done 90 examples of 111
# Done 100 examples of 111
# Done 110 examples of 111
# Done 0 examples of 111
# Done 10 examples of 111
# Done 20 examples of 111
# Done 30 examples of 111
# Done 40 examples of 111
# Done 50 examples of 111
# Done 60 examples of 111
# Done 70 examples of 111
# Done 80 examples of 111
# Done 90 examples of 111
# Done 100 examples of 111
# Done 110 examples of 111

# %%
from deeplift.visualization import viz_sequence
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter

sorted_test_indices = [x[0] for x in 
                       sorted(enumerate(o_test_labels_logtotalcount),
                              key=lambda x: -x[1])]

def smooth(vals):
    return np.convolve(vals, np.ones(1,)/1, mode='same')

for idx in sorted_test_indices[:10]: 
    true_profile = o_test_labels_profile[idx] 
    print("idx",idx)
    print("Counts",np.sum(true_profile,axis=0))
    print("Predcounts",np.exp(o_test_preds_logcount[idx])-1)
    
    for oneovertemp in [1.0]:
        print("oneovertemp",oneovertemp)
        print(o_test_labels_profile[idx].shape)
        print("Pred profile shape", o_test_preds_profile[idx].shape)
        pred_profile = (np.sum(o_test_labels_profile[idx], axis=0)[None,:] #total counts
                      *(np.exp(o_test_preds_profile[idx]*oneovertemp)/
                        np.sum(np.exp(o_test_preds_profile[idx]*oneovertemp),axis=0)[None,:]) )   
        plt.figure(figsize=(20,2))

        start_view = 0
        end_view = seq_len
        total_flanking = seq_len - out_pred_len
        left_flank = int(0.5*total_flanking)
        right_flank = total_flanking - left_flank
        plt.plot(np.arange(out_pred_len)+left_flank, smooth(true_profile[:,0]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, -smooth(true_profile[:,1]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, pred_profile[:,0])
        plt.plot(np.arange(out_pred_len)+left_flank, -pred_profile[:,1])
        plt.xlim(start_view,end_view)
        plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
        plt.show()

    print("counts imp")
    viz_sequence.plot_weights(post_counts_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
    print("profile imp")
    viz_sequence.plot_weights(post_profile_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
# Out:
# idx 95
# Counts [245. 254.]
# Predcounts [4250.7314 4334.9697]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 96
# Counts [222. 238.]
# Predcounts [501.70193 505.24307]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 57
# Counts [227. 224.]
# Predcounts [74.20657 78.59674]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 15
# Counts [286. 156.]
# Predcounts [150.582    76.79661]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 7
# Counts [187. 254.]
# Predcounts [ 55.775963 147.59947 ]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 39
# Counts [148. 266.]
# Predcounts [ 30.738123 100.23133 ]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 4
# Counts [168. 234.]
# Predcounts [103.30077 206.95798]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 66
# Counts [206. 170.]
# Predcounts [107.15595 104.35844]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 52
# Counts [157. 173.]
# Predcounts [145.32077 155.16422]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 22
# Counts [143. 156.]
# Predcounts [80.071724 85.59435 ]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp

# %%
for idx in sorted_test_indices[:10]: 
    true_profile = o_test_labels_profile[idx] 
    print("idx",idx)
    print("Counts",np.sum(true_profile,axis=0))
    print("Predcounts",np.exp(o_test_preds_logcount[idx])-1)
    
    for oneovertemp in [1.0]:
        print("oneovertemp",oneovertemp)
        print(o_test_labels_profile[idx].shape)
        print("Pred profile shape", o_test_preds_profile[idx].shape)
        pred_profile = (np.sum(o_test_labels_profile[idx], axis=0)[None,:] #total counts
                      *(np.exp(o_test_preds_profile[idx]*oneovertemp)/
                        np.sum(np.exp(o_test_preds_profile[idx]*oneovertemp),axis=0)[None,:]) )   
        plt.figure(figsize=(20,2))

        start_view = 220
        end_view = 325
        total_flanking = seq_len - out_pred_len
        left_flank = int(0.5*total_flanking)
        right_flank = total_flanking - left_flank
        plt.plot(np.arange(out_pred_len)+left_flank, smooth(true_profile[:,0]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, -smooth(true_profile[:,1]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, pred_profile[:,0])
        plt.plot(np.arange(out_pred_len)+left_flank, -pred_profile[:,1])
        plt.xlim(start_view,end_view)
        plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
        plt.show()

    print("counts imp")
    viz_sequence.plot_weights(post_counts_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
    print("profile imp")
    viz_sequence.plot_weights(post_profile_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
# Out:
# idx 95
# Counts [245. 254.]
# Predcounts [4250.7314 4334.9697]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 96
# Counts [222. 238.]
# Predcounts [501.70193 505.24307]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 57
# Counts [227. 224.]
# Predcounts [74.20657 78.59674]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 15
# Counts [286. 156.]
# Predcounts [150.582    76.79661]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 7
# Counts [187. 254.]
# Predcounts [ 55.775963 147.59947 ]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 39
# Counts [148. 266.]
# Predcounts [ 30.738123 100.23133 ]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 4
# Counts [168. 234.]
# Predcounts [103.30077 206.95798]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 66
# Counts [206. 170.]
# Predcounts [107.15595 104.35844]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 52
# Counts [157. 173.]
# Predcounts [145.32077 155.16422]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
# idx 22
# Counts [143. 156.]
# Predcounts [80.071724 85.59435 ]
# oneovertemp 1.0
# (225, 2)
# Pred profile shape (225, 2)
# counts imp
# profile imp
