# %% [markdown]
# Train Model

# %%
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers
# Out:
# Using TensorFlow backend.
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import numpy as np
import gzip
import keras
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter
import keras_genomics
from keras_genomics.layers.convolutional import RevCompConv1D
import keras
import keras.layers as kl
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np
from seqdataloader.batchproducers import coordbased
from seqdataloader.batchproducers.coordbased import coordstovals
from seqdataloader.batchproducers.coordbased import coordbatchproducers
from seqdataloader.batchproducers.coordbased import coordbatchtransformers

def multinomial_nll(true_counts, logits):
    """Compute the multinomial negative log-likelihood
    Args:
      true_counts: observed count values
      logits: predicted logit values
    """
    counts_per_example = tf.reduce_sum(true_counts, axis=-1)
    dist = tfp.distributions.Multinomial(total_count=counts_per_example,
                                         logits=logits)
    return (-tf.reduce_sum(dist.log_prob(true_counts)) / 
            tf.to_float(tf.shape(true_counts)[0]))


#from https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/losses.py#L87
class MultichannelMultinomialNLL(object):
    def __init__(self, n):
        self.__name__ = "MultichannelMultinomialNLL"
        self.n = n

    def __call__(self, true_counts, logits):
        for i in range(self.n):
            loss = multinomial_nll(true_counts[..., i], logits[..., i])
            if i == 0:
                total = loss
            else:
                total += loss
        return total

    def get_config(self):
        return {"n": self.n}

#If we want to avoid zero-padding, then the input seq len will be determined
# by parameters of the convolutions
class AbstractProfileModel(object):

    def get_output_profile_len(self):
        raise NotImplementedError()

    def get_model(self):
        raise NotImplementedError()

def trim_flanks_of_conv_layer(conv_layer, output_len, width_to_trim, filters):
    layer = keras.layers.Lambda(
        lambda x: x[:,
          int(0.5*(width_to_trim)):-(width_to_trim-int(0.5*(width_to_trim)))],
        output_shape=(output_len, filters))(conv_layer)
    return layer

#model architecture is based on 
#https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/basepair/models.py#L534
#The non-cli parameters are specified in:
# https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/src/chipnexus/train/seqmodel/joint-model-valid.gin
#The cli parameters are in line 165 of:
# https://docs.google.com/spreadsheets/d/1n3l2HXKSNpmNUOifD41uRzDEAgmOqXMQDxquRaz6WLg/edit#gid=0
# which seems to match https://github.com/kundajelab/basepair/blob/cda0875571066343cdf90aed031f7c51714d991a/src/chipnexus/train/seqmodel/ChIP-seq-default.gin
class RcBPnetArch(AbstractProfileModel):   

    def __init__(self, input_seq_len, c_task_weight, filters,
                       n_dil_layers, conv1_kernel_size,
                       dil_kernel_size,
                       outconv_kernel_size, lr):
        self.input_seq_len = input_seq_len
        self.c_task_weight = c_task_weight
        self.filters = filters
        self.n_dil_layers = n_dil_layers
        self.conv1_kernel_size = conv1_kernel_size
        self.dil_kernel_size = dil_kernel_size
        self.outconv_kernel_size = outconv_kernel_size
        self.lr = lr

    def get_embedding_len(self):
        embedding_len = self.input_seq_len
        embedding_len -= (self.conv1_kernel_size-1)     
        for i in range(1, self.n_dil_layers+1):
            dilation_rate = (2**i)
            embedding_len -= dilation_rate*(self.dil_kernel_size-1)
        return embedding_len

    def get_output_profile_len(self):
        embedding_len = self.get_embedding_len()
        out_profile_len = embedding_len - (self.outconv_kernel_size - 1)
        return out_profile_len

    def get_keras_model(self):

        out_pred_len = self.get_output_profile_len()

        inp = kl.Input(shape=(self.input_seq_len, 4), name='sequence')
        first_conv = RevCompConv1D(filters=self.filters,
                               kernel_size=self.conv1_kernel_size,
                               padding='valid',
                               activation='relu')(inp)
        curr_layer_size = self.input_seq_len - (self.conv1_kernel_size-1)
        bias_counts_input = kl.Input(shape=(1,), name="control_logcount")
        bias_profile_input = kl.Input(shape=(out_pred_len, 2),
                                      name="control_profile")
        prev_layers = [first_conv]
        for i in range(1, self.n_dil_layers + 1):
          dilation_rate = 2**i
          if i == 1:
              prev_sum = first_conv
          else:
              print(prev_layers)
              prev_sum = kl.merge.Average()(prev_layers)
          conv_output = RevCompConv1D(filters=self.filters,
                                  kernel_size=self.dil_kernel_size,
                                  padding='valid',
                                  activation='relu',
                                  dilation_rate=dilation_rate)(prev_sum)          
          width_to_trim = dilation_rate*(self.dil_kernel_size-1)
          curr_layer_size = (curr_layer_size - width_to_trim)
          prev_layers = [trim_flanks_of_conv_layer(
              conv_layer=x, output_len=curr_layer_size,
              width_to_trim=width_to_trim, filters=2*self.filters)
              for x in prev_layers]
          prev_layers.append(conv_output)

        combined_conv = kl.merge.Average()(prev_layers)

        #Counts prediction
        gap_combined_conv = kl.GlobalAvgPool1D()(combined_conv)
        count_out = kl.Reshape((-1,), name="task0_logcount")(
            RevCompConv1D(filters=1, kernel_size=1)(
              kl.Reshape((1,-1))(kl.concatenate([
                  #concatenation of the bias layer both before and after
                  # is needed for rc symmetry
                  kl.Lambda(lambda x: x[:, ::-1])(bias_counts_input),
                  gap_combined_conv,
                  bias_counts_input], axis=-1))))

        profile_out_prebias = RevCompConv1D(
                               filters=1,
                               kernel_size=self.outconv_kernel_size,
                               padding='valid')(combined_conv)
        profile_out = RevCompConv1D(
            filters=1, kernel_size=1, name="task0_profile")(
                    kl.concatenate([
                        #concatenation of the bias layer both before and after
                        # is needed for rc symmetry
                        kl.Lambda(lambda x: x[:, :, ::-1])(bias_profile_input),
                        profile_out_prebias,
                        bias_profile_input], axis=-1))

        model = keras.models.Model(
          inputs=[inp, bias_counts_input, bias_profile_input],
          outputs=[count_out, profile_out])
        model.compile(keras.optimizers.Adam(lr=self.lr),
                      loss=['mse', MultichannelMultinomialNLL(2)],
                      loss_weights=[self.c_task_weight, 1])
        return model

# %%
seq_len = 546
modelwrapper = RcBPnetArch(
    input_seq_len=seq_len,
    c_task_weight=550,
    filters=64,
    n_dil_layers=6,
    conv1_kernel_size=21,
    dil_kernel_size=3,
    outconv_kernel_size=75,
    lr=0.001)
out_pred_len = modelwrapper.get_output_profile_len()
print(out_pred_len, seq_len-out_pred_len)
# Out:
# 200 346

# %%
pos_neg_smooth_log_counts =\
  coordstovals.bigwig.PosAndNegSmoothWindowCollapsedLogCounts(
        pos_strand_bigwig_path="/users/amr1/pho4/data/ctl_chipexo/chipexo.pos_strand.bw",
        neg_strand_bigwig_path="/users/amr1/pho4/data/ctl_chipexo/chipexo.neg_strand.bw",
        counts_mode_name="control_logcount",
        profile_mode_name="control_profile",
        center_size_to_use=out_pred_len,
        smoothing_windows=[1,50])
inputs_coordstovals = coordstovals.core.CoordsToValsJoiner(
    coordstovals_list=[
      coordbased.coordstovals.fasta.PyfaidxCoordsToVals(
        genome_fasta_path="/users/amr1/pho4/data/genome/sacCer3.genome.fa",
        mode_name="sequence",
        center_size_to_use=seq_len),
      pos_neg_smooth_log_counts])

targets_coordstovals = coordstovals.bigwig.PosAndNegSeparateLogCounts(
    pos_strand_bigwig_path="/users/amr1/pho4/data/limited_conditions/cbf1_ana/cbf1.ana.pos.bigwig",
    neg_strand_bigwig_path="/users/amr1/pho4/data/limited_conditions/cbf1_ana/cbf1.ana.neg.bigwig",
    counts_mode_name="task0_logcount",
    profile_mode_name="task0_profile",
    center_size_to_use=out_pred_len)

keras_train_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
      bed_file="/users/amr1/pho4/data/limited_conditions/cbf1_ana/train_1000_around_summits.bed.gz",
      coord_batch_transformer=
          coordbatchtransformers.ReverseComplementAugmenter().chain(
          coordbatchtransformers.UniformJitter(
              maxshift=200, chromsizes_file="/users/amr1/pho4/data/genome/sacCer3.chrom.sizes")),
      batch_size=64,
      shuffle_before_epoch=True, 
      seed=1234),
    inputs_coordstovals=inputs_coordstovals,
    targets_coordstovals=targets_coordstovals)

keras_valid_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
            bed_file="/users/amr1/pho4/data/limited_conditions/cbf1_ana/valid_1000_around_summits.bed.gz",
            batch_size=64,
            shuffle_before_epoch=False, 
            seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)

thebatch = keras_train_batch_generator[0]
for tupleidx,tupleentry in enumerate(thebatch):
  print("Tuple entry",tupleidx)
  for key in tupleentry:
    print(key, tupleentry[key].shape)
# Out:
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# Tuple entry 0
# sequence (128, 546, 4)
# control_logcount (128,)
# control_profile (128, 200, 2)
# Tuple entry 1
# task0_logcount (128, 2)
# task0_profile (128, 200, 2)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

model = modelwrapper.get_keras_model()
print(model.summary())
early_stopping_callback = keras.callbacks.EarlyStopping(
                          patience=25, restore_best_weights=True)
loss_history = model.fit_generator(keras_train_batch_generator,
                  epochs=500,
                  validation_data=keras_valid_batch_generator,
                  callbacks=[early_stopping_callback])
model.set_weights(early_stopping_callback.best_weights)
# Out:
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# [<tf.Tensor 'lambda_1/strided_slice:0' shape=(?, 522, 128) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_2/Relu:0' shape=(?, 522, 128) dtype=float32>]
# [<tf.Tensor 'lambda_2/strided_slice:0' shape=(?, 514, 128) dtype=float32>, <tf.Tensor 'lambda_3/strided_slice:0' shape=(?, 514, 128) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_3/Relu:0' shape=(?, 514, 128) dtype=float32>]
# [<tf.Tensor 'lambda_4/strided_slice:0' shape=(?, 498, 128) dtype=float32>, <tf.Tensor 'lambda_5/strided_slice:0' shape=(?, 498, 128) dtype=float32>, <tf.Tensor 'lambda_6/strided_slice:0' shape=(?, 498, 128) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_4/Relu:0' shape=(?, 498, 128) dtype=float32>]
# [<tf.Tensor 'lambda_7/strided_slice:0' shape=(?, 466, 128) dtype=float32>, <tf.Tensor 'lambda_8/strided_slice:0' shape=(?, 466, 128) dtype=float32>, <tf.Tensor 'lambda_9/strided_slice:0' shape=(?, 466, 128) dtype=float32>, <tf.Tensor 'lambda_10/strided_slice:0' shape=(?, 466, 128) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_5/Relu:0' shape=(?, 466, 128) dtype=float32>]
# [<tf.Tensor 'lambda_11/strided_slice:0' shape=(?, 402, 128) dtype=float32>, <tf.Tensor 'lambda_12/strided_slice:0' shape=(?, 402, 128) dtype=float32>, <tf.Tensor 'lambda_13/strided_slice:0' shape=(?, 402, 128) dtype=float32>, <tf.Tensor 'lambda_14/strided_slice:0' shape=(?, 402, 128) dtype=float32>, <tf.Tensor 'lambda_15/strided_slice:0' shape=(?, 402, 128) dtype=float32>, <tf.Tensor 'rev_comp_conv1d_6/Relu:0' shape=(?, 402, 128) dtype=float32>]
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From <ipython-input-2-dbf16efbe78d>:28: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           (None, 546, 4)       0
# __________________________________________________________________________________________________
# rev_comp_conv1d_1 (RevCompConv1 (None, 526, 128)     5440        sequence[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 522, 128)     0           rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_2 (RevCompConv1 (None, 522, 128)     24640       rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 522, 128)     0           lambda_1[0][0]
#                                                                  rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 514, 128)     0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 514, 128)     0           rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_3 (RevCompConv1 (None, 514, 128)     24640       average_1[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 514, 128)     0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 498, 128)     0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 498, 128)     0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 498, 128)     0           rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_4 (RevCompConv1 (None, 498, 128)     24640       average_2[0][0]
# __________________________________________________________________________________________________
# average_3 (Average)             (None, 498, 128)     0           lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 466, 128)     0           lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 466, 128)     0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 466, 128)     0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 466, 128)     0           rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_5 (RevCompConv1 (None, 466, 128)     24640       average_3[0][0]
# __________________________________________________________________________________________________
# average_4 (Average)             (None, 466, 128)     0           lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 402, 128)     0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 402, 128)     0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 402, 128)     0           lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 402, 128)     0           lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 402, 128)     0           rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_6 (RevCompConv1 (None, 402, 128)     24640       average_4[0][0]
# __________________________________________________________________________________________________
# average_5 (Average)             (None, 402, 128)     0           lambda_11[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
#                                                                  rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 274, 128)     0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 274, 128)     0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 274, 128)     0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 274, 128)     0           lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 274, 128)     0           lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 274, 128)     0           rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_7 (RevCompConv1 (None, 274, 128)     24640       average_5[0][0]
# __________________________________________________________________________________________________
# control_logcount (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# average_6 (Average)             (None, 274, 128)     0           lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_21[0][0]
#                                                                  rev_comp_conv1d_7[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           control_logcount[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 128)          0           average_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 130)          0           lambda_22[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  control_logcount[0][0]
# __________________________________________________________________________________________________
# control_profile (InputLayer)    (None, 200, 2)       0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 130)       0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 200, 2)       0           control_profile[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_9 (RevCompConv1 (None, 200, 2)       9601        average_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_8 (RevCompConv1 (None, 1, 2)         131         reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 200, 6)       0           lambda_23[0][0]
#                                                                  rev_comp_conv1d_9[0][0]
#                                                                  control_profile[0][0]
# __________________________________________________________________________________________________
# task0_logcount (Reshape)        (None, 2)            0           rev_comp_conv1d_8[0][0]
# __________________________________________________________________________________________________
# task0_profile (RevCompConv1D)   (None, 200, 2)       7           concatenate_2[0][0]
# ==================================================================================================
# Total params: 163,019
# Trainable params: 163,019
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/500
# 10/10 [==============================] - 6s 566ms/step - loss: 105811.7183 - task0_logcount_loss: 8.2855 - task0_profile_loss: 101254.6716 - val_loss: 188285.3579 - val_task0_logcount_loss: 5.9167 - val_task0_profile_loss: 185031.1561
# Epoch 2/500
# 10/10 [==============================] - 1s 125ms/step - loss: 102992.9678 - task0_logcount_loss: 3.4081 - task0_profile_loss: 101118.4865 - val_loss: 181985.8172 - val_task0_logcount_loss: 2.9282 - val_task0_profile_loss: 180375.2960
# Epoch 3/500
# 10/10 [==============================] - 2s 161ms/step - loss: 99209.8304 - task0_logcount_loss: 2.6736 - task0_profile_loss: 97739.3651 - val_loss: 174466.5243 - val_task0_logcount_loss: 2.5243 - val_task0_profile_loss: 173078.1572
# Epoch 4/500
# 10/10 [==============================] - 2s 153ms/step - loss: 101627.8085 - task0_logcount_loss: 2.5856 - task0_profile_loss: 100205.7207 - val_loss: 168767.4517 - val_task0_logcount_loss: 2.4874 - val_task0_profile_loss: 167399.4017
# Epoch 5/500
# 10/10 [==============================] - 2s 153ms/step - loss: 108766.8342 - task0_logcount_loss: 2.6471 - task0_profile_loss: 107310.9263 - val_loss: 164155.9315 - val_task0_logcount_loss: 2.4846 - val_task0_profile_loss: 162789.4293
# Epoch 6/500
# 10/10 [==============================] - 1s 146ms/step - loss: 100151.3500 - task0_logcount_loss: 2.9502 - task0_profile_loss: 98528.7670 - val_loss: 163718.2028 - val_task0_logcount_loss: 2.4691 - val_task0_profile_loss: 162360.2217
# Epoch 7/500
# 10/10 [==============================] - 2s 154ms/step - loss: 91917.8729 - task0_logcount_loss: 3.4269 - task0_profile_loss: 90033.0825 - val_loss: 161188.7931 - val_task0_logcount_loss: 2.3973 - val_task0_profile_loss: 159870.2696
# Epoch 8/500
# 10/10 [==============================] - 2s 152ms/step - loss: 95303.6580 - task0_logcount_loss: 3.3650 - task0_profile_loss: 93452.9238 - val_loss: 156702.2178 - val_task0_logcount_loss: 2.5320 - val_task0_profile_loss: 155309.6215
# Epoch 9/500
# 10/10 [==============================] - 1s 148ms/step - loss: 96526.7377 - task0_logcount_loss: 2.6883 - task0_profile_loss: 95048.1867 - val_loss: 154165.5505 - val_task0_logcount_loss: 2.6761 - val_task0_profile_loss: 152693.7091
# Epoch 10/500
# 10/10 [==============================] - 2s 153ms/step - loss: 88903.2657 - task0_logcount_loss: 2.8090 - task0_profile_loss: 87358.2949 - val_loss: 152301.9460 - val_task0_logcount_loss: 3.2584 - val_task0_profile_loss: 150509.8114
# Epoch 11/500
# 10/10 [==============================] - 2s 155ms/step - loss: 80627.4466 - task0_logcount_loss: 2.7410 - task0_profile_loss: 79119.8967 - val_loss: 150618.4484 - val_task0_logcount_loss: 2.6455 - val_task0_profile_loss: 149163.4184
# Epoch 12/500
# 10/10 [==============================] - 1s 143ms/step - loss: 72700.4505 - task0_logcount_loss: 2.7688 - task0_profile_loss: 71177.6126 - val_loss: 148244.0974 - val_task0_logcount_loss: 2.4586 - val_task0_profile_loss: 146891.8654
# Epoch 13/500
# 10/10 [==============================] - 2s 165ms/step - loss: 73880.1643 - task0_logcount_loss: 2.6884 - task0_profile_loss: 72401.5332 - val_loss: 157230.1595 - val_task0_logcount_loss: 2.4649 - val_task0_profile_loss: 155874.4564
# Epoch 14/500
# 10/10 [==============================] - 2s 155ms/step - loss: 69420.4908 - task0_logcount_loss: 2.8363 - task0_profile_loss: 67860.5014 - val_loss: 145847.6612 - val_task0_logcount_loss: 2.4552 - val_task0_profile_loss: 144497.3198
# Epoch 15/500
# 10/10 [==============================] - 2s 165ms/step - loss: 66650.9363 - task0_logcount_loss: 2.9397 - task0_profile_loss: 65034.1009 - val_loss: 147919.4353 - val_task0_logcount_loss: 4.4710 - val_task0_profile_loss: 145460.3597
# Epoch 16/500
# 10/10 [==============================] - 2s 160ms/step - loss: 59864.2452 - task0_logcount_loss: 3.1254 - task0_profile_loss: 58145.2535 - val_loss: 131310.7734 - val_task0_logcount_loss: 4.4302 - val_task0_profile_loss: 128874.1406
# Epoch 17/500
# 10/10 [==============================] - 1s 148ms/step - loss: 65295.0552 - task0_logcount_loss: 3.5160 - task0_profile_loss: 63361.2531 - val_loss: 137411.8472 - val_task0_logcount_loss: 2.4469 - val_task0_profile_loss: 136066.0645
# Epoch 18/500
# 10/10 [==============================] - 2s 163ms/step - loss: 71211.5944 - task0_logcount_loss: 2.9300 - task0_profile_loss: 69600.0723 - val_loss: 133201.7097 - val_task0_logcount_loss: 2.3695 - val_task0_profile_loss: 131898.4660
# Epoch 19/500
# 10/10 [==============================] - 1s 146ms/step - loss: 62215.2388 - task0_logcount_loss: 2.7540 - task0_profile_loss: 60700.5443 - val_loss: 126650.3986 - val_task0_logcount_loss: 2.4500 - val_task0_profile_loss: 125302.9182
# Epoch 20/500
# 10/10 [==============================] - 2s 152ms/step - loss: 51087.1683 - task0_logcount_loss: 2.6504 - task0_profile_loss: 49629.4404 - val_loss: 121058.4072 - val_task0_logcount_loss: 2.5577 - val_task0_profile_loss: 119651.6519
# Epoch 21/500
# 10/10 [==============================] - 2s 161ms/step - loss: 54561.1806 - task0_logcount_loss: 3.0101 - task0_profile_loss: 52905.6428 - val_loss: 117204.6350 - val_task0_logcount_loss: 4.0731 - val_task0_profile_loss: 114964.4061
# Epoch 22/500
# 10/10 [==============================] - 1s 147ms/step - loss: 46285.1845 - task0_logcount_loss: 2.9477 - task0_profile_loss: 44663.9614 - val_loss: 117915.8165 - val_task0_logcount_loss: 3.2398 - val_task0_profile_loss: 116133.9471
# Epoch 23/500
# 10/10 [==============================] - 2s 153ms/step - loss: 43787.4991 - task0_logcount_loss: 3.0655 - task0_profile_loss: 42101.4695 - val_loss: 115117.9862 - val_task0_logcount_loss: 2.7347 - val_task0_profile_loss: 113613.9271
# Epoch 24/500
# 10/10 [==============================] - 2s 155ms/step - loss: 42635.2309 - task0_logcount_loss: 2.9891 - task0_profile_loss: 40991.2345 - val_loss: 109919.8588 - val_task0_logcount_loss: 2.4438 - val_task0_profile_loss: 108575.7845
# Epoch 25/500
# 10/10 [==============================] - 1s 138ms/step - loss: 19751.6150 - task0_logcount_loss: 2.6351 - task0_profile_loss: 18302.2940 - val_loss: 72560.0016 - val_task0_logcount_loss: 2.4335 - val_task0_profile_loss: 71221.5809
# Epoch 38/500
# 10/10 [==============================] - 1s 142ms/step - loss: 17657.9266 - task0_logcount_loss: 2.7022 - task0_profile_loss: 16171.7193 - val_loss: 69621.3183 - val_task0_logcount_loss: 2.7414 - val_task0_profile_loss: 68113.5636
# Epoch 39/500
# 10/10 [==============================] - 1s 148ms/step - loss: 18038.5758 - task0_logcount_loss: 2.6207 - task0_profile_loss: 16597.1682 - val_loss: 66327.0174 - val_task0_logcount_loss: 2.5572 - val_task0_profile_loss: 64920.5421
# Epoch 40/500
# 10/10 [==============================] - 2s 160ms/step - loss: 18240.7065 - task0_logcount_loss: 2.5232 - task0_profile_loss: 16852.9416 - val_loss: 64726.4490 - val_task0_logcount_loss: 2.9582 - val_task0_profile_loss: 63099.4479
# Epoch 41/500
# 10/10 [==============================] - 1s 142ms/step - loss: 17287.6060 - task0_logcount_loss: 2.5583 - task0_profile_loss: 15880.5648 - val_loss: 61947.7720 - val_task0_logcount_loss: 2.6910 - val_task0_profile_loss: 60467.7005
# Epoch 42/500
# 10/10 [==============================] - 2s 155ms/step - loss: 18427.1853 - task0_logcount_loss: 2.6760 - task0_profile_loss: 16955.3794 - val_loss: 60058.3049 - val_task0_logcount_loss: 3.1316 - val_task0_profile_loss: 58335.9173
# Epoch 43/500
# 10/10 [==============================] - 1s 143ms/step - loss: 14207.3091 - task0_logcount_loss: 2.7823 - task0_profile_loss: 12677.0175 - val_loss: 55954.2583 - val_task0_logcount_loss: 2.3738 - val_task0_profile_loss: 54648.6893
# Epoch 44/500
# 10/10 [==============================] - 2s 167ms/step - loss: 14604.6761 - task0_logcount_loss: 2.5623 - task0_profile_loss: 13195.4140 - val_loss: 54056.9908 - val_task0_logcount_loss: 2.4793 - val_task0_profile_loss: 52693.3508
# Epoch 45/500
# 10/10 [==============================] - 1s 150ms/step - loss: 13911.8289 - task0_logcount_loss: 2.6523 - task0_profile_loss: 12453.0435 - val_loss: 53005.3902 - val_task0_logcount_loss: 2.8153 - val_task0_profile_loss: 51456.9897
# Epoch 46/500
# 10/10 [==============================] - 2s 150ms/step - loss: 12157.5536 - task0_logcount_loss: 2.4240 - task0_profile_loss: 10824.3576 - val_loss: 50149.4740 - val_task0_logcount_loss: 2.7894 - val_task0_profile_loss: 48615.3321
# Epoch 47/500
# 10/10 [==============================] - 2s 157ms/step - loss: 11979.0269 - task0_logcount_loss: 2.5968 - task0_profile_loss: 10550.8128 - val_loss: 47295.6063 - val_task0_logcount_loss: 2.8615 - val_task0_profile_loss: 45721.7793
# Epoch 48/500
# 10/10 [==============================] - 2s 150ms/step - loss: 12219.0141 - task0_logcount_loss: 2.5622 - task0_profile_loss: 10809.8029 - val_loss: 45000.8676 - val_task0_logcount_loss: 2.6256 - val_task0_profile_loss: 43556.7882
# Epoch 49/500
# Epoch 74/500
# 10/10 [==============================] - 2s 157ms/step - loss: 4181.9711 - task0_logcount_loss: 2.5251 - task0_profile_loss: 2793.1433 - val_loss: 11091.8262 - val_task0_logcount_loss: 2.6939 - val_task0_profile_loss: 9610.1980
# Epoch 75/500
# 10/10 [==============================] - 2s 160ms/step - loss: 4134.8732 - task0_logcount_loss: 2.5661 - task0_profile_loss: 2723.5170 - val_loss: 10547.8198 - val_task0_logcount_loss: 2.8047 - val_task0_profile_loss: 9005.2257
# Epoch 76/500
# 10/10 [==============================] - 2s 163ms/step - loss: 4069.7934 - task0_logcount_loss: 2.5762 - task0_profile_loss: 2652.9102 - val_loss: 10014.9850 - val_task0_logcount_loss: 2.6418 - val_task0_profile_loss: 8562.0129
# Epoch 77/500
# 10/10 [==============================] - 1s 146ms/step - loss: 3965.6530 - task0_logcount_loss: 2.5502 - task0_profile_loss: 2563.0645 - val_loss: 9595.7885 - val_task0_logcount_loss: 2.7027 - val_task0_profile_loss: 8109.3190
# Epoch 78/500
# 10/10 [==============================] - 2s 158ms/step - loss: 3981.4809 - task0_logcount_loss: 2.6142 - task0_profile_loss: 2543.6594 - val_loss: 9118.1513 - val_task0_logcount_loss: 2.5507 - val_task0_profile_loss: 7715.2820
# Epoch 79/500
# 10/10 [==============================] - 2s 154ms/step - loss: 3956.9888 - task0_logcount_loss: 2.5522 - task0_profile_loss: 2553.2579 - val_loss: 8771.5710 - val_task0_logcount_loss: 2.3924 - val_task0_profile_loss: 7455.7674
# Epoch 80/500
# 10/10 [==============================] - 2s 158ms/step - loss: 3839.3930 - task0_logcount_loss: 2.5887 - task0_profile_loss: 2415.6190 - val_loss: 8652.6519 - val_task0_logcount_loss: 2.5978 - val_task0_profile_loss: 7223.8659
# Epoch 81/500
# 10/10 [==============================] - 2s 157ms/step - loss: 3874.6852 - task0_logcount_loss: 2.5735 - task0_profile_loss: 2459.2723 - val_loss: 8413.9210 - val_task0_logcount_loss: 2.7423 - val_task0_profile_loss: 6905.6406
# Epoch 82/500
# 10/10 [==============================] - 2s 150ms/step - loss: 3787.7504 - task0_logcount_loss: 2.4730 - task0_profile_loss: 2427.6089 - val_loss: 8061.7458 - val_task0_logcount_loss: 2.5395 - val_task0_profile_loss: 6664.9974
# Epoch 83/500
# 10/10 [==============================] - 2s 166ms/step - loss: 3761.2611 - task0_logcount_loss: 2.5269 - task0_profile_loss: 2371.4688 - val_loss: 7783.9564 - val_task0_logcount_loss: 2.4172 - val_task0_profile_loss: 6454.4898
# Epoch 84/500
# 10/10 [==============================] - 2s 153ms/step - loss: 3764.4143 - task0_logcount_loss: 2.6022 - task0_profile_loss: 2333.2311 - val_loss: 7704.0905 - val_task0_logcount_loss: 2.6816 - val_task0_profile_loss: 6229.2305
# Epoch 85/500
# 10/10 [==============================] - 2s 154ms/step - loss: 3766.6682 - task0_logcount_loss: 2.5621 - task0_profile_loss: 2357.5404 - val_loss: 7512.0387 - val_task0_logcount_loss: 2.6212 - val_task0_profile_loss: 6070.3596
# Epoch 110/500
# 10/10 [==============================] - 1s 145ms/step - loss: 3520.5259 - task0_logcount_loss: 2.6582 - task0_profile_loss: 2058.4938 - val_loss: 6252.1363 - val_task0_logcount_loss: 3.0386 - val_task0_profile_loss: 4580.8872
# Epoch 111/500
# 10/10 [==============================] - 2s 150ms/step - loss: 3575.3215 - task0_logcount_loss: 2.6984 - task0_profile_loss: 2091.1798 - val_loss: 5946.2768 - val_task0_logcount_loss: 2.4888 - val_task0_profile_loss: 4577.4587
# Epoch 112/500
# 10/10 [==============================] - 1s 147ms/step - loss: 3348.8111 - task0_logcount_loss: 2.5251 - task0_profile_loss: 1960.0307 - val_loss: 5829.4080 - val_task0_logcount_loss: 2.3050 - val_task0_profile_loss: 4561.6749
# Epoch 113/500
# 10/10 [==============================] - 1s 136ms/step - loss: 3435.1778 - task0_logcount_loss: 2.6417 - task0_profile_loss: 1982.2581 - val_loss: 5816.9499 - val_task0_logcount_loss: 2.3394 - val_task0_profile_loss: 4530.3006
# Epoch 114/500
# 10/10 [==============================] - 2s 157ms/step - loss: 3403.0311 - task0_logcount_loss: 2.5520 - task0_profile_loss: 1999.4264 - val_loss: 5999.6472 - val_task0_logcount_loss: 2.7224 - val_task0_profile_loss: 4502.3042
# Epoch 115/500
# 10/10 [==============================] - 1s 143ms/step - loss: 3361.7987 - task0_logcount_loss: 2.4463 - task0_profile_loss: 2016.3485 - val_loss: 5781.0404 - val_task0_logcount_loss: 2.3698 - val_task0_profile_loss: 4477.6483
# Epoch 116/500
# 10/10 [==============================] - 2s 158ms/step - loss: 3440.1094 - task0_logcount_loss: 2.5438 - task0_profile_loss: 2041.0382 - val_loss: 5763.6032 - val_task0_logcount_loss: 2.3679 - val_task0_profile_loss: 4461.2406
# Epoch 117/500
# 10/10 [==============================] - 1s 148ms/step - loss: 3436.9686 - task0_logcount_loss: 2.6247 - task0_profile_loss: 1993.3623 - val_loss: 5716.3147 - val_task0_logcount_loss: 2.3297 - val_task0_profile_loss: 4434.9932
# Epoch 118/500
# 10/10 [==============================] - 1s 130ms/step - loss: 3453.8259 - task0_logcount_loss: 2.6263 - task0_profile_loss: 2009.3842 - val_loss: 5975.1906 - val_task0_logcount_loss: 2.8327 - val_task0_profile_loss: 4417.2024
# Epoch 119/500
# 10/10 [==============================] - 2s 157ms/step - loss: 3372.9901 - task0_logcount_loss: 2.5164 - task0_profile_loss: 1988.9535 - val_loss: 5759.9782 - val_task0_logcount_loss: 2.4319 - val_task0_profile_loss: 4422.4316
# Epoch 120/500
# 10/10 [==============================] - 2s 157ms/step - loss: 3390.9758 - task0_logcount_loss: 2.6008 - task0_profile_loss: 1960.5133 - val_loss: 5726.3837 - val_task0_logcount_loss: 2.3846 - val_task0_profile_loss: 4414.8788
# Epoch 121/500
# 10/10 [==============================] - 1s 145ms/step - loss: 3298.0345 - task0_logcount_loss: 2.4457 - task0_profile_loss: 1952.9150 - val_loss: 5705.7595 - val_task0_logcount_loss: 2.3883 - val_task0_profile_loss: 4392.1707
# Epoch 122/500
# 10/10 [==============================] - 2s 158ms/step - loss: 3266.0432 - task0_logcount_loss: 2.3279 - task0_profile_loss: 1985.7126 - val_loss: 5938.3335 - val_task0_logcount_loss: 2.8724 - val_task0_profile_loss: 4358.5254
# Epoch 123/500
# 10/10 [==============================] - 2s 156ms/step - loss: 3244.6291 - task0_logcount_loss: 2.3848 - task0_profile_loss: 1933.0013 - val_loss: 5719.9936 - val_task0_logcount_loss: 2.5125 - val_task0_profile_loss: 4338.0954
# Epoch 124/500
# 10/10 [==============================] - 1s 144ms/step - loss: 3312.1016 - task0_logcount_loss: 2.4752 - task0_profile_loss: 1950.7202 - val_loss: 5627.7967 - val_task0_logcount_loss: 2.3306 - val_task0_profile_loss: 4345.9887
# Epoch 125/500
# 10/10 [==============================] - 1s 144ms/step - loss: 3356.9294 - task0_logcount_loss: 2.5491 - task0_profile_loss: 1954.9362 - val_loss: 5616.9490 - val_task0_logcount_loss: 2.2980 - val_task0_profile_loss: 4353.0604
# Epoch 126/500
# 10/10 [==============================] - 1s 150ms/step - loss: 3236.3310 - task0_logcount_loss: 2.3852 - task0_profile_loss: 1924.4675 - val_loss: 5758.3576 - val_task0_logcount_loss: 2.6170 - val_task0_profile_loss: 4318.9842
# Epoch 127/500
# 10/10 [==============================] - 2s 155ms/step - loss: 3325.4711 - task0_logcount_loss: 2.4971 - task0_profile_loss: 1952.0704 - val_loss: 5669.3724 - val_task0_logcount_loss: 2.4892 - val_task0_profile_loss: 4300.3367
# Epoch 128/500
# 10/10 [==============================] - 2s 156ms/step - loss: 3333.5564 - task0_logcount_loss: 2.4269 - task0_profile_loss: 1998.7868 - val_loss: 5573.6268 - val_task0_logcount_loss: 2.3394 - val_task0_profile_loss: 4286.9676
# Epoch 129/500
# 10/10 [==============================] - 2s 165ms/step - loss: 3329.5631 - task0_logcount_loss: 2.5340 - task0_profile_loss: 1935.8869 - val_loss: 5913.6278 - val_task0_logcount_loss: 3.0151 - val_task0_profile_loss: 4255.2997
# Epoch 130/500
# 10/10 [==============================] - 1s 149ms/step - loss: 3299.1095 - task0_logcount_loss: 2.5525 - task0_profile_loss: 1895.2591 - val_loss: 5852.8242 - val_task0_logcount_loss: 2.9252 - val_task0_profile_loss: 4243.9650
# Epoch 131/500
# 10/10 [==============================] - 2s 152ms/step - loss: 3264.6173 - task0_logcount_loss: 2.4064 - task0_profile_loss: 1941.1188 - val_loss: 5956.6257 - val_task0_logcount_loss: 3.1307 - val_task0_profile_loss: 4234.7604
# Epoch 132/500
# 10/10 [==============================] - 2s 152ms/step - loss: 3411.2827 - task0_logcount_loss: 2.6486 - task0_profile_loss: 1954.5793 - val_loss: 5621.5807 - val_task0_logcount_loss: 2.5435 - val_task0_profile_loss: 4222.6643
# Epoch 133/500
# 10/10 [==============================] - 2s 153ms/step - loss: 3256.8396 - task0_logcount_loss: 2.4577 - task0_profile_loss: 1905.1209 - val_loss: 5468.1039 - val_task0_logcount_loss: 2.2709 - val_task0_profile_loss: 4219.1136
# Epoch 134/500
# 10/10 [==============================] - 2s 153ms/step - loss: 2549.0343 - task0_logcount_loss: 1.4957 - task0_profile_loss: 1726.3763 - val_loss: 4737.7346 - val_task0_logcount_loss: 1.1529 - val_task0_profile_loss: 4103.6267
# Epoch 288/500
# 10/10 [==============================] - 2s 161ms/step - loss: 2543.4107 - task0_logcount_loss: 1.5223 - task0_profile_loss: 1706.1369 - val_loss: 4665.7444 - val_task0_logcount_loss: 1.1370 - val_task0_profile_loss: 4040.3927
# Epoch 289/500
# 10/10 [==============================] - 1s 149ms/step - loss: 2418.7789 - task0_logcount_loss: 1.3163 - task0_profile_loss: 1694.8166 - val_loss: 4850.0620 - val_task0_logcount_loss: 1.0337 - val_task0_profile_loss: 4281.5387
# Epoch 290/500
# 10/10 [==============================] - 2s 158ms/step - loss: 2389.3750 - task0_logcount_loss: 1.4071 - task0_profile_loss: 1615.4435 - val_loss: 4582.8876 - val_task0_logcount_loss: 0.9919 - val_task0_profile_loss: 4037.3365
# Epoch 291/500
# 10/10 [==============================] - 2s 154ms/step - loss: 2415.1765 - task0_logcount_loss: 1.4059 - task0_profile_loss: 1641.9498 - val_loss: 4649.4476 - val_task0_logcount_loss: 1.2238 - val_task0_profile_loss: 3976.3380
# Epoch 292/500
# 10/10 [==============================] - 1s 148ms/step - loss: 2453.0511 - task0_logcount_loss: 1.4767 - task0_profile_loss: 1640.8623 - val_loss: 4593.0394 - val_task0_logcount_loss: 1.1017 - val_task0_profile_loss: 3987.0857
# Epoch 293/500
# 10/10 [==============================] - 2s 158ms/step - loss: 2427.1792 - task0_logcount_loss: 1.3737 - task0_profile_loss: 1671.6273 - val_loss: 4575.2201 - val_task0_logcount_loss: 1.0081 - val_task0_profile_loss: 4020.7511
# Epoch 294/500
# 10/10 [==============================] - 1s 147ms/step - loss: 2372.0657 - task0_logcount_loss: 1.3678 - task0_profile_loss: 1619.7960 - val_loss: 4593.8804 - val_task0_logcount_loss: 0.9657 - val_task0_profile_loss: 4062.7614
# Epoch 295/500
# 10/10 [==============================] - 1s 142ms/step - loss: 2339.9163 - task0_logcount_loss: 1.2856 - task0_profile_loss: 1632.8166 - val_loss: 4526.2172 - val_task0_logcount_loss: 1.0412 - val_task0_profile_loss: 3953.5512
# Epoch 296/500
# 10/10 [==============================] - 1s 149ms/step - loss: 2379.4756 - task0_logcount_loss: 1.3652 - task0_profile_loss: 1628.6387 - val_loss: 4640.2698 - val_task0_logcount_loss: 0.9091 - val_task0_profile_loss: 4140.2837
# Epoch 297/500
# 10/10 [==============================] - 2s 155ms/step - loss: 2299.7536 - task0_logcount_loss: 1.2144 - task0_profile_loss: 1631.8564 - val_loss: 4935.1559 - val_task0_logcount_loss: 0.8747 - val_task0_profile_loss: 4454.0443
# Epoch 298/500
# 10/10 [==============================] - 2s 151ms/step - loss: 2482.1344 - task0_logcount_loss: 1.2490 - task0_profile_loss: 1795.2072 - val_loss: 6074.2222 - val_task0_logcount_loss: 0.9326 - val_task0_profile_loss: 5561.2932
# Epoch 299/500
# 10/10 [==============================] - 1s 145ms/step - loss: 2570.7738 - task0_logcount_loss: 1.5123 - task0_profile_loss: 1739.0158 - val_loss: 4696.7960 - val_task0_logcount_loss: 0.9553 - val_task0_profile_loss: 4171.3666
# Epoch 300/500
# 10/10 [==============================] - 2s 158ms/step - loss: 2373.8080 - task0_logcount_loss: 1.2587 - task0_profile_loss: 1681.5146 - val_loss: 4812.9714 - val_task0_logcount_loss: 1.3869 - val_task0_profile_loss: 4050.1533
# Epoch 301/500
# 10/10 [==============================] - 1s 148ms/step - loss: 2463.2023 - task0_logcount_loss: 1.4278 - task0_profile_loss: 1677.8998 - val_loss: 4711.1849 - val_task0_logcount_loss: 1.1798 - val_task0_profile_loss: 4062.3002
# Epoch 302/500
# 10/10 [==============================] - 1s 148ms/step - loss: 2440.0809 - task0_logcount_loss: 1.4526 - task0_profile_loss: 1641.1645 - val_loss: 4535.1175 - val_task0_logcount_loss: 0.8621 - val_task0_profile_loss: 4060.9531
# Epoch 303/500
# 10/10 [==============================] - 2s 152ms/step - loss: 2539.9071 - task0_logcount_loss: 1.3551 - task0_profile_loss: 1794.5891 - val_loss: 5151.5489 - val_task0_logcount_loss: 1.4910 - val_task0_profile_loss: 4331.4824
# Epoch 304/500
# 10/10 [==============================] - 1s 139ms/step - loss: 2460.8477 - task0_logcount_loss: 1.4394 - task0_profile_loss: 1669.2033 - val_loss: 4817.8603 - val_task0_logcount_loss: 1.1437 - val_task0_profile_loss: 4188.8375
# Epoch 305/500
# 10/10 [==============================] - 1s 147ms/step - loss: 2520.3761 - task0_logcount_loss: 1.4452 - task0_profile_loss: 1725.5029 - val_loss: 4790.9815 - val_task0_logcount_loss: 1.4998 - val_task0_profile_loss: 3966.1139
# Epoch 306/500
# 10/10 [==============================] - 2s 153ms/step - loss: 2574.9536 - task0_logcount_loss: 1.6906 - task0_profile_loss: 1645.1435 - val_loss: 4945.1487 - val_task0_logcount_loss: 1.2351 - val_task0_profile_loss: 4265.8395
# Epoch 307/500
# 10/10 [==============================] - 2s 155ms/step - loss: 2469.9195 - task0_logcount_loss: 1.3835 - task0_profile_loss: 1709.0164 - val_loss: 4552.5772 - val_task0_logcount_loss: 1.0168 - val_task0_profile_loss: 3993.3420
# Epoch 308/500
# 10/10 [==============================] - 1s 146ms/step - loss: 2355.5961 - task0_logcount_loss: 1.3015 - task0_profile_loss: 1639.7649 - val_loss: 4655.3809 - val_task0_logcount_loss: 0.8782 - val_task0_profile_loss: 4172.3804
# Epoch 309/500
# 10/10 [==============================] - 1s 148ms/step - loss: 2301.6929 - task0_logcount_loss: 1.2147 - task0_profile_loss: 1633.5895 - val_loss: 4535.2546 - val_task0_logcount_loss: 0.9858 - val_task0_profile_loss: 3993.0846
# Epoch 310/500
# 10/10 [==============================] - 2s 151ms/step - loss: 2251.7558 - task0_logcount_loss: 1.1490 - task0_profile_loss: 1619.7946 - val_loss: 4899.7937 - val_task0_logcount_loss: 0.9278 - val_task0_profile_loss: 4389.4900
# Epoch 311/500
# 10/10 [==============================] - 2s 154ms/step - loss: 2267.9626 - task0_logcount_loss: 1.1286 - task0_profile_loss: 1647.2486 - val_loss: 4539.7667 - val_task0_logcount_loss: 0.8197 - val_task0_profile_loss: 4088.9251
# Epoch 312/500
# 10/10 [==============================] - 1s 147ms/step - loss: 2227.1522 - task0_logcount_loss: 1.1424 - task0_profile_loss: 1598.8424 - val_loss: 4456.9555 - val_task0_logcount_loss: 0.8195 - val_task0_profile_loss: 4006.2397
# Epoch 313/500
# 10/10 [==============================] - 2s 157ms/step - loss: 2305.9455 - task0_logcount_loss: 1.2063 - task0_profile_loss: 1642.4758 - val_loss: 4999.1622 - val_task0_logcount_loss: 0.8990 - val_task0_profile_loss: 4504.7143
# Epoch 314/500
# 10/10 [==============================] - 2s 158ms/step - loss: 2216.1352 - task0_logcount_loss: 1.0836 - task0_profile_loss: 1620.1393 - val_loss: 4551.9928 - val_task0_logcount_loss: 0.8123 - val_task0_profile_loss: 4105.2518
# Epoch 315/500
# 10/10 [==============================] - 2s 155ms/step - loss: 2334.1783 - task0_logcount_loss: 1.3005 - task0_profile_loss: 1618.9067 - val_loss: 4505.6035 - val_task0_logcount_loss: 1.0126 - val_task0_profile_loss: 3948.6753
# Epoch 316/500
# 10/10 [==============================] - 1s 146ms/step - loss: 2390.2142 - task0_logcount_loss: 1.3713 - task0_profile_loss: 1636.0248 - val_loss: 4585.0434 - val_task0_logcount_loss: 1.1733 - val_task0_profile_loss: 3939.7390
# Epoch 317/500
# 10/10 [==============================] - 1s 145ms/step - loss: 2291.9919 - task0_logcount_loss: 1.2221 - task0_profile_loss: 1619.8524 - val_loss: 4417.7601 - val_task0_logcount_loss: 0.8219 - val_task0_profile_loss: 3965.6930
# Epoch 318/500
# 10/10 [==============================] - 2s 155ms/step - loss: 2204.3647 - task0_logcount_loss: 1.0679 - task0_profile_loss: 1617.0065 - val_loss: 4546.6848 - val_task0_logcount_loss: 0.8444 - val_task0_profile_loss: 4082.2608
# Epoch 319/500
# 10/10 [==============================] - 2s 153ms/step - loss: 2219.3352 - task0_logcount_loss: 1.1028 - task0_profile_loss: 1612.8057 - val_loss: 4437.4293 - val_task0_logcount_loss: 0.7942 - val_task0_profile_loss: 4000.6336
# Epoch 320/500
# 10/10 [==============================] - 2s 156ms/step - loss: 2179.2828 - task0_logcount_loss: 1.0855 - task0_profile_loss: 1582.2684 - val_loss: 4682.7237 - val_task0_logcount_loss: 0.8283 - val_task0_profile_loss: 4227.1379
# Epoch 321/500
# 10/10 [==============================] - 1s 148ms/step - loss: 2229.5027 - task0_logcount_loss: 1.0303 - task0_profile_loss: 1662.8495 - val_loss: 4621.8858 - val_task0_logcount_loss: 1.0397 - val_task0_profile_loss: 4050.0557
# Epoch 322/500
# 10/10 [==============================] - 2s 151ms/step - loss: 2219.2439 - task0_logcount_loss: 1.0939 - task0_profile_loss: 1617.6083 - val_loss: 4801.1150 - val_task0_logcount_loss: 0.8006 - val_task0_profile_loss: 4360.7594
# Epoch 323/500
# 10/10 [==============================] - 2s 160ms/step - loss: 2284.8909 - task0_logcount_loss: 1.1925 - task0_profile_loss: 1629.0352 - val_loss: 4882.8134 - val_task0_logcount_loss: 1.0779 - val_task0_profile_loss: 4289.9555
# Epoch 324/500
# 10/10 [==============================] - 1s 148ms/step - loss: 2290.6339 - task0_logcount_loss: 1.1458 - task0_profile_loss: 1660.4354 - val_loss: 4742.3953 - val_task0_logcount_loss: 0.8897 - val_task0_profile_loss: 4253.0627
# Epoch 325/500
# 10/10 [==============================] - 1s 144ms/step - loss: 2288.0726 - task0_logcount_loss: 1.1835 - task0_profile_loss: 1637.1503 - val_loss: 4547.9659 - val_task0_logcount_loss: 0.8357 - val_task0_profile_loss: 4088.3108
# Epoch 326/500
# 10/10 [==============================] - 1s 141ms/step - loss: 2288.4400 - task0_logcount_loss: 1.1488 - task0_profile_loss: 1656.6107 - val_loss: 4533.6184 - val_task0_logcount_loss: 0.8440 - val_task0_profile_loss: 4069.4229
# Epoch 327/500
# 10/10 [==============================] - 2s 155ms/step - loss: 2407.6197 - task0_logcount_loss: 1.2962 - task0_profile_loss: 1694.7173 - val_loss: 4615.7376 - val_task0_logcount_loss: 0.8695 - val_task0_profile_loss: 4137.5014
# Epoch 328/500
# 10/10 [==============================] - 2s 158ms/step - loss: 2386.7446 - task0_logcount_loss: 1.3740 - task0_profile_loss: 1631.0699 - val_loss: 4936.6214 - val_task0_logcount_loss: 1.0510 - val_task0_profile_loss: 4358.5907
# Epoch 329/500
# 10/10 [==============================] - 2s 151ms/step - loss: 2298.7512 - task0_logcount_loss: 1.0681 - task0_profile_loss: 1711.2867 - val_loss: 5012.6134 - val_task0_logcount_loss: 0.8145 - val_task0_profile_loss: 4564.6617
# Epoch 330/500
# 10/10 [==============================] - 2s 157ms/step - loss: 2394.1599 - task0_logcount_loss: 1.2347 - task0_profile_loss: 1715.0540 - val_loss: 4834.1005 - val_task0_logcount_loss: 0.9091 - val_task0_profile_loss: 4334.1045
# Epoch 331/500
# 10/10 [==============================] - 2s 156ms/step - loss: 2283.2222 - task0_logcount_loss: 1.1074 - task0_profile_loss: 1674.1473 - val_loss: 5666.1949 - val_task0_logcount_loss: 0.8886 - val_task0_profile_loss: 5177.4579
# Epoch 332/500
# 10/10 [==============================] - 1s 148ms/step - loss: 2364.6994 - task0_logcount_loss: 1.0978 - task0_profile_loss: 1760.9159 - val_loss: 5257.5517 - val_task0_logcount_loss: 1.0115 - val_task0_profile_loss: 4701.2303
# Epoch 333/500
# 10/10 [==============================] - 2s 150ms/step - loss: 2324.0123 - task0_logcount_loss: 1.0712 - task0_profile_loss: 1734.8709 - val_loss: 5045.5416 - val_task0_logcount_loss: 1.2878 - val_task0_profile_loss: 4337.2660
# Epoch 334/500
# 10/10 [==============================] - 1s 147ms/step - loss: 2316.5667 - task0_logcount_loss: 1.1774 - task0_profile_loss: 1668.9696 - val_loss: 4807.6365 - val_task0_logcount_loss: 1.2354 - val_task0_profile_loss: 4128.1626
# Epoch 335/500
# 10/10 [==============================] - 2s 167ms/step - loss: 2365.3867 - task0_logcount_loss: 1.3123 - task0_profile_loss: 1643.6322 - val_loss: 4923.0081 - val_task0_logcount_loss: 1.0964 - val_task0_profile_loss: 4319.9928
# Epoch 336/500
# 10/10 [==============================] - 2s 164ms/step - loss: 2246.6554 - task0_logcount_loss: 1.0049 - task0_profile_loss: 1693.9751 - val_loss: 4647.9345 - val_task0_logcount_loss: 0.8065 - val_task0_profile_loss: 4204.3534
# Epoch 337/500
# 10/10 [==============================] - 2s 156ms/step - loss: 2278.5420 - task0_logcount_loss: 1.0458 - task0_profile_loss: 1703.3359 - val_loss: 4924.7646 - val_task0_logcount_loss: 0.8950 - val_task0_profile_loss: 4432.4890
# Epoch 338/500
# 10/10 [==============================] - 2s 154ms/step - loss: 2250.5197 - task0_logcount_loss: 1.1118 - task0_profile_loss: 1639.0535 - val_loss: 4952.1533 - val_task0_logcount_loss: 0.8211 - val_task0_profile_loss: 4500.5727
# Epoch 339/500
# 10/10 [==============================] - 2s 172ms/step - loss: 2294.4756 - task0_logcount_loss: 1.0730 - task0_profile_loss: 1704.3479 - val_loss: 4936.1042 - val_task0_logcount_loss: 1.3511 - val_task0_profile_loss: 4193.0113
# Epoch 340/500
# 10/10 [==============================] - 2s 158ms/step - loss: 2439.7865 - task0_logcount_loss: 1.2183 - task0_profile_loss: 1769.7244 - val_loss: 4629.7525 - val_task0_logcount_loss: 0.8255 - val_task0_profile_loss: 4175.7224
# Epoch 341/500
# 10/10 [==============================] - 1s 144ms/step - loss: 2327.9941 - task0_logcount_loss: 1.1519 - task0_profile_loss: 1694.4288 - val_loss: 4704.1357 - val_task0_logcount_loss: 0.8066 - val_task0_profile_loss: 4260.5114
# Epoch 342/500
# 10/10 [==============================] - 1s 143ms/step - loss: 2166.7779 - task0_logcount_loss: 1.0200 - task0_profile_loss: 1605.7571 - val_loss: 4534.4604 - val_task0_logcount_loss: 0.8028 - val_task0_profile_loss: 4092.9089

# %%
model.save('/users/amr1/pho4/data/models/cbf1_limited_ana_model.h5')

# %%
from keras.models import load_model
from keras.utils import CustomObjectScope

with CustomObjectScope({'MultichannelMultinomialNLL': MultichannelMultinomialNLL,'RevCompConv1D': RevCompConv1D}):
    model = load_model('/users/amr1/pho4/data/models/cbf1_limited_ana_model.h5')
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           (None, 546, 4)       0
# __________________________________________________________________________________________________
# rev_comp_conv1d_1 (RevCompConv1 (None, 526, 128)     5440        sequence[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 522, 128)     0           rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_2 (RevCompConv1 (None, 522, 128)     24640       rev_comp_conv1d_1[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 522, 128)     0           lambda_1[0][0]
#                                                                  rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 514, 128)     0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 514, 128)     0           rev_comp_conv1d_2[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_3 (RevCompConv1 (None, 514, 128)     24640       average_1[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 514, 128)     0           lambda_2[0][0]
#                                                                  lambda_3[0][0]
#                                                                  rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 498, 128)     0           lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 498, 128)     0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 498, 128)     0           rev_comp_conv1d_3[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_4 (RevCompConv1 (None, 498, 128)     24640       average_2[0][0]
# __________________________________________________________________________________________________
# average_3 (Average)             (None, 498, 128)     0           lambda_4[0][0]
#                                                                  lambda_5[0][0]
#                                                                  lambda_6[0][0]
#                                                                  rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 466, 128)     0           lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 466, 128)     0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 466, 128)     0           lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 466, 128)     0           rev_comp_conv1d_4[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_5 (RevCompConv1 (None, 466, 128)     24640       average_3[0][0]
# __________________________________________________________________________________________________
# average_4 (Average)             (None, 466, 128)     0           lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
#                                                                  rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 402, 128)     0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 402, 128)     0           lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 402, 128)     0           lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 402, 128)     0           lambda_10[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 402, 128)     0           rev_comp_conv1d_5[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_6 (RevCompConv1 (None, 402, 128)     24640       average_4[0][0]
# __________________________________________________________________________________________________
# average_5 (Average)             (None, 402, 128)     0           lambda_11[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_15[0][0]
#                                                                  rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 274, 128)     0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 274, 128)     0           lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 274, 128)     0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 274, 128)     0           lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 274, 128)     0           lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 274, 128)     0           rev_comp_conv1d_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_7 (RevCompConv1 (None, 274, 128)     24640       average_5[0][0]
# __________________________________________________________________________________________________
# control_logcount (InputLayer)   (None, 1)            0
# __________________________________________________________________________________________________
# average_6 (Average)             (None, 274, 128)     0           lambda_16[0][0]
#                                                                  lambda_17[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_21[0][0]
#                                                                  rev_comp_conv1d_7[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 1)            0           control_logcount[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 128)          0           average_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 130)          0           lambda_22[0][0]
#                                                                  global_average_pooling1d_1[0][0]
#                                                                  control_logcount[0][0]
# __________________________________________________________________________________________________
# control_profile (InputLayer)    (None, 200, 2)       0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 130)       0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 200, 2)       0           control_profile[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_9 (RevCompConv1 (None, 200, 2)       9601        average_6[0][0]
# __________________________________________________________________________________________________
# rev_comp_conv1d_8 (RevCompConv1 (None, 1, 2)         131         reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 200, 6)       0           lambda_23[0][0]
#                                                                  rev_comp_conv1d_9[0][0]
#                                                                  control_profile[0][0]
# __________________________________________________________________________________________________
# task0_logcount (Reshape)        (None, 2)            0           rev_comp_conv1d_8[0][0]
# __________________________________________________________________________________________________
# task0_profile (RevCompConv1D)   (None, 200, 2)       7           concatenate_2[0][0]
# ==================================================================================================
# Total params: 163,019
# Trainable params: 163,019
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# evaluate

# %%
o_test_preds_logcount = []
o_test_biastrack_logcount = []
o_test_biastrack_profile = []
o_test_seqs = []
o_test_preds_profile = []
o_test_labels_logcount = []
o_test_labels_profile = []

keras_test_batch_generator = coordbased.core.KerasBatchGenerator(
  coordsbatch_producer=coordbatchproducers.SimpleCoordsBatchProducer(
            bed_file="/users/amr1/pho4/data/limited_conditions/cbf1_ana/test_1000_around_summits.bed.gz",
            batch_size=64,
            shuffle_before_epoch=False, 
            seed=1234),
  inputs_coordstovals=inputs_coordstovals,
  targets_coordstovals=targets_coordstovals)

orig_seqs = []

for batch_idx in range(len(keras_test_batch_generator)):
    batch_inputs, batch_labels = keras_test_batch_generator[batch_idx]
    o_test_seqs.append(batch_inputs['sequence']) 
    o_test_biastrack_logcount.append(batch_inputs['control_logcount'])
    o_test_biastrack_profile.append(batch_inputs['control_profile'])    
    test_preds = model.predict(batch_inputs)
    o_test_preds_logcount.append(test_preds[0])
    o_test_preds_profile.append(test_preds[1])
    o_test_labels_logcount.append(batch_labels['task0_logcount'])
    o_test_labels_profile.append(batch_labels['task0_profile'])
o_test_biastrack_logcount = np.concatenate(o_test_biastrack_logcount, axis=0)
o_test_biastrack_profile = np.concatenate(o_test_biastrack_profile,axis=0)
o_test_seqs = np.concatenate(o_test_seqs,axis=0)
o_test_preds_logcount = np.concatenate(o_test_preds_logcount, axis=0)
o_test_preds_profile = np.concatenate(o_test_preds_profile, axis=0)
o_test_labels_logcount = np.concatenate(o_test_labels_logcount, axis=0)
o_test_labels_profile = np.concatenate(o_test_labels_profile, axis=0)

from matplotlib import pyplot as plt
from scipy.stats import spearmanr

o_test_labels_logtotalcount = np.log(np.sum(np.exp(o_test_labels_logcount) - 1,axis=-1) + 1)

plt.scatter(o_test_biastrack_logcount, o_test_labels_logtotalcount, alpha=0.1)
plt.xlabel("Bias track log counts")
plt.ylabel("True log total counts")
plt.plot([np.min(o_test_biastrack_logcount), np.max(o_test_biastrack_logcount)],
         [np.min(o_test_biastrack_logcount), np.max(o_test_biastrack_logcount)],
         color="black")
plt.show()
print(spearmanr(o_test_biastrack_logcount, o_test_labels_logtotalcount))


#do a scatterplot of total count predictions
plt.scatter(o_test_preds_logcount[:,0], o_test_labels_logcount[:,0], alpha=0.1)
plt.xlabel("Predicted log counts - Forward Strand")
plt.ylabel("True log counts - Forward Strand")
plt.plot([np.min(o_test_preds_logcount[:,0]), np.max(o_test_preds_logcount[:,0])],
         [np.min(o_test_preds_logcount[:,0]), np.max(o_test_preds_logcount[:,0])],
         color="black")
plt.show()
print(spearmanr(o_test_preds_logcount[:,0], o_test_labels_logcount[:,0]))

plt.scatter(o_test_preds_logcount[:,1], o_test_labels_logcount[:,1], alpha=0.1)
plt.xlabel("Predicted log counts - Reverse Strand")
plt.ylabel("True log counts - Reverse Strand")
plt.plot([np.min(o_test_preds_logcount[:,1]), np.max(o_test_preds_logcount[:,1])],
         [np.min(o_test_preds_logcount[:,1]), np.max(o_test_preds_logcount[:,1])],
         color="black")
plt.show()
print(spearmanr(o_test_preds_logcount[:,1], o_test_labels_logcount[:,1]))
# Out:
# Heads up: coordinates in bed file are assumed to be on the positive strand; if strand in the bed file is improtant to you, please add that feature to SimpleCoordsBatchProducer
# SpearmanrResult(correlation=0.0746840607556309, pvalue=0.4489411914724891)
# SpearmanrResult(correlation=0.735324685484268, pvalue=4.1917186563117055e-19)
# SpearmanrResult(correlation=0.733482619597985, pvalue=5.686079624114797e-19)

# %%
# %matplotlib inline

o_train_preds_logcount = []
o_train_biastrack_logcount = []
o_train_biastrack_profile = []
o_train_seqs = []
o_train_preds_profile = []
o_train_labels_logcount = []
o_train_labels_profile = []

orig_seqs = []

for batch_idx in range(len(keras_train_batch_generator)):
    batch_inputs, batch_labels = keras_train_batch_generator[batch_idx]
    o_train_seqs.append(batch_inputs['sequence']) 
    o_train_biastrack_logcount.append(batch_inputs['control_logcount'])
    o_train_biastrack_profile.append(batch_inputs['control_profile'])    
    train_preds = model.predict(batch_inputs)
    o_train_preds_logcount.append(train_preds[0])
    o_train_preds_profile.append(train_preds[1])
    o_train_labels_logcount.append(batch_labels['task0_logcount'])
    o_train_labels_profile.append(batch_labels['task0_profile'])
o_train_biastrack_logcount = np.concatenate(o_train_biastrack_logcount, axis=0)
o_train_biastrack_profile = np.concatenate(o_train_biastrack_profile,axis=0)
o_train_seqs = np.concatenate(o_train_seqs,axis=0)
o_train_preds_logcount = np.concatenate(o_train_preds_logcount, axis=0)
o_train_preds_profile = np.concatenate(o_train_preds_profile, axis=0)
o_train_labels_logcount = np.concatenate(o_train_labels_logcount, axis=0)
o_train_labels_profile = np.concatenate(o_train_labels_profile, axis=0)

from matplotlib import pyplot as plt
from scipy.stats import spearmanr

o_train_labels_logtotalcount = np.log(np.sum(np.exp(o_train_labels_logcount) - 1,axis=-1) + 1)

plt.scatter(o_train_biastrack_logcount, o_train_labels_logtotalcount, alpha=0.1)
plt.xlabel("Bias track log counts")
plt.ylabel("True log total counts")
plt.plot([np.min(o_train_biastrack_logcount), np.max(o_train_biastrack_logcount)],
         [np.min(o_train_biastrack_logcount), np.max(o_train_biastrack_logcount)],
         color="black")
plt.show()
print(spearmanr(o_train_biastrack_logcount, o_train_labels_logtotalcount))


#do a scatterplot of total count predictions
plt.scatter(o_train_preds_logcount[:,0], o_train_labels_logcount[:,0], alpha=0.1)
plt.xlabel("Predicted log counts - Forward Strand")
plt.ylabel("True log counts - Forward Strand")
plt.plot([np.min(o_train_preds_logcount[:,0]), np.max(o_train_preds_logcount[:,0])],
         [np.min(o_train_preds_logcount[:,0]), np.max(o_train_preds_logcount[:,0])],
         color="black")
plt.show()
print(spearmanr(o_train_preds_logcount[:,0], o_train_labels_logcount[:,0]))

plt.scatter(o_train_preds_logcount[:,1], o_train_labels_logcount[:,1], alpha=0.1)
plt.xlabel("Predicted log counts - Reverse Strand")
plt.ylabel("True log counts - Reverse Strand")
plt.plot([np.min(o_train_preds_logcount[:,1]), np.max(o_train_preds_logcount[:,1])],
         [np.min(o_train_preds_logcount[:,1]), np.max(o_train_preds_logcount[:,1])],
         color="black")
plt.show()
print(spearmanr(o_train_preds_logcount[:,1], o_train_labels_logcount[:,1]))
# Out:
# SpearmanrResult(correlation=0.16042218208798437, pvalue=3.093567299319623e-08)
# SpearmanrResult(correlation=0.7338433329935453, pvalue=1.0453946339666236e-199)
# SpearmanrResult(correlation=0.7446900349150319, pvalue=9.562432937198976e-209)

# %% [markdown]
# Interpretation

# %%
import shap
from deeplift.dinuc_shuffle import dinuc_shuffle

def combine_mult_and_diffref(mult, orig_inp, bg_data):
    to_return = []
    for l in [0]:
        projected_hypothetical_contribs = np.zeros_like(bg_data[l]).astype("float")
        assert len(orig_inp[l].shape)==2
        #At each position in the input sequence, we iterate over the one-hot encoding
        # possibilities (eg: for genomic sequence, this is ACGT i.e.
        # 1000, 0100, 0010 and 0001) and compute the hypothetical 
        # difference-from-reference in each case. We then multiply the hypothetical
        # differences-from-reference with the multipliers to get the hypothetical contributions.
        #For each of the one-hot encoding possibilities,
        # the hypothetical contributions are then summed across the ACGT axis to estimate
        # the total hypothetical contribution of each position. This per-position hypothetical
        # contribution is then assigned ("projected") onto whichever base was present in the
        # hypothetical sequence.
        #The reason this is a fast estimate of what the importance scores *would* look
        # like if different bases were present in the underlying sequence is that
        # the multipliers are computed once using the original sequence, and are not
        # computed again for each hypothetical sequence.
        for i in range(orig_inp[l].shape[-1]):
            hypothetical_input = np.zeros_like(orig_inp[l]).astype("float")
            hypothetical_input[:,i] = 1.0
            hypothetical_difference_from_reference = (hypothetical_input[None,:,:]-bg_data[l])
            hypothetical_contribs = hypothetical_difference_from_reference*mult[l]
            projected_hypothetical_contribs[:,:,i] = np.sum(hypothetical_contribs,axis=-1) 
        to_return.append(np.mean(projected_hypothetical_contribs,axis=0))
    to_return.append(np.zeros_like(orig_inp[1]))
    return to_return

def shuffle_several_times(s):
    numshuffles=20
    return [np.array([dinuc_shuffle(s[0]) for i in range(numshuffles)]),
            np.array([s[1] for i in range(numshuffles)])]

profile_model_counts_explainer = shap.explainers.deep.TFDeepExplainer(
    ([model.input[0], model.input[1]],
     tf.reduce_sum(model.outputs[0],axis=-1)),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)

#See Google slide deck for explanations
#We meannorm as per section titled "Adjustments for Softmax Layers"
# in the DeepLIFT paper
meannormed_logits = (
    model.outputs[1]-
    tf.reduce_mean(model.outputs[1],axis=1)[:,None,:])
#'stop_gradient' will prevent importance from being propagated through
# this operation; we do this because we just want to treat the post-softmax
# probabilities as 'weights' on the different logits, without having the
# network explain how the probabilities themselves were derived
#Could be worth contrasting explanations derived with and without stop_gradient
# enabled...
stopgrad_meannormed_logits = tf.stop_gradient(meannormed_logits)
softmax_out = tf.nn.softmax(stopgrad_meannormed_logits,axis=1)
#Weight the logits according to the softmax probabilities, take the sum for each
# example. This mirrors what was done for the bpnet paper.
weightedsum_meannormed_logits = tf.reduce_sum(softmax_out*meannormed_logits,
                                              axis=(1,2))
profile_model_profile_explainer = shap.explainers.deep.TFDeepExplainer(
    ([model.input[0], model.input[2]],
     weightedsum_meannormed_logits),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)
# Out:
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  StopGradient used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients

# %%
#The shap scores
post_counts_hypimps,_ = profile_model_counts_explainer.shap_values(
    [o_test_seqs, np.zeros((len(o_test_seqs), 1))],
    progress_message=10)
post_profile_hypimps,_ = profile_model_profile_explainer.shap_values(
    [o_test_seqs, np.zeros((len(o_test_seqs), out_pred_len, 2))],
    progress_message=10)

post_counts_actualimps = post_counts_hypimps*o_test_seqs
post_profile_actualimps = post_profile_hypimps*o_test_seqs
# Out:
# Done 0 examples of 105
# WARNING:tensorflow:From /users/amr1/miniconda3/envs/basepair/lib/python3.6/site-packages/shap/explainers/deep/deep_tf.py:493: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Done 10 examples of 105
# Done 20 examples of 105
# Done 30 examples of 105
# Done 40 examples of 105
# Done 50 examples of 105
# Done 60 examples of 105
# Done 70 examples of 105
# Done 80 examples of 105
# Done 90 examples of 105
# Done 100 examples of 105
# Done 0 examples of 105
# Done 10 examples of 105
# Done 20 examples of 105
# Done 30 examples of 105
# Done 40 examples of 105
# Done 50 examples of 105
# Done 60 examples of 105
# Done 70 examples of 105
# Done 80 examples of 105
# Done 90 examples of 105
# Done 100 examples of 105

# %%
from deeplift.visualization import viz_sequence
from matplotlib import pyplot as plt
from matplotlib.ticker import FormatStrFormatter

sorted_test_indices = [x[0] for x in 
                       sorted(enumerate(o_test_labels_logtotalcount),
                              key=lambda x: -x[1])]

def smooth(vals):
    return np.convolve(vals, np.ones(1,)/1, mode='same')

for idx in sorted_test_indices[:10]: 
    true_profile = o_test_labels_profile[idx] 
    print("idx",idx)
    print("Counts",np.sum(true_profile,axis=0))
    print("Predcounts",np.exp(o_test_preds_logcount[idx])-1)
    
    for oneovertemp in [1.0]:
        print("oneovertemp",oneovertemp)
        print(o_test_labels_profile[idx].shape)
        print("Pred profile shape", o_test_preds_profile[idx].shape)
        pred_profile = (np.sum(o_test_labels_profile[idx], axis=0)[None,:] #total counts
                      *(np.exp(o_test_preds_profile[idx]*oneovertemp)/
                        np.sum(np.exp(o_test_preds_profile[idx]*oneovertemp),axis=0)[None,:]) )   
        plt.figure(figsize=(20,2))

        start_view = 0
        end_view = seq_len
        total_flanking = seq_len - out_pred_len
        left_flank = int(0.5*total_flanking)
        right_flank = total_flanking - left_flank
        plt.plot(np.arange(out_pred_len)+left_flank, smooth(true_profile[:,0]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, -smooth(true_profile[:,1]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, pred_profile[:,0])
        plt.plot(np.arange(out_pred_len)+left_flank, -pred_profile[:,1])
        plt.xlim(start_view,end_view)
        plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
        plt.show()

    print("counts imp")
    viz_sequence.plot_weights(post_counts_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
    print("profile imp")
    viz_sequence.plot_weights(post_profile_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
# Out:
# idx 88
# Counts [15058. 17913.]
# Predcounts [274807.16 311602.72]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 15
# Counts [14034. 17216.]
# Predcounts [15880.054 13081.811]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 89
# Counts [ 7558. 11957.]
# Predcounts [85462.65 90857.96]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 54
# Counts [9557. 8739.]
# Predcounts [1304.326  1492.6158]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 40
# Counts [ 3696. 11468.]
# Predcounts [53963.72  42169.492]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 6
# Counts [8192. 6461.]
# Predcounts [2203.5168 4320.818 ]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 51
# Counts [4600. 5488.]
# Predcounts [2546.7566 3170.982 ]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 4
# Counts [3461. 6272.]
# Predcounts [1606.6049 7432.1914]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 19
# Counts [4094. 5377.]
# Predcounts [1670.89   1305.8345]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 22
# Counts [3853. 4619.]
# Predcounts [1199.2473 1490.4203]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp

# %%
for idx in sorted_test_indices[:10]: 
    true_profile = o_test_labels_profile[idx] 
    print("idx",idx)
    print("Counts",np.sum(true_profile,axis=0))
    print("Predcounts",np.exp(o_test_preds_logcount[idx])-1)
    
    for oneovertemp in [1.0]:
        print("oneovertemp",oneovertemp)
        print(o_test_labels_profile[idx].shape)
        print("Pred profile shape", o_test_preds_profile[idx].shape)
        pred_profile = (np.sum(o_test_labels_profile[idx], axis=0)[None,:] #total counts
                      *(np.exp(o_test_preds_profile[idx]*oneovertemp)/
                        np.sum(np.exp(o_test_preds_profile[idx]*oneovertemp),axis=0)[None,:]) )   
        plt.figure(figsize=(20,2))

        start_view = 220
        end_view = 325
        total_flanking = seq_len - out_pred_len
        left_flank = int(0.5*total_flanking)
        right_flank = total_flanking - left_flank
        plt.plot(np.arange(out_pred_len)+left_flank, smooth(true_profile[:,0]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, -smooth(true_profile[:,1]), alpha=0.3)
        plt.plot(np.arange(out_pred_len)+left_flank, pred_profile[:,0])
        plt.plot(np.arange(out_pred_len)+left_flank, -pred_profile[:,1])
        plt.xlim(start_view,end_view)
        plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
        plt.show()

    print("counts imp")
    viz_sequence.plot_weights(post_counts_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
    print("profile imp")
    viz_sequence.plot_weights(post_profile_actualimps[idx][start_view:end_view],
                            subticks_frequency=10)
# Out:
# idx 88
# Counts [15058. 17913.]
# Predcounts [274807.16 311602.72]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 15
# Counts [14034. 17216.]
# Predcounts [15880.054 13081.811]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 89
# Counts [ 7558. 11957.]
# Predcounts [85462.65 90857.96]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 54
# Counts [9557. 8739.]
# Predcounts [1304.326  1492.6158]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 40
# Counts [ 3696. 11468.]
# Predcounts [53963.72  42169.492]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 6
# Counts [8192. 6461.]
# Predcounts [2203.5168 4320.818 ]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 51
# Counts [4600. 5488.]
# Predcounts [2546.7566 3170.982 ]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 4
# Counts [3461. 6272.]
# Predcounts [1606.6049 7432.1914]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 19
# Counts [4094. 5377.]
# Predcounts [1670.89   1305.8345]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
# idx 22
# Counts [3853. 4619.]
# Predcounts [1199.2473 1490.4203]
# oneovertemp 1.0
# (200, 2)
# Pred profile shape (200, 2)
# counts imp
# profile imp
