# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

bins = np.linspace(0, 1, 11)
for key in ['AR_R2', 'AR_R3', 'AR_R4', 'AR_R5', 'AR_R6', 'AR_R7', 'AR_R8']:
    for table in ['kmerTableDivide.csv','kmerTableTransit.csv','symmetricKmerTableDivide.csv','symmetricKmerTableTransit.csv']:
        allAffs = []
        firstLine = True
        with open("results/"+key+"/"+table) as inp:
            for line in inp:
                if firstLine:
                    firstLine = False
                    continue
                row = line.strip().split(',')
                if 'symmetric' in table and int(row[2]) == 0: continue
                aff = float(row[-2])
                allAffs.append(aff)
        digitized = np.digitize(allAffs, bins)
        print(key, table)
        for i in range(1, 11): print("bin ", i, " contains ", len(digitized[digitized == i]))
        plt.hist(allAffs, density=False, bins=11)
        plt.ylabel('Counts')
        plt.xlabel('Affinity')
        plt.xlim((0,1.01))
        plt.show()
# Out:
# AR_R2 kmerTableDivide.csv
# bin  1  contains  47134384
# bin  2  contains  4468043
# bin  3  contains  675801
# bin  4  contains  230148
# bin  5  contains  92109
# bin  6  contains  38939
# bin  7  contains  18144
# bin  8  contains  8274
# bin  9  contains  2512
# bin  10  contains  230
# AR_R2 kmerTableTransit.csv
# bin  1  contains  47189209
# bin  2  contains  4418317
# bin  3  contains  672887
# bin  4  contains  229010
# bin  5  contains  91500
# bin  6  contains  38741
# bin  7  contains  17973
# bin  8  contains  8241
# bin  9  contains  2475
# bin  10  contains  231
# AR_R2 symmetricKmerTableDivide.csv
# bin  1  contains  46665570
# bin  2  contains  4896597
# bin  3  contains  691025
# bin  4  contains  241243
# bin  5  contains  98409
# bin  6  contains  42324
# bin  7  contains  19925
# bin  8  contains  9700
# bin  9  contains  3364
# bin  10  contains  426
# AR_R2 symmetricKmerTableTransit.csv
# bin  1  contains  46747972
# bin  2  contains  4821391
# bin  3  contains  686943
# bin  4  contains  239741
# bin  5  contains  97622
# bin  6  contains  41899
# bin  7  contains  19769
# bin  8  contains  9566
# bin  9  contains  3272
# bin  10  contains  408
# AR_R3 kmerTableDivide.csv
# bin  1  contains  17098833
# bin  2  contains  7587380
# bin  3  contains  660596
# bin  4  contains  184289
# bin  5  contains  64680
# bin  6  contains  22662
# bin  7  contains  8860
# bin  8  contains  3952
# bin  9  contains  1320
# bin  10  contains  190
# AR_R3 kmerTableTransit.csv
# bin  1  contains  17111576
# bin  2  contains  7574973
# bin  3  contains  660228
# bin  4  contains  184390
# bin  5  contains  64556
# bin  6  contains  22690
# bin  7  contains  8865
# bin  8  contains  3967
# bin  9  contains  1319
# bin  10  contains  198
# AR_R3 symmetricKmerTableDivide.csv
# bin  1  contains  15965348
# bin  2  contains  8668343
# bin  3  contains  690287
# bin  4  contains  196797
# bin  5  contains  70482
# bin  6  contains  25146
# bin  7  contains  9842
# bin  8  contains  4512
# bin  9  contains  1674
# bin  10  contains  330
# AR_R3 symmetricKmerTableTransit.csv
# bin  1  contains  16059330
# bin  2  contains  8579945
# bin  3  contains  686755
# bin  4  contains  195741
# bin  5  contains  69850
# bin  6  contains  24934
# bin  7  contains  9762
# bin  8  contains  4488
# bin  9  contains  1638
# bin  10  contains  318
# AR_R4 kmerTableDivide.csv
# bin  1  contains  970612
# bin  2  contains  15480092
# bin  3  contains  753830
# bin  4  contains  154040
# bin  5  contains  45736
# bin  6  contains  14958
# bin  7  contains  4937
# bin  8  contains  1807
# bin  9  contains  572
# bin  10  contains  131
# AR_R4 kmerTableTransit.csv
# bin  1  contains  952006
# bin  2  contains  15501640
# bin  3  contains  751105
# bin  4  contains  153921
# bin  5  contains  45656
# bin  6  contains  14945
# bin  7  contains  4930
# bin  8  contains  1807
# bin  9  contains  576
# bin  10  contains  129
# AR_R4 symmetricKmerTableDivide.csv
# bin  1  contains  582946
# bin  2  contains  15866025
# bin  3  contains  750130
# bin  4  contains  157507
# bin  5  contains  46848
# bin  6  contains  15468
# bin  7  contains  5148
# bin  8  contains  1894
# bin  9  contains  606
# bin  10  contains  142
# AR_R4 symmetricKmerTableTransit.csv
# bin  1  contains  595218
# bin  2  contains  15859353
# bin  3  contains  745577
# bin  4  contains  156878
# bin  5  contains  46578
# bin  6  contains  15390
# bin  7  contains  5080
# bin  8  contains  1902
# bin  9  contains  596
# bin  10  contains  142
# AR_R5 kmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  9661375
# bin  3  contains  1132423
# bin  4  contains  155541
# bin  5  contains  39748
# bin  6  contains  11625
# bin  7  contains  3837
# bin  8  contains  1110
# bin  9  contains  360
# bin  10  contains  113
# AR_R5 kmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  9676597
# bin  3  contains  1119312
# bin  4  contains  153994
# bin  5  contains  39381
# bin  6  contains  11495
# bin  7  contains  3791
# bin  8  contains  1101
# bin  9  contains  350
# bin  10  contains  111
# AR_R5 symmetricKmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  9671149
# bin  3  contains  1120031
# bin  4  contains  157001
# bin  5  contains  40538
# bin  6  contains  11828
# bin  7  contains  3950
# bin  8  contains  1150
# bin  9  contains  366
# bin  10  contains  118
# AR_R5 symmetricKmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  9683584
# bin  3  contains  1109142
# bin  4  contains  155897
# bin  5  contains  40234
# bin  6  contains  11728
# bin  7  contains  3930
# bin  8  contains  1140
# bin  9  contains  364
# bin  10  contains  112
# AR_R6 kmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  5718099
# bin  3  contains  1736385
# bin  4  contains  198577
# bin  5  contains  39894
# bin  6  contains  10485
# bin  7  contains  3316
# bin  8  contains  860
# bin  9  contains  283
# bin  10  contains  81
# AR_R6 kmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  5737903
# bin  3  contains  1719669
# bin  4  contains  196127
# bin  5  contains  39440
# bin  6  contains  10364
# bin  7  contains  3270
# bin  8  contains  845
# bin  9  contains  282
# bin  10  contains  80
# AR_R6 symmetricKmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  5590881
# bin  3  contains  1859395
# bin  4  contains  201179
# bin  5  contains  40902
# bin  6  contains  10852
# bin  7  contains  3454
# bin  8  contains  928
# bin  9  contains  306
# bin  10  contains  82
# AR_R6 symmetricKmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  5607815
# bin  3  contains  1844630
# bin  4  contains  199408
# bin  5  contains  40614
# bin  6  contains  10790
# bin  7  contains  3418
# bin  8  contains  916
# bin  9  contains  306
# bin  10  contains  82
# AR_R7 kmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  2189409
# bin  3  contains  2312065
# bin  4  contains  279427
# bin  5  contains  47719
# bin  6  contains  11068
# bin  7  contains  3117
# bin  8  contains  844
# bin  9  contains  261
# bin  10  contains  79
# AR_R7 kmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  2203881
# bin  3  contains  2301176
# bin  4  contains  276589
# bin  5  contains  47124
# bin  6  contains  10951
# bin  7  contains  3094
# bin  8  contains  837
# bin  9  contains  258
# bin  10  contains  79
# AR_R7 symmetricKmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  1954976
# bin  3  contains  2541486
# bin  4  contains  283885
# bin  5  contains  47989
# bin  6  contains  11256
# bin  7  contains  3178
# bin  8  contains  864
# bin  9  contains  276
# bin  10  contains  78
# AR_R7 symmetricKmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  1969948
# bin  3  contains  2529186
# bin  4  contains  281643
# bin  5  contains  47671
# bin  6  contains  11170
# bin  7  contains  3158
# bin  8  contains  862
# bin  9  contains  272
# bin  10  contains  78
# AR_R8 kmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  1
# bin  3  contains  2581876
# bin  4  contains  344646
# bin  5  contains  59477
# bin  6  contains  12429
# bin  7  contains  3128
# bin  8  contains  877
# bin  9  contains  216
# bin  10  contains  87
# AR_R8 kmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  1
# bin  3  contains  2585954
# bin  4  contains  341482
# bin  5  contains  58758
# bin  6  contains  12274
# bin  7  contains  3106
# bin  8  contains  862
# bin  9  contains  213
# bin  10  contains  87
# AR_R8 symmetricKmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  0
# bin  3  contains  2548612
# bin  4  contains  375289
# bin  5  contains  61449
# bin  6  contains  12834
# bin  7  contains  3290
# bin  8  contains  948
# bin  9  contains  216
# bin  10  contains  98
# AR_R8 symmetricKmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  0
# bin  3  contains  2551984
# bin  4  contains  372561
# bin  5  contains  60955
# bin  6  contains  12714
# bin  7  contains  3270
# bin  8  contains  940
# bin  9  contains  214
# bin  10  contains  98

# %%
for key in ['GR_R2', 'GR_R3', 'GR_R4', 'GR_R5', 'GR_R6', 'GR_R7', 'GR_R8']:
    for table in ['kmerTableDivide.csv','kmerTableTransit.csv','symmetricKmerTableDivide.csv','symmetricKmerTableTransit.csv']:
        allAffs = []
        firstLine = True
        with open("results/"+key+"/"+table) as inp:
            for line in inp:
                if firstLine:
                    firstLine = False
                    continue
                row = line.strip().split(',')
                if 'symmetric' in table and int(row[2]) == 0: continue
                aff = float(row[-2])
                allAffs.append(aff)
        digitized = np.digitize(allAffs, bins)
        print(key, table)
        for i in range(1, 11): print("bin ", i, " contains ", len(digitized[digitized == i]))
        plt.hist(allAffs, density=False, bins=11)
        plt.ylabel('Counts')
        plt.xlabel('Affinity')
        plt.xlim((0,1.01))
        plt.show()
# Out:
# GR_R2 kmerTableDivide.csv
# bin  1  contains  52354363
# bin  2  contains  14390212
# bin  3  contains  520152
# bin  4  contains  57272
# bin  5  contains  1788
# bin  6  contains  6
# bin  7  contains  20
# bin  8  contains  16
# bin  9  contains  15
# bin  10  contains  11
# GR_R2 kmerTableTransit.csv
# bin  1  contains  52179280
# bin  2  contains  14556992
# bin  3  contains  526742
# bin  4  contains  58818
# bin  5  contains  1955
# bin  6  contains  6
# bin  7  contains  19
# bin  8  contains  17
# bin  9  contains  15
# bin  10  contains  11
# GR_R2 symmetricKmerTableDivide.csv
# bin  1  contains  51928995
# bin  2  contains  14901386
# bin  3  contains  445245
# bin  4  contains  47523
# bin  5  contains  633
# bin  6  contains  11
# bin  7  contains  35
# bin  8  contains  11
# bin  9  contains  8
# bin  10  contains  8
# GR_R2 symmetricKmerTableTransit.csv
# bin  1  contains  51718545
# bin  2  contains  15103985
# bin  3  contains  451366
# bin  4  contains  49125
# bin  5  contains  759
# bin  6  contains  13
# bin  7  contains  34
# bin  8  contains  12
# bin  9  contains  8
# bin  10  contains  8
# GR_R3 kmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  34299024
# bin  3  contains  5436762
# bin  4  contains  835605
# bin  5  contains  281848
# bin  6  contains  117002
# bin  7  contains  43924
# bin  8  contains  18900
# bin  9  contains  3739
# bin  10  contains  62
# GR_R3 kmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  34353605
# bin  3  contains  5389038
# bin  4  contains  830999
# bin  5  contains  280795
# bin  6  contains  116258
# bin  7  contains  43678
# bin  8  contains  18776
# bin  9  contains  3655
# bin  10  contains  62
# GR_R3 symmetricKmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  31686425
# bin  3  contains  7788621
# bin  4  contains  982785
# bin  5  contains  335887
# bin  6  contains  145849
# bin  7  contains  60720
# bin  8  contains  25576
# bin  9  contains  10281
# bin  10  contains  721
# GR_R3 symmetricKmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  31787322
# bin  3  contains  7698123
# bin  4  contains  975901
# bin  5  contains  334357
# bin  6  contains  145022
# bin  7  contains  59952
# bin  8  contains  25426
# bin  9  contains  10080
# bin  10  contains  682
# GR_R4 kmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  20974306
# bin  3  contains  4757547
# bin  4  contains  639000
# bin  5  contains  202003
# bin  6  contains  77094
# bin  7  contains  26811
# bin  8  contains  10047
# bin  9  contains  3712
# bin  10  contains  374
# GR_R4 kmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  21029142
# bin  3  contains  4708732
# bin  4  contains  635222
# bin  5  contains  200763
# bin  6  contains  76564
# bin  7  contains  26541
# bin  8  contains  9918
# bin  9  contains  3655
# bin  10  contains  357
# GR_R4 symmetricKmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  20036977
# bin  3  contains  5615712
# bin  4  contains  683631
# bin  5  contains  220229
# bin  6  contains  86214
# bin  7  contains  31122
# bin  8  contains  11350
# bin  9  contains  4896
# bin  10  contains  762
# GR_R4 symmetricKmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  20083693
# bin  3  contains  5573140
# bin  4  contains  681031
# bin  5  contains  219440
# bin  6  contains  85853
# bin  7  contains  30856
# bin  8  contains  11348
# bin  9  contains  4790
# bin  10  contains  742
# GR_R5 kmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  11105230
# bin  3  contains  5476310
# bin  4  contains  510562
# bin  5  contains  130669
# bin  6  contains  42621
# bin  7  contains  13223
# bin  8  contains  4211
# bin  9  contains  1123
# bin  10  contains  134
# GR_R5 kmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  11177515
# bin  3  contains  5411500
# bin  4  contains  505037
# bin  5  contains  129473
# bin  6  contains  42171
# bin  7  contains  13013
# bin  8  contains  4152
# bin  9  contains  1097
# bin  10  contains  125
# GR_R5 symmetricKmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  9869471
# bin  3  contains  6644133
# bin  4  contains  555483
# bin  5  contains  144600
# bin  6  contains  48133
# bin  7  contains  15558
# bin  8  contains  4946
# bin  9  contains  1496
# bin  10  contains  262
# GR_R5 symmetricKmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  9942683
# bin  3  contains  6577285
# bin  4  contains  550887
# bin  5  contains  143596
# bin  6  contains  47663
# bin  7  contains  15358
# bin  8  contains  4894
# bin  9  contains  1470
# bin  10  contains  246
# GR_R6 kmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  1118795
# bin  3  contains  9398302
# bin  4  contains  644613
# bin  5  contains  119150
# bin  6  contains  34197
# bin  7  contains  10198
# bin  8  contains  2799
# bin  9  contains  686
# bin  10  contains  120
# GR_R6 kmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  1208470
# bin  3  contains  9321179
# bin  4  contains  634193
# bin  5  contains  117681
# bin  6  contains  33767
# bin  7  contains  10041
# bin  8  contains  2743
# bin  9  contains  670
# bin  10  contains  116
# GR_R6 symmetricKmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  346763
# bin  3  contains  10128626
# bin  4  contains  673429
# bin  5  contains  127275
# bin  6  contains  37344
# bin  7  contains  11266
# bin  8  contains  3202
# bin  9  contains  784
# bin  10  contains  170
# GR_R6 symmetricKmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  373401
# bin  3  contains  10112758
# bin  4  contains  664491
# bin  5  contains  126075
# bin  6  contains  36944
# bin  7  contains  11122
# bin  8  contains  3134
# bin  9  contains  766
# bin  10  contains  168
# GR_R7 kmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  0
# bin  3  contains  7799438
# bin  4  contains  973166
# bin  5  contains  121370
# bin  6  contains  28295
# bin  7  contains  7853
# bin  8  contains  1796
# bin  9  contains  438
# bin  10  contains  62
# GR_R7 kmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  0
# bin  3  contains  7811959
# bin  4  contains  962096
# bin  5  contains  120273
# bin  6  contains  28052
# bin  7  contains  7772
# bin  8  contains  1775
# bin  9  contains  430
# bin  10  contains  61
# GR_R7 symmetricKmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  0
# bin  3  contains  7633823
# bin  4  contains  1117827
# bin  5  contains  136143
# bin  6  contains  32566
# bin  7  contains  9146
# bin  8  contains  2276
# bin  9  contains  530
# bin  10  contains  106
# GR_R7 symmetricKmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  0
# bin  3  contains  7647169
# bin  4  contains  1105894
# bin  5  contains  135122
# bin  6  contains  32312
# bin  7  contains  9038
# bin  8  contains  2250
# bin  9  contains  526
# bin  10  contains  106
# GR_R8 kmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  0
# bin  3  contains  4994554
# bin  4  contains  1502933
# bin  5  contains  154942
# bin  6  contains  27977
# bin  7  contains  6984
# bin  8  contains  1529
# bin  9  contains  343
# bin  10  contains  57
# GR_R8 kmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  0
# bin  3  contains  5012359
# bin  4  contains  1487565
# bin  5  contains  152900
# bin  6  contains  27683
# bin  7  contains  6906
# bin  8  contains  1512
# bin  9  contains  338
# bin  10  contains  56
# GR_R8 symmetricKmerTableDivide.csv
# bin  1  contains  0
# bin  2  contains  0
# bin  3  contains  4673440
# bin  4  contains  1801894
# bin  5  contains  171657
# bin  6  contains  31863
# bin  7  contains  8114
# bin  8  contains  1850
# bin  9  contains  418
# bin  10  contains  82
# GR_R8 symmetricKmerTableTransit.csv
# bin  1  contains  0
# bin  2  contains  0
# bin  3  contains  4692987
# bin  4  contains  1784683
# bin  5  contains  169715
# bin  6  contains  31573
# bin  7  contains  8048
# bin  8  contains  1816
# bin  9  contains  416
# bin  10  contains  80
